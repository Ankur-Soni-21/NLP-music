# %% [markdown]
# # Text Generation

# %% [markdown]
# ## Introduction

# %% [markdown]
# Markov chains can be used for very basic text generation. Think about every word in a corpus as a state. We can make a simple assumption that the next word is only dependent on the previous word - which is the basic assumption of a Markov chain.
#
# Markov chains don't generate text as well as deep learning, but it's a good (and fun!) start.

# %% [markdown]
# ## Select Text to Imitate

# %% [markdown]
# In this notebook, we're specifically going to generate text in the style of Ali Wong, so as a first step, let's extract the text from her comedy routine.

# %%
# Read in the corpus, including punctuation!
import pandas as pd

data = pd.read_pickle('03D_corpus.pkl')
data
# Out:
#                                                         transcript  \
# Death and other  Death and Other Details\nSeason 1 Episode 6\nE...
# Jacqueline       In “Get on Your Knees,” Jacqueline Novak trans...
# Kevin            Kevin Bridges: The Overdue Catch-Up (2023) is ...
# Taylor           In her 2024 Netflix stand-up comedy special, “...
# The iron claw    The Iron Claw (2023)\nDirected by: Sean Durkin...
#
#                         full_name
# Death and other  Taylor Tomlinson
# Jacqueline          Kevin Bridges
# Kevin            Jacqueline Novak
# Taylor            Death and other
# The iron claw       The iron Claw

# %%
# Extract only taylor's text
Taylor_text = data.transcript.loc['Taylor']
Taylor_text[:200]
# Out:
# 'In her 2024 Netflix stand-up comedy special, “Have It All,” Taylor Tomlinson offers a sharp, witty exploration of modern life, relationships, and personal growth, all through her humorous and insightf'

# %% [markdown]
# ## Build a Markov Chain Function

# %% [markdown]
# We are going to build a simple Markov chain function that creates a dictionary:
# * The keys should be all of the words in the corpus
# * The values should be a list of the words that follow the keys

# %%
from collections import defaultdict

def markov_chain(text):
    '''The input is a string of text and the output will be a dictionary with each word as
       a key and each value as the list of words that come after the key in the text.'''
    
    # Tokenize the text by word, though including punctuation
    words = text.split(' ')
    
    # Initialize a default dictionary to hold all of the words and next words
    m_dict = defaultdict(list)
    
    # Create a zipped list of all of the word pairs and put them in word: list of next words format
    for current_word, next_word in zip(words[0:-1], words[1:]):
        m_dict[current_word].append(next_word)

    # Convert the default dict back into a dictionary
    m_dict = dict(m_dict)
    return m_dict

# %%
# Create the dictionary for Ali's routine, take a look at it
Taylor_dict = markov_chain(Taylor_text)
Taylor_dict
# Out:
# {'In': ['her', 'therapy.'],
#  'her': ['2024',
#   'humorous',
#   'journey',
#   'own',
#   '♪',
#   '♪',
#   '♪',
#   '♪',
#   '♪',
#   '♪',
#   'every',
#   'for',
#   'ex',
#   'clients.',
#   'partner',
#   'attic',
#   'on',
#   'about',
#   'engagement',
#   'the'],
#  '2024': ['Netflix', 'Scraps'],
#  'Netflix': ['stand-up', 'special', 'and', 'special', 'money', 'special.”'],
#  'stand-up': ['comedy', 'show', 'that'],
#  'comedy': ['special,'],
#  'special,': ['“Have'],
#  '“Have': ['It', 'you', 'you', 'time'],
#  'It': ['All,”',
#   'was',
#   'changed',
#   'was',
#   'was',
#   'was…',
#   'gets',
#   'is',
#   'has',
#   'is',
#   'confuses',
#   'was',
#   'totally',
#   'doesn’t',
#   'doesn’t',
#   'is',
#   'feels',
#   'is',
#   'doesn’t',
#   'was',
#   'has',
#   'was',
#   'was'],
#  'All,”': ['Taylor'],
#  'Taylor': ['Tomlinson', 'Tomlinson!'],
#  'Tomlinson': ['offers', 'shares', 'crafts'],
#  'offers': ['a'],
#  'a': ['sharp,',
#   'world',
#   'robbery',
#   'dating',
#   'narrative',
#   'subtle',
#   'fucking',
#   'week',
#   'dating',
#   'breakup,',
#   'dating',
#   'kid',
#   'shallow',
#   'grave?”',
#   'dating',
#   'bar.',
#   'puddle.',
#   'Samantha.”',
#   'prude.',
#   'breakup.',
#   'year?”',
#   'breakup,',
#   'kid,',
#   'good',
#   'lot',
#   'child.',
#   'version',
#   'person.',
#   'perfect',
#   'human',
#   'religious',
#   'wonder',
#   'little',
#   'year',
#   'half',
#   'few',
#   'good',
#   'room.',
#   'special',
#   'family.”',
#   'bit.',
#   'pair',
#   'man?',
#   'dream',
#   'horse',
#   'wheelie',
#   'good',
#   'number',
#   'tax',
#   'baby',
#   'dating',
#   'coffee',
#   'blind',
#   'nearsighted',
#   'person',
#   'stack',
#   'trench',
#   'loser.',
#   'bowling',
#   'real',
#   'one-night',
#   'Barnes',
#   'friend',
#   'slut',
#   'whore.”',
#   'slut',
#   'whore',
#   'whore',
#   'family',
#   'college',
#   'threesome',
#   'guy',
#   'flight,',
#   'big',
#   'random',
#   'boy',
#   'man',
#   'human',
#   'murderer,',
#   'stuffed',
#   'claw',
#   'friend.',
#   'couple',
#   'devastating',
#   'friend',
#   'breakup',
#   'photo',
#   'model.',
#   'no-screens',
#   'quilt,',
#   'field.',
#   'man',
#   'man',
#   'man,',
#   'model?',
#   'different…”',
#   'model,',
#   'different…',
#   'text',
#   'movie.',
#   'nice',
#   'single',
#   'few',
#   'bitch,',
#   'lot',
#   'lid',
#   'cart.',
#   'basket.”',
#   'one-man',
#   'conspiracy',
#   'relationship,',
#   'cemetery.”',
#   'doctor.',
#   'March',
#   'really',
#   'lot',
#   'podcast',
#   'movie,',
#   'magician',
#   'few',
#   'baby',
#   'dog.',
#   'team',
#   'doctor.',
#   'doctor',
#   'doctor',
#   'regular',
#   'second',
#   'white',
#   'light',
#   'witch?',
#   'dumb',
#   'disco',
#   'different',
#   'lot',
#   'weird',
#   'lot',
#   'weird',
#   'confident',
#   'handstand.',
#   'handstand',
#   'handstand',
#   'couple',
#   'couple',
#   'handstand',
#   'weird',
#   'divorce.',
#   'good',
#   'conversation',
#   'few',
#   'weird',
#   'handle',
#   'fucking',
#   'fortune',
#   'totally',
#   '“type,”',
#   'romance',
#   'hard',
#   'limited',
#   'hot',
#   'lot',
#   'relationship.',
#   'candle',
#   'slice',
#   'tall,',
#   'delicate',
#   'basketball',
#   'basketball',
#   'really',
#   'hot',
#   'woman',
#   'car',
#   'fun',
#   'kid',
#   'woman',
#   'stone',
#   'lake.',
#   'man',
#   'brick',
#   'window.',
#   'man',
#   'woman',
#   'friend',
#   'pic',
#   'spectrum.”',
#   'girl',
#   'kid,',
#   'girl,',
#   'broken',
#   'joke,',
#   'lot',
#   'sex',
#   'sex',
#   'live',
#   'verbal',
#   'thumbs',
#   'little',
#   'picnic',
#   'picnic',
#   'picnic',
#   'lot',
#   'kid,',
#   'tangent.',
#   'book.',
#   'book.',
#   'breakup.',
#   'terrible',
#   'guy',
#   'couple',
#   'hat',
#   'hat.',
#   'lot?”',
#   'lot',
#   'safe',
#   'safe',
#   'married',
#   'safe',
#   'little',
#   'lot',
#   'relationship,',
#   'first',
#   'guy.',
#   'first',
#   'date',
#   'secure',
#   'very',
#   'chance.”',
#   'date.”',
#   'prince.',
#   'sandwich',
#   'bitch,',
#   'good',
#   'good',
#   'good',
#   'good',
#   'bit,',
#   'family.',
#   'shop.',
#   'kid,',
#   'TED',
#   'TikTok',
#   'grown-up.',
#   'music',
#   'bit.”',
#   'lot',
#   'rusty',
#   'piece',
#   'bunch',
#   'lot',
#   'costume',
#   'dumb',
#   'rollercoaster.',
#   'hero.',
#   'problem.',
#   'big',
#   'joke.',
#   'lot',
#   'result',
#   'dream',
#   'few',
#   'year',
#   'green',
#   'call',
#   'place',
#   'yeast',
#   'little',
#   'favor?”',
#   'video',
#   'weird',
#   'confident',
#   'different',
#   'different',
#   'different',
#   'strong',
#   'very',
#   'very',
#   'weird',
#   'book”?',
#   'book?',
#   'deep,',
#   'week'],
#  'sharp,': ['witty'],
#  'witty': ['exploration'],
#  'exploration': ['of', 'of'],
#  'of': ['modern',
#   'married',
#   'dating',
#   'staying',
#   'navigating',
#   'contemporary',
#   'that,',
#   'our',
#   'the',
#   'that?',
#   'you.”',
#   'them!',
#   'us',
#   'ugly',
#   'this',
#   'a',
#   'the',
#   'the',
#   'gloves',
#   'sweaty',
#   'tonight’s',
#   'them,',
#   'those',
#   'that.',
#   'what',
#   'frightened',
#   'someone',
#   'the',
#   'you,',
#   'being',
#   'being',
#   'my',
#   'that.',
#   'hope',
#   'stuffed',
#   'him',
#   'maybe',
#   'like',
#   'America.',
#   'the',
#   'the',
#   'that',
#   'progressive',
#   'the',
#   'every',
#   'you',
#   'her',
#   'clients.',
#   'do',
#   'like',
#   'us!',
#   'trouble',
#   'them.',
#   'them',
#   'God,',
#   'your',
#   'men',
#   'TikToks.',
#   'this',
#   'us',
#   'those.',
#   'shit',
#   'people',
#   'her.',
#   'person',
#   'you.',
#   'yourselves',
#   'smells',
#   'empathy,',
#   'empathy',
#   'like',
#   'mine',
#   'Margot',
#   'failure.',
#   'my',
#   'experience',
#   'that',
#   'people',
#   'applause,',
#   'applause.',
#   'applause,',
#   'okay.',
#   'sex.',
#   'people',
#   'the',
#   'nowhere,',
#   'this',
#   'people',
#   'the',
#   'footprints',
#   'my',
#   'you,',
#   'material',
#   'mine',
#   'people',
#   'people',
#   'friends',
#   'the',
#   'it',
#   'shit,',
#   'my',
#   'kids',
#   'weddings',
#   'anybody',
#   'them',
#   'the',
#   'cool',
#   'being',
#   'taking',
#   'me',
#   'Hugh',
#   'sexuality'],
#  'modern': ['life,', 'life,'],
#  'life,': ['relationships,', 'politics,'],
#  'relationships,': ['and', 'not', 'and', 'blending'],
#  'and': ['personal',
#   'insightful',
#   'the',
#   'confronting',
#   'ambitions,',
#   'thought-provoking.',
#   'the',
#   'a',
#   'external',
#   'gentlemen,',
#   'it',
#   'photos',
#   'they',
#   'fun,',
#   'wallet.’',
#   'went',
#   'all',
#   'went,',
#   'I',
#   'their',
#   'my',
#   'she',
#   'nice.',
#   'a',
#   'his',
#   'a',
#   'goes,',
#   'I',
#   'I’ve',
#   'I’m',
#   'no',
#   'two',
#   'I',
#   'I',
#   'Jake.',
#   'this',
#   'this',
#   'forth.',
#   'goes,',
#   'sit',
#   'wait',
#   'you’re',
#   'smiling,',
#   'get',
#   'I',
#   'then',
#   'a',
#   'a',
#   'ex-boyfriends',
#   'write',
#   'it',
#   'you',
#   'pull',
#   'disappointment.',
#   'when',
#   'more',
#   'the',
#   'evolved.',
#   'his',
#   'I',
#   'have',
#   'the',
#   'your',
#   'I',
#   'I',
#   'it',
#   'I',
#   'that',
#   'they’re',
#   'turned',
#   'was',
#   'can’t',
#   'everyone',
#   'goes,',
#   'have',
#   'the',
#   'over',
#   'over.',
#   'quiet',
#   'tell',
#   'talks.',
#   'it',
#   'emotional',
#   'movies',
#   'over',
#   'over',
#   'they’re',
#   'her',
#   'you',
#   'never',
#   'remember',
#   'your',
#   'I',
#   'be',
#   'then',
#   'they’re',
#   'she',
#   'I',
#   'learn',
#   'you’re',
#   'one',
#   'out',
#   'you',
#   'worthless?”',
#   'as',
#   'have',
#   'travel!”',
#   'having',
#   'are',
#   'I',
#   'I',
#   'we’re',
#   'envy',
#   'envy',
#   'go,',
#   'baby',
#   '“practices',
#   'I',
#   'your',
#   'so',
#   'so',
#   'my',
#   'I',
#   '2,000',
#   'I',
#   'tell',
#   'Xanax.',
#   'that’s',
#   'broader',
#   'gender',
#   'self-discovery,',
#   'relationships,',
#   'whimsy',
#   'truths'],
#  'personal': ['growth,', 'anecdotes', 'stories', 'anecdotes'],
#  'growth,': ['all'],
#  'all': ['through',
#   'the',
#   'my',
#   'to',
#   'right?',
#   'naked.',
#   'the',
#   'throughout',
#   'right?',
#   'called',
#   'be',
#   'the',
#   'night.',
#   'kinds',
#   'smug,',
#   'the',
#   'the',
#   'of',
#   'that',
#   'the',
#   'right.',
#   'stepped',
#   'Gen',
#   'queer,',
#   'in',
#   'so',
#   'you',
#   'these',
#   'day',
#   'the',
#   'forget',
#   'of',
#   'night.”',
#   'did',
#   'forgot.”',
#   'turning',
#   'our',
#   'figured',
#   '30,',
#   'of',
#   'alone.”',
#   'these'],
#  'through': ['her',
#   'a',
#   'a',
#   'since',
#   'a',
#   'a',
#   'the',
#   'a',
#   'a',
#   'their',
#   'their',
#   'a',
#   '“Jingle',
#   'a',
#   'the',
#   'on',
#   'our',
#   'a',
#   'everything.',
#   'depression'],
#  'humorous': ['and'],
#  'insightful': ['lens.', 'stand-up'],
#  'lens.': ['Tomlinson'],
#  'shares': ['her'],
#  'journey': ['towards'],
#  'towards': ['understanding', 'the'],
#  'understanding': ['herself'],
#  'herself': ['and'],
#  'the': ['world',
#   'flawed',
#   'absurdities',
#   'challenges',
#   'trials',
#   'quest',
#   'realization',
#   'floor',
#   'last',
#   'biggest',
#   'apps',
#   'high',
#   'weekend?',
#   'grave?”',
#   'time?',
#   'scariest',
#   'hottest',
#   'back',
#   'head.',
#   'wind',
#   'dumbest',
#   'fuck?”',
#   'whole',
#   'first',
#   'more',
#   'Grand',
#   'world,',
#   'whole',
#   'whole',
#   'show,',
#   'end,',
#   'actors',
#   'pair',
#   'show.',
#   'highest',
#   'Netflix',
#   'auction,',
#   'front,',
#   'story',
#   'dream,',
#   'Tiger',
#   'win',
#   'woman',
#   'auctioneer,',
#   'auction,',
#   'generosity',
#   'truth',
#   'end.',
#   'glove.',
#   'Bible.',
#   'dating',
#   'way.',
#   'street',
#   'room.',
#   'same',
#   'middle',
#   'middle',
#   'bed',
#   'food',
#   'toilet',
#   'sky?',
#   'last',
#   'most',
#   'thing.',
#   'same',
#   'glass',
#   'neutral',
#   'worst',
#   'person',
#   'calls',
#   'other',
#   'truth.',
#   'Bible',
#   '’90s,',
#   'single',
#   'restaurant',
#   'car.',
#   'ghosting,',
#   'catfishing,',
#   'deepfake',
#   'car',
#   'best',
#   'scene',
#   'crime.',
#   'information,',
#   'way',
#   'huddle',
#   'car',
#   'fuck?',
#   'car',
#   'ones',
#   'story.”',
#   'ground.”',
#   'shit',
#   'street',
#   'ingredients.',
#   'cake.',
#   'weekend.',
#   'exact',
#   'next',
#   'emergency',
#   'ER',
#   'whole',
#   'technology',
#   'emergency',
#   'emergency',
#   'front',
#   'time.”',
#   'way',
#   'AirPod',
#   'pillowcase.”',
#   'back',
#   'emergency',
#   'ER',
#   'AR.',
#   'time',
#   'AR',
#   'bad',
#   'devil,',
#   'love',
#   'same',
#   'cold',
#   'way',
#   'basic',
#   'Calm',
#   'wall?',
#   'end.',
#   'wall.',
#   'handstand',
#   'bed,',
#   'guy',
#   'first',
#   'other',
#   'other',
#   'whole',
#   'last',
#   'sound',
#   'other',
#   'best',
#   'front',
#   'floor',
#   'kitchen',
#   'cold',
#   'bathroom',
#   'same',
#   'same',
#   'patriarchy.”',
#   'patriarchy.”',
#   'most',
#   'beach',
#   'concept',
#   'MVP',
#   'trash,',
#   'fastest',
#   'time',
#   'respect',
#   'sex',
#   'garden.',
#   'garden?',
#   'garden',
#   'horrors',
#   'most',
#   'record.',
#   'holes',
#   'sex',
#   'bottom',
#   'time.”',
#   'audience,',
#   'front',
#   'fight.”',
#   'issues',
#   'sand.',
#   'last',
#   'day.',
#   'parking',
#   'last',
#   'career',
#   'window.',
#   'mirror,',
#   'same',
#   'same',
#   'week.”',
#   'back',
#   'coolest',
#   'coolest.”',
#   'girl',
#   'moon',
#   'relationships',
#   'career',
#   'drums.”',
#   'whole',
#   'one,',
#   'phone',
#   'way,',
#   'whole',
#   'show,',
#   'video.',
#   'instructions',
#   'bed',
#   'show.',
#   'parking',
#   'privacy',
#   'Loft.',
#   'best'],
#  'world': ['around', 'obsessed'],
#  'around': ['her,', '’cause', 'me,', 'all', 'Europe,'],
#  'her,': ['touching', 'over'],
#  'touching': ['on'],
#  'on': ['everything',
#   'the',
#   'perfection',
#   'a',
#   'a',
#   'those',
#   '’em.',
#   'Netflix.',
#   'Netflix,',
#   'Netflix',
#   'top.',
#   'that.',
#   'tour.',
#   'Broadway,',
#   'a',
#   'television,',
#   'a',
#   'his',
#   'eye',
#   'who',
#   'dating',
#   'a',
#   'the',
#   'Tinder.',
#   '’em.',
#   'a',
#   'Bumble.”',
#   'social',
#   'it',
#   'the',
#   'your',
#   'anxiety',
#   'them.',
#   'the',
#   'the',
#   'somebody’s…',
#   'this',
#   'the',
#   'the',
#   'the',
#   'my',
#   'our',
#   'eBay.”',
#   'you?”',
#   'straight',
#   'women',
#   'a',
#   'a',
#   'a',
#   'another',
#   'a',
#   'women',
#   'my',
#   'it.',
#   'a',
#   'myself,',
#   'myself.',
#   'a',
#   'a',
#   'a',
#   'their',
#   'this',
#   'my',
#   'a',
#   'my',
#   'you',
#   'train',
#   'work',
#   'what',
#   'you',
#   'the',
#   'my',
#   'that',
#   'vacation',
#   'the',
#   'stage,',
#   'selfie',
#   'this',
#   'your',
#   'your',
#   'your',
#   'Your',
#   'human'],
#  'everything': ['from', 'right.', 'for'],
#  'from': ['the',
#   'a',
#   'societal',
#   'embracing',
#   'the',
#   'State',
#   'State',
#   'Progressive',
#   'relationship',
#   'Bank',
#   'a',
#   'home',
#   'the',
#   'a',
#   'the',
#   'Aladdin',
#   'me',
#   'some',
#   'Courtney.',
#   'the'],
#  'flawed': ['advice'],
#  'advice': ['of', 'every', 'from.', 'for', 'after'],
#  'married': ['friends,',
#   'friends',
#   'friends',
#   'friends',
#   'friends.',
#   'friends.',
#   'friends,',
#   'friends',
#   'this',
#   'friends',
#   'friends,',
#   'friends',
#   'friends,',
#   'each',
#   'friend,',
#   'and',
#   'an',
#   'him,'],
#  'friends,': ['the', 'okay?', 'who', 'and', 'go', 'go'],
#  'absurdities': ['of', 'and'],
#  'dating': ['apps,',
#   'disaster',
#   'app.',
#   'app.',
#   'story,',
#   'app',
#   'apps?',
#   'app?',
#   'app',
#   'apps.',
#   'app',
#   'because',
#   'a',
#   'a',
#   'another',
#   'straight'],
#  'apps,': ['to'],
#  'to': ['the',
#   'oneself',
#   'the',
#   '“have',
#   'change',
#   'be',
#   'be',
#   'stand',
#   'my',
#   'be',
#   'settle.',
#   'have',
#   'have',
#   'have',
#   'be',
#   'have',
#   'be',
#   'sixth',
#   'me',
#   'feel',
#   'have',
#   'Hugh.”',
#   'go',
#   'see',
#   'the',
#   'lose',
#   'live',
#   'me',
#   'me,',
#   'include',
#   'get',
#   'pay',
#   'say,',
#   'the',
#   'say,',
#   'sign',
#   'the',
#   'cut',
#   'touch',
#   'me',
#   'know',
#   'have',
#   'my',
#   'talk',
#   'hear',
#   'put',
#   'hang',
#   'have',
#   'invite',
#   'do',
#   'deal',
#   'your',
#   'jump',
#   'relationship.',
#   'get',
#   'something',
#   'her',
#   'catch',
#   '30,',
#   'be',
#   'say,',
#   'be',
#   'get',
#   'hang',
#   'third-wheel',
#   'dinner,',
#   'meet',
#   'see',
#   'do',
#   'tell',
#   'their',
#   'come.',
#   'know',
#   'introduce',
#   'your',
#   'your',
#   'one',
#   'them',
#   'the',
#   'like',
#   'walk',
#   'stop',
#   'your',
#   'meet',
#   'write',
#   'show',
#   'like',
#   'meet',
#   'be',
#   'dig',
#   'therapy',
#   'you.',
#   'find',
#   'figure',
#   'get',
#   'call',
#   'keep',
#   'the',
#   'the',
#   'the',
#   'a',
#   'calm',
#   'take',
#   'the',
#   'the',
#   'tell',
#   'me',
#   'see',
#   'come',
#   'sneak',
#   'do',
#   'get',
#   'tell',
#   'sleep',
#   'spray',
#   'be',
#   'say',
#   'every',
#   'every',
#   'sleep.',
#   'sleep.',
#   'do',
#   'do',
#   'be',
#   'hear',
#   'be',
#   'sleep.',
#   'you.',
#   'him',
#   'who?',
#   'the',
#   'get',
#   'offload',
#   'someone’s',
#   'my',
#   'your',
#   'your',
#   'the',
#   'sleep.”',
#   'get',
#   'talk',
#   'expect.',
#   'expect.',
#   'continue',
#   'them,',
#   'on',
#   'me',
#   'shit',
#   'watch.',
#   'explain',
#   'a',
#   'argue.',
#   'get',
#   'empathize',
#   'get',
#   'come.',
#   'figure',
#   'date',
#   'get',
#   'like',
#   'get',
#   'like',
#   'take',
#   'do',
#   'skip',
#   'see',
#   'a',
#   'just',
#   'prove',
#   'people.',
#   'you?”',
#   'me.”',
#   'be',
#   'get',
#   'have',
#   'sit',
#   'play',
#   'go',
#   'fucking',
#   'yell,',
#   'you?',
#   'make',
#   'you',
#   'a',
#   'crowd',
#   'a',
#   'tell',
#   'that.',
#   'be.',
#   'ask',
#   'forget.',
#   'tell',
#   'the',
#   'ask',
#   'learn',
#   'comfort',
#   'marry.”',
#   'be',
#   'stop',
#   'have',
#   'say',
#   'ask',
#   'get',
#   'work',
#   'be',
#   'notice,',
#   'work',
#   'smell',
#   'haunt',
#   'hurt',
#   '’em',
#   'be',
#   'feel',
#   'me.',
#   'be',
#   'be',
#   'work',
#   'get',
#   'get',
#   'have',
#   'have,',
#   'all',
#   'do',
#   'put',
#   'learn',
#   'parent',
#   'do',
#   'heal,',
#   'parent',
#   'shake',
#   'wake',
#   'them',
#   'turn',
#   'focus',
#   'have',
#   'sit',
#   'wear',
#   'space.',
#   'work',
#   'space.”',
#   'do',
#   'run',
#   'have',
#   'check',
#   'her',
#   'make',
#   'see',
#   'see',
#   'hear',
#   'this',
#   'reflect',
#   'your'],
#  'challenges': ['of'],
#  'staying': ['true'],
#  'true': ['to', 'fulfillment', 'colors,', 'until'],
#  'oneself': ['in'],
#  'in': ['a',
#   'response]',
#   'response]',
#   'a',
#   'a',
#   'constant',
#   'my',
#   'the',
#   'a',
#   'my',
#   'love',
#   'God.',
#   'my',
#   'person.',
#   'person',
#   'New',
#   'between',
#   'a',
#   'the',
#   'the',
#   'the',
#   'on',
#   'front,”',
#   'church',
#   'half.”',
#   'here',
#   'here',
#   'a',
#   'The',
#   'a',
#   'green',
#   'a',
#   'your',
#   'bed,',
#   'bed,',
#   'bed',
#   'my',
#   'the',
#   'all-caps,',
#   'the',
#   'together.',
#   'love',
#   'the',
#   'me',
#   'a',
#   'the',
#   'their',
#   'front',
#   'the',
#   'real',
#   'the',
#   'the',
#   'there,',
#   'an',
#   'the',
#   'the',
#   'a',
#   'touch',
#   'therapy.',
#   'AirPods.',
#   'regular',
#   'those.',
#   'two',
#   'one',
#   'our',
#   'my',
#   'middle',
#   'fact,',
#   'there.”',
#   'to',
#   'the',
#   'me',
#   'a',
#   'your',
#   'a',
#   'order?',
#   'a',
#   'the',
#   'the',
#   'the',
#   'the',
#   'bed.',
#   'hotel',
#   'front',
#   'life',
#   'serious',
#   'me',
#   'my',
#   'a',
#   'a',
#   'a',
#   'his',
#   'this',
#   'here?',
#   'the',
#   'the',
#   'the',
#   'a',
#   'a',
#   'my',
#   'my',
#   'the',
#   'the',
#   'relationships',
#   'my',
#   'the',
#   'the',
#   'relationships.',
#   'a',
#   'the',
#   'this',
#   'this',
#   'high',
#   'a',
#   'your',
#   'the',
#   'on',
#   'our',
#   'five',
#   'your',
#   'the',
#   'a',
#   'space',
#   'Vegas',
#   'Vegas.',
#   'my',
#   'Europe',
#   'April,',
#   'high',
#   'her',
#   'a',
#   'Colorado,',
#   'a',
#   'my',
#   'a',
#   'a',
#   'a',
#   'glasses]',
#   'the',
#   '“The'],
#  'obsessed': ['with'],
#  'with': ['appearances.',
#   'jobs',
#   'no',
#   'us',
#   'this',
#   'my',
#   'Hugh',
#   'hobbies',
#   'this',
#   'a',
#   'two',
#   'me,',
#   'an',
#   'it',
#   'a',
#   'the',
#   'married',
#   'our',
#   'your',
#   'ideas.',
#   'another',
#   'panic',
#   'AirPods.',
#   'the',
#   'talk?',
#   'my',
#   'me.”',
#   'new',
#   'this',
#   'who',
#   'a',
#   'me',
#   'my',
#   'me.',
#   'your',
#   'me.',
#   'keen',
#   'personal'],
#  'appearances.': ['Through'],
#  'Through': ['personal'],
#  'anecdotes': ['that', 'Dylan'],
#  'that': ['range',
#   'turned',
#   'true',
#   'was',
#   'I',
#   'that',
#   'was',
#   'one',
#   'I’m',
#   'will',
#   'I',
#   'man.',
#   'money',
#   'detail,',
#   'me',
#   'I’ve',
#   'it',
#   'like?”',
#   'story',
#   'guy',
#   'is?”',
#   'I',
#   'I’m',
#   'be',
#   'I',
#   'Steve',
#   'POS.”',
#   'they’ve',
#   'you',
#   'night',
#   'we',
#   'personally.',
#   'on',
#   'seems',
#   'client',
#   'impossible.',
#   'I',
#   'paperwork',
#   'seems',
#   'is',
#   'says,',
#   'it',
#   'joke',
#   'I’m',
#   'you',
#   'I',
#   'is.',
#   'one.',
#   'a',
#   'I',
#   'quote',
#   'philosopher?',
#   'you’re',
#   'you',
#   'you',
#   'you',
#   'make',
#   'until',
#   'I’m',
#   'it’s',
#   'I',
#   'skill.',
#   'shit',
#   'in',
#   'was',
#   'hard.',
#   'like,',
#   'I',
#   'are',
#   'is',
#   'stops',
#   'was',
#   'once',
#   'smell',
#   'makes',
#   'shuffle',
#   'scene',
#   'means…',
#   'means',
#   'I',
#   'I',
#   'I’m',
#   'on',
#   'to',
#   'growing',
#   'baby’s',
#   'we’re',
#   'we’re',
#   'all',
#   'I',
#   'that’s',
#   'that’s',
#   'was',
#   'married',
#   'landing.',
#   'trip',
#   'Todd’s',
#   'she',
#   'I',
#   'night,',
#   'I',
#   'I',
#   'people',
#   'turns'],
#  'range': ['from'],
#  'robbery': ['that'],
#  'turned': ['into', 'around', '30'],
#  'into': ['a',
#   'the',
#   'it',
#   'things',
#   'therapy',
#   'a',
#   'it,',
#   'another',
#   'that',
#   'it.',
#   'a'],
#  'disaster': ['to'],
#  'trials': ['of'],
#  'navigating': ['single'],
#  'single': ['life',
#   'friends.',
#   'friend,',
#   'friend',
#   'for',
#   'thing',
#   'all',
#   'for',
#   'is',
#   'than',
#   'one.',
#   'friend,',
#   'too',
#   'for',
#   'for'],
#  'life': ['and',
#   'out',
#   'updates',
#   'updates?',
#   'was',
#   'are',
#   'for',
#   'with',
#   'trying'],
#  'confronting': ['her'],
#  'own': ['insecurities', 'parade.'],
#  'insecurities': ['and'],
#  'ambitions,': ['Tomlinson'],
#  'crafts': ['a'],
#  'narrative': ['that’s'],
#  'that’s': ['both',
#   'how',
#   'when',
#   'how.',
#   'why',
#   'what',
#   'kinda…',
#   'an',
#   'happened',
#   'gross.”',
#   'completely',
#   'not',
#   'like,',
#   'going',
#   'gratitude.',
#   'important.',
#   'the',
#   'completely',
#   'okay.'],
#  'both': ['relatable', 'of', 'at', 'wanna', 'had', 'pity', 'pity'],
#  'relatable': ['and'],
#  'thought-provoking.': ['Her'],
#  'Her': ['reflections', 'ex', 'fiancé'],
#  'reflections': ['on'],
#  'quest': ['to'],
#  '“have': ['it'],
#  'it': ['all”',
#   'was',
#   'was',
#   'because',
#   'very',
#   'wouldn’t',
#   'at',
#   'all,',
#   'all.”',
#   'all.',
#   'all.',
#   'all.”',
#   'all.',
#   'all',
#   'before',
#   'a',
#   'all,',
#   'be',
#   'gets',
#   'because',
#   'makes',
#   'is',
#   'is.”',
#   'is',
#   'for',
#   'usually',
#   'your',
#   'goes',
#   'right',
#   'has',
#   'going?',
#   'would',
#   'so',
#   'till',
#   'pretty',
#   'was',
#   'back',
#   'was',
#   'out',
#   'would',
#   'electrocutes',
#   'in',
#   'is',
#   'out.”',
#   'is',
#   'changes',
#   'to',
#   'works.',
#   'on',
#   'up.',
#   'in',
#   'was',
#   'anymore.”',
#   'calms',
#   'is',
#   'into',
#   'now',
#   'because',
#   'to',
#   'gross',
#   'okay',
#   'like',
#   'off?',
#   'my',
#   'in',
#   'is',
#   'is?”',
#   'didn’t',
#   'really',
#   'to',
#   'from',
#   'has',
#   'all?',
#   'is',
#   'is',
#   'all',
#   'works',
#   'was',
#   'was',
#   'on',
#   'for'],
#  'all”': ['and'],
#  'realization': ['that'],
#  'fulfillment': ['might'],
#  'might': ['not', 'add.', 'be'],
#  'not': ['come',
#   'judging,',
#   'to',
#   'more',
#   'agreed',
#   'gonna',
#   'a',
#   'a',
#   'to',
#   'anymore.',
#   'gonna',
#   'what',
#   'dating',
#   'the',
#   'have',
#   'about',
#   'your',
#   'take',
#   'you.',
#   'the',
#   'a',
#   'gonna',
#   'DM',
#   'leave',
#   'to',
#   'more',
#   'noticing.”',
#   'appreciating',
#   'gonna',
#   'go',
#   'going',
#   'that',
#   'my',
#   'supposed',
#   'get',
#   'into',
#   'cured',
#   'a',
#   'ready',
#   'to',
#   'great,',
#   'going',
#   'healthy,',
#   'proud,',
#   'small',
#   'have',
#   'have',
#   'saying',
#   'a',
#   'good,',
#   'be'],
#  'come': ['from', 'on', 'in', 'in', 'home', 'to', 'true.'],
#  'societal': ['achievements', 'themes,'],
#  'achievements': ['but'],
#  'but': ['from',
#   'it',
#   'she’s',
#   'maybe',
#   'it’s',
#   'it',
#   'me.”',
#   'it’s',
#   'I’m',
#   'they',
#   'that',
#   'the',
#   'it’s',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'also',
#   'it',
#   'I',
#   'you’re',
#   'in',
#   'I',
#   'I',
#   'I'],
#  'embracing': ['one’s'],
#  'one’s': ['unique', 'usually', 'gonna', 'available.”', 'carrying'],
#  'unique': ['path'],
#  'path': ['resonate'],
#  'resonate': ['deeply,'],
#  'deeply,': ['offering'],
#  'offering': ['laughter'],
#  'laughter': ['and'],
#  'subtle': ['critique'],
#  'critique': ['of'],
#  'contemporary': ['culture’s'],
#  'culture’s': ['fixation'],
#  'fixation': ['on'],
#  'perfection': ['and'],
#  'external': ['approval.'],
#  'approval.': ['*'],
#  '*': ['*', '*', '[crowd', 'Name*'],
#  '[crowd': ['cheering]'],
#  'cheering]': ['[“Boys',
#   'I',
#   'This',
#   'I',
#   'Another',
#   'This',
#   'All',
#   'You',
#   'Yeah.',
#   'Does'],
#  '[“Boys': ['Wanna', 'Wanna'],
#  'Wanna': ['Be', 'Be'],
#  'Be': ['Her”', 'grateful', 'careful', 'Her”'],
#  'Her”': ['by', 'playing]'],
#  'by': ['Peaches',
#   'Wolverine,”',
#   'the',
#   'the',
#   'myself,',
#   'that',
#   'three',
#   'Judy',
#   'my',
#   '30,',
#   'Jacqueline'],
#  'Peaches': ['playing]'],
#  'playing]': ['[rowdy', '[emcee]', 'Thank'],
#  '[rowdy': ['electroclash'],
#  'electroclash': ['rock'],
#  'rock': ['music'],
#  'music': ['playing]', 'video.'],
#  '[emcee]': ['Ladies'],
#  'Ladies': ['and'],
#  'gentlemen,': ['Taylor'],
#  'Tomlinson!': ['♪'],
#  '♪': ['The',
#   '♪',
#   'The',
#   '♪',
#   'The',
#   '♪',
#   'The',
#   '♪',
#   'The',
#   '♪',
#   'The',
#   'DC,',
#   'OMG,',
#   '♪',
#   'This',
#   '♪',
#   'Needs',
#   'But'],
#  'The': ['boys',
#   'girls',
#   'boys',
#   'girls',
#   'boys',
#   'girls',
#   'Music',
#   'show',
#   'actors',
#   'smugness',
#   'Sixth',
#   'first',
#   'first',
#   'peace,',
#   'constant',
#   'bread',
#   'best',
#   'stories',
#   'next',
#   'elementary',
#   'only',
#   'ER',
#   'worrying',
#   'reason',
#   'information’s',
#   'crowd’s'],
#  'boys': ['wanna', 'wanna', 'wanna'],
#  'wanna': ['be',
#   'be',
#   'be',
#   'be',
#   'be',
#   'be',
#   'play?”',
#   'hear',
#   'hear',
#   'be',
#   'see',
#   'end',
#   'just…'],
#  'be': ['her',
#   'her',
#   'her',
#   'her',
#   'her',
#   'her',
#   'honest,',
#   'happy.',
#   'fair.”',
#   'helpful.',
#   'single',
#   'in',
#   'divorced.',
#   'hot',
#   'hilarious',
#   'if',
#   'like,',
#   'cool.”',
#   'with',
#   'there',
#   'single',
#   'mature',
#   'better',
#   'like,',
#   'models?',
#   'a',
#   'cremated.”',
#   'dark?',
#   'hotter',
#   'upside',
#   'totally',
#   'like,',
#   'sexist.',
#   'bad',
#   'like',
#   'way',
#   'single',
#   'felt',
#   'felt',
#   'a',
#   'good',
#   'honest.',
#   'published.'],
#  'girls': ['wanna', 'wanna', 'wanna', 'who'],
#  'DC,': ['how'],
#  'how': ['we',
#   'we’re',
#   'I',
#   'many,',
#   'to',
#   'hot',
#   'hard',
#   'I',
#   'I',
#   'I',
#   'does',
#   'to',
#   'to',
#   'to',
#   'many',
#   'old',
#   'it’s',
#   'tall',
#   'that’s',
#   'a',
#   'to',
#   'hard',
#   'hard',
#   'little',
#   'to',
#   'the',
#   'you',
#   'you'],
#  'we': ['doing?',
#   'got',
#   'doing,',
#   'dug',
#   'were',
#   'were',
#   'end',
#   'do?”',
#   'think',
#   'all',
#   'were',
#   'had',
#   'go.',
#   'were',
#   'just',
#   'know',
#   'get',
#   'get',
#   'have',
#   'just',
#   'go',
#   'just',
#   'think',
#   'don’t',
#   'got?',
#   'move',
#   'went',
#   'have',
#   'were',
#   'never',
#   'do!',
#   'can',
#   'break',
#   'both',
#   'all',
#   'always',
#   'should',
#   'have',
#   'were',
#   'are,',
#   'start',
#   'make',
#   'got?',
#   'need',
#   'got,'],
#  'doing?': ['[cheering'],
#  '[cheering': ['in', 'subsides]'],
#  'response]': ['How', 'It'],
#  'How': ['stupid', 'we', 'are', 'did', 'are', 'am', 'old', 'long'],
#  'stupid': ['was'],
#  'was': ['that?',
#   'silly,',
#   'my',
#   'so',
#   'too',
#   'like,',
#   'dumb.',
#   'using',
#   'me.',
#   'doing',
#   'different.',
#   'the',
#   'on',
#   'so',
#   'like,',
#   'pretty',
#   'a',
#   'fair.',
#   'pretty,',
#   'like,',
#   'like,',
#   'a',
#   'like',
#   'like',
#   'there',
#   'great.',
#   'like,',
#   'like,',
#   'a',
#   'Jake',
#   'expensive.',
#   'like,',
#   'barely',
#   'busy',
#   'that',
#   'fun.',
#   'your',
#   'like,',
#   'like,',
#   'like,',
#   'attracted',
#   'like,',
#   'so',
#   'terrified',
#   'so',
#   'gonna',
#   'outside',
#   'just',
#   'dating',
#   'being',
#   'not…',
#   'there,',
#   'right',
#   'coming',
#   'so',
#   'happening?',
#   'silly?”',
#   'like,',
#   'ugly',
#   'gonna',
#   'gonna',
#   'like,',
#   'fun.',
#   'a',
#   'like,',
#   'so',
#   'a',
#   'there',
#   'so',
#   'like,',
#   'talking',
#   'asking',
#   'like,',
#   'like,',
#   'a',
#   'another',
#   'like,',
#   'a',
#   'like,',
#   'a',
#   'a',
#   'my',
#   'ten,',
#   'in',
#   'driving',
#   'like,',
#   'like,',
#   'home.',
#   'trying',
#   'a',
#   'devastated.”',
#   'like,',
#   'this',
#   'his',
#   'really',
#   'an',
#   'like,',
#   'like,',
#   'like,',
#   'looking',
#   'me',
#   'me',
#   'on',
#   'pretty',
#   'like,',
#   'a',
#   'watching',
#   'watching',
#   'not',
#   'this',
#   'all',
#   'true',
#   'a',
#   'single,',
#   'dating,',
#   'Jumanji.',
#   'awesome.',
#   'really',
#   'alone',
#   'like,',
#   'like,',
#   'so',
#   'there',
#   'touched',
#   'thinking',
#   'not'],
#  'that?': ['[audience', 'Did', '[laughter]'],
#  '[audience': ['laughing]',
#   'cheering]',
#   'cheering]',
#   'wooing',
#   'laughs]',
#   'laughs]',
#   'chuckling]',
#   'laughs]',
#   'laughs]',
#   'cheering]',
#   'laughs]',
#   'laughs]',
#   'laughing]',
#   'laughing]',
#   'laughing,',
#   'laughs]',
#   'laughing]',
#   'laughing]',
#   'member]',
#   'laughs]',
#   'laughs]',
#   'laughing,',
#   'laughing]',
#   'laughing]',
#   'cheers]',
#   'laughing]',
#   'winces]',
#   'laughs]',
#   'laughs]',
#   'laughs]',
#   'laughing]',
#   'laughing]',
#   'laughing,',
#   'laughing]',
#   'laughing]',
#   'laughs,',
#   'laughing]',
#   'cheers]',
#   'cheers]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'cheering]',
#   'laughing]',
#   'member',
#   'laughing,',
#   'member',
#   'member',
#   'laughing]',
#   'member',
#   'laughs]',
#   'laughing]',
#   'laughing]',
#   'laughs]',
#   'laughs]',
#   'laughing]',
#   'clapping]',
#   'cheering]',
#   'member]',
#   'laughing,',
#   'laughs]',
#   'laughs]',
#   'cheering]',
#   'laughing]',
#   'cheering]',
#   'member]',
#   'member'],
#  'laughing]': ['I',
#   'As',
#   '…but',
#   'Dating',
#   '“I',
#   'I',
#   'I',
#   '[Tomlinson',
#   'Hang',
#   'It’s',
#   '“I',
#   '“So',
#   'I’ve',
#   '“You',
#   'We',
#   'They’re',
#   '“My',
#   '[audience',
#   'It’s',
#   'All',
#   'I',
#   'I',
#   'I’ve',
#   'It'],
#  'I': ['came',
#   'know',
#   'was',
#   'thought',
#   'might',
#   'was',
#   'know',
#   'have',
#   'am',
#   'was',
#   'have',
#   'know',
#   'have',
#   'wake',
#   'hitchhike',
#   'am',
#   'got',
#   'was',
#   'got',
#   'was',
#   'thought',
#   'was',
#   'was',
#   'didn’t',
#   'thought',
#   'thought',
#   'thought',
#   'can',
#   'met',
#   'stopped',
#   'started',
#   'can’t',
#   'cannot',
#   'have',
#   'thought',
#   'was',
#   'saw',
#   'was',
#   'don’t',
#   'looked',
#   'was',
#   'have',
#   'was',
#   'don’t',
#   'can’t',
#   'thought',
#   'start',
#   'got',
#   'kid',
#   'hesitate',
#   'had',
#   'think',
#   'think',
#   'blacked',
#   'came',
#   'just',
#   'am',
#   'have',
#   'were',
#   'did',
#   'will',
#   'wish',
#   'could',
#   'was',
#   'completely',
#   'was',
#   'was',
#   'love',
#   'can',
#   'have',
#   'read',
#   'know',
#   'don’t',
#   'can',
#   'don’t',
#   'hadn’t',
#   'hated',
#   'saw',
#   'think',
#   'can’t',
#   'had',
#   'came.”',
#   'feel',
#   'poop',
#   'came',
#   'always',
#   'have',
#   'call',
#   'told',
#   'wanna',
#   'wanna',
#   'set',
#   'really',
#   'have',
#   'used',
#   'really',
#   'was',
#   'was',
#   'don’t',
#   'don’t',
#   'could',
#   'dated',
#   'was',
#   'live',
#   'fall',
#   'eat',
#   'buy.',
#   'clog',
#   'don’t',
#   'lived',
#   'was',
#   'was',
#   'beg',
#   'was',
#   'was',
#   'used',
#   'was',
#   'was',
#   'don’t',
#   'die.',
#   'told',
#   'understand.',
#   'get',
#   'had',
#   'didn’t',
#   'called',
#   'think',
#   'met',
#   'closed',
#   'open',
#   'love',
#   'get',
#   'have',
#   'don’t',
#   'wish',
#   'could',
#   'mean,',
#   'love',
#   'love',
#   'can',
#   'bring?',
#   'know.”',
#   'don’t',
#   'could',
#   'wanted.',
#   'keep',
#   'deserve',
#   'want',
#   'brought',
#   'did',
#   'did',
#   'was',
#   'know',
#   'know',
#   'don’t',
#   'was',
#   'realized',
#   'went',
#   'bring',
#   'went',
#   'was',
#   'want',
#   'can',
#   'went',
#   'fell',
#   'swallowed',
#   'wish',
#   'could',
#   'would',
#   'started',
#   'fell',
#   'swallowed',
#   'have',
#   'may',
#   'said,',
#   'can',
#   'don’t',
#   'thought',
#   'had,',
#   'don’t',
#   'thought',
#   'want',
#   'was',
#   'think',
#   'have',
#   'don’t',
#   'know',
#   'mentioned',
#   'have',
#   'know',
#   'promise',
#   'think',
#   'feel',
#   'ask',
#   'ask',
#   'have',
#   'will',
#   'haven’t',
#   'don’t',
#   'come',
#   'do',
#   'have',
#   'need',
#   'can’t.',
#   'just',
#   'haven’t',
#   'have',
#   'ask',
#   'listen',
#   'said',
#   'am',
#   'would',
#   'could!',
#   'said,',
#   'can’t',
#   'lay',
#   'was',
#   'get',
#   'go',
#   'tried',
#   'do',
#   'want',
#   'didn’t',
#   'told',
#   'looked',
#   'was',
#   'Googled',
#   'make',
#   'don’t',
#   'watch',
#   'know',
#   'date',
#   'know',
#   'have',
#   'start',
#   'talk',
#   'did.”',
#   'always',
#   'say.”',
#   'was',
#   "guess.'”",
#   'don’t',
#   'feel.”',
#   'don’t.”',
#   'feel.”',
#   'like',
#   'just',
#   'dunno',
#   'know',
#   'do.”',
#   'do.”',
#   'think.',
#   'just',
#   'might',
#   'think',
#   'was',
#   'was',
#   'could',
#   'was',
#   'was',
#   'really',
#   'identify',
#   'am',
#   'can’t',
#   'supposed',
#   'would',
#   'don’t',
#   'don’t',
#   'get',
#   'already',
#   'have',
#   'have',
#   'was',
#   'didn’t',
#   'was',
#   'play',
#   'know',
#   'should',
#   'keep',
#   'wish',
#   'really',
#   'want',
#   'talk',
#   'wouldn’t',
#   'need',
#   'don’t',
#   'didn’t',
#   'didn’t',
#   'never',
#   'think',
#   'was',
#   'got',
#   'had',
#   'still',
#   'don’t',
#   'said',
#   'still',
#   'think.',
#   'got',
#   'had',
#   'never',
#   'just',
#   'saw',
#   'started',
#   'was',
#   'read',
#   'was',
#   'read',
#   'need',
#   'know',
#   'was',
#   'know.”',
#   'used',
#   'went',
#   'had',
#   'was',
#   'wanted',
#   'was',
#   'said,',
#   'was',
#   'hope',
#   'used',
#   'asked',
#   'asked',
#   'know.',
#   'was',
#   'said,',
#   'asked',
#   'said,',
#   'have',
#   'was',
#   'was',
#   'used',
#   'thought',
#   'wouldn’t',
#   'realized',
#   'have',
#   'realized',
#   'don’t',
#   'wear',
#   'know',
#   'don’t',
#   'wear',
#   'was',
#   'realized',
#   'said,',
#   'can’t',
#   'thought',
#   'could.',
#   'text',
#   'was',
#   'have',
#   'have',
#   'have',
#   'needed',
#   'turned',
#   'have',
#   'am',
#   'am,',
#   'am,',
#   'don’t',
#   'mean,',
#   'know',
#   'don’t',
#   'have',
#   'don’t',
#   'am',
#   'know',
#   'see',
#   'also',
#   'still',
#   'don’t',
#   'was',
#   'was',
#   'always',
#   'feel',
#   'got',
#   'was',
#   'wake',
#   'let',
#   'think',
#   'have',
#   'kept',
#   'love',
#   'think.”',
#   'do',
#   'do',
#   'think',
#   'have',
#   'know',
#   'know',
#   'both',
#   'know',
#   'was',
#   'go,',
#   'had',
#   'do',
#   'think',
#   'think',
#   'guess',
#   'can’t',
#   'don’t',
#   'told',
#   'said,',
#   'would',
#   'would',
#   'finally',
#   'was',
#   'was',
#   'took',
#   'called',
#   'can’t',
#   'got',
#   'was',
#   'got',
#   'just',
#   'talked',
#   'was',
#   'was',
#   'have',
#   'actually',
#   'have',
#   'love',
#   'was',
#   'went',
#   'said,',
#   'went,',
#   'got',
#   'texted',
#   'love',
#   'have',
#   'don’t',
#   'accept'],
#  'came': ['up', 'to,', 'for.', 'out,', 'out,', 'out'],
#  'up': ['from',
#   'front.',
#   'next',
#   'in',
#   '30',
#   'in',
#   'those',
#   'a',
#   'every',
#   'to',
#   'to',
#   'as',
#   'to',
#   'in',
#   'so',
#   'close?',
#   'about',
#   'religious,',
#   'sheltered.',
#   'and',
#   'to',
#   'every',
#   'all',
#   'drunk',
#   'there.”',
#   'after'],
#  'floor': ['like', 'in', 'in'],
#  'like': ['I’m',
#   'a',
#   'a',
#   'that.',
#   'seeing',
#   'seeing',
#   'a',
#   'a',
#   'college,',
#   'six',
#   'Haley',
#   'a',
#   'getting',
#   'being',
#   'being',
#   'you',
#   'asking',
#   'a',
#   'a',
#   'being',
#   'that.',
#   'a',
#   'a',
#   'suspicious',
#   'your',
#   'people',
#   'maybe',
#   'a',
#   'us.”',
#   'to',
#   'that.',
#   'something,',
#   'a',
#   'a',
#   'the',
#   'I',
#   'lavender',
#   'this',
#   'trying',
#   'me.',
#   'me.',
#   'you,',
#   'me.”',
#   'trying',
#   'throwing',
#   'learning',
#   'that.',
#   '6:30,',
#   'tying',
#   'I',
#   'lip-syncing,',
#   'we',
#   'I',
#   'it',
#   '10,',
#   'she'],
#  'I’m': ['a',
#   'happy',
#   'making',
#   'not',
#   'filming',
#   'gonna',
#   'like,',
#   'doing',
#   'doing',
#   'trying',
#   'like,',
#   'not',
#   'like,',
#   'not',
#   'basically',
#   'an',
#   'like,',
#   'like,',
#   'like,',
#   'working',
#   'worried',
#   'a',
#   'like,',
#   'older,',
#   'like,',
#   'like,',
#   'grateful',
#   'being',
#   'like,',
#   'not',
#   'my',
#   'doing',
#   'like,',
#   'like,',
#   'so',
#   'like,',
#   'like,',
#   'stupid.”',
#   'such',
#   'against',
#   'just',
#   'like,',
#   'gonna',
#   'just',
#   'gonna',
#   'like,',
#   'like,',
#   'literally',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'being',
#   'not.”',
#   'bisexual',
#   'the',
#   'hearing',
#   'talking.',
#   'sexist',
#   'like,',
#   'like,',
#   'straight.',
#   'like,',
#   'sorry',
#   'a',
#   'talking',
#   'sorry.',
#   'having',
#   'gonna',
#   'like,',
#   'petty',
#   'single.',
#   'so',
#   'alone.',
#   'on',
#   'a',
#   'run',
#   'so',
#   'glad',
#   'gonna',
#   'a',
#   'a',
#   'doing',
#   'working',
#   'like,',
#   'like,',
#   'like,',
#   'miserable',
#   'like,',
#   'just',
#   'like,',
#   'not',
#   'like,',
#   'so',
#   'gonna',
#   'gonna',
#   'never'],
#  'fucking': ['Jonas', 'quarters,', 'was.”', 'Harry', 'the', 'hell!”'],
#  'Jonas': ['brother.'],
#  'brother.': ['I'],
#  'know': ['that',
#   'that',
#   'you’re',
#   'what,',
#   'when',
#   'he’s',
#   'people.',
#   'that',
#   'the',
#   'what',
#   'about',
#   'who',
#   'what',
#   'what',
#   'what',
#   'what',
#   'where',
#   'that',
#   'I',
#   'you',
#   'some',
#   'what?',
#   'worrying',
#   'what',
#   'what',
#   'how',
#   'you',
#   'how',
#   'how',
#   'that',
#   'how',
#   'there',
#   'I’m',
#   'when',
#   'that?',
#   'how',
#   'we',
#   'why',
#   'what',
#   'you',
#   'what',
#   'this.”',
#   'how',
#   'if',
#   'some',
#   'if',
#   'I’m',
#   'if',
#   'how',
#   'what’s',
#   'that',
#   'that',
#   'my',
#   'what',
#   'your',
#   'what'],
#  'silly,': ['and'],
#  'my': ['idea!',
#   'career',
#   'third',
#   'name',
#   'married',
#   'soulmate…',
#   'God,',
#   'life.',
#   'face.',
#   'God,',
#   'phone.',
#   'breath',
#   'friends',
#   'friends',
#   'sad',
#   'period',
#   'Hogwarts',
#   'friend',
#   'last',
#   'dream',
#   'third',
#   'career.',
#   'buddy',
#   'friends,',
#   'first',
#   'man.',
#   'male',
#   'most',
#   'God.”',
#   'father',
#   'relationships,',
#   'dad',
#   'dark',
#   'twenties.',
#   'entire',
#   'God!',
#   'God,',
#   'soulmate',
#   'eyes,',
#   'friends',
#   'married',
#   'God.',
#   'tattoo',
#   'last',
#   'treat?”',
#   'therapist’s',
#   'focus',
#   'entire',
#   'sister',
#   'sleepy-sleeps',
#   'intestines?',
#   'other',
#   'problem',
#   'God,',
#   'mom',
#   'grandma…',
#   'feelings.',
#   'anxiety.',
#   'therapist',
#   'life.',
#   'partner',
#   'favorite',
#   'God,',
#   'whole',
#   'friend',
#   'sisters',
#   'passion,',
#   'peers.',
#   'belt.',
#   'period,',
#   'own.',
#   'period,',
#   'other',
#   'big',
#   'faith',
#   'glove',
#   'sex',
#   'God!”',
#   'dad',
#   'parents',
#   'early',
#   'twenties',
#   'dad',
#   'dad',
#   'relationships',
#   'ass.',
#   'God.',
#   'biggest',
#   'siblings,',
#   'biggest',
#   'brother',
#   'emotions.',
#   'life',
#   'own.',
#   'phone',
#   'friends',
#   'friends',
#   'friends',
#   'dream',
#   'twenties',
#   'dream',
#   'own.',
#   'best',
#   'first',
#   'wedding',
#   'dick',
#   'God.',
#   'God!',
#   'whole',
#   'best',
#   'mental',
#   'best',
#   'phone,',
#   'job',
#   'God.'],
#  'idea!': ['I'],
#  'so': ['embarrassed',
#   'much',
#   'it',
#   'sorry.',
#   'offended.',
#   'many',
#   'insanely',
#   'blessed.',
#   'well,',
#   'moved',
#   'awkward,',
#   'good',
#   'much.”',
#   'afraid',
#   'scared',
#   'quickly',
#   'problematic,',
#   'pretty,',
#   'well.',
#   'brave.',
#   'embarrassed.',
#   'we’ll',
#   'much',
#   'confident,',
#   'many',
#   'many',
#   'disappointed',
#   'romantic.”',
#   'proud',
#   'close.',
#   'hard.”',
#   'much',
#   'much',
#   'afraid',
#   'hard.',
#   'smart.',
#   'stupid,',
#   'I',
#   'fun',
#   'you',
#   'sorry.”',
#   'much.',
#   'funny',
#   'you’re',
#   'you’re',
#   'now',
#   'impressed.',
#   'nice.”',
#   'sweet',
#   'hurtful.',
#   'seen',
#   'insulted',
#   'happy',
#   'much,',
#   'much.'],
#  'embarrassed': ['that'],
#  'thought': ['of',
#   'about',
#   'you',
#   'that’s',
#   'life',
#   'about',
#   'it’d',
#   'a',
#   'the',
#   'to',
#   'that',
#   'was',
#   'this',
#   'you'],
#  'that,': ['but', 'I', 'Jesus!”', 'last,'],
#  'too': ['late',
#   'thin.',
#   'late.',
#   '’cause',
#   'much',
#   'fast.',
#   'loose',
#   'hard.”',
#   'much.”',
#   'hard!”'],
#  'late': ['when'],
#  'when': ['we',
#   'you',
#   'I',
#   'I',
#   'you',
#   'I',
#   'they’re',
#   'they’re',
#   'they’re',
#   'I',
#   'I',
#   'they',
#   'you,',
#   'I’m',
#   'you',
#   'you’re',
#   'you’ve',
#   'you’re',
#   'I',
#   'you’re',
#   'you',
#   'a',
#   'a',
#   'you',
#   'you',
#   'I',
#   'I',
#   'I’m',
#   'you'],
#  'got': ['here',
#   'on',
#   'mugged,',
#   'on',
#   'on',
#   'to',
#   'me',
#   'me',
#   'Hugh',
#   'nothing',
#   'what',
#   'cheated',
#   'a',
#   'me',
#   'me',
#   'it?”',
#   'to',
#   'the',
#   'my',
#   'my',
#   'FaceTime',
#   'pregnant',
#   'to',
#   'it!”',
#   'to',
#   'to',
#   'a',
#   'offstage',
#   'a'],
#  'here': ['to', 'on', 'never', 'we', 'at', 'the'],
#  'change': ['it', 'so'],
#  'because': ['men',
#   'the',
#   '‘God’',
#   'it',
#   'when',
#   'it’s',
#   'as',
#   'I',
#   'so',
#   'it',
#   'he',
#   'when',
#   'you',
#   'I',
#   'I',
#   'I'],
#  'men': ['with', 'feel', 'when', 'to'],
#  'jobs': ['had'],
#  'had': ['built',
#   'the',
#   'an',
#   'braces.',
#   'once.',
#   'sex',
#   'some',
#   'a',
#   'a',
#   'cords',
#   'COVID',
#   'a',
#   'three',
#   'three',
#   'a',
#   'married',
#   'three',
#   'this',
#   'walked',
#   'no',
#   'worked',
#   'a'],
#  'built': ['it.'],
#  'it.': ['And',
#   'Went',
#   '[audience',
#   'Is',
#   'Who',
#   '[audience',
#   'And',
#   'Here’s',
#   'It’s',
#   '[laughter,',
#   '‘Cause',
#   'Forget',
#   'Just',
#   'It',
#   'I',
#   'I',
#   'Lot'],
#  'And': ['were',
#   'I',
#   'recently,',
#   'before',
#   'I',
#   'we’re',
#   'that’s',
#   'the',
#   'then',
#   'I',
#   'I',
#   'I’m',
#   'he',
#   'then',
#   'I’m',
#   'you',
#   'I',
#   'they’re',
#   'you',
#   'you’re',
#   'she’s',
#   'then',
#   'then',
#   'then',
#   'we',
#   'before',
#   'they',
#   'then',
#   'that',
#   'I',
#   'then',
#   'I',
#   'then',
#   'you',
#   'you’re',
#   'he’s',
#   'I',
#   'I',
#   'I',
#   'he’s',
#   'my',
#   'I',
#   'my',
#   'you’re',
#   'it’s',
#   'no',
#   'that',
#   'my',
#   'that',
#   'that',
#   'as',
#   'I',
#   'now',
#   'these',
#   'it’s',
#   '30',
#   'then',
#   'now',
#   'so',
#   'I',
#   'it’s',
#   'that',
#   'everybody’s',
#   'I’m',
#   'because',
#   'it',
#   'I',
#   'I'],
#  'were': ['operating',
#   'very',
#   'like,',
#   'an',
#   'in',
#   'also',
#   'like,',
#   'at',
#   'to',
#   'inside',
#   'all',
#   'lying',
#   'gonna',
#   'thinking',
#   'thinking',
#   'like,',
#   'a',
#   'like…',
#   'like,',
#   'you',
#   'at',
#   'your',
#   'asking',
#   'so',
#   'supposed',
#   'no',
#   '10.',
#   'on',
#   'in',
#   'absolutely',
#   'fantastic.',
#   'some'],
#  'operating': ['it'],
#  'very': ['well,',
#   'well',
#   'supportive.',
#   'emotional',
#   'emotional',
#   'firm',
#   'firm'],
#  'well,': ['I', 'it', 'we’d', 'but', 'those'],
#  'add.': ['And'],
#  'like,': ['“We',
#   '“Well,',
#   '“Go',
#   '“Do',
#   '“More',
#   '“I',
#   '“Why',
#   '“Oh',
#   '‘Let',
#   '“We',
#   '“Mugged?',
#   '“No,',
#   '“Well…”',
#   '“Know',
#   '“She',
#   '“Yeah,',
#   '“Nobody',
#   '“I',
#   '“I',
#   '“This',
#   '“Well,',
#   '“How',
#   'what',
#   '“This',
#   '“It’s',
#   '“Don’t',
#   '“It’s',
#   '“Oh,',
#   '“Goddammit,',
#   '“Oh,',
#   '“This',
#   '“Well,',
#   '“Totally.',
#   '“I',
#   '“What’s',
#   '“Oh',
#   '“Excuse',
#   '“Hey.',
#   '“Really?”',
#   '“God,',
#   '“Wish',
#   '“Hey,',
#   '“Look,',
#   '“Please,',
#   '“You',
#   '“I’m',
#   '“I',
#   '“Hey,',
#   '“I',
#   '“Oh,',
#   '“No,',
#   '“Oh,',
#   '‘Well,',
#   '“Well,',
#   '“Let’s',
#   '“I',
#   '“Ugh.',
#   '“Jason',
#   '“I',
#   '“Okay.',
#   '“I',
#   '“It’s',
#   '“Well,',
#   '“You',
#   '“Someone',
#   'what',
#   '“You',
#   '“Let’s',
#   '“They’re',
#   '“Something',
#   '“That’s',
#   '“It’s',
#   '“I',
#   '“No,',
#   '“Just',
#   '“Some',
#   '“This',
#   '“Okay.',
#   '“Aw,',
#   '“What',
#   '“Newt',
#   '“Come',
#   '“You',
#   '“I',
#   '“Yeah.',
#   '“Oh',
#   '“What?',
#   '“What?',
#   '“Okay.',
#   '“Oh,',
#   '‘What?',
#   '“I’ve',
#   '“You',
#   '“Okay.',
#   '“You',
#   '“Yeah,',
#   '“No,',
#   '“Fucking',
#   '“No!”',
#   '“I’ll',
#   '“Who',
#   '“This',
#   '“She',
#   '“Prove',
#   '“Okay.',
#   '“No,',
#   '“I',
#   '“You’re',
#   '“What',
#   '“Sure,',
#   '“It’s',
#   'Lorelai',
#   '“It’s',
#   '“I',
#   '“Oh',
#   '“Yeah,',
#   '“All',
#   '“Do',
#   '“Tell',
#   '“Who',
#   '“Wow,',
#   '“I',
#   '“Enough.”',
#   '“Two',
#   '“What?”',
#   '“A',
#   '“Jesus.',
#   '“Dude,',
#   '“Hello,',
#   '“I’m',
#   '“Can',
#   '“You',
#   '“You',
#   '“No,',
#   '“I',
#   '“You',
#   '“I',
#   '“I’ve',
#   '“Yeah,',
#   '“But',
#   '“But',
#   '“I’m',
#   '“Oh',
#   '“Whatever,',
#   '“You’ve',
#   '“He’s',
#   '“You',
#   '“Hey,',
#   '“Just',
#   '“You’re',
#   '“What?',
#   '“And',
#   '“By',
#   '“No,',
#   '“Yeah!”',
#   '“I'],
#  '“We': ['can', 'think', 'got', 'noticed', 'do.”', 'have', 'are'],
#  'can': ['probably',
#   'do',
#   'feel',
#   'have',
#   'bring',
#   'always',
#   'do',
#   'finger',
#   'go.”',
#   'opt',
#   'tell',
#   'we',
#   'I',
#   'look',
#   'tell',
#   'think',
#   'and',
#   'hear?',
#   'come',
#   'play',
#   'all',
#   'have',
#   'see',
#   'handle',
#   'no',
#   'you',
#   'beat'],
#  'probably': ['just', 'get', 'fine,', 'focus', 'have'],
#  'just': ['scrap',
#   'in',
#   'share',
#   'date',
#   'be',
#   'have',
#   'leave.',
#   'a',
#   'doing',
#   'say',
#   'like',
#   'posted',
#   'power',
#   'dating',
#   'wanted',
#   'seemed',
#   'like,',
#   'table',
#   'amazing',
#   'see',
#   'kind',
#   'go.”',
#   'one',
#   'need',
#   'jaded.',
#   'want',
#   'curious.',
#   'talks',
#   'suffer',
#   'binged',
#   'turn',
#   'want',
#   'say',
#   'a',
#   'walked',
#   'me',
#   'vertical.',
#   'a',
#   'science.”',
#   'goes',
#   'wanted',
#   'wanted',
#   'fine.”'],
#  'scrap': ['it,'],
#  'it,': ['right?”',
#   'and',
#   'a',
#   'and',
#   'man.”',
#   'and',
#   'but',
#   'that’s',
#   'but',
#   'you'],
#  'right?”': ['They’re', '“Go', 'That', 'You’re'],
#  'They’re': ['like,',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'getting',
#   'trying',
#   'fun,',
#   'like,',
#   'not',
#   'gonna',
#   'like,',
#   'all',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'in',
#   'like,'],
#  '“Well,': ['this', 'why', 'I', 'shit.', 'yeah.', 'obviously,', 'stop', 'by'],
#  'this': ['is',
#   'weekend?”',
#   'guy',
#   'great',
#   'to',
#   'woman,',
#   'woman',
#   'woman.',
#   'girl',
#   'sex',
#   'spring.',
#   'isn’t',
#   'is',
#   'enough,',
#   'week?',
#   'out',
#   'story',
#   'all',
#   'show.',
#   'question.',
#   'question',
#   'tour.',
#   'boring',
#   'tour.',
#   'candle',
#   'game.”',
#   'analogy,',
#   'week,',
#   'on',
#   'unemployed',
#   'together.”',
#   'guy?',
#   'guy.”',
#   'was',
#   'compartmentalizing',
#   'year',
#   'stuff',
#   'year',
#   'other',
#   'job',
#   'business',
#   'business',
#   'responsibility.',
#   'age',
#   'around.”',
#   'weird',
#   'weird',
#   'year',
#   'where',
#   'is',
#   'one.',
#   'city'],
#  'is': ['like',
#   'going',
#   'the',
#   'my',
#   'a',
#   'a',
#   'gonna',
#   'what',
#   '100%',
#   'now',
#   'now',
#   'crazy.',
#   'for',
#   'so',
#   'not',
#   'a',
#   'meeting',
#   'so',
#   'hot',
#   'a',
#   'such',
#   'like',
#   'not',
#   'what',
#   'what’s',
#   'a',
#   'personality',
#   'a',
#   'crazy.',
#   'tracking',
#   'that',
#   'to',
#   'your',
#   'why',
#   'where',
#   'where',
#   'just',
#   'probably',
#   'the',
#   'not',
#   'how',
#   'to',
#   'impressive',
#   'a',
#   'not',
#   'not',
#   'like',
#   'so',
#   'a',
#   'trans,',
#   'not',
#   'so',
#   'another',
#   'so',
#   'a',
#   'it?”',
#   'that',
#   'not',
#   'to',
#   'that',
#   'going',
#   'available!”',
#   'your',
#   'it?'],
#  'week': ['of', 'she', 'with', 'directly'],
#  'our': ['lives,',
#   'face',
#   'bargain!”',
#   'hands',
#   'side',
#   'hometown,',
#   'first',
#   'sibling',
#   'biggest',
#   'heads',
#   'shit',
#   'twenties.',
#   'lives'],
#  'lives,': ['so…”'],
#  'so…”': ['I', 'My'],
#  'dumb.': ['Thank', 'I'],
#  'Thank': ['you', 'you', 'you', 'you.', 'you', 'you,', 'you', 'you'],
#  'you': ['for',
#   'so',
#   'to',
#   'on',
#   'like',
#   'fight',
#   'wanna',
#   'asked',
#   'guys',
#   'do',
#   'proud',
#   'have',
#   'think',
#   'have',
#   'a',
#   'something.’',
#   'got',
#   'go',
#   'just',
#   'told',
#   'just',
#   'walk',
#   'have',
#   'don’t',
#   'could.',
#   'either',
#   'know',
#   'have.',
#   'can',
#   'when',
#   'get',
#   'spend',
#   'not,',
#   'for',
#   'I',
#   'what',
#   'get',
#   'go',
#   'can’t',
#   'know?',
#   'gotta',
#   'think',
#   'possibly',
#   'about?',
#   'like',
#   'so',
#   'guys.',
#   'guys.',
#   'don’t',
#   'gotta',
#   'can',
#   'too!”',
#   'get',
#   'more',
#   'been',
#   'okay?”',
#   'are',
#   'if',
#   'think',
#   'were',
#   'idiot!',
#   'are',
#   'hide',
#   'come',
#   'know,',
#   'do',
#   'guys',
#   'love',
#   'ever…?”',
#   'introduce',
#   'get',
#   'go',
#   'gotta',
#   'see',
#   'both',
#   'have',
#   'waste',
#   'every',
#   'want',
#   'feel',
#   'drove',
#   'swallowed',
#   'could',
#   'back.”',
#   'are',
#   'have',
#   'go',
#   'go',
#   'mean',
#   'I’ve',
#   'put',
#   'think',
#   'have',
#   'think',
#   'have',
#   'tried',
#   'removed.',
#   'got?',
#   'got?',
#   'do',
#   'sleep',
#   'got?',
#   'trying',
#   'trying',
#   'got?',
#   'miss',
#   'tried',
#   'in',
#   'the',
#   'got?”',
#   'can’t',
#   'know',
#   'for',
#   'worry,',
#   'just',
#   'think',
#   'have',
#   'don’t.',
#   'know',
#   'had',
#   'know',
#   'and',
#   'are',
#   'get',
#   'tried',
#   'feel',
#   'could',
#   'for',
#   'do,',
#   'are.”',
#   'feel?”',
#   'don’t.”',
#   'pregnant,',
#   'can’t',
#   'bitch!”',
#   'ask',
#   'wanted',
#   'don’t',
#   'wet?',
#   'not',
#   'can',
#   'want',
#   'don’t',
#   'know',
#   'come,',
#   'know',
#   'didn’t',
#   'mind',
#   'were?',
#   'and',
#   'consent',
#   'when',
#   'got',
#   'were',
#   'asking',
#   'for',
#   'so',
#   'serious?',
#   'to',
#   'the',
#   'weren’t',
#   'were',
#   'get',
#   'know',
#   'to',
#   'know.”',
#   'know',
#   'know.',
#   'what',
#   'want',
#   'have',
#   'start',
#   'smell',
#   'later.',
#   'leave',
#   'know',
#   'guys',
#   'get',
#   'have',
#   'so',
#   'have',
#   'need',
#   'watch',
#   'please',
#   'doing',
#   'would’ve',
#   'stay',
#   'snort',
#   'keep',
#   'have',
#   'know.”',
#   'up',
#   'don’t',
#   'know',
#   'were',
#   'and',
#   'guys',
#   'ask',
#   'were',
#   'could',
#   'know',
#   'can',
#   'don’t',
#   'guys',
#   'so',
#   'so,',
#   'got?',
#   'know',
#   'think',
#   'have',
#   'think…',
#   'guys,',
#   'up',
#   'got,',
#   'guys.',
#   'for'],
#  'for': ['indulging',
#   'coming.',
#   'your',
#   'you.',
#   'a',
#   'them',
#   'what',
#   'an',
#   'some',
#   'sex…',
#   'clapping.',
#   'charity.”',
#   'me,',
#   'that.',
#   'him.',
#   '45',
#   'some',
#   'you.”',
#   'me.',
#   'an',
#   'a',
#   'the',
#   'a',
#   'years.',
#   'you',
#   'every',
#   'you',
#   'a',
#   'you.”',
#   'your',
#   'years.',
#   'anxiety',
#   'everyone.',
#   'a',
#   'every',
#   'the',
#   'playing.',
#   'this.',
#   'a',
#   '10',
#   '10',
#   '10',
#   'anything',
#   'almost',
#   'you!”',
#   'a',
#   'your',
#   'all',
#   'the',
#   '’em.',
#   'a',
#   'a',
#   'anybody',
#   'relationship',
#   'people',
#   'fights?”',
#   '‘pineapple,',
#   'relationship',
#   'long',
#   'a',
#   'this',
#   '30',
#   'months,',
#   'shit',
#   'like',
#   'my',
#   'her.',
#   'you.”',
#   'playing.',
#   'five',
#   'five'],
#  'indulging': ['me.'],
#  'me.': ['[chuckles]',
#   'I',
#   'He',
#   'It',
#   'Now,',
#   'That',
#   'Are',
#   'I',
#   'Easy.',
#   'So',
#   'She',
#   'Every',
#   'Like,',
#   'Just',
#   'Because',
#   'If',
#   'Okay.'],
#  '[chuckles]': ['How', 'It’s'],
#  'doing,': ['DC?', 'Taylor?”'],
#  'DC?': ['Thank', 'This'],
#  'much': ['for', 'time.', 'mental', 'harder.', 'more'],
#  'coming.': ['[audience'],
#  'have': ['to',
#   'the',
#   'sex',
#   'that',
#   'one',
#   'your',
#   'it',
#   'it',
#   'it',
#   'their',
#   'it',
#   'a',
#   'this',
#   'been',
#   'been',
#   'it',
#   'it',
#   'money.”',
#   'a',
#   'it',
#   'those',
#   'to',
#   'two',
#   'two.”',
#   'casual',
#   'casual',
#   'a',
#   'some',
#   'a',
#   'people',
#   'to',
#   'a',
#   'another',
#   'a',
#   'to',
#   'all',
#   'time',
#   'anxiety?',
#   'to',
#   'inadvertently',
#   'swallowed…”',
#   'a',
#   'pancakes',
#   'the',
#   'to',
#   'trouble',
#   'a',
#   'a',
#   'never',
#   'you',
#   'one?',
#   'you',
#   'you',
#   'to',
#   'to',
#   'heard',
#   'a',
#   'a',
#   'a',
#   'beds,',
#   'anxiety,',
#   'a',
#   'a',
#   'anxiety.',
#   'three',
#   'that',
#   'the',
#   'it.',
#   'the',
#   'many',
#   'any',
#   'any.',
#   'had,',
#   'a',
#   'a',
#   'a',
#   'one.”',
#   'to',
#   'to',
#   'a',
#   'these',
#   'time',
#   'demands',
#   'demands',
#   'turns',
#   'spent',
#   'the',
#   'it',
#   'a',
#   'kids',
#   'childhood',
#   'childhood',
#   'colic.',
#   'a',
#   'kids',
#   'your',
#   'all',
#   'it',
#   'three',
#   'a',
#   'my',
#   'your',
#   'the',
#   'a',
#   'my',
#   'the',
#   'her',
#   'never',
#   'a',
#   'one',
#   'a',
#   'anything?',
#   'a',
#   'never',
#   'one',
#   'we',
#   'Xanax,',
#   'you'],
#  'honest,': ['my'],
#  'career': ['is', 'that', 'I’ve'],
#  'going': ['very',
#   'for',
#   'through',
#   'to',
#   'over',
#   'down',
#   'down',
#   'through',
# ...
#   'trying',
#   'to',
#   'my',
#   'here'],
#  'insanely': ['lucky'],
#  'lucky': ['in', 'as'],
#  'career.': ['And'],
#  '“Nobody': ['has', 'move!”'],
#  'every': ['single',
#   'second',
#   'Monday.',
#   'day',
#   'occasion.',
#   'movement.',
#   'time',
#   'session',
#   'week.',
#   'week',
#   'occasion.',
#   'sleep',
#   'audience',
#   'night.',
#   'article,',
#   'podcast,',
#   'audience,',
#   'night',
#   'day.',
#   'time',
#   'time',
#   'morning,'],
#  'thing': ['going', 'is', 'I’ve', 'right'],
#  'person.': ['You', '[audience'],
#  'You': ['have',
#   'can',
#   'get',
#   'know,',
#   'gotta',
#   'feel',
#   'feel',
#   'get',
#   'can',
#   'like',
#   'guys',
#   'want',
#   'wanna',
#   'can’t',
#   'play',
#   'get',
#   'don’t',
#   'want',
#   'want',
#   'can',
#   'gotta',
#   'bake',
#   'can’t',
#   'get',
#   'fill',
#   'think',
#   'have',
#   'need',
#   'fall',
#   'eavesdrop',
#   'listen',
#   'have',
#   'okay?”',
#   'do',
#   'trick',
#   'do',
#   'just',
#   'didn’t',
#   'did.',
#   'ever',
#   'know',
#   'call',
#   'were',
#   'guys'],
#  'blessed.': ['Be'],
#  'grateful': ['for', 'to', 'for', 'after', 'as'],
#  'have.': ['Focus', 'I'],
#  'Focus': ['on'],
#  'gets': ['to', 'down', 'down', 'there,', 'better'],
#  'then': ['I',
#   'he',
#   'they’re',
#   'you',
#   'lost',
#   'he',
#   'me',
#   'we',
#   'whoever',
#   'the',
#   'you',
#   'what',
#   'you’re',
#   'someone’s',
#   'you’re',
#   'what'],
#  'saw': ['Hugh', 'on', 'it.”', 'Music', 'me', 'my'],
#  'Hugh': ['Jackman',
#   'Jackman',
#   'Jackman.',
#   'Jackman',
#   'Jackman',
#   'is',
#   'Jackman',
#   'Jackman.',
#   'Jackman’s'],
#  'Jackman': ['in', 'is', 'was', 'in', 'steps'],
#  'guess': ['you', 'astronaut'],
#  'there’s': ['none', 'this'],
#  'none': ['left'],
#  'left': ['because'],
#  '‘God’': ['gave'],
#  'gave': ['it'],
#  'Hugh.”': ['Hugh'],
#  'perfect': ['specimen'],
#  'specimen': ['of'],
#  'human': ['man.', 'beings.', 'woman.', 'absurdities'],
#  'man.': ['Seeing', 'It', 'You’re'],
#  'Seeing': ['him'],
#  'him': ['in',
#   'later.',
#   'I’m',
#   'and',
#   'say.',
#   'talk.',
#   'the',
#   'all',
#   'through',
#   'in'],
#  'person': ['was', 'with', 'they', 'over'],
#  'religious': ['experience.', 'trauma?'],
#  'experience.': ['It'],
#  'changed': ['me.', 'my'],
#  'seeing': ['the', 'Niagara'],
#  'Grand': ['Canyon.'],
#  'Canyon.': ['Everyone'],
#  'Everyone': ['should'],
#  'should': ['do', 'hang', 'we', 'cut', 'golf', 'shut', 'try?”'],
#  'die.': ['He', 'A'],
#  'wonder': ['of'],
#  'world,': ['that'],
#  'Niagara': ['Falls.'],
#  'Falls.': ['You'],
#  'bring': ['the', 'bread?', 'the'],
#  'family.': ['You', 'I'],
#  'little': ['wet,', 'early', 'bit,', 'feelings', 'work', 'part'],
#  'wet,': ['but'],
#  'it’s': ['fun.',
#   'like.',
#   'four.”',
#   'like,',
#   'shit',
#   'lovely.',
#   'not.',
#   'the',
#   'in',
#   'still',
#   'in',
#   'really',
#   'supposed',
#   'not',
#   'gross',
#   'done.',
#   'just',
#   'not',
#   'not',
#   'good',
#   'fine.'],
#  'fun.': ['It', 'We', 'We'],
#  'was…': ['[laughter,'],
#  '[laughter,': ['applause]',
#   'applause]',
#   'applause]',
#   'applause]',
#   'applause]'],
#  'applause]': ['Here’s', 'I', 'This', 'And', 'And', 'And'],
#  'Here’s': ['what', 'the', 'my', 'a'],
#  'happened.': ['About', 'We'],
#  'About': ['a'],
#  'year': ['and', 'now,', 'of', 'I', 'to', 'especially,', 'as', 'before'],
#  'half': ['ago,', 'are', 'the', 'are,', 'of', 'give'],
#  'ago,': ['we', 'but', 'doesn’t'],
#  'New': ['York,'],
#  'York,': ['doing'],
#  'shows': ['on', 'and', 'in'],
#  'tour.': ['We', 'If', 'It'],
#  'We': ['had',
#   'are',
#   'should',
#   'could',
#   'could',
#   'can',
#   'moved',
#   'were',
#   'all',
#   'were',
#   'were',
#   'have',
#   'should',
#   'both',
#   'get',
#   'found',
#   'got',
#   'all',
#   'all',
#   'faked',
#   'didn’t.',
#   'got',
#   'do',
#   'have'],
#  'off': ['night', 'drinks.', 'at', 'a', 'an'],
#  'between': ['theater', 'my'],
#  'theater': ['shows.'],
#  'shows.': ['So'],
#  'me,': ['my',
#   'an',
#   'this',
#   'by',
#   'just',
#   'found',
#   'you',
#   'I’m',
#   'I’m',
#   '“Hey,',
#   'this'],
#  'buddy': ['Dustin,'],
#  'Dustin,': ['and'],
#  'wife,': ['Melissa,'],
#  'Melissa,': ['and'],
#  'few': ['friends,', 'hours', 'of', 'years', 'months', 'years'],
#  'also': ['happy,', 'kind', 'see'],
#  'happy,': ['went'],
#  'see': ['The',
#   'him?”',
#   'the',
#   'a',
#   'you.',
#   'your',
#   'you',
#   'whose',
#   'us,',
#   'what',
#   'quadruple-stuffed',
#   'how',
#   'how',
#   'him',
#   'this.”',
#   'if',
#   'me!”'],
#  'Music': ['Man', 'Man,'],
#  'Man': ['on'],
#  'Broadway,': ['starring'],
#  'starring': ['Hugh'],
#  'Jackman.': ['Was', '[audience'],
#  'Was': ['it'],
#  'show?': ['I'],
#  'there': ['the', 'for', 'when', 'and', 'too.”', 'was', 'was', 'the'],
#  'should’ve': ['called', 'beat', 'started'],
#  'called': ['the',
#   'Broadway',
#   'a',
#   'a',
#   'me',
#   'to',
#   'her.',
#   '“the',
#   'off',
#   'to'],
#  'show,': ['“We', 'can'],
#  'room.': ['Who', 'I', 'It’s', 'When', 'I'],
#  'Who': ['wants', 'wants', 'you', 'said', 'did'],
#  'him?”': ['The'],
#  'great.': ['At', '[audience', 'We’re', 'We’re'],
#  'At': ['the', 'the', 'least'],
#  'end,': ['they’re'],
#  'they’re': ['doing',
#   'about',
#   'about',
#   'like,',
#   'trying',
#   'talking',
#   'not',
#   'just',
#   'all',
#   'like,',
#   'all',
#   'all',
#   'all',
#   'like,',
#   'in',
#   'condescending',
#   'like,'],
#  'curtain': ['calls.'],
#  'calls.': ['The'],
#  'actors': ['are', 'steps'],
#  'taking': ['their', 'your', 'someone'],
#  'bows.': ['One'],
#  'One': ['of', 'wrote'],
#  'steps': ['forward', 'forward,'],
#  'forward': ['and'],
#  'goes,': ['“You’ve',
#   '“Before',
#   '“Great.',
#   '“I',
#   '“Yeah.',
#   '“You’ll',
#   '“No,',
#   '“Hey,',
#   '“Have',
#   '“When',
#   '“Then',
#   '“Who',
#   '“Obviously,',
#   '“I',
#   '“Do',
#   '“You',
#   '“I',
#   '“He',
#   '“Notice',
#   '“We',
#   '“Cunt.”',
#   '“Why?',
#   '“Yeah,',
#   '“Oh',
#   '“I'],
#  '“You’ve': ['come', 'gotta'],
#  'week,': ['Tonight', 'he’s', 'your'],
#  'Tonight': ['we’re', 'Hugh'],
#  'raising': ['money'],
#  'money': ['for', 'on?”', 'on?'],
#  'amazing': ['charity', 'all'],
#  'charity': ['called'],
#  'Broadway': ['Cares.'],
#  'Cares.': ['Tonight'],
#  'sign': ['the', 'both'],
#  'pair': ['of', 'of'],
#  'gloves': ['he', 'worn'],
#  'wore': ['in'],
#  'show.': ['We’re', 'I', 'Meet'],
#  'auction': ['them'],
#  'highest': ['bidder.”'],
#  'bidder.”': ['And'],
#  'mean…': ['I'],
#  'money.”': ['They', 'So'],
#  '“This': ['is', 'is', 'was', 'one’s', 'dude', 'shit', 'idiot!”'],
#  'spend': ['the', 'that', 'your'],
#  'on?”': ['And', '“I'],
#  'family.”': ['[audience'],
#  '“There’s': ['no'],
#  'else': ['here,', 'we', 'think', 'we', 'thinks…'],
#  'here,': ['and', 'Dr.'],
#  'already': ['had', 'saw', 'know'],
#  'braces.': ['If'],
#  'gloves.”': ['Also,', 'Thank'],
#  'Also,': ['I'],
#  'it’d': ['be'],
#  'hilarious': ['as'],
#  'bit.': ['Because'],
#  'everybody': ['asks'],
#  'asks': ['you'],
#  'television,': ['“What’d'],
#  'on?': ['A'],
#  'A': ['new',
#   'new',
#   'dating',
#   'doctor,',
#   'few',
#   'woman',
#   'straight',
#   'cat',
#   'witty,'],
#  'new': ['jacket?',
#   'car?”',
#   'girlfriend,',
#   'hobbies',
#   'fingerings.',
#   'things.'],
#  'jacket?': ['A'],
#  'car?”': ['And'],
#  '“How': ['funny', 'do', 'was', 'about'],
#  'funny': ['would', 'about', 'how'],
#  'would': ['it',
#   'these',
#   'be',
#   'that',
#   'be',
#   'fall',
#   'seem',
#   'that',
#   'be',
#   'love',
#   'not',
#   'not',
#   'a'],
#  'big': ['TV', 'ask', 'deal.”', 'one!”', 'one.'],
#  'TV': ['purchase'],
#  'purchase': ['was'],
#  'sweaty': ['gloves'],
#  'worn': ['by'],
#  'Wolverine,”': ['right?'],
#  'right?': ['[chuckles]',
#   'I',
#   'Someone',
#   'So',
#   'And',
#   'Like,',
#   '[laughter,',
#   'I'],
#  'I,': ['a', 'a'],
#  'man?': ['So'],
#  'start': ['competing', 'doing', 'dating', 'to', 'the'],
#  'competing': ['in'],
#  'auction,': ['and', 'I'],
#  'well.': ['‘Cause', 'You’re'],
#  'nothing': ['to', 'weird.', 'in'],
#  'lose': ['and'],
#  'live': ['for.', 'alone', 'here.”', 'entertainer.'],
#  'for.': ['I’m', 'We', 'When'],
#  'down': ['to', 'to', 'deep', 'on', 'real', 'on', 'on', 'on', 'and'],
#  'two': ['other',
#   'gloves.',
#   'ladies',
#   'other',
#   'AirPods,',
#   'things?',
#   'holes',
#   'years',
#   'weeks'],
#  'other': ['bidders.',
#   'people.',
#   'half',
#   'than',
#   'sister',
#   'room.',
#   'room?',
#   'room?”',
#   'two',
#   'stuff.',
#   'like,',
#   'people’s'],
#  'bidders.': ['It'],
#  'older': ['woman'],
#  'woman': ['towards', 'needed', 'in', 'in', 'to', 'feels', 'rejects'],
#  'front,': ['and'],
#  'not,': ['Jake'],
#  'Jake': ['from', 'from', 'could'],
#  'State': ['Farm.', 'Farm', 'Farm'],
#  'Farm.': ['That'],
#  '100%': ['true,'],
#  'true,': ['that'],
#  'detail,': ['and'],
#  'hesitate': ['to'],
#  'include': ['it'],
#  'makes': ['the', 'that', 'me'],
#  'story': ['sound', '’cause', 'happened'],
#  'sound': ['like', 'of'],
#  'once.': ['“So', 'We', 'Two'],
#  '“So': ['in', 'brave,', 'glad'],
#  'dream,': ['I’m'],
#  'trying': ['to',
#   'not',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'not'],
#  'Hugh’s': ['gloves.'],
#  'gloves.': ['Jake', 'If'],
#  'Farm': ['thinks', 'backs'],
#  'he’s': ['gonna',
#   'dead',
#   'like,',
#   'like…',
#   'doing.”',
#   'like,',
#   'pretending',
#   'gonna'],
#  'Fat': ['chance,'],
#  'chance,': ['commercial'],
#  'commercial': ['boy.'],
#  'boy.': ['Those'],
#  'Those': ['are', 'are'],
#  'mine.”': ['“Then'],
#  '“Then': ['Flo', 'I'],
#  'Flo': ['from'],
#  'Progressive': ['rides'],
#  'rides': ['in'],
#  'horse': ['for'],
#  'some': ['reason.”',
#   'reason.',
#   'daddy',
#   'people',
#   'bread,',
#   'slack',
#   'kids',
#   'belts.',
#   'of',
#   'people',
#   'point,',
#   'bullying,',
#   'shows',
#   'basic'],
#  'reason.”': ['“Whoops,'],
#  '“Whoops,': ['who’s'],
#  'who’s': ['that?”', 'not'],
#  'that?”': ['“Tony', 'I’m'],
#  '“Tony': ['the'],
#  'Tiger': ['pops'],
#  'pops': ['a'],
#  'wheelie': ['on'],
#  'motorbike.”': ['“All-cash'],
#  '“All-cash': ['offer.”'],
#  'offer.”': ['“You'],
#  'beat': ['Tony.', 'us', 'firm'],
#  'Tony.': ['That’s'],
#  'That’s': ['old',
#   'basic.',
#   'why',
#   'how',
#   'what',
#   'power,',
#   'freedom,',
#   'embarrassing.”',
#   'messed',
#   'kind',
#   'when',
#   'been',
#   'one.',
#   'the',
#   'how',
#   'the',
#   'my',
#   'never',
#   'a',
#   'his',
#   'a',
#   'how'],
#  'old': ['money.”', 'you', 'were'],
#  'now': ['me,',
#   'me',
#   'that',
#   'as',
#   'that',
#   'She’s',
#   'fortunate',
#   'I',
#   'that',
#   'there’s'],
#  'woman,': ['and'],
#  'Jake.': ['I'],
#  'happened': ['next', 'a', 'when', 'to'],
#  'could': ['tell',
#   'tell',
#   'bowl.',
#   'bowl',
#   'date',
#   'never',
#   'be',
#   'pretend',
#   'have',
#   'feel',
#   'not',
#   'get',
#   'benefit',
#   'hear'],
#  'tell': ['that',
#   'you',
#   'who',
#   'you',
#   'him',
#   'that',
#   'your',
#   'them',
#   'me',
#   'three',
#   'me',
#   'me',
#   'you',
#   'you',
#   'me',
#   'you',
#   'me.'],
#  'needed': ['the', 'it.'],
#  'win': ['more'],
#  'did.': ['So', 'My', 'Let’s', 'Do'],
#  'neighbor,': ['State'],
#  'backs': ['out.'],
#  'out.': ['Yep.'],
#  'Yep.': ['It'],
#  'woman.': ['We', 'I'],
#  'ping-ponging,': ['back'],
#  'forth.': ['I'],
#  'blacked': ['out'],
#  'to,': ['we', 'I'],
#  'number': ['that', 'three.', 'three.”'],
#  'agreed': ['to'],
#  'pay': ['since', 'to'],
#  'college.': ['So'],
#  'exactly': ['like', 'as', 'a'],
#  'college,': ['I’m'],
#  'crazy.': ['I’m', 'You'],
#  'finish.”': ['[audience'],
#  'As': ['they’re'],
#  'say,': ['“Once,', 'I', 'but', '“See?', 'do', '“Hey,', '“read'],
#  '“Once,': ['twice,'],
#  'twice,': ['sold'],
#  'sold': ['to'],
#  'front,”': ['Hugh'],
#  'forward,': ['stops'],
#  'stops': ['the', 'the'],
#  'auctioneer,': ['and'],
#  '“Before': ['we', 'we'],
#  'end': ['the', 'it.'],
#  'moved': ['by', 'in'],
#  'generosity': ['of'],
#  'tonight’s': ['audience.'],
#  'audience.': ['You', 'What'],
#  'know,': ['I', 'I', 'they', 'babe.', 'but', 'there'],
#  'them,': ['would', 'I’m', 'right?'],
#  'these': ['two', 'stay', 'holes.', 'kids', 'polite', 'kids', 'people'],
#  'ladies': ['match'],
#  'match': ['each'],
#  'each': ['other’s', 'other.', 'other,', 'other.', 'other'],
#  'other’s': ['bid?”'],
#  'bid?”': ['And'],
#  'Now,': ['I’ve', 'round'],
#  'never': ['paid',
#   'been',
#   'been,',
#   'been',
#   'heard',
#   'heard.',
#   'been',
#   'guess.',
#   "be.'”",
#   'did.',
#   'heard',
#   'heard',
#   'ever',
#   'one',
#   'got',
#   'will.”',
#   'catch',
#   'asked',
#   'thought',
#   'speak',
#   'get',
#   'happened',
#   'does',
#   'happened.',
#   'felt',
#   'heard',
#   'coming'],
#  'paid': ['for'],
#  'sex…': ['[audience'],
#  '…but': ['I'],
#  'drop': ['seven'],
#  'seven': ['grand'],
#  'grand': ['on'],
#  'eye': ['contact'],
#  'contact': ['with'],
#  'laughing,': ['clapping]', 'cheering]', 'whooping]', 'cheering]', 'wincing]'],
#  'clapping]': ['[cheering', 'Round'],
#  'subsides]': ['Thank'],
#  'clapping.': ['That'],
#  'joke': ['was', 'I', 'money.'],
#  'expensive.': ['[audience'],
#  'tax': ['write-off.”'],
#  'write-off.”': ['I’m'],
#  '“Don’t': ['worry.', 'throw'],
#  'worry.': ['I', 'We'],
#  'make': ['sure',
#   'me',
#   'you',
#   'me',
#   'me',
#   'you',
#   'in',
#   'are',
#   'you',
#   'sure.',
#   'sure',
#   'a'],
#  'sure': ['that', 'it’s', 'you'],
#  'is.”': ['I', 'I’m'],
#  'wish': ['I', 'he', 'I', 'that'],
#  'charity.”': ['But'],
#  'truth': ['is,'],
#  'is,': ['I', 'but'],
#  'completely': ['forgot', 'fine.', 'fine.'],
#  'forgot': ['till', 'your'],
#  'till': ['the', 'later', 'you’re'],
#  'end.': ['Even', 'So'],
#  'Even': ['then,', 'if'],
#  'then,': ['I'],
#  'barely': ['listening.'],
#  'listening.': ['I'],
#  'busy': ['talking'],
#  'talking': ['to', 'shop', 'about.', 'to', 'to'],
#  'glove.': ['Like,'],
#  '“Hugh’s': ['fingers'],
#  'fingers': ['were'],
#  'inside': ['you.', 'me,'],
#  'like?”': ['“He’s'],
#  '“He’s': ['surprisingly', 'got'],
#  'surprisingly': ['gentle.”'],
#  'gentle.”': ['“I'],
#  'knew': ['it.”'],
#  '’cause': ['I', 'we', 'you', 'it', 'that', 'I', 'then', 'he’s'],
#  'always': ['tell',
#   'want',
#   'show',
#   'had',
#   'wanted',
#   'like,',
#   'have',
#   'will',
#   'get',
#   'pictured',
#   'wanted.'],
#  'grew': ['up', 'up'],
#  'church': ['based', 'youth'],
#  'based': ['on'],
#  'starts': ['laughing', 'playing'],
#  'laughing': ['at'],
#  'two.”': ['You’re'],
#  '“Oh,': ['I', 'he', 'no', 'we’re', 'you', 'we’re'],
#  'read': ['the', 'every', 'every', 'what', 'it', 'it,'],
#  'Bible.': ['I'],
#  'cut': ['a', 'me'],
#  'baby': ['in', 'or', 'outside?”', 'showers,'],
#  'half.”': ['I'],
#  'app': ['thing', 'profile,', 'date'],
#  'way.': ['Don’t', 'Got'],
#  'Don’t': ['think', 'tell', 'worry.', 'you', 'make', 'make', 'even', 'get'],
#  'Is': ['anyone', 'laser', 'this', 'it', 'it?', 'it', 'it'],
#  'anyone': ['in', 'in', 'ever', 'have', 'around', 'had', 'think'],
#  'apps?': ['[light'],
#  '[light': ['applause,'],
#  'applause,': ['whooping]', 'how', 'who'],
#  'whooping]': ['Okay,', 'I', '“Kinda'],
#  'app?': ['[louder'],
#  '[louder': ['whooping]'],
#  'care': ['for', 'that'],
#  'Wish': ['I'],
#  'hadn’t': ['asked.'],
#  'asked.': ['The'],
#  'smugness': ['of'],
#  'whoos.': ['I'],
#  'hated': ['every'],
#  'second': ['of', 'option', 'row?'],
#  'you’ve': ['never', 'never', 'never', 'been'],
#  'been,': ['let'],
#  'let': ['me', 'you'],
#  'like.': ['Every'],
#  'profile,': ['you'],
#  'six': ['photos', 'different'],
#  'different': ['human', 'room', 'personality', 'city!', 'city?', 'city?!'],
#  'beings.': ['Then'],
#  'sit': ['in', 'there', 'down', 'in'],
#  'coffee': ['shop'],
#  'shop': ['and', 'about'],
#  'wait': ['for', 'till', 'until'],
#  '“Come': ['on,', 'on,'],
#  'on,': ['picture', 'picture', 'which', 'Taylor.', 'this'],
#  'picture': ['number', 'number'],
#  'three.': ['Come'],
#  'Come': ['on,'],
#  'three.”': ['And'],
#  '“Goddammit,': ['it’s'],
#  'four.”': ['But'],
#  'leave.': ['You'],
#  'gotta': ['sit', 'go', 'understand,', 'get', 'start', 'ask', 'admit,'],
#  '45': ['minutes,'],
#  'minutes,': ['nodding', 'will'],
#  'nodding': ['and'],
#  'smiling,': ['knowing'],
#  'knowing': ['you’re'],
#  'ghost': ['him'],
#  'later.': ['You', 'I'],
#  'creepy.': ['You'],
#  'Haley': ['Joel'],
#  'Joel': ['Osment'],
#  'Osment': ['in'],
#  'Sixth': ['Sense.'],
#  'Sense.': ['Just'],
#  'doesn’t': ['know', 'it?', 'matter', 'help.', 'prepare', 'do', 'really'],
#  'dead': ['yet.”', 'body?”'],
#  'yet.”': ['[audience', '[laughter]'],
#  'Dating': ['is', 'is', 'is', 'feels'],
#  'awkward,': ['especially'],
#  'especially': ['dating'],
#  'apps.': ['A'],
#  'blind': ['date,'],
#  'date,': ['but', 'and'],
#  'nearsighted': ['one,'],
#  'one,': ['you', 'you’d', 'when'],
#  'know?': ['The'],
#  'date’s': ['easy.'],
#  'easy.': ['You'],
#  'dinner,': ['drinks.', 'see'],
#  'drinks.': ['That’s', 'Saying'],
#  'basic.': ['But'],
#  'hang': ['again.', 'out', 'out'],
#  'again.': ['What', 'I', 'Your'],
#  'shit.': ['I’m'],
#  'hobbies': ['or', 'as'],
#  'interests.': ['I’m'],
#  'basically': ['just'],
#  'stack': ['of'],
#  'frightened': ['possums'],
#  'possums': ['in'],
#  'trench': ['coat,'],
#  ...}

# %% [markdown]
# ## Create a Text Generator

# %% [markdown]
# We're going to create a function that generates sentences. It will take two things as inputs:
# * The dictionary you just created
# * The number of words you want generated
#
# Here are some examples of generated sentences:
#
# >'Shape right turn– I also takes so that she’s got women all know that snail-trail.'
#
# >'Optimum level of early retirement, and be sure all the following Tuesday… because it’s too.'

# %%
import random

def generate_sentence(chain, count=15):
    '''Input a dictionary in the format of key = current word, value = list of next words
       along with the number of words you would like to see in your generated sentence.'''

    # Capitalize the first word
    word1 = random.choice(list(chain.keys()))
    sentence = word1.capitalize()

    # Generate the second word from the value list. Set the new word as the first word. Repeat.
    for i in range(count-1):
        word2 = random.choice(chain[word1])
        word1 = word2
        sentence += ' ' + word2

    # End it with a period
    sentence += '.'
    return(sentence)

# %%
generate_sentence(Taylor_dict)
# Out:
# 'Half ago, but I was being called a special tonight. Can’t finger these people in.'

# %% [markdown]
# ### Assignment:
# 1. Generate sentence for other comedians also.
# 2. Try making the generate_sentence function better. Maybe allow it to end with a random punctuation mark or end whenever it gets to a word that already ends with a punctuation mark.

# %% [markdown]
# # KEVIN

# %%
k_text = data.transcript.loc['Kevin']
k_text[:200]
# Out:
# 'Kevin Bridges: The Overdue Catch-Up (2023) is a comedy special that encapsulates Kevin Bridges’ return to the stage, set against the backdrop of the Cork Opera House. He opens with gratitude for the a'

# %%
k_dict = markov_chain(k_text)
k_dict
# Out:
# {'Kevin': ['Bridges:', 'Bridges’', 'Bridges!', 'for'],
#  'Bridges:': ['The'],
#  'The': ['Overdue',
#   'guy’s',
#   'proper',
#   'whole',
#   'real',
#   'Spanish',
#   'black',
#   'transfer',
#   'Celtic!',
#   'north',
#   'country.',
#   'country.',
#   'Orange',
#   'family…',
#   'family',
#   'football',
#   'game’s',
#   'gaffer',
#   'body',
#   'fuck?',
#   'gym!',
#   'gym!',
#   'guy',
#   'youth,',
#   'youth,',
#   'gym',
#   'guy’s',
#   'doctor',
#   'over-the-phone',
#   'cream',
#   'afternoon’s',
#   'Rise',
#   'Simpsons',
#   'baby,',
#   'Simpsons',
#   'memories',
#   'romantic',
#   'guy',
#   'Queen’s',
#   'doors',
#   'show',
#   'youth',
#   'way',
#   'driver',
#   'game',
#   'game,',
#   'only',
#   'street',
#   'warmth',
#   'reporter’s',
#   'youth,',
#   'kid',
#   'craic'],
#  'Overdue': ['Catch-Up'],
#  'Catch-Up': ['(2023)'],
#  '(2023)': ['is'],
#  'is': ['a',
#   'an',
#   'important',
#   'my',
#   'really…',
#   'sending',
#   'my',
#   'back',
#   'released,',
#   'scary.',
#   'being',
#   'beating',
#   'insanity.',
#   'a',
#   'a',
#   'when',
#   'a',
#   'a',
#   'the',
#   'why',
#   'it',
#   'back',
#   'a',
#   'why',
#   'maybe',
#   'like',
#   'silent.',
#   'a',
#   'the',
#   'important',
#   'this?!”',
#   'this?”',
#   'a',
#   'way',
#   'called',
#   'how',
#   'pointing',
#   'mentally',
#   'back',
#   'always',
#   'making',
#   'a',
#   'free',
#   'quite,',
#   'gonna',
#   'when',
#   'in',
#   'a',
#   'a',
#   'a',
#   'how',
#   'why…',
#   'why',
#   'that',
#   'in',
#   'also',
#   'gonna',
#   'a',
#   'gonna',
#   'the',
#   'found',
#   'on',
#   'life.',
#   'it.”',
#   'there…',
#   'what',
#   'wholesome',
#   'how',
#   'everything,',
#   'everything,',
#   'this?”',
#   'that?”',
#   'what',
#   'the',
#   'being',
#   'when',
#   'a',
#   'fascinating.',
#   'the',
#   'what',
#   'going',
#   'funny.',
#   'King',
#   'the',
#   'the',
#   'in',
#   'to',
#   'a',
#   'to',
#   'a',
#   'a',
#   'a',
#   'a',
#   'long,',
#   'just',
#   'just',
#   'that',
#   'not',
#   'pretty',
#   'a…',
#   'the',
#   'for'],
#  'a': ['comedy',
#   'tone',
#   'keen',
#   'world',
#   'mirror',
#   'venue.',
#   'bit',
#   'hoodie?',
#   'last…',
#   'final',
#   'laugh.',
#   'laugh.',
#   'tense',
#   'lot',
#   'bit',
#   'chuckle.',
#   'war',
#   'few',
#   'fucking',
#   'special,',
#   'Cork',
#   'special.',
#   'chance,',
#   'while,',
#   'legal',
#   'thousand',
#   'semi.',
#   'lot',
#   'husband.',
#   'husband.',
#   'big',
#   'safari.',
#   'good',
#   'diamond.',
#   'bit',
#   'husband',
#   'father',
#   'husband',
#   'father',
#   'few',
#   'game,',
#   'nonce',
#   'statement.',
#   '36-year-old',
#   'vacancy.”',
#   'time',
#   'decade',
#   'time',
#   'day',
#   'face',
#   'cotton',
#   '’20s',
#   'waste',
#   'house.',
#   'four-four-one',
#   'three-point',
#   'one-way',
#   'successful',
#   'tap-in,',
#   'time',
#   'time',
#   'big',
#   'point',
#   '2021st,',
#   'nicer',
#   'totally',
#   'café.',
#   'smashed',
#   'class.',
#   'class',
#   'middle-class',
#   'block.',
#   'start.',
#   'week',
#   'nice',
#   'nice',
#   'meaningful',
#   'reverse',
#   'new',
#   'kid,',
#   'schoolkid,',
#   'fact.',
#   'fact.',
#   'fact.”',
#   'means',
#   'reputation.',
#   'Bunsen',
#   'supply',
#   'working-class',
#   'length,',
#   'couple',
#   'school…',
#   'time',
#   'bit…',
#   'bit',
#   'couple',
#   'parent,',
#   'bike',
#   'guy',
#   'guy…',
#   'guy',
#   'moving',
#   'world',
#   'request,',
#   'bit',
#   'few',
#   'pop-up',
#   'new',
#   'wee',
#   'wee',
#   'wee',
#   'cycle.”',
#   'file',
#   'montage,',
#   'compilation',
#   'Bluetooth',
#   'coward!',
#   'coward.”',
#   'bit',
#   'fucking',
#   'fucking',
#   'Chinese',
#   'good',
#   'problem.”',
#   'big',
#   'big',
#   'shame',
#   'charity',
#   'big',
#   'portly',
#   'bit',
#   'clutcher',
#   'video',
#   'pass',
#   'bit',
#   'miscarriage',
#   'fat',
#   'crime',
#   'crime.',
#   'parent,',
#   'few',
#   'couple',
#   'savings',
#   'bag',
#   'bit',
#   'bit',
#   'million',
#   'fucking',
#   'letter',
#   'hostile',
#   'bit',
#   'day,',
#   'running',
#   'class',
#   'couple',
#   'program.',
#   'happy',
#   'capitalist',
#   'gulag',
#   'Saturday',
#   'squat',
#   'dark',
#   'painful',
#   'painful',
#   'bit',
#   'kettlebell,',
#   'seated',
#   'bit',
#   'very',
#   'proper…',
#   'scary…',
#   'bit',
#   'doctor',
#   'prescription.',
#   'doctor,',
#   'cream',
#   'cheap',
#   'child,',
#   'baby,',
#   'squiggle',
#   'BLT,',
#   'packet',
#   '180,',
#   'coward!',
#   'wee',
#   'full',
#   'lesson,',
#   'shame,',
#   'sex',
#   'duck',
#   'simple',
#   'wee',
#   'sleep',
#   'sleep.”',
#   'nice',
#   'few',
#   'nickname',
#   'stoner,',
#   'daytime',
#   'haircut,',
#   'think,',
#   'good',
#   'good',
#   'fantastic',
#   'terrific',
#   'fucking',
#   'great',
#   'good',
#   'cat’s',
#   'cat’s',
#   'look,',
#   'week,',
#   'wee',
#   'decentralized',
#   'white',
#   'new',
#   'cat?”',
#   'wee',
#   'wee',
#   'co-dependent',
#   '5K,',
#   'former',
#   'form',
#   'moment',
#   'volatile',
#   'caravan,',
#   'Sunday',
#   'Sunday',
#   'family',
#   'Sunday.',
#   'Sunday',
#   'picture.',
#   'cunt.”',
#   'stranger’s',
#   'cunt?',
#   'cunt.”',
#   'cunt?”',
#   'cunt.',
#   'bit',
#   'picture',
#   'solid',
#   'filter.”',
#   'romantic',
#   'fucking',
#   'real',
#   'day',
#   'school',
#   'wee',
#   'nine-euro',
#   'romantic',
#   'silence',
#   'silence',
#   'bit',
#   'bit',
#   'bit',
#   'fuse',
#   'weekend-defining',
#   'case.',
#   'pain',
#   'photograph',
#   'bit',
#   'hard',
#   'fuck.',
#   'cliff.',
#   'strong',
#   'lot',
#   'number,',
#   'few',
#   'curb',
#   'van',
#   'bit',
#   'time',
#   'similar',
#   'terrifying',
#   'crass',
#   'young',
#   'young',
#   'wee…',
#   'new',
#   'wee',
#   'headlock.',
#   'six-pack.',
#   'laugh',
#   'joke,',
#   'show',
#   'show',
#   'comedian,',
#   'stand-up',
#   'few',
#   'news',
#   'KitKat',
#   'couple',
#   'mark',
#   'laugh.',
#   'dig',
#   'wee',
#   'video',
#   'laugh.',
#   'fucking',
#   'joke.',
#   'video',
#   'Twitter',
#   'check.',
#   'cunt.”',
#   'bit',
#   'bit',
#   'strange',
#   'ten-year-old',
#   'knife',
#   'bottle',
#   'bottle',
#   'packet',
#   'packet',
#   'blender',
#   'wee',
#   'strange',
#   'strange',
#   'bed',
#   'decent',
#   'time',
#   'bit.',
#   'child',
#   'fucking',
#   'dinosaur,',
#   'box',
#   'box',
#   'bit',
#   'bit',
#   'very',
#   'city',
#   'taxi',
#   'comedian.',
#   'savant.',
#   'comedian.',
#   'proud',
#   'progressive',
#   'gender-neutral',
#   'good',
#   'game',
#   'lot',
#   'door,',
#   'reaction',
#   'fucking',
#   'millennial,',
#   'window',
#   'visual',
#   'human',
#   'Tuesday',
#   'while!”',
#   'loose',
#   'door',
#   'snowflake.',
#   'venue!',
#   'city!',
#   'wee',
#   'piss.',
#   'nice',
#   'bit',
#   'lot',
#   'difficult',
#   'fuck!',
#   'serious',
#   'list',
#   'tough',
#   'vest!',
#   'resort',
#   'bit.',
#   'happy',
#   'big',
#   'wee',
#   'pool',
#   'day',
#   'winter',
#   'lot',
#   'kid,',
#   'kid.',
#   'skive',
#   'PlayStation,',
#   'bit',
#   'Scouse',
#   'challenge.',
#   'laugh.',
#   'school',
#   'work',
#   'Friday',
#   'class',
#   'massive',
#   'pleasure',
#   'deep,',
#   'week'],
#  'comedy': ['special', 'shows', 'show'],
#  'special': ['that', 'recording', 'here,', 'that', '“Have'],
#  'that': ['encapsulates',
#   'a',
#   'in',
#   'has',
#   'would',
#   'German',
#   'was',
#   'was',
#   'the',
#   'could',
#   'shit?',
#   'sentence',
#   'we',
#   'shit',
#   'he',
#   'killed',
#   'again.',
#   'you',
#   'my',
#   'class',
#   'carried',
#   'aversion',
#   'can',
#   'is',
#   'could',
#   'situation.',
#   'man',
#   'is',
#   'somewhere.',
#   'badly.”',
#   'prick',
#   'made',
#   'randomly…',
#   'the',
#   'word',
#   'support',
#   'just',
#   'five',
#   'bastard.',
#   'is',
#   'as',
#   'balcony?',
#   'is',
#   'enough',
#   'up',
#   'the',
#   'I',
#   'we',
#   'hemorrhoids,',
#   'is…',
#   'is',
#   'cream,',
#   'anything.',
#   'I',
#   'guy',
#   'maybe',
#   'she',
#   'be',
#   'suit',
#   'anybody',
#   'is,',
#   'would',
#   'easy',
#   'is',
#   'guy',
#   'guy.',
#   'start,',
#   'bitterness',
#   'was',
#   'tache.',
#   'would’ve',
#   'wee',
#   'is',
#   'cat’s',
#   'even',
#   'stuff,',
#   'jogging',
#   'I',
#   'bit',
#   'Mark',
#   'feels',
#   'you',
#   'dopamine',
#   'dopamine',
#   'pace,',
#   'side,',
#   'would’ve',
#   'in',
#   'his',
#   'bit.',
#   'out',
#   'afternoon',
#   'wee',
#   'could',
#   'silence',
#   'you',
#   'you',
#   'I’m',
#   'is,',
#   'is',
#   'in',
#   'decaying',
#   'young',
#   'old',
#   'on',
#   'Capri-Sun',
#   'wedding.',
#   'wee',
#   'I',
#   'cheer',
#   'magnitude,',
#   'stuff',
#   'option.',
#   'she',
#   'was',
#   'Twitter',
#   'liquid?',
#   'they',
#   'was…',
#   'time',
#   'they',
#   'was',
#   'whole',
#   'to',
#   'just',
#   'cunt',
#   'cunt',
#   'cunt!',
#   'a',
#   'the',
#   'would',
#   'man',
#   'he',
#   'man’s',
#   'moment',
#   'shit',
#   'needs',
#   'was',
#   'heat.',
#   'to',
#   'life',
#   'your',
#   'power',
#   'guy',
#   'just',
#   'made',
#   'life',
#   'is',
#   'guy.',
#   'corridor.',
#   'guy.',
#   'I’ve',
#   'turns'],
#  'encapsulates': ['Kevin'],
#  'Bridges’': ['return', 'narrative'],
#  'return': ['to'],
#  'to': ['the',
#   'broader',
#   'connect',
#   'society.',
#   'the',
#   'this',
#   'record',
#   'reply',
#   'everything',
#   'hear',
#   'get',
#   'see',
#   'take',
#   'have',
#   'find',
#   'convince',
#   'send',
#   'assist',
#   'how',
#   'convince',
#   'be,',
#   'call',
#   'normal.',
#   'see',
#   'celebrate',
#   'be',
#   'go',
#   'my',
#   'see',
#   'stand',
#   'apply',
#   'the',
#   'decide',
#   'enter',
#   'be',
#   'break',
#   'your',
#   'your',
#   'perform',
#   'close.',
#   'science.',
#   'say.',
#   'your',
#   'you',
#   'accept',
#   'tears,',
#   'my',
#   'go',
#   'risk',
#   'meet',
#   'have',
#   'meet',
#   'socialize',
#   'be',
#   'eavesdrop.',
#   'his',
#   'be',
#   'the',
#   'forge',
#   'their',
#   'butterfly',
#   'fight.',
#   'fight.',
#   'fight.',
#   'confrontation',
#   'learn',
#   'stand',
#   'have',
#   'my',
#   'ask',
#   'bring',
#   'go',
#   'somebody’s',
#   'ask',
#   'move',
#   'go',
#   'somebody’s',
#   'the',
#   'watch,',
#   'pair',
#   'get',
#   'help,',
#   'look',
#   'weight',
#   'know',
#   'open',
#   'be',
#   'be',
#   'play',
#   'minute',
#   'go',
#   'remember',
#   'control',
#   'get',
#   'stay…',
#   'stay',
#   'try',
#   'keep',
#   'interpret',
#   'your',
#   'my',
#   'my',
#   'confuse',
#   'your',
#   'anybody',
#   'drink',
#   'carry',
#   'say,',
#   'spend',
#   'the',
#   'fill',
#   'my',
#   'be',
#   'the',
#   'follow.',
#   'help',
#   'a',
#   'attend',
#   'the',
#   'lower',
#   'withstand',
#   'Switzerland,',
#   'leave',
#   'drive',
#   'discuss',
#   'get',
#   'rush',
#   'pull',
#   'get',
#   'get',
#   'see',
#   'see',
#   'your',
#   'be',
#   'get',
#   'a',
#   'workshop',
#   'the',
#   'worry',
#   'go',
#   'make',
#   'go',
#   'Boots',
#   'buy',
#   'Boots',
#   'leave',
#   'suffer',
#   'walk',
#   'grow',
#   'manipulate',
#   'the',
#   'see',
#   'put',
#   'know,',
#   'watch.',
#   'these',
#   'conduct.',
#   'the',
#   'the',
#   'be',
#   'bed',
#   'get',
#   'take',
#   'take',
#   'turn',
#   'open',
#   'that.',
#   'me.',
#   'see',
#   'one',
#   'finally',
#   'do.',
#   'watch',
#   'me,',
#   'make',
#   'take',
#   'cut',
#   'run',
#   'learn',
#   'cash',
#   'Instagram.',
#   'my',
#   'get',
#   'rides',
#   'put',
#   'look',
#   'read',
#   'look',
#   'look',
#   'suggest',
#   'accuse',
#   'the',
#   'me',
#   'Darren,',
#   'resist',
#   'confront',
#   'me.',
#   'explain',
#   'take',
#   'my',
#   'the',
#   'come',
#   'go',
#   'die',
#   'comedy',
#   'be',
#   'a',
#   'be.',
#   'the',
#   'such',
#   'have',
#   'sit',
#   'be',
#   'university',
#   'be',
#   'keep',
#   'Owen’s',
#   'embrace',
#   'be',
#   'the',
#   'hear',
#   'tell',
#   'be',
#   'people’s',
#   'his',
#   'greet',
#   'a',
#   'get',
#   'have',
#   'come',
#   'reception',
#   'go',
#   'my',
#   'hunt',
#   'show',
#   'her',
#   'hide',
#   'go',
#   'walk',
#   'tears',
#   'my',
#   'see',
#   'defend',
#   'really',
#   'have…',
#   'spread',
#   'ditch',
#   'switch',
#   'Fallujah',
#   'you',
#   'Scotland',
#   'realize.',
#   'realize',
#   'grow',
#   'Friday,',
#   'them.',
#   'quit',
#   'ask',
#   'school,',
#   'slit',
#   'Ladbrokes.',
#   'the',
#   'my',
#   'know',
#   'know',
#   'see',
#   'my',
#   '15,',
#   'selling',
#   'prove',
#   'reflect',
#   'your'],
#  'the': ['stage,',
#   'backdrop',
#   'Cork',
#   'audience’s',
#   'trivialities',
#   'absurdity',
#   'quirks',
#   'evolving',
#   'complexities',
#   'human',
#   'stage',
#   'amazing',
#   'stunning',
#   'cinema,',
#   'opera',
#   'telly.',
#   'spring/',
#   'fuck',
#   'telly.',
#   'telly.',
#   'question.',
#   'fucking',
#   'news',
#   'rest',
#   'NATO',
#   'fight',
#   'first',
#   'Second',
#   'fear!',
#   'Americans',
#   'jargon',
#   'war',
#   'new',
#   'world',
#   'telly.',
#   'time…',
#   'time',
#   'turn',
#   'century.',
#   'bed',
#   'same',
#   'man',
#   'question?”',
#   'years',
#   'old…',
#   'old',
#   'local',
#   'first',
#   'day',
#   'street',
#   'can,',
#   'young',
#   'window',
#   'front',
#   'game,',
#   'fatherhood',
#   'Dwight',
#   'world.',
#   'fucking',
#   '’80s',
#   '’80s,',
#   '’80s',
#   'mirror',
#   'student',
#   'UK,',
#   'House',
#   'whole',
#   'midst',
#   'family',
#   'whole',
#   'decks,',
#   'rest',
#   'big',
#   'end.',
#   'whole',
#   'scientists',
#   'cathedral!',
#   'synagogue!”',
#   'past…',
#   'past',
#   'city',
#   'upper',
#   'upper',
#   'table',
#   'see-saw.',
#   'living',
#   'people',
#   'years',
#   'upper',
#   'best',
#   'best',
#   'best',
#   'school',
#   'best',
#   'best',
#   'best',
#   'conclusion,',
#   'three',
#   'person',
#   'upper',
#   'bike',
#   'door',
#   'upstairs',
#   'esthetic',
#   'communal',
#   'fucking',
#   'Christmas',
#   'esthetic',
#   'communal',
#   'guy.',
#   'bike',
#   'door.',
#   'stairs,',
#   'door,',
#   'door’s',
#   'voices',
#   'voices',
#   'bike',
#   'way',
#   'front,',
#   'kind',
#   'handlebars,',
#   'basket',
#   'psychology',
#   'fucking',
#   'minute',
#   'Bluetooth',
#   'music!',
#   'Celtic!',
#   'Celtic.”',
#   'name',
#   'north.',
#   'north,',
#   'north',
#   'north',
#   'Google',
#   'biscuit',
#   'fucking',
#   'Shankill',
#   'price…',
#   'fuck',
#   'body',
#   'window,',
#   'wrong',
#   'telly.',
#   'ITV',
#   'rest',
#   'world',
#   'rest',
#   'world.',
#   'manager,',
#   'pitch,',
#   'telly,',
#   'pitch',
#   'dugout,',
#   'subs',
#   'clock,',
#   'stairs,',
#   'advertising',
#   'tank,',
#   'pitch',
#   'pitch,',
#   'Twitter',
#   'vile',
#   'Benny',
#   'end.',
#   'gym.',
#   'fuck',
#   'special',
#   'white',
#   'youth.',
#   'fucking',
#   'way',
#   'young…',
#   'generation,',
#   'youth,',
#   'gym',
#   'gym',
#   'Instagram',
#   'protein',
#   'steroids,',
#   'Octagon',
#   'one',
#   'nearest',
#   'gym.',
#   'treadmill',
#   'end,',
#   'gym.',
#   'kids',
#   'class.',
#   'circuits',
#   'products',
#   'squat,',
#   'Instagram,',
#   'squat,',
#   'squat',
#   'human',
#   'most',
#   'male',
#   'fuck',
#   'class',
#   'gym.',
#   'pain',
#   'poster',
#   'stairs',
#   'mirror.',
#   'fuck',
#   'torch',
#   'bathroom',
#   'mirror…',
#   'fuck',
#   'bit.',
#   'time.',
#   'fuck',
#   'doctor.',
#   'fucking',
#   'doctor.',
#   'over-the-',
#   'mirror.',
#   'fuck',
#   'phone?',
#   'story,',
#   'doctor',
#   'name',
#   'cream.',
#   'name',
#   'expense',
#   'Boots',
#   'Anusol',
#   'counter.”',
#   'hope',
#   'N.',
#   'word',
#   'pronunciation.',
#   'planets?',
#   'one.',
#   'aisle',
#   'darkest',
#   'shelf',
#   'Boots',
#   'Boots',
#   'Boots',
#   'game.',
#   'gym',
#   'squats',
#   'high',
#   'high',
#   'foods',
#   'Atkins',
#   'park,',
#   'pond',
#   'ducks,',
#   'whole',
#   'whole',
#   'telly,',
#   'evenings',
#   'telly,',
#   'cockpit.',
#   'edge',
#   'corner.',
#   'charger.',
#   'telly.',
#   'sign',
#   'sign',
#   'back',
#   'History',
#   'morning.',
#   'picture',
#   'fuck',
#   'day.',
#   'day.',
#   'Jews’',
#   'birds.”',
#   'end',
#   'whole',
#   'telly,',
#   'minute',
#   'day,',
#   'corner,',
#   'answer,',
#   'bed',
#   'night.',
#   'staff,',
#   'morning,',
#   'night',
#   'Kinder',
#   'euro',
#   'size',
#   'phones.',
#   'same.',
#   'phones.',
#   'mental',
#   'two',
#   'socials',
#   'dopamine,',
#   'likes.',
#   'social',
#   'like.',
#   'snide',
#   'like,',
#   'comments',
#   'replies.',
#   'telly.',
#   'selfie.',
#   'dog,',
#   'wife,',
#   'Sunday,',
#   'family',
#   'high-stakes',
#   'likes',
#   'comments,',
#   'dopamine',
#   'dealer',
#   'moment.',
#   'fuck',
#   'bed.',
#   'fun',
#   'point',
#   'fuck',
#   'same.',
#   'pictures',
#   'picture.',
#   'harsh',
#   'time.',
#   'first',
#   'other',
#   'one',
#   'hearing,',
#   'hotel,',
#   'breakfast',
#   'promenade,',
#   'guy',
#   'Segway',
#   'guy',
#   'Segway',
#   'Hugo?',
#   'names.',
#   'youth.',
#   'only',
#   'aging',
#   'momentum',
#   'deck.',
#   'deck',
#   'wanker',
#   'wa-hey!',
#   'first',
#   'shape',
#   'cross,',
#   'bread',
#   'story.',
#   'evening',
#   'Queen’s',
#   'story…',
#   'world,',
#   'editor',
#   'interests',
#   'evening',
#   'Queen’s',
#   'show',
#   'show,',
#   'show',
#   'price',
#   'show',
#   'situation',
#   'hardworking',
#   'doors',
#   'UK',
#   'energy',
#   'time,',
#   'only',
#   'coming',
#   'new',
#   'show',
#   'problem',
#   'corridor',
#   'VAR',
#   'night',
#   'jokes',
#   'world.',
#   'blame',
#   'times,',
#   'youth',
#   'big',
#   'vaping.',
#   'fuck',
#   'telly,',
#   'wee',
#   'forsaken',
#   'kids',
#   'jackpot',
#   'telly.',
#   'past',
#   'telly.',
#   'new',
#   'generations',
#   'constant',
#   'process',
#   'old',
#   'better',
#   'front',
#   'school',
#   'late',
#   'courage',
#   'taxi',
#   'conversation',
#   'subject',
#   'driver…',
#   'Brit',
#   'Brit',
#   'generation',
#   'youth',
#   'older',
#   'original',
#   'game',
#   'premise',
#   'game,',
#   'evening,',
#   'game',
#   'door',
#   'knowledge',
#   'man,',
#   'man',
#   'house,',
#   'knock',
#   'telly,',
#   'door',
#   'door,',
#   'door.',
#   'couch',
#   'basement',
#   'face',
#   'phone',
#   'door',
#   'night.”',
#   'snowflakes!',
#   'real',
#   'older',
#   'wrong',
#   'one',
#   'young',
#   'planet',
#   'United',
#   'planet',
#   'fuck',
#   'planet’s',
#   'benefits',
#   'world,',
#   'news',
#   'studio.”',
#   'youth.',
#   'end,',
#   'day,',
#   'hours',
#   'PlayStation',
#   'speakers,',
#   'telly.',
#   'game',
#   'game,',
#   'longer',
#   'more',
#   'abuse',
#   'bookie’s',
#   'fruit',
#   'main',
#   'corridor.',
#   'corridor',
#   'stuff',
#   'man',
#   'problem',
#   'show',
#   'first',
#   'pursuit',
#   'privacy',
#   'Loft.',
#   'best'],
#  'stage,': ['set'],
#  'set': ['against', 'up'],
#  'against': ['the', 'Russia', 'Yankee', 'England,', 'the'],
#  'backdrop': ['of'],
#  'of': ['the',
#   'intimacy',
#   'modern',
#   'social',
#   'domestic',
#   'generational',
#   'life',
#   'Cork.',
#   'all,',
#   'debate,',
#   'shit.',
#   'time',
#   'the',
#   'Tayto.',
#   'the',
#   'haggling',
#   'my',
#   'them’s',
#   'dad',
#   'a',
#   'Commons',
#   'the',
#   'fame',
#   'the',
#   'black',
#   'worship',
#   'taste',
#   'my',
#   'you',
#   'the',
#   'Glasgow.',
#   'this,',
#   'our',
#   'a',
#   'playground',
#   'currency:',
#   'youse!”',
#   'fights',
#   'bullying,',
#   'times,',
#   'fights.”',
#   'my',
#   'convenience.',
#   'the',
#   'backup',
#   'my',
#   'bike',
#   'men,',
#   'your',
#   'weight',
#   'Ireland',
#   'Cork?',
#   'this',
#   'the',
#   'the',
#   '70,000,',
#   'me',
#   'weight,',
#   'justice',
#   'their',
#   'stone',
#   'spice',
#   'a',
#   'young',
#   'physical',
#   'water',
#   'them',
#   'in',
#   'Bulgarian',
#   'Russian',
#   'Romanian',
#   'this',
#   'brutal',
#   'you',
#   'weight',
#   'weight',
#   'orifices',
#   'Covid',
#   'descriptive',
#   'the',
#   'people’s',
#   'all,',
#   'days,',
#   'tangy',
#   'my',
#   'Cork.',
#   'the',
#   'research',
#   'me,',
#   'Adolf',
#   'self-assurance.',
#   'hundreds',
#   'thousands,',
#   'him.',
#   'me,',
#   'it,',
#   'bed,',
#   'bed!”',
#   'the',
#   'the',
#   'that',
#   'your',
#   'gambling.”',
#   'genuine',
#   'that',
#   'my',
#   'this?”',
#   'some',
#   'a',
#   'being',
#   'advice,',
#   'being',
#   'evidence.',
#   'your',
#   'originality',
#   'workmen',
#   'them',
#   'daydream,',
#   'his.',
#   'the',
#   'the',
#   'Anglo-Irish',
#   'the',
#   'that',
#   'a',
#   'jokes',
#   'respect',
#   'the',
#   'state',
#   'me',
#   'good',
#   'you',
#   'his',
#   'juice.',
#   'Marlboro',
#   'Haribo',
#   'puffs.”',
#   'Prime,',
#   'today',
#   'our',
#   'every',
#   'them',
#   'telling',
#   'moving',
#   'my',
#   'nostalgia',
#   'me.',
#   'one',
#   'the',
#   'self-acceptance.',
#   'Sam',
#   'this',
#   'you',
#   'the',
#   'you',
#   'your',
#   'the',
#   'us',
#   'my',
#   'such',
#   'kids',
#   'yourselves.',
#   'hope',
#   'immediate',
#   'climate',
#   'kids',
#   'a',
#   'Cork,',
#   'applause',
#   'you',
#   'yourselves!',
#   'societal',
#   'sexuality'],
#  'Cork': ['Opera', 'Opera', 'audience,'],
#  'Opera': ['House.', 'House.'],
#  'House.': ['He', 'What'],
#  'He': ['opens',
#   'touches',
#   'was',
#   'does',
#   'literally',
#   'killed',
#   'was',
#   'was',
#   'never',
#   'takes',
#   'could',
#   'was',
#   'would',
#   'passed'],
#  'opens': ['with'],
#  'with': ['gratitude',
#   'humor,',
#   'wider',
#   'a',
#   'the',
#   '24',
#   'my',
#   'Gavin.”',
#   'the',
#   'which',
#   'violence.',
#   'such',
#   'prick,',
#   'wireless',
#   'the',
#   'the',
#   'their',
#   'one',
#   'the',
#   'the',
#   'air',
#   'these',
#   'you,',
#   'social',
#   'dopamine',
#   'a',
#   'this',
#   'your',
#   'the',
#   'this',
#   'Twitter',
#   'the',
#   'their',
#   'these',
#   'the',
#   'your',
#   'personal'],
#  'gratitude': ['for'],
#  'for': ['the',
#   'coming',
#   'the',
#   'coming',
#   'a',
#   'a',
#   'it.',
#   'a',
#   'them,',
#   'me.',
#   'almost',
#   'the',
#   'such',
#   'those',
#   'the',
#   'the',
#   'a',
#   'a',
#   'me',
#   'dinner.',
#   'any',
#   'dinner.”',
#   'your',
#   'their',
#   'a',
#   'your',
#   'yourself',
#   'physical',
#   'myself',
#   'your',
#   'a',
#   'you,',
#   'guys',
#   'the',
#   'that',
#   'somebody',
#   'a',
#   'later',
#   'whatever',
#   'fuck’s',
#   'somebody',
#   'a',
#   'five',
#   'your',
#   'rectal',
#   'himself.',
#   'that',
#   'a',
#   'my',
#   'my',
#   'example.',
#   'a',
#   'the',
#   'ages,',
#   'five',
#   'maybe',
#   'a',
#   'as',
#   'the',
#   'any',
#   'emergency',
#   'the',
#   'the',
#   'a',
#   'a',
#   'an',
#   'a',
#   'stand-up',
#   'these',
#   'being',
#   'a',
#   'a',
#   'a',
#   'how',
#   'those',
#   'his',
#   'his',
#   'as',
#   'context,',
#   'somebody?',
#   'the',
#   'us?”',
#   'everybody',
#   'knocking',
#   'listening!',
#   'any…',
#   'anybody',
#   'the',
#   'that.',
#   'the',
#   'example.',
#   'a',
#   'my',
#   'my',
#   'listening.'],
#  'audience’s': ['presence,'],
#  'presence,': ['setting'],
#  'setting': ['a'],
#  'tone': ['of'],
#  'intimacy': ['and'],
#  'and': ['shared',
#   'societal',
#   'sharp',
#   'the',
#   'the',
#   'deeper',
#   'a',
#   'gentlemen,',
#   'intimate,',
#   'then',
#   'then',
#   'Germany',
#   'his',
#   'cringe',
#   'house',
#   'now',
#   'then',
#   'a',
#   'I’m',
#   'it',
#   'it',
#   'I',
#   'there',
#   'I',
#   'I',
#   'laugh',
#   'we',
#   'I',
#   'I’ll',
#   'I’ll',
#   'no',
#   'them,',
#   'May',
#   'Covid,',
#   'changes',
#   'smell?',
#   'I’ve',
#   'I’m',
#   'my',
#   'this',
#   'I',
#   'I',
#   'I',
#   'leathered',
#   'New',
#   'I',
#   'then',
#   'it’s',
#   'my',
#   'the',
#   'stick',
#   'broadband',
#   'frustrated,',
#   'clicking.',
#   'they',
#   'back',
#   'it’s',
#   'then',
#   'celebrated',
#   'it’s',
#   'it',
#   'celebrities,',
#   'I',
#   'I',
#   'tells',
#   'start',
#   'then',
#   'then',
#   'the',
#   'then',
#   'it',
#   'upon',
#   'work',
#   'mental',
#   'I',
#   'then',
#   'I',
#   'degrading',
#   'humiliating',
#   'then',
#   'it',
#   'mental',
#   'adding',
#   'a',
#   'then',
#   'basically,',
#   'inspect',
#   'turn',
#   'just',
#   'too',
#   'it',
#   'the',
#   'buy',
#   'it',
#   'as',
#   'on',
#   'ask',
#   'I',
#   'expect',
#   'defend',
#   'start',
#   'she',
#   'then',
#   'exposed',
#   'my',
#   'my',
#   'all',
#   'seen',
#   'it’s',
#   'eventually',
#   'I',
#   'I',
#   'it’s',
#   'go',
#   'Fall',
#   'blue',
#   'that',
#   'you,',
#   'I’m',
#   'I’m',
#   'you.',
#   'you',
#   'cryptocurrencies',
#   'all',
#   'I',
#   'I',
#   'endorphins',
#   'serotonin,',
#   'your',
#   'your',
#   'post',
#   'every',
#   'fulfillment,',
#   'I’m',
#   'the',
#   'then',
#   'she',
#   'she',
#   'jumped',
#   'the',
#   'all',
#   'I',
#   'I',
#   'there’s',
#   'it',
#   'make',
#   'convince…',
#   'wife',
#   'I’m',
#   'then',
#   'your',
#   'you’re',
#   'combust',
#   'your',
#   'send',
#   'I',
#   '18',
#   'I',
#   'I',
#   'I',
#   'there',
#   'one',
#   'I',
#   'you',
#   'move',
#   'kicking',
#   'I',
#   'you',
#   'as',
#   'don’t',
#   'make',
#   'then',
#   'babysitters',
#   'hotels',
#   'all',
#   'their',
#   'funny.',
#   'uploaded',
#   'that’s',
#   'put',
#   'then',
#   'everybody’s',
#   'then',
#   'they',
#   'move',
#   'a',
#   'get',
#   'take',
#   'their',
#   'they’re',
#   'if',
#   'we',
#   'tourism,',
#   'keep…',
#   'stay',
#   'stay…',
#   'understand',
#   'all',
#   'stay',
#   'we',
#   'a',
#   'on',
#   'your',
#   'your',
#   'your',
#   'progressive',
#   'the',
#   'he',
#   'the',
#   'I',
#   'the',
#   'into',
#   'then',
#   'would',
#   'you',
#   'you',
#   'run',
#   'your',
#   'laughing,',
#   'that',
#   'your',
#   'ran',
#   'hopefully',
#   'I’d',
#   'greet',
#   'ran',
#   'start',
#   'running',
#   'say',
#   'gentlemen,',
#   'it’s',
#   'stuff',
#   'maybe',
#   'it’s',
#   'Shiites.”',
#   'Northern',
#   'Protestants',
#   'they’re',
#   'nervous,',
#   'I’m',
#   'then',
#   'you',
#   'downplay',
#   'that’s',
#   'everybody',
#   'that’s',
#   'gentlemen',
#   'my',
#   'we',
#   'I',
#   'recording',
#   'it’s',
#   'self-discovery,',
#   'gender',
#   'self-discovery,',
#   'relationships,',
#   'whimsy',
#   'truths'],
#  'shared': ['excitement.'],
#  'excitement.': ['Bridges’'],
#  'narrative': ['weaves'],
#  'weaves': ['through'],
#  'through': ['personal',
#   'a',
#   'it.',
#   'it.',
#   'my',
#   'being',
#   'my',
#   'your',
#   'all',
#   'the'],
#  'personal': ['anecdotes,', 'experiences', 'anecdotes'],
#  'anecdotes,': ['observations'],
#  'observations': ['on', 'with'],
#  'on': ['everyday',
#   'themes',
#   'the',
#   'this',
#   'camera!',
#   'the',
#   'my',
#   'that',
#   'the',
#   'daytime',
#   'these',
#   'a',
#   'a',
#   'his',
#   'my',
#   'everywhere.',
#   'the',
#   'the',
#   'the',
#   'their',
#   'these',
#   'with',
#   'mates',
#   'Sunday,',
#   'my',
#   'my',
#   'the',
#   'the',
#   'a',
#   'Christmas',
#   'again?”',
#   'the',
#   'the',
#   'here?',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'this',
#   'the',
#   'national',
#   'getting',
#   'the',
#   'the',
#   'a',
#   'until,',
#   'one',
#   'just',
#   'your',
#   'the',
#   'my',
#   'over.',
#   'our',
#   'this,',
#   'the',
#   'and',
#   'demand.',
#   'these',
#   'the',
#   'the',
#   'at',
#   'inside',
#   'his',
#   'his',
#   'Instagram',
#   'down!',
#   'out',
#   'out',
#   'holiday',
#   'the',
#   'social',
#   'the',
#   'the',
#   'a',
#   'the',
#   'that',
#   'there,',
#   'a',
#   'his',
#   'Instagram',
#   'my',
#   'a',
#   'that',
#   'a',
#   'as',
#   'the',
#   'the',
#   'video,',
#   'the',
#   'Instagram',
#   'the',
#   'the',
#   'as',
#   'in',
#   'Twitter.',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'that',
#   'my',
#   'the',
#   'a',
#   'the',
#   'the',
#   'the',
#   'the',
#   'my',
#   'a',
#   'a',
#   'too',
#   'and',
#   'a',
#   'running',
#   'Your',
#   'human'],
#  'everyday': ['life,'],
#  'life,': ['and', 'to', 'innit?', 'I’ve', 'dating,', 'politics,'],
#  'societal': ['commentary,', 'issues,', 'perfection.'],
#  'commentary,': ['marked'],
#  'marked': ['by', '*'],
#  'by': ['his', 'Faithless', 'segwaying', '2050.”', 'kids', 'Jacqueline'],
#  'his': ['signature',
#   'comedic',
#   'wee',
#   'pals',
#   'bedroom',
#   'armpit,',
#   'chin,',
#   'own',
#   'dad',
#   'school.',
#   'mates',
#   'words,',
#   'door,',
#   'bike.',
#   'shoulders.',
#   'voice,',
#   'sparkling',
#   'shoulder',
#   'nap',
#   'pictures,',
#   'dog?',
#   'sandals',
#   'feet.',
#   'energy',
#   'door,',
#   'property',
#   'evening,',
#   'tea,',
#   'door.',
#   'property.',
#   'door.',
#   'throat',
#   'regime'],
#  'signature': ['wit'],
#  'wit': ['and'],
#  'sharp': ['insight.'],
#  'insight.': ['He'],
#  'touches': ['on'],
#  'themes': ['ranging', 'demonstrates'],
#  'ranging': ['from'],
#  'from': ['the',
#   'being',
#   'three',
#   'Covid!”',
#   'me.',
#   'tight',
#   'baby',
#   'what',
#   'a',
#   'a',
#   'their',
#   'my',
#   'the',
#   'the',
#   'PE',
#   'a',
#   'piles',
#   'your',
#   'art',
#   'a',
#   'nowhere.',
#   'the',
#   'under',
#   'us!',
#   'the',
#   'school.',
#   'school,',
#   'that',
#   'a',
#   'this',
#   'the'],
#  'trivialities': ['of'],
#  'modern': ['living,', 'world', 'life,'],
#  'living,': ['such'],
#  'such': ['as',
#   'handsome',
#   'a',
#   'a',
#   'a',
#   'pressure.',
#   'a',
#   'lengthy',
#   'a',
#   'blatant'],
#  'as': ['the',
#   'both',
#   'well.',
#   'to',
#   'one',
#   'convincing',
#   'well',
#   'I',
#   'soon',
#   'that',
#   'well,',
#   'well,',
#   'humble,',
#   'though',
#   'the',
#   'well.',
#   'in',
#   'I',
#   'soon',
#   'I',
#   'a',
#   'if',
#   'much,',
#   'long',
#   '“Insomnia”',
#   'the',
#   'niche',
#   'esoteric',
#   'their',
#   'I’m',
#   'she',
#   'a',
#   'she',
#   'soon',
#   'I',
#   'he',
#   'I',
#   'soon',
#   'it’s',
#   'well,',
#   'quite',
#   'new,',
#   'I',
#   'I',
#   'a',
#   'adults,',
#   'evidence…',
#   'we',
#   'long',
#   'people',
#   'a',
#   'a',
#   'normal.',
#   'a',
#   'the',
#   'long',
#   'he',
#   'a',
#   'I',
#   'always'],
#  'absurdity': ['of'],
#  'social': ['media', 'themes', 'event,', 'media.', 'media.', 'media', 'media'],
#  'media': ['and', 'is.', 'currency,'],
#  'quirks': ['of'],
#  'domestic': ['life,'],
#  'broader': ['societal'],
#  'issues,': ['including'],
#  'including': ['politics,'],
#  'politics,': ['climate', 'and'],
#  'climate': ['change,', 'change', 'change.'],
#  'change,': ['and'],
#  'evolving': ['dynamics'],
#  'dynamics': ['of'],
#  'generational': ['attitudes.'],
#  'attitudes.': ['Throughout,'],
#  'Throughout,': ['Bridges'],
#  'Bridges': ['navigates'],
#  'navigates': ['the'],
#  'complexities': ['of'],
#  'life': ['with', 'lessons', 'as', 'presents', 'is', 'is'],
#  'humor,': ['offering'],
#  'offering': ['both'],
#  'both': ['light-hearted', 'an', 'look'],
#  'light-hearted': ['amusement'],
#  'amusement': ['and'],
#  'deeper': ['reflections', 'and'],
#  'reflections': ['on'],
#  'human': ['condition.',
#   'history.',
#   'history.',
#   'sphincter…',
#   'interaction',
#   'absurdities'],
#  'condition.': ['His'],
#  'His': ['ability', 'mental', 'dog’s'],
#  'ability': ['to'],
#  'connect': ['personal'],
#  'experiences': ['with'],
#  'wider': ['social'],
#  'demonstrates': ['not'],
#  'not': ['only',
#   'actually',
#   'quite',
#   'suit',
#   'really',
#   'particularly',
#   'come',
#   'recognized.”',
#   'about',
#   'a',
#   'the',
#   'hear',
#   'see',
#   'responding.',
#   'about',
#   'gonna',
#   'about',
#   'be'],
#  'only': ['his',
#   'three',
#   'heard',
#   'women',
#   'when',
#   '13',
#   'pile',
#   'half',
#   'accurate',
#   'old',
#   'thing',
#   'imagine',
#   'imagine',
#   'Scottish.',
#   'Irish.',
#   'Monday'],
#  'comedic': ['talent', 'exploration'],
#  'talent': ['but'],
#  'but': ['also',
#   'there’s',
#   'a',
#   'it’s',
#   'I',
#   'I’m',
#   'because',
#   'they',
#   'was',
#   'you',
#   'there’s',
#   'it',
#   'I',
#   'you',
#   'you',
#   'Zuckerberg',
#   'I',
#   'at',
#   'you',
#   'it’s',
#   'a',
#   'I',
#   'I',
#   'I’m',
#   'we’re',
#   'I',
#   'then,',
#   'at',
#   'that’s',
#   'my'],
#  'also': ['a', 'there,', 'aware'],
#  'keen': ['observational'],
#  'observational': ['acuity,'],
#  'acuity,': ['inviting'],
#  'inviting': ['audiences'],
#  'audiences': ['into'],
#  'into': ['a',
#   'each',
#   'his',
#   'how',
#   'a',
#   'my',
#   'this',
#   'a',
#   'my',
#   'one',
#   'a',
#   'a',
#   'wine,',
#   'a',
#   'medical',
#   'an',
#   'your',
#   'a'],
#  'world': ['where', 'is', 'tour,', 'closed.', 'where', 'against', 'if', 'had'],
#  'where': ['laughter',
#   'were',
#   'I',
#   'only',
#   'organized',
#   'a',
#   'he',
#   'I',
#   'my',
#   'the',
#   'you’d',
#   'we',
#   'we'],
#  'laughter': ['serves', 'and'],
#  'serves': ['as'],
#  'an': ['escape',
#   'honor.',
#   'angle,',
#   'ex-alcoholic,',
#   'age',
#   'old-school',
#   'inquiry',
#   'octopus',
#   'area',
#   'F1',
#   'example,',
#   'apartment,',
#   'issue,',
#   'update',
#   'accent,',
#   'hour',
#   'intense',
#   'Only',
#   'image',
#   'asset',
#   'Irish',
#   'old',
#   'evening',
#   'adult',
#   'accurate',
#   'empowering,',
#   'unplanned',
#   'audience!',
#   'amazing',
#   'individual.”',
#   'emotional'],
#  'escape': ['and'],
#  'mirror': ['to', 'with'],
#  'society.': ['*'],
#  '*': ['*', '*', 'Ladies', 'Name*'],
#  'Ladies': ['and', 'and'],
#  'gentlemen,': ['please', 'what'],
#  'please': ['welcome'],
#  'welcome': ['to'],
#  'stage': ['the', 'in'],
#  'amazing': ['Kevin', 'and', '15-year-old.'],
#  'Bridges!': ['Thank', 'Thanks'],
#  'Thank': ['you.',
#   'you!',
#   'you.',
#   'you.',
#   'you,',
#   'you.',
#   'you,',
#   'you.',
#   'you.',
#   'you.',
#   'you.',
#   'you.',
#   'you!',
#   'you!',
#   'you',
#   'you,',
#   'you!'],
#  'you.': ['Thank',
#   'Wow.',
#   'Thank',
#   'Yes!',
#   'You',
#   'I',
#   'You’ll',
#   'I',
#   'Good',
#   'We’ve',
#   'My',
#   'Bread’s',
#   '‘How',
#   'That’s…',
#   'That’s'],
#  'you!': ['Thank', 'Goodnight!', 'Thank', 'The'],
#  'Wow.': ['Good', 'Just', 'Too', 'He', 'It’s', 'I'],
#  'Good': ['evening!',
#   'evening.',
#   'evening,',
#   'man.',
#   'man.',
#   'man.',
#   'people.',
#   'man.'],
#  'evening!': ['Good'],
#  'evening.': ['Good', 'There’s'],
#  'evening,': ['Cork!', 'he', 'you’d', 'whatever'],
#  'Cork!': ['Thank'],
#  'you,': ['people',
#   'good',
#   '“My',
#   'Cillian.',
#   'mate?',
#   'bro!”',
#   'Kev,',
#   'Kev.',
#   'Kev.',
#   'Owen?',
#   'sir,',
#   'genuinely.',
#   'people,'],
#  'people': ['of',
#   'on',
#   'coming',
#   'from',
#   'who',
#   'are',
#   'from',
#   'to',
#   'of',
#   'have',
#   'have',
#   'there’s',
#   'has',
#   'has',
#   'has',
#   'have…’',
#   'there’s',
#   'in,',
#   'laugh',
#   'in',
#   'get',
#   'are',
#   'who',
#   'who',
#   'are',
#   'are',
#   'up',
#   'and',
#   'used',
#   'just',
#   'just'],
#  'Cork.': ['Thank', 'I', 'That’s'],
#  'Yes!': ['This'],
#  'This': ['is…',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'new',
#   'could',
#   'is',
#   'is…',
#   'is',
#   'is',
#   'is',
#   'might',
#   'was',
#   'has',
#   'has',
#   'is'],
#  'is…': ['This', 'I', 'it’s', 'That’s', 'I', 'I', 'that', 'That', 'This'],
#  'honor.': ['Thank'],
#  'good': ['people,',
#   'to',
#   'to',
#   'deal',
#   'at',
#   'at',
#   'business',
#   'for',
#   'until',
#   'question.',
#   'question.',
#   'one',
#   'and',
#   'for',
#   'that',
#   'points.',
#   'vantage',
#   'in',
#   'at',
#   'at'],
#  'people,': ['first', 'I', 'because', 'so', 'they', 'with', 'yes!', 'and'],
#  'first': ['of',
#   'time',
#   'special.',
#   'show,',
#   'one',
#   'time.',
#   'see',
#   'one',
#   'time.',
#   'special',
#   'gig'],
#  'all,': ['for', 'Kevin,'],
#  'coming': ['out', 'out', 'for', 'next.', 'on', 'back', 'months.', 'for'],
#  'out': ['to',
#   'for',
#   'for',
#   'my',
#   'playing?”',
#   'of',
#   'of',
#   'and',
#   'it’s',
#   'exercises',
#   'bread.',
#   'the',
#   'of',
#   'of',
#   'of',
#   'for',
#   'of',
#   'just',
#   'in',
#   'all',
#   'of',
#   'of',
#   'there',
#   'playing?”',
#   'places'],
#  'this': ['very',
#   'tour,',
#   'earth?',
#   'front',
#   'guy.',
#   'year,',
#   'is',
#   'is…',
#   'madness',
#   'time!',
#   'is',
#   'was',
#   'city',
#   'country?',
#   'pitch.”',
#   'jog',
#   'is',
#   'is',
#   'afternoon?”',
#   'was',
#   'in',
#   'life.',
#   'Boots',
#   'hectic,',
#   'shit',
#   'is',
#   'is',
#   'stunning',
#   'part',
#   'person.',
#   'evening.',
#   'time',
#   'has',
#   'is',
#   'taxi',
#   'guy,',
#   'guy.',
#   'evening?',
#   'is',
#   'year,',
#   'is'],
#  'very': ['special',
#   'confrontational',
#   'specific',
#   'common',
#   'subtle.',
#   'much!'],
#  'recording': ['here', 'specials,'],
#  'here': ['in',
#   'at',
#   'trying',
#   'in',
#   'have',
#   'to',
#   'in',
#   'to',
#   'for',
#   'waiting.',
#   'for',
#   'for',
#   'for',
#   'between'],
#  'in': ['the',
#   'the',
#   'the',
#   'this…?',
#   'the',
#   'that,',
#   'to',
#   'the',
#   'Europe',
#   'a',
#   'the',
#   'my',
#   'Cork,',
#   'anybody’s',
#   'Africa.',
#   'being',
#   'my',
#   'the',
#   'the',
#   'there,',
#   'there…',
#   'there.',
#   '2021.',
#   'the',
#   'the',
#   'there.',
#   'the',
#   'supermarkets',
#   'China,',
#   'human',
#   'an',
#   'a',
#   'there,',
#   'a',
#   'here',
#   'that',
#   'the',
#   'his',
#   'the',
#   'a',
#   'a',
#   'moderation,',
#   'an',
#   'his',
#   'the',
#   'a',
#   'the',
#   'that',
#   'there…',
#   'there',
#   'the',
#   'there.',
#   'there.',
#   'there.',
#   'front',
#   '2019',
#   'connection',
#   'Cork?',
#   'the',
#   'on',
#   'the',
#   'the',
#   'fucking',
#   'a',
#   'front',
#   'the',
#   'training.”',
#   'the',
#   'fast-forward',
#   'shape.',
#   'a',
#   'life.',
#   'the',
#   'for',
#   'with',
#   'the',
#   'recently,',
#   'the',
#   'the',
#   'my',
#   'a',
#   'a',
#   'a',
#   'the',
#   'the',
#   'shape.',
#   'this',
#   'silence.',
#   'the',
#   'case',
#   'and',
#   'the',
#   'the',
#   'silence.”',
#   'Boots,',
#   'the',
#   'dialogue',
#   'the',
#   'this',
#   'the',
#   'there.',
#   'the',
#   'front',
#   'front',
#   'the',
#   'the',
#   'the',
#   'Turkish?’',
#   'Turkey?',
#   'the',
#   'a',
#   'the',
#   'bed',
#   'bed,',
#   'and',
#   'and',
#   'there,',
#   'one',
#   'front',
#   'there',
#   'the',
#   'public.',
#   'such',
#   'mind.',
#   'that…',
#   'senior',
#   'school.',
#   'a',
#   'Mass',
#   'that',
#   'my',
#   'Glasgow',
#   'this',
#   'the',
#   'there',
#   'a',
#   'the',
#   'my',
#   'trouble.',
#   'the',
#   'the',
#   'a',
#   'here',
#   'the',
#   'my',
#   'Glasgow',
#   'the',
#   '2023,',
#   'a',
#   'Glasgow',
#   'Glasgow',
#   'Glasgow,',
#   'disgust!',
#   'a',
#   'Glasgow,',
#   'the',
#   'the',
#   'that',
#   '2023?',
#   'the',
#   'the',
#   'exile,',
#   'bin',
#   'your',
#   'here’s',
#   'Glasgow',
#   'November',
#   'November!',
#   'the',
#   'the',
#   'that',
#   'the',
#   'the',
#   'comparison',
#   'to',
#   'progress.',
#   'school,',
#   'the',
#   'Ireland.'],
#  'stunning': ['Cork', 'guy.'],
#  'What': ['a',
#   'a',
#   'a',
#   'a',
#   'was',
#   'did',
#   'was',
#   'did',
#   'do',
#   'I’m',
#   'the',
#   'does',
#   'does',
#   'had',
#   'had',
#   'a',
#   'happened',
#   'a',
#   'a',
#   'a',
#   'was'],
#  'venue.': ['Nice'],
#  'Nice': ['and'],
#  'intimate,': ['we'],
#  'we': ['can',
#   'go.',
#   'can',
#   'have',
#   'love',
#   'lived',
#   'had',
#   'were',
#   'go.',
#   'never',
#   'record',
#   'discuss',
#   'can',
#   'got',
#   'talking',
#   'are',
#   'fucking',
#   'go,',
#   'play',
#   'looked',
#   'left',
#   'passed',
#   'should',
#   'say.',
#   'get',
#   'are',
#   'found',
#   'are.',
#   'don’t',
#   'handle',
#   'even',
#   'done?',
#   'don’t',
#   'love…',
#   'lived',
#   'left',
#   'left',
#   'drove'],
#  'can': ['see',
#   'have',
#   'look',
#   'get',
#   'ever',
#   'hang',
#   'leave',
#   'be',
#   'actually',
#   'even',
#   'no',
#   'fuck',
#   'hope',
#   'eventually',
#   'see',
#   'wave',
#   'hide',
#   'get',
#   'backfire,',
#   'only',
#   'just',
#   'just',
#   'later',
#   'you',
#   'worship',
#   'judge',
#   'have',
#   'joke',
#   'either',
#   'start',
#   'I'],
#  'see': ['right',
#   'people',
#   'Russell',
#   'the',
#   'children',
#   'him',
#   'that',
#   'foreign',
#   'me.',
#   'it',
#   'to',
#   'a',
#   'how',
#   'you',
#   'you,',
#   'you',
#   'the',
#   'them',
#   'the',
#   'an',
#   'Jesus',
#   'on',
#   'what',
#   'what',
#   'what',
#   'you',
#   'children',
#   'the'],
#  'right': ['into', 'here.', 'in', 'now?”', 'now.”', 'for'],
#  'each': ['other’s', 'other?'],
#  'other’s': ['eyes'],
#  'eyes': ['here.'],
#  'here.': ['It', 'I’m', 'The', 'Let’s', 'Those'],
#  'It': ['is…',
#   'is.',
#   'is',
#   'is,',
#   'is…',
#   'is.',
#   'is.',
#   'killed',
#   'was',
#   'makes',
#   'was',
#   'was',
#   'looks',
#   'is',
#   'is.',
#   'just',
#   'looked',
#   'happened',
#   'said…',
#   'said,',
#   'said,',
#   'said,',
#   'was',
#   'was',
#   'took',
#   'All”'],
#  'I': ['was',
#   'was',
#   'was',
#   'thought,',
#   'mean?',
#   'had',
#   'was',
#   'thought',
#   'thought',
#   'don’t',
#   'still',
#   'used',
#   'don’t',
#   'was',
#   'know.',
#   'don’t',
#   'must',
#   'don’t',
#   'used',
#   'got',
#   'proposed.',
#   'became',
#   'became',
#   'never',
#   'would',
#   'fucking…',
#   'old?',
#   'now',
#   'said',
#   'was',
#   'was',
#   'thought',
#   'was',
#   'said',
#   'hope',
#   'was',
#   'sometimes',
#   'can',
#   'don’t',
#   'think',
#   'think',
#   'think',
#   'don’t',
#   'think',
#   'don’t',
#   'know.',
#   'don’t',
#   'mean?',
#   'don’t',
#   'don’t',
#   'grew',
#   'grew',
#   'hear,',
#   'don’t',
#   'said',
#   'never',
#   'never',
#   'cannae',
#   'cannae',
#   'cannae',
#   'was',
#   'think',
#   'probably',
#   'have',
#   'believe,',
#   'don’t',
#   'don’t',
#   'learned',
#   'was',
#   'like',
#   'was',
#   'heard',
#   'guarantee',
#   'was',
#   'know',
#   'came',
#   'witness',
#   'looked',
#   'was',
#   'was',
#   'never',
#   'certainly',
#   'was',
#   'lost',
#   'was',
#   'was',
#   'have',
#   'live',
#   'used',
#   'kept',
#   'never',
#   'was',
#   'would',
#   'would…',
#   'would',
#   'could',
#   'could’ve',
#   'could’ve',
#   'apologized',
#   'said',
#   'brought',
#   'closed',
#   'closed',
#   'read',
#   'lost',
#   'got',
#   'just',
#   'was',
#   'love',
#   'wanted',
#   'was…',
#   'was',
#   'thought',
#   'thought',
#   'have',
#   'carry',
#   'used',
#   'lost',
#   'had',
#   'doubt',
#   'was',
#   'played',
#   'was',
#   'was',
#   'was',
#   'was',
#   'was',
#   'was',
#   'break',
#   'get',
#   'get',
#   'get',
#   'stupidly',
#   'was',
#   'lose',
#   'done…',
#   'done',
#   'find',
#   'went',
#   'can',
#   'tried',
#   'don’t…',
#   'was',
#   'talking…?',
#   'could’ve',
#   'somehow',
#   'just',
#   'know',
#   'went,',
#   'was',
#   'don’t',
#   'went',
#   'learned',
#   'was',
#   'don’t',
#   'was',
#   'just',
#   'had',
#   'don’t',
#   'felt',
#   'had',
#   'had',
#   'gave',
#   'later',
#   'don’t',
#   'tried',
#   'don’t',
#   'will',
#   'was',
#   'had',
#   'had',
#   'thought',
#   'had',
#   'phoned.',
#   'panicked.',
#   'never',
#   'just',
#   'phoned',
#   'hope',
#   'just',
#   'don’t',
#   'gonna',
#   'can',
#   'was',
#   'had',
#   'don’t',
#   'had',
#   'required.',
#   'thought,',
#   'said,',
#   'said,',
#   'just',
#   'said,',
#   'don’t',
#   'watched',
#   'don’t',
#   'loved',
#   'turn',
#   'look',
#   'went',
#   'can',
#   'made',
#   'believe',
#   'think',
#   'spend',
#   'get',
#   'close',
#   'come',
#   'know…',
#   'know',
#   'turn',
#   'know',
#   'would',
#   'try…',
#   'try',
#   'put',
#   'don’t',
#   'don’t',
#   'bet',
#   'know,',
#   'turn',
#   'will',
#   'wonder',
#   'wonder',
#   'know',
#   'know',
#   'thought',
#   'love',
#   'never',
#   'love',
#   'still',
#   'just',
#   'could',
#   'could',
#   'tried',
#   'made',
#   'tried',
#   'tried',
#   'learned',
#   'learned',
#   'managed',
#   'was',
#   'managed',
#   'thought,',
#   'learned.',
#   'posted',
#   'know',
#   'got',
#   'doubled',
#   'learnt.',
#   'realized',
#   'enjoy',
#   'enjoy',
#   'was…',
#   'was',
#   'know',
#   'was',
#   'thought,',
#   'will',
#   'know',
#   'would',
#   'think.',
#   'know',
#   'just',
#   'never',
#   'was',
#   'was',
#   'looked',
#   'was',
#   'was',
#   'was',
#   'said',
#   'just',
#   'never',
#   'have',
#   'have',
#   'said?',
#   'said',
#   'wished',
#   'usually',
#   'said',
#   'told',
#   'got',
#   'told',
#   'believe',
#   'learned',
#   'tripped',
#   'tried',
#   'eventually',
#   'heard',
#   'looked',
#   'thought',
#   'thought,',
#   'got',
#   'don’t',
#   'can',
#   'don’t',
#   'just',
#   'like',
#   'don’t',
#   'caused',
#   'caused',
#   'had',
#   'know',
#   'don’t',
#   'had',
#   'will',
#   'just',
#   'chose',
#   'chose',
#   'said',
#   'said',
#   'agree',
#   'began',
#   'realized',
#   'mean,',
#   'don’t',
#   'just',
#   'know',
#   'mean?',
#   'don’t',
#   'should',
#   'don’t',
#   'don’t',
#   'thought,',
#   'bet',
#   'got',
#   'try',
#   'don’t',
#   'try',
#   'try',
#   'try',
#   'try',
#   'will',
#   'showed',
#   'was',
#   'thought,',
#   'thought,',
#   'would',
#   'would’ve',
#   'will',
#   'would',
#   'thought',
#   'thought',
#   'was',
#   'was',
#   'thought',
#   'was',
#   'could',
#   'might',
#   'could',
#   'remember',
#   'just',
#   'would',
#   'hope',
#   'finished',
#   'know',
#   'might',
#   'believe…',
#   'think',
#   'was',
#   'was',
#   'came',
#   'learned',
#   'bought',
#   'played',
#   'find',
#   'was',
#   'threatened',
#   'look',
#   'will',
#   'would',
#   'never',
#   'don’t',
#   'hear',
#   'was',
#   'never',
#   'accept'],
#  'was': ['unsure',
#   'going',
#   'a',
#   'in',
#   'saying,',
#   'quite',
#   'quite',
#   'like',
#   'watching,',
#   'refreshing.',
#   'putting',
#   'looking',
#   'quite',
#   'putting',
#   'still',
#   'born…',
#   'born',
#   'born',
#   'handled,',
#   'like',
#   'on',
#   'even',
#   'getting',
#   'impressive.',
#   'massive.',
#   'born',
#   'laughing',
#   'walking',
#   'walking',
#   'boasting',
#   'walking',
#   'irrelevant,',
#   'never',
#   'done',
#   'shite',
#   'not',
#   'in',
#   'at',
#   'at',
#   'irritating',
#   'ruining',
#   'to',
#   'tough',
#   'that?',
#   'clearly',
#   'that…',
#   'up',
#   'gonna',
#   'for',
#   'actually…',
#   'a',
#   'the',
#   'quite',
#   'a',
#   'a',
#   'invited',
#   'told',
#   'gonna',
#   'fat-shamed',
#   'that?',
#   'gonna',
#   'I',
#   'at',
#   'the',
#   'designed',
#   'holding',
#   'doing',
#   'terrified.',
#   'only',
#   'basically',
#   'nothing',
#   'fine.',
#   'that',
#   'poor.',
#   'the',
#   'nights,',
#   'Hitler’s.',
#   'a',
#   'quite…',
#   'quite',
#   'born,',
#   'in',
#   'having',
#   'a',
#   'tempted,',
#   'the',
#   'on',
#   'like,',
#   'me.',
#   'like…',
#   'a',
#   'smoking.',
#   'one',
#   'a',
#   'even',
#   'embarrassing,',
#   '33',
#   'ripped,',
#   'in.',
#   'I',
#   'confirmed',
#   'fucking',
#   'it.',
#   'still',
#   'all',
#   'an',
#   'gonna',
#   'graffiti.',
#   'a',
#   'supportive.',
#   'in',
#   'telling',
#   'wearing?',
#   'wearing',
#   'wearing',
#   'called.',
#   'gonna',
#   'gonna',
#   'gonna',
#   'hunting',
#   'nobody',
#   'actually',
#   'poised',
#   'quite',
#   'gonna',
#   'me,',
#   'held',
#   'shite',
#   'quite',
#   'good',
#   'only',
#   'a',
#   'all',
#   'ever',
#   'good',
#   'a',
#   'being',
#   'an',
#   'the',
#   'that,',
#   '17'],
#  'unsure': ['whether', 'as'],
#  'whether': ['I'],
#  'going': ['to',
#   'to',
#   'on',
#   'on',
#   'to',
#   'up',
#   'on,',
#   'there,',
#   'on',
#   'to',
#   'ahead,',
#   'fucking',
#   'on,'],
#  'record': ['this', 'the'],
#  'tour,': ['and', 'it’s'],
#  'then': ['there',
#   'I',
#   'I',
#   'for',
#   'I',
#   'the',
#   'it',
#   'five',
#   'I',
#   'jogging',
#   'you',
#   'sauna,',
#   'you',
#   'leave',
#   'my',
#   'her',
#   'my',
#   'the',
#   'my',
#   'day',
#   'what',
#   'when',
#   'on',
#   'everybody',
#   'move',
#   'in',
#   'I',
#   'I',
#   'the',
#   'they’re',
#   'the',
#   'you',
#   'a'],
#  'there': ['was',
#   'were',
#   'in',
#   'become',
#   'and',
#   'a',
#   'is',
#   'was',
#   'are',
#   'ever',
#   'ever',
#   'ever',
#   'sleeping.',
#   'that',
#   'with',
#   'was',
#   'might',
#   'may',
#   'until',
#   'was',
#   'was',
#   'was',
#   'to'],
#  'bit': ['of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'in',
#   'of',
#   'mental.',
#   'too',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'old',
#   'quiet',
#   'quiet,',
#   'quiet,',
#   'of',
#   'cos',
#   'deeper',
#   'strange,',
#   'like…',
#   'of',
#   'Scottish,',
#   'of',
#   'rusty.'],
#  'debate,': ['and'],
#  'cinema,': ['watching'],
#  'watching': ['Oppenheimer.',
#   'an',
#   'at',
#   'my',
#   'her',
#   'her',
#   'him.',
#   'that',
#   'Hitler,',
#   'Ashley'],
#  'Oppenheimer.': ['Cillian'],
#  'Cillian': ['Murphy.'],
#  'Murphy.': ['And'],
#  'And': ['I',
#   'then,',
#   'Germany’s',
#   'you’d',
#   'as',
#   'as',
#   'I’ll',
#   'he’ll',
#   'this',
#   'I',
#   'then',
#   'I',
#   'I',
#   'I',
#   'it',
#   'I',
#   'I',
#   'I’ve',
#   'I’ve',
#   'I',
#   'that',
#   'I',
#   'that',
#   'I',
#   'we’re',
#   'I’d',
#   'I',
#   'we',
#   'my',
#   'then',
#   'that’s',
#   'we',
#   'that',
#   'that',
#   'that’s',
#   'I’m',
#   'then',
#   'that’s',
#   'that’s',
#   'shortly',
#   'it',
#   'then',
#   'I',
#   'I',
#   'I',
#   'we',
#   'then',
#   'then',
#   'then…”',
#   'age,',
#   'upon',
#   'it',
#   'if',
#   'what',
#   'what',
#   'then',
#   'then',
#   'that',
#   'that’s',
#   'then',
#   'that’s',
#   'sometimes,',
#   'then',
#   'I',
#   'it’s',
#   'then,',
#   'if',
#   'it’s',
#   'the',
#   'my',
#   'you',
#   'that',
#   'this'],
#  'thought,': ['“Where',
#   '“I’m',
#   '“This',
#   '“No,',
#   '“No,',
#   '“Not',
#   '“Fuck',
#   '“Bravo,',
#   '“Bravo,'],
#  '“Where': ['do', 'are'],
#  'do': ['they',
#   'you',
#   'that.”',
#   'you',
#   'you',
#   'a',
#   'you',
#   'you',
#   'you',
#   'you',
#   'travel',
#   'youse',
#   'Catholics'],
#  'they': ['make',
#   'were',
#   'can',
#   'don’t',
#   'stay',
#   'stay',
#   'feel',
#   'have',
#   'start',
#   'make',
#   'no',
#   'don’t',
#   'never',
#   'call',
#   'were',
#   'call',
#   'should…',
#   'missed',
#   'would',
#   'wrote?',
#   'will'],
#  'make': ['such', 'the', 'the', 'a', 'you', 'it', 'a', 'me'],
#  'handsome': ['bastards?”'],
#  'bastards?”': ['Where'],
#  'Where': ['on', 'are', 'are'],
#  'earth?': ['Get'],
#  'Get': ['these', 'these', 'a', 'some', 'a', 'the', 'it.', 'it', 'the'],
#  'these': ['people…',
#   'people',
#   'days.',
#   'days.',
#   'stages',
#   'double',
#   'big',
#   'young',
#   'every',
#   'things,',
#   'pharmaceutical',
#   'protein',
#   'turbulent',
#   'fucking',
#   'fucked-up',
#   'nights',
#   'days?',
#   'days.',
#   'moments.',
#   'days,',
#   'days?”',
#   'people.',
#   'fucking',
#   'days.',
#   'wee'],
#  'people…': ['Get'],
#  'camera!': ['And'],
#  'then,': ['look', 'Kev.', 'Kev.', 'at', 'my'],
#  'look': ['at',
#   'because',
#   'back',
#   'back',
#   'at',
#   'back',
#   'after',
#   'at',
#   'at',
#   'over',
#   'at',
#   'calm',
#   'good',
#   'at',
#   'at',
#   'at',
#   'at',
#   'at',
#   'back',
#   'back'],
#  'at': ['this',
#   'the…',
#   'who',
#   'the',
#   'the',
#   'an',
#   'the',
#   '’em,',
#   'the',
#   'the',
#   'you,',
#   'the',
#   'chess',
#   'nursery',
#   'baby',
#   '30',
#   'school.',
#   'my',
#   'football,',
#   'fighting,',
#   'football.',
#   'school.',
#   'a',
#   'school',
#   'a',
#   'the',
#   'the',
#   'the',
#   'home.',
#   'minute',
#   'school,',
#   'the',
#   'a',
#   'the',
#   'the',
#   'the',
#   'Uran-yus?',
#   'the',
#   'the',
#   'night',
#   'two',
#   'Hitler’s',
#   'night.',
#   'night?”',
#   'cat',
#   'the',
#   'that',
#   'the',
#   'any',
#   'the',
#   'more',
#   'statues,',
#   'the',
#   'Dicey',
#   'that',
#   'comedians',
#   '6:45',
#   '6:30',
#   'the',
#   'the',
#   'every',
#   'the',
#   'the',
#   'one',
#   'my',
#   'me.',
#   'our',
#   'the',
#   'my',
#   'us.',
#   'being',
#   'being',
#   'life.',
#   'least',
#   'being',
#   'this',
#   'being'],
#  'front': ['row', 'row,', 'door', 'of', 'of', 'of…', 'of', 'of', 'of'],
#  'row': ['here,'],
#  'here,': ['so…', 'because', 'Cork.', 'Kevin?', 'Kev?”', 'Kev.', 'Kev.'],
#  'so…': ['The'],
#  'guy’s': ['even', 'telling'],
#  'even': ['wore…',
#   'finished',
#   'claiming',
#   'places',
#   'say',
#   'a',
#   'a',
#   'further.”',
#   'further.',
#   'performing…',
#   'though',
#   'hosted',
#   'play'],
#  'wore…': ['Is'],
#  'Is': ['that', 'that', 'there', 'that', 'that'],
#  'hoodie?': ['Good'],
#  'man.': ['That’s',
#   'That’s',
#   'Come',
#   'I’m',
#   'You',
#   'Started',
#   'This',
#   'Wow.',
#   'My',
#   'Strength',
#   'Don’t',
#   'Keep',
#   'Lying',
#   'Come',
#   'And',
#   'This',
#   'He’d',
#   'Religious',
#   'Sectarian',
#   'If'],
#  'That’s': ['it,',
#   'decent',
#   'what',
#   'the',
#   'a',
#   'a',
#   'a',
#   'what',
#   'how',
#   'what',
#   'a',
#   'when',
#   'the',
#   'good,',
#   'the',
#   'what',
#   'all',
#   'it.',
#   'where',
#   'the',
#   'when',
#   'it.',
#   'why',
#   'when',
#   'why',
#   'where',
#   'why',
#   'what',
#   'a',
#   'weird.',
#   'why',
#   'all',
#   'what’s',
#   'the',
#   'what',
#   'what',
#   'a',
#   'what',
#   'what',
#   'what',
#   'a',
#   'what',
#   'the',
#   'a',
#   'how',
#   'just',
#   'a',
#   'just',
#   'where',
#   'what'],
#  'it,': ['front', 'going', 'Kev.', 'Kev.', 'me', 'Kev?'],
#  'row,': ['in'],
#  'opera': ['house,'],
#  'house,': ['on', 'right,', 'was'],
#  'telly.': ['“Where’s',
#   'We’re',
#   'You’re',
#   'By',
#   'I',
#   '“I',
#   'And',
#   'I',
#   'Cheer',
#   'The'],
#  '“Where’s': ['my', 'my'],
#  'my': ['PE',
#   'special!',
#   'first',
#   'first',
#   'life.',
#   'relative',
#   'kitchen',
#   'window',
#   'trash',
#   'wife,',
#   'mouth,',
#   'son',
#   'son',
#   'birthday.',
#   "birthday.'”",
#   'son',
#   'backstory',
#   'previous',
#   'son',
#   'citizenship,',
#   'son’s',
#   'wife',
#   'son',
#   'wife,',
#   'wife',
#   'dog',
# ...
#  'dabbled,': ['right?'],
#  'right?': ['I’ve',
#   'We',
#   'And',
#   'But…',
#   'I’m',
#   'She',
#   'I',
#   'It',
#   'Those',
#   'I…',
#   'And',
#   'I',
#   'Right,',
#   'I',
#   'Cos',
#   'Ex-footballers',
#   'This',
#   'They',
#   'The',
#   'Just',
#   'That',
#   'Your',
#   'You',
#   'Cos',
#   'Now,',
#   'And',
#   'The',
#   'Your',
#   'I',
#   'He’s',
#   'It’s',
#   'For',
#   'A'],
#  'dabbled': ['in'],
#  'being': ['old',
#   'able',
#   'judged.',
#   'the',
#   'the',
#   'good',
#   'good',
#   'fucking',
#   'candid',
#   'a',
#   'a',
#   'a',
#   'the',
#   'quiet.',
#   'quiet?',
#   'forced',
#   'out',
#   'easily',
#   'robbed',
#   'a',
#   'a',
#   'certain',
#   'a',
#   '15',
#   'picked',
#   'bullied,',
#   '15,',
#   'bullied,',
#   '15.',
#   '15.',
#   'here.'],
#  'suit': ['me', 'you.', 'being'],
#  'refreshing.': ['I'],
#  'said': ['something',
#   'to',
#   'to',
#   'sorry',
#   'there.',
#   'to',
#   'to',
#   'I',
#   'fuck',
#   'we',
#   'was,',
#   'the',
#   'cunt,'],
#  'something': ['old', 'in', 'in', 'this', 'every', 'for', 'right.”', 'new,'],
#  'months': ['ago.'],
#  'ago.': ['I'],
#  'putting': ['something', 'my', 'together'],
#  'kitchen': ['bin,'],
#  'bin,': ['and'],
#  'looking': ['out', 'in', 'promising,', 'at', 'at', 'through'],
#  'window': ['and', 'making', 'closes', 'to', 'and'],
#  'children': ['in', 'out', 'were', 'out'],
#  'street': ['just', 'lights'],
#  'playing': ['a',
#   'a',
#   'snooker',
#   'as',
#   'FIFA.',
#   'Liverpool.',
#   'wants',
#   'pubs'],
#  'game,': ['an', 'the', 'Soccer', 'it', 'for', 'lad.'],
#  'old-school': ['game.'],
#  'game.': ['They', 'You', 'That’s'],
#  'tablets': ['or'],
#  'or': ['devices,',
#   'being',
#   'bouncing',
#   'the',
#   'this',
#   'No',
#   'hemorrhoids',
#   'old',
#   'watching',
#   'somebody',
#   'whatever',
#   'day',
#   'hear',
#   'you’re',
#   'making',
#   'you',
#   'Irish,'],
#  'devices,': ['and'],
#  'nice.': ['And', 'We’ll'],
#  'trash': ['in'],
#  'can,': ['I'],
#  'wife,': ['“Isn’t', '“This', 'the', '“How', '“I’m', '“Isn’t'],
#  '“Isn’t': ['it', 'it'],
#  'great': ['to', 'question', 'to'],
#  'playing?”': ['And', 'That’s'],
#  'soon': ['as', 'as', 'as', 'as', 'as', 'as', 'as'],
#  'sentence': ['left'],
#  'left': ['my', 'arm', 'the', 'that', 'that'],
#  'mouth,': ['the'],
#  'young': ['me',
#   'people,',
#   'guys',
#   'for',
#   'soul',
#   'soul.',
#   'soul',
#   'people',
#   'team'],
#  'there,': ['saying,',
#   'right?',
#   'up',
#   'a',
#   'phone.',
#   'mate?',
#   'saying,',
#   'Kev.”',
#   'there’s',
#   'asking',
#   'then',
#   'and',
#   'an'],
#  '“Wow,': ['Kev,'],
#  'Kev,': ['what',
#   'far',
#   'absolutely',
#   'get',
#   'get',
#   'keep',
#   'mate.',
#   'have',
#   'what',
#   'see',
#   'far',
#   'cos'],
#  'nonce': ['comment.”'],
#  'comment.”': ['“Far'],
#  '“Far': ['too', 'too'],
#  'too': ['young,',
#   'young.',
#   'close.',
#   'advanced.',
#   'much',
#   'many',
#   'busy',
#   'cute.',
#   'cute!',
#   'early',
#   'early.',
#   'much',
#   'many',
#   'nice'],
#  'far': ['too', 'too'],
#  'young.': ['Decades', 'Right?'],
#  'Decades': ['away'],
#  'away': ['from', 'like', 'from', 'in', 'up', 'this'],
#  'able': ['to'],
#  'stand': ['at', 'up', 'at'],
#  'statement.': ['Don’t'],
#  'Don’t': ['fucking', 'suffer', 'try', 'listen', 'come', 'you', 'you'],
#  'wave': ['at', 'at', 'a'],
#  '’em,': ['Kev.', 'hungover,', 'cos'],
#  'Kev.': ['One',
#   'Thirty-six,',
#   'You',
#   'Fucking…”',
#   'That’s',
#   'Get',
#   'The',
#   'Just',
#   'It’s',
#   'You’re',
#   'Every',
#   'I',
#   '‘How',
#   'Remember',
#   'Google',
#   'Kev,',
#   'Come',
#   'That',
#   'You’re',
#   'Don’t',
#   'You’ve',
#   'Enjoy'],
#  'One': ['of', 'minute', 'click!', 'day,'],
#  'them’s': ['seen'],
#  'You’ll': ['get', 'be', 'take', 'be', 'hit', 'hear,'],
#  'door': ['kicked',
#   'of',
#   'to',
#   'to',
#   'with',
#   'in',
#   'and',
#   'and',
#   'and',
#   'and'],
#  'kicked': ['in,'],
#  'in,': ['Kev.', '“I', '“Were', 'but', 'or'],
#  'Thirty-six,': ['man!'],
#  'man!': ['You'],
#  '36-year-old': ['lollipop'],
#  'lollipop': ['man,'],
#  'Kevin?': ['No.', 'I'],
#  'No.': ['Cos', 'Don’t', 'Same'],
#  'Cos': ['it',
#   'it’s',
#   'my',
#   'there’s',
#   'it',
#   'people',
#   'everybody',
#   'we',
#   'I',
#   'we'],
#  'arrestable': ['to'],
#  'apply': ['for'],
#  'vacancy.”': ['I’m'],
#  'fatherhood': ['game.'],
#  'decide': ['what'],
#  'kind': ['of', 'of', 'of…', 'of'],
#  'dad': ['you’re', 'at', 'down', 'being', 'took', 'did,'],
#  'gonna': ['be.',
#   'take',
#   'get',
#   'get',
#   'have',
#   'be.',
#   'call',
#   'get',
#   'get',
#   'ask',
#   'start',
#   'explain',
#   'have',
#   'leave',
#   'storm',
#   'lose',
#   'die.”',
#   'fucking',
#   'die,',
#   'die.”',
#   'die,',
#   'fucking',
#   'spike',
#   'spike',
#   'be,',
#   'try',
#   'do',
#   'come',
#   'watch',
#   'eat',
#   'have',
#   'get',
#   'be',
#   'find',
#   'slit',
#   'laugh',
#   'learn'],
#  'be.': ['If', 'Get', 'I’m'],
#  'If': ['you’re',
#   'you’re…',
#   'you’re',
#   'I',
#   'life',
#   'you’re',
#   'I',
#   'you',
#   'my',
#   'my',
#   'you'],
#  'Dwight': ['York'],
#  'York': ['hands-off'],
#  'hands-off': ['approach'],
#  'approach': ['or…'],
#  'or…': ['If'],
#  'you’re…': ['gonna'],
#  'there…': ['If', 'the', '…saying,'],
#  'there.': ['See,',
#   'Mate,',
#   '“There',
#   'You',
#   'That',
#   'You’ll',
#   'I',
#   'What',
#   'Is',
#   'Nineteen.',
#   'And',
#   'I',
#   'You…',
#   'Just'],
#  'my…': ['See,'],
#  'son': ['was',
#   'was',
#   'has',
#   'was',
#   'has',
#   'into',
#   'to',
#   'was',
#   'was',
#   'would',
#   'was',
#   'was'],
#  'born…': ['My'],
#  'My': ['son',
#   'wife’s',
#   'wife',
#   'program.”',
#   'wife',
#   'wife',
#   'wife',
#   'arse',
#   'mental',
#   'son',
#   'wife',
#   'son',
#   'dog',
#   'wife’s',
#   'mum',
#   'wife'],
#  'born': ['in', 'in', 'into.'],
#  '2021.': ['What', 'Glasgow'],
#  'enter': ['the'],
#  'world.': ['What', 'José', 'There’s'],
#  'decade': ['it'],
#  'far,': ['and'],
#  'hope': ['there’ll', 'for.', 'we', 'that', 'I', 'I', 'for', 'for'],
#  'there’ll': ['be', 'be', 'be', 'come'],
#  'laugh': ['at', 'at', 'when', 'and', 'at'],
#  'surreal': ['madness'],
#  'madness': ['that', 'will'],
#  'through.': ['I', 'I’m', 'I'],
#  '’80s': ['and', 'and'],
#  'love': ['the', 'it,', 'these', 'you,'],
#  '’80s,': ['right?'],
#  'sometimes': ['ponder'],
#  'ponder': ['if'],
#  'grown': ['up'],
#  'I’ll': ['walk',
#   'see',
#   'be',
#   'be',
#   'take',
#   'get',
#   'give',
#   'just',
#   'go',
#   'see',
#   'be',
#   'be',
#   'tell',
#   'tell',
#   'tell',
#   'look',
#   'teach'],
#  'walk': ['into',
#   'over,',
#   'over',
#   'over',
#   'on',
#   'up',
#   'up',
#   'it,',
#   'up',
#   'back'],
#  'bedroom': ['and'],
#  'standing': ['there', 'in', 'in', 'on', 'in'],
#  '24': ['toilet'],
#  'toilet': ['rolls'],
#  'rolls': ['under'],
#  'under': ['his', 'his', 'Covid', 'my', 'my', 'his', 'his'],
#  'armpit,': ['a'],
#  'face': ['mask', 'of'],
#  'mask': ['under'],
#  'chin,': ['deep'],
#  'deep': ['throating'],
#  'throating': ['a'],
#  'cotton': ['bud,'],
#  'bud,': ['going…'],
#  'going…': ['And', 'I', '“Kev!', 'Right,'],
#  'going?”': ['And', '“Oh,'],
#  'he’ll': ['be'],
#  '“It’s': ['a', 'not', 'kind', 'not', 'cos', 'all'],
#  '’20s': ['night,'],
#  'night,': ['Dad,', 'iPhones', 'I’ll'],
#  'Dad,': ['at'],
#  'student': ['union.”'],
#  'union.”': ['And'],
#  'will': ['come',
#   'know',
#   'gladly',
#   'be',
#   'always',
#   'post',
#   'not',
#   'not',
#   'explain',
#   'translate.',
#   'defend',
#   'fuck',
#   'teach',
#   'come.',
#   'not'],
#  'come': ['back.',
#   'to',
#   'on!',
#   'from',
#   'alive.',
#   'near',
#   'out?',
#   'in',
#   'to',
#   'a',
#   'for',
#   'to',
#   'here',
#   'here',
#   'for',
#   'home',
#   'home',
#   'to',
#   'up',
#   'on.',
#   'to'],
#  '“Who’s': ['going?”', 'Logan'],
#  'five': ['other', 'minutes', 'minutes', 'minutes', 'minutes.', 'kilometers.'],
#  'three': ['different', 'households', 'accepted', 'liters', 'years'],
#  'different': ['households.”', 'upbringing', 'people'],
#  'households.”': ['Remember'],
#  'all': ['that',
#   'heavily.',
#   'I',
#   'the',
#   'the',
#   'this…',
#   'the',
#   'the',
#   'contact',
#   'day',
#   'you',
#   'that',
#   'the',
#   'back.',
#   'that',
#   'that',
#   'you',
#   'that.',
#   'the',
#   'my',
#   'right',
#   'right!',
#   'right.',
#   'round'],
#  'shit': ['we', 'at', 'said.', 'that', 'on'],
#  'through,': ['where'],
#  'households': ['could'],
#  'socialize?': ['Having'],
#  'Having': ['to', 'to'],
#  'ruthless,': ['planning'],
#  'planning': ['any'],
#  'any': ['social',
#   'parents',
#   'more',
#   'realistic',
#   'absinthe,',
#   'exercise',
#   'Anusol',
#   'of',
#   'point,',
#   'old',
#   'senior',
#   'country'],
#  'event,': ['having'],
#  'having': ['to',
#   'an',
#   'to',
#   'lunch',
#   'to',
#   'won.',
#   'a',
#   'his',
#   'to',
#   'to',
#   'to',
#   'a',
#   'a'],
#  'break': ['it', 'into'],
#  'mate': ['who'],
#  'own': ['that', 'peg', 'upbringing.', 'school', 'arsehole', 'mortality'],
#  'cannae': ['come', 'afford', 'fall', 'afford', 'just', 'joke', 'say'],
#  'barbecue': ['because'],
#  'he’s': ['a',
#   'the',
#   'shrugging',
#   'managed',
#   'got',
#   'saying,',
#   'having',
#   'done',
#   'a',
#   'still',
#   'a'],
#  'waste': ['of'],
#  'house.': ['“I’ll'],
#  '“I’ll': ['just'],
#  'tell': ['him,', 'you', 'you', 'you…', 'the', 'you'],
#  'him,': ['‘Sorry,'],
#  '‘Sorry,': ['Gary,'],
#  'Gary,': ['you’re'],
#  'coming,': ['mate.'],
#  'four': ['in', 'days'],
#  'Mate,': ['it’s'],
#  'birthday.': ['I’m'],
#  'four-four-one': ['on'],
#  "birthday.'”": ['We'],
#  'live': ['through', 'in', 'on', 'and', 'to', 'from'],
#  'inquiries': ['going', 'worldwide.'],
#  'Every': ['country’s', 'city', 'nutritionist', 'single', 'single', 'news'],
#  'country’s': ['having'],
#  'inquiry': ['into'],
#  'Covid': ['was', 'restrictions,', 'was', 'running', 'debris', 'has'],
#  'handled,': ['inquiries'],
#  'worldwide.': ['I'],
#  'followed,': ['over'],
#  'UK,': ['we'],
#  'two': ['years', 'in', 'in', 'positive', 'or', 'degrees'],
#  'restrictions,': ['whilst'],
#  'whilst': ['the'],
#  'House': ['of'],
#  'Commons': ['was'],
#  'Magaluf.': ['I'],
#  'think': ['that’s',
#   'Covid…',
#   'it’s',
#   'there’s',
#   'religion',
#   'you’ll',
#   'you',
#   'that',
#   'you’re',
#   'you’re',
#   'more',
#   'that',
#   'that’s',
#   'he',
#   'he’s',
#   'a'],
#  'happened.': ['Boris'],
#  'Boris': ['Johnson', 'Johnson'],
#  'Johnson': ['and', 'was'],
#  'partying': ['the'],
#  'whole': ['way',
#   'family,',
#   'time,',
#   'world',
#   'family',
#   'day.',
#   'fucking',
#   'world',
#   'time?',
#   'adult'],
#  'way': ['through',
#   'for',
#   'you’re',
#   'it',
#   'too',
#   'off',
#   'before',
#   'did',
#   'there,',
#   'children',
#   'that',
#   'of'],
#  'proper': ['lockdowns'],
#  'lockdowns': ['as', 'in'],
#  'well,': ['April', 'a', 'Kev.'],
#  'April': ['and'],
#  'May': ['2020,'],
#  '2020,': ['right'],
#  'midst': ['of'],
#  'family': ['quiz,', 'on', 'meal', 'man.', 'goals.'],
#  'quiz,': ['sitting,'],
#  'sitting,': ['your'],
#  'head': ['shaved,', 'of'],
#  'shaved,': ['the'],
#  'family,': ['like', 'abandon'],
#  'marines.': ['Saturday'],
#  'Saturday': ['night,', 'morning.'],
#  'iPhones': ['propped'],
#  'propped': ['up'],
#  'Yankee': ['candles.'],
#  'candles.': ['“How'],
#  '“How': ['many', 'fast', 'many', 'many', 'did', 'dare'],
#  'many': ['hearts',
#   'balls',
#   'people',
#   'people',
#   'people',
#   'people',
#   'people',
#   'people',
#   'people',
#   'countries.'],
#  'hearts': ['does'],
#  'does': ['an', 'not', 'the', 'the', 'Bitcoin…?’', 'the', 'eventually'],
#  'octopus': ['have?”'],
#  'have?”': ['The'],
#  'time,': ['Boris', 'right?', 'that'],
#  'decks,': ['fucking,'],
#  '“Order,': ['order!”'],
#  'order!”': ['Whilst'],
#  'Whilst': ['we'],
#  'supermarkets': ['forgetting'],
#  'forgetting': ['tomato'],
#  'tomato': ['purée,'],
#  'purée,': ['petrified'],
#  'petrified': ['to'],
#  'perform': ['a'],
#  'three-point': ['turn'],
#  'one-way': ['aisle.'],
#  'aisle.': ['People'],
#  'glaring': ['at'],
#  '“My': ['dad’s', '95-year-old', 'dog’s'],
#  'dad’s': ['got'],
#  'asthma,': ['you'],
#  'maniac!': ['That'],
#  'That': ['way!”',
#   'was',
#   'was',
#   'was',
#   'is',
#   'was',
#   'is',
#   'was',
#   'was',
#   'is',
#   'is',
#   'would’ve',
#   'is',
#   'was',
#   'would’ve',
#   'is',
#   'is',
#   'is…',
#   'is',
#   'was',
#   'is',
#   'wee',
#   'wee…',
#   'was',
#   'is',
#   'is',
#   'is',
#   'must',
#   'makes',
#   'was',
#   'was',
#   'is',
#   'guy.',
#   'guy.'],
#  'way!”': ['I'],
#  'Covid…': ['I', 'Anything!'],
#  'gone.': ['I’m', 'And', 'Gone.'],
#  'pretty': ['sure', 'low', 'much'],
#  'sure': ['it’s'],
#  'over.': ['I', 'I'],
#  'China,': ['but'],
#  'fucked': ['off', 'off'],
#  'off': ['home.',
#   'a',
#   'a',
#   'back',
#   'and',
#   'the',
#   'again.',
#   'with',
#   'the',
#   'my',
#   'the',
#   'the',
#   'on',
#   'the',
#   'the',
#   'for',
#   'the',
#   'a',
#   'from',
#   'school.',
#   'school.'],
#  'home.': ['After…', 'I’m', 'That', 'This'],
#  'After…': ['After'],
#  'After': ['a'],
#  'successful': ['world'],
#  'killed': ['six', '50', '200', 'himself.'],
#  'six': ['million'],
#  'million': ['people.', 'and', 'box.'],
#  'Wow!': ['I', 'Even', 'That’s', 'What'],
#  'numbers,': ['but'],
#  'hall': ['of'],
#  'fame': ['when'],
#  'pandemics': ['throughout'],
#  'throughout': ['human'],
#  'history.': ['You', 'We'],
#  'real': ['big', 'relationship.', 'snowflakes,'],
#  'hitters.': ['The'],
#  'Spanish': ['flu,', 'here?'],
#  'flu,': ['that'],
#  '50': ['million.'],
#  'million.': ['The'],
#  'black': ['death', 'ice'],
#  'death': ['killed', 'was'],
#  '200': ['million'],
#  'Covid,': ['six.', 'that', 'all'],
#  'six.': ['Covid'],
#  'claiming': ['assists'],
#  'assists': ['towards'],
#  'towards': ['the', 'the', 'the'],
#  'end.': ['Covid…', 'That’s'],
#  'Anything!': ['“My'],
#  '95-year-old': ['grandfather'],
#  'grandfather': ['died'],
#  'died': ['from', 'than', 'plus', 'by'],
#  'Covid!”': ['“Come'],
#  'tap-in,': ['man.”'],
#  'man.”': ['A', '“Just'],
#  'ice': ['was'],
#  'getting': ['him.',
#   'dragged',
#   'half',
#   'a',
#   'passed',
#   'the',
#   'warmer.',
#   'abuse',
#   'hammered',
#   'beat'],
#  'can’t': ['have', 'even'],
#  'running': ['away', 'tap', 'away,', 'away.', 'down'],
#  'Alan': ['Shearer'],
#  'Shearer': ['celebrating'],
#  'celebrating': ['that.'],
#  'closed.': ['That', 'Wow!'],
#  'impressive.': ['We’ll'],
#  'We’ll': ['never',
#   'go',
#   'make',
#   'probably…',
#   'probably',
#   'put',
#   'never',
#   'become,'],
#  'again.': ['Even', 'A', 'I', 'O-D-H-R-A-N.'],
#  'Even': ['McDonald’s', 'churches,', 'their', 'fucking', 'he’s', 'Covid,'],
#  'McDonald’s': ['closed.'],
#  'churches,': ['even'],
#  'places': ['of', 'and'],
#  'worship': ['forced', 'him.'],
#  'forced': ['to', 'to'],
#  'close.': ['That', 'I'],
#  'massive.': ['What'],
#  'witnessed': ['a', 'me'],
#  'organized': ['religion'],
#  'religion': ['listened', 'can'],
#  'listened': ['to'],
#  'science.': ['Wow!'],
#  'they’ve': ['dismissed', 'got', 'got', 'got', 'got'],
#  'dismissed': ['everything'],
#  'scientists': ['had'],
#  'say.': ['“The', 'Snowflakes.'],
#  '“The': ['Big', 'fucking'],
#  'Bang?': ['Nah.'],
#  'Nah.': ['Evolution?', 'A'],
#  'Evolution?': ['Nah.'],
#  'dry': ['continuous'],
#  'continuous': ['cough'],
#  'cough': ['and'],
#  'changes': ['to', 'I'],
#  'sense': ['of', 'tension,'],
#  'taste': ['and'],
#  'smell?': ['Fucking'],
#  'shut': ['the', 'up.', 'up.”', 'up!”'],
#  'cathedral!': ['These'],
#  'geeks': ['have', 'decided'],
#  'point': ['this', 'of', 'to'],
#  'time!': ['Somebody'],
#  'Somebody': ['sanitize', 'recommended', 'in'],
#  'sanitize': ['the'],
#  'synagogue!”': ['Two'],
#  'Two': ['Christmases'],
#  'Christmases': ['got'],
#  'canceled.': ['I'],
#  'recover.': ['Jesus’s'],
#  'Jesus’s': ['birthday,'],
#  'birthday,': ['canceled,'],
#  'canceled,': ['twice.'],
#  'twice.': ['A'],
#  'birthday': ['as'],
#  '2021st,': ['innit?'],
#  'Gone.': ['That’s'],
#  'into.': ['Anyway,'],
#  'Anyway,': ['it', 'what', 'ladies'],
#  'Fatherhood,': ['it’s'],
#  'new.': ['Thanks'],
#  'Thanks': ['to', 'for', 'for'],
#  'know,': ['again.', 'mate.', 'people', 'that’s', 'but', 'but'],
#  'backstory': ['for'],
#  'those': ['of', 'minor', 'cookies,', 'of', 'of', 'of'],
#  'unfamiliar': ['with', 'with'],
#  'previous': ['work.'],
#  'work.': ['But', 'This'],
#  'grew': ['up…', 'up'],
#  'up…': ['I'],
#  'area': ['that'],
#  'describe': ['as'],
#  'humble,': ['right?'],
#  'past…': ['for'],
#  'past': ['maybe', 'us', 'few', 'his'],
#  'maybe': ['decade,',
#   'a',
#   'speed',
#   'she',
#   'even',
#   'a',
#   'day',
#   'one',
#   'it’s',
#   'read'],
#  'decade,': ['I’ve'],
#  'nicer': ['part'],
#  'part': ['of', 'of'],
#  'city': ['of', 'or', 'center', 'break.', 'Glasgow'],
#  'Glasgow.': ['I’ve'],
#  'amongst': ['the', 'the'],
#  'upper': ['middle', 'echelons,', 'middle', 'middle', 'body'],
#  'middle': ['classes,', 'classes.', 'classes'],
#  'classes,': ['the'],
#  'echelons,': ['and'],
#  'fitted': ['in'],
#  'But…': ['But'],
#  'born,': ['it', 'I'],
#  'granted': ['me'],
#  'citizenship,': ['right?'],
#  'accept': ['that', 'happiness', 'the'],
#  'son’s': ['gonna'],
#  'totally': ['different'],
#  'upbringing': ['from'],
#  'names…': ['Kids'],
#  'Kids': ['have'],
#  'names': ['like'],
#  ...}

# %%
generate_sentence(k_dict)
# Out:
# 'Soothing bedtime story. There’s always an evening of men, cos you’re lighting a chuckle. We’ve.'

# %% [markdown]
# # Jacqueline

# %%
j_text = data.transcript.loc['Jacqueline']
j_text[:200]
# Out:
# 'In “Get on Your Knees,” Jacqueline Novak transcends the typical stand-up comedy show by delivering a unique blend of personal anecdotes and intellectual exploration into the act of oral sex, transform'

# %%
j_dict = markov_chain(j_text)
j_dict
# Out:
# {'In': ['“Get', 'the', 'order', 'a', 'theory,', 'order'],
#  '“Get': ['on', 'on'],
#  'on': ['Your',
#   'the',
#   'gender',
#   'Your',
#   'the',
#   'my',
#   'that',
#   'keeping',
#   'through',
#   'it.',
#   'some',
#   'stage',
#   'who',
#   'such',
#   'the',
#   'Monday',
#   'the',
#   'one',
#   'it.',
#   'my',
#   'this',
#   'the',
#   'me.',
#   'you',
#   'the',
#   'the',
#   'the',
#   'the',
#   'it',
#   'the',
#   'this',
#   'the',
#   'the',
#   'what',
#   'this',
#   'that',
#   'the',
#   'to',
#   'the',
#   'terms',
#   'your',
#   'the',
#   'track',
#   'track.',
#   'in.',
#   'and',
#   'it,',
#   'this',
#   'this',
#   'the',
#   'the',
#   'it.',
#   'it.',
#   'that',
#   'a',
#   'this',
#   'this',
#   'upstairs.',
#   'the',
#   'that',
#   'it,',
#   'this',
#   'this',
#   'the',
#   'the',
#   'the',
#   'a',
#   'this',
#   'me.',
#   'this',
#   'Earth.',
#   'my',
#   'behalf',
#   'this.”',
#   'her.',
#   'her,',
#   'her,',
#   'itself?',
#   'behalf',
#   'the',
#   'my',
#   'the',
#   'your',
#   'unfamiliar',
#   'the',
#   'that',
#   'that',
#   'few.',
#   'the',
#   'this',
#   'that',
#   'coming.',
#   'his',
#   'our',
#   'the',
#   '1,000',
#   'through',
#   'just',
#   'purpose.',
#   'the',
#   'purpose.',
#   'human'],
#  'Your': ['Knees,”',
#   'Knees”',
#   'appendage,',
#   'body,',
#   'voice',
#   'voice',
#   'voice',
#   'email'],
#  'Knees,”': ['Jacqueline'],
#  'Jacqueline': ['Novak'],
#  'Novak': ['transcends', 'invites', 'navigates'],
#  'transcends': ['the'],
#  'the': ['typical',
#   'act',
#   'Cherry',
#   'primal',
#   'act,',
#   'audience',
#   'subject,',
#   'juxtaposition',
#   'often-comical',
#   'complexities',
#   'absurdity',
#   'midnight',
#   'journey,',
#   'whole',
#   'thing,',
#   'air',
#   'whole',
#   'thing',
#   'uncertainty,',
#   '[exhales]…',
#   'tenuousness.',
#   'blow',
#   'point',
#   'position',
#   'eyes',
#   'Hound’s',
#   'future',
#   'caboose.',
#   'wind',
#   'top',
#   'show',
#   'muscles',
#   'eyes',
#   'moon',
#   'first',
#   'moon,',
#   'stage,',
#   'chin',
#   'class?”',
#   'form,',
#   'flesh,',
#   'body',
#   'one.',
#   'surrender',
#   'edges',
#   'point?',
#   'orb',
#   'embarrassment',
#   'ghost',
#   'home',
#   'orbs,',
#   'wedding.”',
#   'great-grandmother',
#   'afterlife',
#   'basic',
#   'point.',
#   'point.',
#   'point',
#   'form,',
#   'flesh,',
#   'common',
#   'word,',
#   'word',
#   'back',
#   'same',
#   'side',
#   'mouth.',
#   'word',
#   'voice',
#   'clinician',
#   'problem',
#   'problem',
#   'word',
#   'word',
#   'problem.',
#   'problem',
#   'syllables',
#   'true…',
#   'true',
#   '“nis.”',
#   '“nis.”',
#   'whole',
#   'sexy',
#   'word',
#   'problem',
#   'penis',
#   'feelings',
#   'penis.',
#   'little',
#   'penis.',
#   'penis.',
#   'penis',
#   'person',
#   'little',
#   'penis',
#   'kitchen',
#   'adults',
#   'second',
#   'nephew',
#   'nephew',
#   'same',
#   'penis.',
#   'penis,',
#   'penis',
#   'penis',
#   'word',
#   'penis',
#   'word',
#   'sense',
#   'wafer',
#   'divine.',
#   'penis',
#   'fucking',
#   'penis',
#   'soul',
#   'vine.',
#   'penis,',
#   'sun.',
#   'rest',
#   'body.',
#   'vulva',
#   'flower,',
#   'rose,',
#   'petals',
#   'rose.',
#   'vulva.',
#   'vulva',
#   'roses.”',
#   'bouquet,',
#   'evidence',
#   'wall.',
#   'petals',
#   'vulva…',
#   'vulva',
#   'kind',
#   'vulva…',
#   'way',
#   'way',
#   'layers,',
#   'burger',
#   'flower.',
#   'penis',
#   'most',
#   'shower',
#   'little',
#   'shoulder.',
#   'penis',
#   'fuck',
#   'rude',
#   'penis',
#   'whole',
#   'penis',
#   'night.”',
#   'sensitive.',
#   'nag.',
#   'drama',
#   'ultimate',
#   'party,',
#   'very',
#   'fainting',
#   'inner',
#   'face',
#   'old',
#   'courthouse',
#   'Devil!',
#   'only',
#   'journal.',
#   'journal,',
#   'grenade',
#   'shock',
#   'vaginal',
#   'masculine,',
#   'battle',
#   'rhythm',
#   'battle',
#   'penis…',
#   'penis',
#   'more',
#   'crotchal',
#   'body…',
#   'things',
#   'puppet',
#   'front',
#   'stage',
#   'children',
#   'show',
#   'other',
#   'narrative.',
#   'cover,',
#   'story',
#   'article',
#   'tender',
#   'tip.”',
#   'body',
#   'tip',
#   'first',
#   'penis,',
#   'most',
#   'castle?',
#   'gauntlet',
#   'sensitive',
#   'shaft,',
#   'underside',
#   'shaft,',
#   'skin',
#   'balls,',
#   'storied',
#   'balls,',
#   'way',
#   'essence',
#   'same,',
#   'cause…',
#   'cause',
#   'witch.',
#   'witch.',
#   'witch',
#   'helplessness',
#   'refusal',
#   'lower',
#   'urine',
#   'dick.',
#   'love',
#   'game.',
#   'idea,',
#   'plan?',
#   'idea?',
#   'penis,',
#   'older',
#   'relationship',
#   'blow',
#   'fridge',
#   'cucumber.',
#   'art',
#   'teacher.”',
#   'humiliations',
#   'cucumber',
#   'way',
#   'words',
#   'air.',
#   'first',
#   'few',
#   'impossible?',
#   'confidence',
#   'potentially',
#   'biz.”',
#   'bathroom',
#   'mirror',
#   'person',
#   'mirror.',
#   'mirror,',
#   'gamble',
#   'math',
#   'seemingly',
#   'years.',
#   'balls',
#   'balls',
#   'toys',
#   'pediatrician’s',
#   'balls,',
#   'balls,',
#   'balls?',
#   'most',
#   'principle',
#   'teacher',
#   'position',
#   'position',
#   'position',
#   'dancing',
#   'big',
#   'end',
#   'potential',
#   'other',
#   'counterclockwise',
#   'balls,',
#   'impulse',
#   'anatomy',
#   'balls',
#   'neck',
#   'bag',
#   'balls,',
#   'question',
#   'balls.',
#   'balls.',
#   'balls',
#   'bag',
#   'burden',
#   'intern',
#   'same',
#   'other',
#   'weight.',
#   'way.',
#   'work.”',
#   'same',
#   'balls',
#   'feebleness',
#   'blow',
#   'lesson,',
#   'end',
#   'day',
#   'blow',
#   'person?',
#   'spirit',
#   'thing.”',
#   'simple',
#   'thing',
#   'beat.',
#   'whole',
#   'question',
#   'penis’s',
#   'penis',
#   'penis.',
#   'sky,',
#   'change',
#   'rockest-hardest',
#   'jus,',
#   'chef.',
#   'bone.”',
#   'way',
#   'side',
#   'street',
#   'way,',
#   'Washington',
#   'next',
#   'language',
#   'penis',
#   'penis’s',
#   'rock-hard',
#   'anaconda,',
#   'penis',
#   'very',
#   'sort',
#   'same',
#   'arm',
#   'sleeve',
#   'silky',
#   'woolen',
#   'word',
#   'dictionary,',
#   'thesaurus…',
#   'thesaurus.',
#   'way',
#   'ribbon-cutting',
#   'walls',
#   'more',
#   'moment.”',
#   'very',
#   'equivalent',
#   'entryway.',
#   'parking',
#   'first',
#   'penis',
#   'pipe.',
#   'plumber?',
#   'choke…',
#   'penis.',
#   'penis',
#   'back',
#   'cock.',
#   'need',
#   'first',
#   'last',
#   'essential',
#   'thing',
#   'boyfriend',
#   'smell',
#   'fresh',
#   'family’s',
#   'basement,',
#   'deck?',
#   'boyfriend.',
#   'torso.',
#   'whole…',
#   'whole',
#   'sense',
#   'desire,',
#   'desire',
#   'consumption',
#   'fry,',
#   'quote',
#   'wisdom',
#   'ages.',
#   'young.”',
#   'past.',
#   'July',
#   'moonlight,',
#   'feeling',
#   'awesomeness',
#   'full',
#   'entire',
#   'entire',
#   'older',
#   'beer',
#   'car',
#   'Personal',
#   '48',
#   'Giant',
#   'PSATs.',
#   'limiting',
#   'party',
#   'way,',
#   'teeth.”',
#   'teeth',
#   'way',
#   'blow',
#   'mouth,',
#   'side',
#   'road…',
#   'blow',
#   'ages,',
#   'first',
#   'woods',
#   'other',
#   'craziest…”',
#   'craziest',
#   'windowed',
#   'letter,',
#   'address',
#   'same',
#   'craziest',
#   'intensity',
#   'blow',
#   'wasting',
#   'essential',
#   'thing.',
#   'problem.',
#   'person',
#   'jangle',
#   'bells',
#   'blow',
#   'problem',
#   'dumb',
#   'moment',
#   'torso',
#   'face',
#   'thing.',
#   'answer',
#   'house’s',
#   'resort.',
#   'eventual',
#   'moody',
#   'true',
#   'family.',
#   'idea',
#   'scratch-and-sniff',
#   'back',
#   'sticker',
#   'seam',
#   'Health',
#   'pride',
#   'time.',
#   'son',
#   'father,',
#   'man’s',
#   'role',
#   'side.',
#   'road,',
#   'hell',
#   'boyfriend’s',
#   'word',
#   'word',
#   'same',
#   'mix',
#   'meanings',
#   'recognition',
#   'potency',
#   'word',
#   'current',
#   'fuck',
#   'way',
#   'father,',
#   'way',
#   'father’s',
#   'quality',
#   'Olympic',
#   'year,',
#   'failed',
#   'end',
#   'summer',
#   'first',
#   'difference',
#   'spirit',
#   'cave',
#   'way',
#   'basement',
#   'stairs',
#   'running',
#   'confident',
#   'top',
#   'show,',
#   'fuckin’',
#   'course',
#   'show.',
#   'running',
#   'end',
#   'last',
#   'original',
#   'ladder,',
#   'plan',
#   'way.',
#   'time.',
#   'language',
#   'windows',
#   'Russian',
#   'same',
#   'prose',
#   'interesting',
#   'story,',
#   'worst',
#   'most',
#   'collection.”',
#   'dick',
#   'end.',
#   'moon,',
#   'south',
#   'simple',
#   'little',
#   'clicker,',
#   'ego.',
#   'expression.',
#   'difficult',
#   'chips',
#   'sophistication.',
#   'guidance',
#   'deans,',
#   'very',
#   'place,',
#   'coursework',
#   'blow',
#   'blow',
#   'blow',
#   'blow',
#   'work',
#   'fruits',
#   'time',
#   'sort',
#   'day.',
#   'lead',
#   'television',
#   'lead',
#   'show?',
#   'darkest',
#   'show.',
#   'form,',
#   'flesh',
#   'indignities',
#   'embarrassments',
#   'real',
#   'photo,',
#   'old',
#   'diner',
#   'table?',
#   'latest',
#   'old',
#   'old',
#   'way',
#   '“B.”',
#   'prospect',
#   'cycle',
#   'innocent,',
#   'innocent,',
#   'scary,',
#   'way',
#   'bats',
#   'cave',
#   'bats',
#   'little',
#   'other',
#   'way',
#   'university',
#   'level',
#   'slut',
#   'rules',
#   'sleeves',
#   'place?',
#   'top.',
#   'cost',
#   'latest',
#   'end',
#   'blow',
#   'final',
#   'others',
#   'Sharon',
#   'whole',
#   'latest',
#   'entire',
#   'very',
#   'Batman',
#   'courage',
#   'teeth',
#   'most',
#   'other',
#   'cave',
#   'while',
#   'fools.',
#   'two',
#   'toothy',
#   'biz,',
#   'sunset',
#   'most',
#   'male',
#   'day',
#   'male',
#   'pops',
#   'table.',
#   'mystery',
#   'ditz.',
#   'answer',
#   'D',
#   'D',
#   'man',
#   'way',
#   'same',
#   'favor,',
#   'beauty',
#   'toothy',
#   'audacity',
#   'reminder',
#   'way',
#   'teeth.',
#   'teeth',
#   'blow',
#   'seeds',
#   'watermelon.',
#   'pleasure',
#   'blow',
#   'sand',
#   'oyster',
#   'pearl.',
#   'sea',
#   'caramel.',
#   'caramel',
#   'taste.',
#   'blow',
#   'ways',
#   'little',
#   'cereal',
#   'little',
#   'wall',
#   'grains',
#   'steady,',
#   'cereal.',
#   'teeth',
#   'blow',
#   'details',
#   'textures',
#   'English',
#   'universal',
#   'particular.',
#   'plums',
#   'icebox,',
#   'popping',
#   'microphone.',
#   'windowpane,”',
#   'blow',
#   'richest',
#   'blow',
#   'stakes.',
#   'teeth,',
#   'boneless',
#   'teeth…',
#   'centuries',
#   'thing.',
#   'fun',
#   'rough',
#   'lip',
#   'point.',
#   'ghost',
#   'orb.',
#   'human',
#   'form’s',
#   'universe',
#   'splendor',
#   'soul',
#   'translation',
#   'lesson',
#   'way…',
#   'lesson',
#   'dignity',
#   'ocean.',
#   'ocean.',
#   'ocean',
#   'feet',
#   'ocean',
#   'legs',
#   'ocean.',
#   'holes',
#   'teeth',
#   'blow',
#   'rules,',
#   'throne,',
#   'ecstasy',
#   'blow',
#   'pursuit',
#   'privacy',
#   'Loft.',
#   'best'],
#  'typical': ['stand-up'],
#  'stand-up': ['comedy'],
#  'comedy': ['show'],
#  'show': ['by', 'because', 'up,', 'up', 'continues,', 'you', 'me', 'me'],
#  'by': ['delivering',
#   'self-deprecation,',
#   'Madonna',
#   'now',
#   'some',
#   'the',
#   'kicking',
#   'since',
#   'for',
#   'the',
#   'a',
#   'the',
#   'car.”',
#   'the',
#   'to',
#   'Vladimir',
#   'one.',
#   'it.',
#   'you.”',
#   'me',
#   'the',
#   'now,',
#   'the'],
#  'delivering': ['a'],
#  'a': ['unique',
#   'theatrical',
#   'cerebral',
#   'refusal',
#   'fresh',
#   '“thinking,',
#   'society',
#   'thought-provoking',
#   'Prayer”',
#   'mystery',
#   'little',
#   'prayer',
#   'microphone',
#   'blow',
#   'bit',
#   'way',
#   'parent',
#   'sibling,',
#   'term',
#   'more',
#   'strong',
#   'sort',
#   'constant',
#   'nightmare,',
#   'nightmare',
#   'woman',
#   'bit',
#   'mental',
#   'mental',
#   'gray',
#   'ghost.',
#   'ghost,',
#   'future',
#   'ghost,',
#   'place',
#   'house,',
#   'quaint',
#   'meditation',
#   'ghost,',
#   'ghost,',
#   'strong',
#   'robust',
#   'ghost.',
#   'bit.',
#   'lifelong',
#   'photograph',
#   'little',
#   'great-grandson.',
#   'thing',
#   'heterosexual',
#   'patent',
#   'girl',
#   'ponytail',
#   'lot',
#   'good',
#   'kind',
#   'word',
#   'problem',
#   'soft',
#   'problem.',
#   'joke.',
#   'problem',
#   'way,',
#   'cock,',
#   'cock,',
#   'cock?',
#   'cock.”',
#   'penis',
#   'cock,',
#   'friend’s',
#   'cock,',
#   'little',
#   'cock?',
#   'cock.”',
#   'chance',
#   'chance',
#   'fan',
#   'regularity',
#   'sort',
#   'taste',
#   'fan.',
#   'filling',
#   'filling',
#   'little',
#   'building,',
#   'romantic',
#   'boldly',
#   'minute.”',
#   'bouquet',
#   'crack',
#   'more',
#   'shot.',
#   'tattered',
#   'tale',
#   'vulva',
#   'burger',
#   'threat',
#   'spill.',
#   'risk',
#   'sudden',
#   'feminine',
#   'Susan,',
#   'little',
#   'certain',
#   'scene,',
#   'face.',
#   'hysterical',
#   'kind',
#   'hideous',
#   'little',
#   'hint',
#   'family',
#   'pushing',
#   'journal',
#   'selfless,',
#   'tree',
#   'puppet',
#   'puppet',
#   'list',
#   'part',
#   'penis.”',
#   'warning',
#   'sexually-inspiring',
#   'village.',
#   'very',
#   'burping',
#   'room',
#   'penis',
#   'toothy',
#   'big',
#   'practical',
#   'potential',
#   'diagonal…',
#   'diagonal',
#   'blow',
#   'cucumber',
#   'demonstration',
#   'face',
#   'little',
#   'storm.',
#   'nearly',
#   'proper',
#   'sort',
#   'good',
#   'risk',
#   'risk',
#   'fool.”',
#   'fool,',
#   'fool.',
#   'fool',
#   'fool',
#   'guaran…',
#   'guarantee',
#   'couple',
#   'specific',
#   'hint',
#   'principal',
#   'baby.”',
#   'couple',
#   'freeze.',
#   'freeze.',
#   'plastic',
#   'bus',
#   'bit',
#   'point',
#   'single',
#   'minor',
#   'couple',
#   'group',
#   'picnic',
#   'moment',
#   'dick',
#   'dick',
#   'dick',
#   'dick',
#   'dick',
#   'field',
#   'pinch',
#   'weapon…',
#   'girl',
#   'second?',
#   'girl',
#   'penis-paper-scissors',
#   'good',
#   'rock.',
#   '50-50',
#   'rock',
#   'rock.”',
#   'slappy',
#   'spirit.',
#   'spirit.',
#   'risk',
#   'nice',
#   'pureed',
#   'bite,',
#   'boneless',
#   'bag',
#   'nipple.',
#   'pebble',
#   'tiny,',
#   'rock',
#   'rock',
#   'sudden.',
#   'little',
#   'snake.',
#   'snake.',
#   'penis',
#   'complaint',
#   'guided',
#   'guided',
#   'coat',
#   'minute',
#   'bit',
#   'penis',
#   'guest',
#   'working',
#   'while',
#   'glove',
#   'glove,',
#   'matter',
#   'building.',
#   'store,',
#   'Target,',
#   'problem',
#   'choking',
#   'long',
#   'few',
#   'gumball.',
#   'gumball',
#   'real',
#   'threat',
#   'blow',
#   'boyfriend',
#   'grade',
#   'bed',
#   'patient',
#   'table',
#   'slow-moving',
#   'newly-finished',
#   'blow',
#   'vacuum.',
#   'bummer',
#   'French',
#   'bit.',
#   'big',
#   'young,',
#   'team-spirit-building',
#   'way.',
#   'blow',
#   '‘Just',
#   'car.',
#   'beer.”',
#   'cocktail',
#   'young',
#   'close',
#   'negative',
#   'blow',
#   'blow',
#   'thing,',
#   'blow',
#   'thing',
#   'simple,',
#   'window',
#   'blow',
#   'risk,',
#   'way',
#   'little',
#   'fool',
#   'second',
#   'second',
#   'blow',
#   'position',
#   'solution,',
#   'deep',
#   'self-starter,',
#   'voucher.',
#   'gift',
#   'hotel',
#   'big',
#   'shit.',
#   'goof,',
#   'collection',
#   'variety',
#   'little',
#   'good',
#   'faded',
#   'man’s',
#   'stink',
#   'sticker',
#   'sexually-active',
#   'problem,',
#   'sexually-active,',
#   'notable',
#   'boyfriend’s',
#   'figure',
#   'good',
#   'wave',
#   'whiff',
#   'particular',
#   'lot',
#   'cognitive',
#   'man',
#   'single',
#   'river,',
#   'river',
#   'stone,',
#   'courtesy',
#   'man.',
#   'blow',
#   'new',
#   'new',
#   'new',
#   'blow',
#   'mask',
#   'sexual',
#   'literal',
#   'moment',
#   'dead',
#   'single',
#   'little',
#   'diving',
#   'move',
#   'new',
#   'new',
#   '‘just',
#   'second',
#   'way.',
#   'slightly',
#   'tooth,',
#   'character',
#   'short',
#   'blow',
#   'way?',
#   'young',
#   'little',
#   'minute.',
#   'little',
#   'tiny',
#   'difference,',
#   'Tony',
#   'point',
#   'difficult',
#   'sort',
#   '4.0',
#   'lesser',
#   'triumph.',
#   'goddamn',
#   'sort',
#   'lot',
#   'Jew,',
#   'kind',
#   'Jewish',
#   'conquered',
#   'basic',
#   'working',
#   'love',
#   'poem?',
#   'crude',
#   'lot',
#   'French',
#   'fry.',
#   'let-down',
#   'marriage',
#   'blow',
#   'love',
#   'modern',
#   'real',
#   'man.',
#   'single',
#   'photo',
#   'hint',
#   'knowing',
#   'photo,',
#   'winter',
#   'fear',
#   'little',
#   'Batman,',
#   'fear',
#   'strength,',
#   'fear',
#   'restaurant.',
#   'blow',
#   'little',
#   'little',
#   'broken',
#   'lot',
#   'chuckle',
#   'fear,',
#   'confident',
#   'long,',
#   'quirky',
#   'little',
#   'bookstore',
#   'little',
#   'bookshop.',
#   'little.',
#   'spirit…”',
#   'toothy',
#   'problem,',
#   'tragic',
#   'confident…',
#   'giant.',
#   'giant,',
#   'little',
#   'single',
#   'flaw,',
#   'thousand',
#   'constant',
#   'steady',
#   'man’s',
#   'base…',
#   'dry',
#   'restaurant.',
#   'man',
#   'lantern,',
#   'mystery.”',
#   'word.”',
#   'vigilance.',
#   'child-proofing,',
#   'drunken',
#   'sweat.',
#   'hard',
#   'toothy',
#   'toothy',
#   'toothy',
#   'toothy',
#   'blow',
#   'blow',
#   'blow',
#   'blow',
#   'mouth.',
#   'mouth',
#   'roomier',
#   'dick',
#   'blow',
#   'reminder,',
#   'flawed',
#   'flailing',
#   'bad',
#   'prize.',
#   'wonderful',
#   'Susan',
#   'bone',
#   'boneless',
#   'hobgoblin',
#   'smooth,',
#   'fit.',
#   'round',
#   'round',
#   'mouth',
#   'couple',
#   'more',
#   'visitation.',
#   'small',
#   'few',
#   'body',
#   'ghost.',
#   'nightclub',
#   'cautionary',
#   'single',
#   'prayer',
#   'dream',
#   'prayer',
#   'dream',
#   'prayer',
#   'muse',
#   'mystery',
#   'dream',
#   'prayer',
#   'prayer',
#   'muse',
#   'mystery',
#   'dream',
#   'prayer',
#   'prayer',
#   'week'],
#  'unique': ['blend'],
#  'blend': ['of'],
#  'of': ['personal',
#   'oral',
#   'physical',
#   'embodying',
#   'sexual',
#   'human',
#   'tedium,”',
#   'our',
#   'these',
#   'your',
#   'love,',
#   'thing.',
#   'poetic',
#   'the',
#   'being',
#   'enchantment.',
#   'ideas',
#   'mine,',
#   'sack',
#   'sex',
#   'course,',
#   'myself',
#   'course.',
#   'in',
#   'instantly',
#   'these',
#   'the',
#   'light',
#   'you',
#   'the',
#   'a',
#   'seemingly',
#   'course,',
#   'me',
#   'you’d',
#   'dignity',
#   'your',
#   'slips',
#   'the',
#   'the',
#   'tender',
#   'these',
#   'devastation,',
#   'that',
#   'telling',
#   'the',
#   'the',
#   'these',
#   'like,',
#   'church',
#   'the',
#   'an',
#   'eternal',
#   'the',
#   'the',
#   'roses',
#   'them',
#   'the',
#   'the',
#   'tilted',
#   'a',
#   'how',
#   'a',
#   'a',
#   'the',
#   'guy',
#   'women.',
#   'the',
#   'the',
#   'a',
#   'sudden',
#   'Abigail',
#   'my',
#   'a',
#   'pleasure,',
#   'the',
#   'the',
#   'the',
#   'it',
#   'the',
#   'for',
#   'came',
#   'instructions',
#   'the',
#   'a',
#   'the',
#   'the',
#   'the',
#   'course.',
#   'an',
#   'blue',
#   'overtired…',
#   'the',
#   'the',
#   '“Oh,',
#   'teeth,',
#   'a',
#   'nowhere,',
#   'the',
#   'respect',
#   'which',
#   'the',
#   'blinking',
#   'prudent',
#   'the',
#   'as',
#   'the',
#   '50%',
#   'zero',
#   'self-hatred',
#   'act.',
#   'play…',
#   'cliché',
#   'contrivance.',
#   'the',
#   'me',
#   'my',
#   'all,',
#   'my',
#   'authenticity.',
#   'this.',
#   'what',
#   'the',
#   'daring',
#   'the',
#   'the',
#   'inherently',
#   'could',
#   'the',
#   'gravity',
#   'people',
#   'running',
#   'this',
#   'how',
#   'the',
#   'the',
#   'object.',
#   'spinach,',
#   'parsley.',
#   'meat.',
#   'blood',
#   'the',
#   'a',
#   'thing',
#   'the',
#   'me',
#   'me',
#   'a',
#   'them',
#   'amble',
#   'this',
#   'a',
#   'scale',
#   'what',
#   'fear',
#   'choking,',
#   'my',
#   'choking',
#   'myself',
#   'their',
#   'a',
#   'a',
#   'the',
#   'desire',
#   'the',
#   'things,',
#   'quotations.',
#   'lock',
#   'the',
#   'the',
#   'this',
#   'the',
#   'thing.”',
#   'the',
#   'a',
#   'Awaken',
#   'your',
#   'teeth,',
#   'you',
#   'you.',
#   'you.',
#   'view',
#   'the',
#   'it?',
#   'that,',
#   'that.',
#   'genius,',
#   'my',
#   'dignity.',
#   'the',
#   'genitals.',
#   'the',
#   'the',
#   'someone',
#   'sexual',
#   'confidence,',
#   'idiosyncratic',
#   'lesser',
#   'the',
#   'the',
#   'personhood.',
#   'the',
#   'being',
#   'your',
#   'my',
#   'his',
#   'us',
#   'yours.',
#   'asshole.',
#   'the',
#   'six',
#   'these',
#   'stir',
#   'original',
#   'my',
#   'your',
#   'it.',
#   'the',
#   'someone',
#   'the',
#   'my',
#   'needed',
#   'my',
#   'confidence',
#   'the',
#   'my',
#   'a',
#   'the',
#   'the',
#   'a',
#   'in',
#   'Vladimir',
#   'pizza',
#   'it,',
#   'yourself.',
#   'the',
#   'a',
#   'you',
#   'course.',
#   'the',
#   'pain.',
#   'neuroses.',
#   '3.7-in-the-AP-course-load',
#   'gal.',
#   'them.',
#   'Catholic-ish',
#   'Catholic',
#   'scurrying',
#   'Philip',
#   'philosophy',
#   'our',
#   'friends,',
#   'prevailing',
#   'course,',
#   'yourself',
#   'your',
#   'mine.',
#   'mine.',
#   'them.',
#   'them,',
#   'them',
#   'you',
#   'a',
#   'these',
#   'sugar',
#   'my',
#   'bats.',
#   'bats',
#   'these',
#   'my',
#   'nuance',
#   'diagonals',
#   'my',
#   'excellence?',
#   'tragic',
#   'excellence.',
#   'my',
#   'goes',
#   'a',
#   'confident',
#   'blow',
#   'his',
#   'laughter',
#   'laying',
#   'just…',
#   'the',
#   'them.',
#   'orifices',
#   'the',
#   'spectacle.',
#   'the',
#   'my',
#   'life',
#   'little',
#   'act,',
#   'our',
#   'course…',
#   'course,',
#   'the',
#   'appreciating',
#   'that,',
#   'riches.',
#   'their',
#   'riches',
#   'men',
#   'letters',
#   'appreciating…',
#   'fools,',
#   'you',
#   'my',
#   'my',
#   'societal'],
#  'personal': ['anecdotes', 'stories', 'anecdotes'],
#  'anecdotes': ['and', 'Dylan'],
#  'and': ['intellectual',
#   'the',
#   'a',
#   'the',
#   'comedic',
#   'expression,',
#   'keep',
#   'fair',
#   'torso,',
#   'ass',
#   'it’s',
#   'fly',
#   'I’ll',
#   'I',
#   'someone’ll',
#   'you',
#   'appear',
#   'you',
#   'no,',
#   'age.',
#   'yet,',
#   'now',
#   'kick',
#   'I',
#   'rightfully',
#   'down',
#   'the',
#   'we…',
#   'it’s',
#   'then',
#   'again',
#   'it',
#   'it',
#   'it',
#   'I',
#   'one',
#   'then',
#   'then',
#   'they’re',
#   'applauding]',
#   'said,',
#   'then',
#   'sulking',
#   'fair',
#   'that’s',
#   'absorb',
#   'strong.',
#   'does',
#   'hangs',
#   'scaring',
#   'you’re',
#   'I’d',
#   'that’s',
#   'delicate.',
#   'tap.',
#   'tap.',
#   'it’ll',
#   'pretty',
#   'I’m',
#   'me',
#   'the',
#   'over',
#   'I',
#   'Over',
#   'Over?',
#   '’cause',
#   'she',
#   'I’m',
#   'she',
#   'I',
#   'do',
#   'let',
#   'then',
#   'that',
#   'myself?',
#   'insult',
#   'someone',
#   'someone',
#   'then',
#   'hate',
#   'applauding]',
#   'you',
#   'then',
#   'she',
#   'the',
#   'if',
#   'applauding]',
#   'authentically',
#   'I',
#   'I',
#   'I',
#   'came',
#   'presently?',
#   'I',
#   'I',
#   'that’s',
#   'what',
#   'applauding]',
#   'sure,',
#   'take',
#   'shake',
#   'at',
#   'angle',
#   'the',
#   'me.',
#   'I',
#   'it’s',
#   'you',
#   'me',
#   'someone',
#   'close',
#   'open',
#   'close',
#   'the',
#   'I’ve',
#   'applauding]',
#   'make',
#   'panic',
#   'applauding]',
#   'make',
#   'then',
#   'it',
#   'I',
#   'I',
#   'the',
#   'my',
#   'that’s',
#   'I’d',
#   'speed-read',
#   'I’m',
#   'the',
#   'I’m',
#   'the',
#   'me,',
#   'then',
#   'that',
#   'they',
#   'now',
#   'applauding]',
#   'on',
#   'she',
#   'then',
#   'then',
#   'still',
#   'applauding]',
#   'for',
#   'then',
#   'the',
#   'I’m',
#   'applauding]',
#   'I',
#   'a',
#   'we',
#   'we',
#   'so',
#   'feebly',
#   'I…',
#   'I',
#   'the',
#   'for',
#   'applauding]',
#   'I',
#   'discomfort',
#   'yours.',
#   'an',
#   'then',
#   'I',
#   'there',
#   'shouldn’t',
#   'did',
#   'it’s',
#   'applauding]',
#   'over',
#   'applauding]',
#   'the',
#   'I',
#   'drowned.',
#   'applauding]',
#   'I',
#   'he',
#   'then',
#   'then',
#   'I',
#   'my',
#   'right,',
#   'actual',
#   'I',
#   'just',
#   'decay',
#   'sort',
#   'sort',
#   'then',
#   'applauding]',
#   'it’s',
#   'I',
#   'I',
#   'cheering]',
#   'hideous',
#   'I…',
#   'it',
#   'I',
#   'I',
#   'cheering]',
#   'let',
#   'it',
#   'I',
#   'now',
#   'it',
#   'inspiring.',
#   'my',
#   'that’s',
#   'there',
#   'dies',
#   'I',
#   'the',
#   'I',
#   'applauding]',
#   'someone',
#   '“I’m',
#   'I’m',
#   'this',
#   'I',
#   'I',
#   'you',
#   'uh…',
#   'I',
#   'applauding]',
#   'this',
#   'not',
#   'fair',
#   'demonstrate',
#   'I',
#   'I',
#   'you',
#   'applauding]',
#   'I',
#   'I',
#   'I’m',
#   'cigarettes.”',
#   'hold',
#   'I',
#   'so',
#   'applauding]',
#   'with',
#   'finally,',
#   'say,',
#   'destroys',
#   'it’s',
#   'now',
#   'just',
#   'I',
#   'applauding]',
#   'it',
#   'that’s',
#   'he',
#   'fails,',
#   'tries',
#   'fails,',
#   'through',
#   'failing',
#   'trying,',
#   'you’re',
#   'this',
#   'desire',
#   'another',
#   'laughing]',
#   'let',
#   'cheering]',
#   'past',
#   'before',
#   'yet',
#   'directly,',
#   'I',
#   'delight.',
#   'I’ll',
#   'assholes',
#   'self-discovery,',
#   'broader',
#   'self-discovery,',
#   'relationships,',
#   'whimsy',
#   'truths'],
#  'intellectual': ['exploration', 'analysis.', 'like'],
#  'exploration': ['into'],
#  'into': ['the',
#   'a',
#   'a',
#   'the',
#   'the',
#   'the',
#   'the',
#   'a',
#   'the',
#   'the',
#   'on',
#   'this',
#   'your',
#   'her',
#   'what',
#   'the',
#   'a',
#   'a',
#   'Target,',
#   'that',
#   'my',
#   'my',
#   'the',
#   'the',
#   'my',
#   'which'],
#  'act': ['of', 'like', 'like', 'like'],
#  'oral': ['sex,'],
#  'sex,': ['transforming', 'technically-speaking,'],
#  'transforming': ['it'],
#  'it': ['into',
#   'feels',
#   'reminds',
#   'in',
#   'will',
#   'represents',
#   'up',
#   'can',
#   'up.',
#   'is',
#   'is',
#   'moving',
#   'later?',
#   'takes.',
#   'as',
#   'happened',
#   'has',
#   'up',
#   'from',
#   'started',
#   'sounds',
#   'is.',
#   'becomes',
#   'like',
#   'what',
#   'wants',
#   'away.',
#   'like',
#   'even',
#   'suffices.',
#   'time',
#   'is',
#   'has',
#   'and',
#   'sort',
#   'is',
#   'is',
#   'doesn’t…',
#   'doesn’t',
#   'withers.',
#   'blooms',
#   'withers',
#   'blooms',
#   'gathers',
#   'in',
#   'into',
#   'just',
#   'requires',
#   'a',
#   'up',
#   'holds.',
#   'down,',
#   'out.',
#   'on',
#   'doesn’t',
#   'holds.',
#   'doesn’t',
#   'does.',
#   'as',
#   'doesn’t',
#   'back',
#   'always',
#   'with',
#   'can',
#   'takes',
#   'was',
#   'was',
#   'in',
#   'and',
#   'and',
#   'but',
#   'was',
#   'feels',
#   'is',
#   'wasn’t',
#   'more',
#   'again',
#   'one',
#   'spin',
#   'all',
#   'took',
#   'comes',
#   'feels',
#   'comes',
#   'takes.',
#   'in',
#   'happens.',
#   'into',
#   'over',
#   'fell',
#   'out.',
#   'seems',
#   'is.',
#   'seem',
#   'was',
#   'to',
#   'quite',
#   'gets',
#   'with',
#   '’cause',
#   'was',
#   'too',
#   'in',
#   'as',
#   '’cause',
#   '’cause',
#   'and',
#   'and',
#   'sounds',
#   'as',
#   'up',
#   'taut,',
#   'safely',
#   'was',
#   'to',
#   'to',
#   'in',
#   'on',
#   'in',
#   'was',
#   'cannot',
#   'shouldn’t',
#   'should',
#   'just',
#   'like',
#   'yet.',
#   'well.',
#   'before.',
#   'badly,',
#   'badly.',
#   'did.',
#   'to',
#   'was',
#   'was',
#   'before',
#   'to',
#   'goes.',
#   'aside.',
#   'solved',
#   'would',
#   'is',
#   'out,',
#   'white',
#   'was',
#   'was',
#   'wasn’t',
#   'once',
#   'again,',
#   'would',
#   'again,',
#   'all',
#   'was',
#   'crack.',
#   'crack,',
#   'back',
#   'is',
#   'is',
#   'is.',
#   'in',
#   'in',
#   'all',
#   'all',
#   'might',
#   'got',
#   'should,',
#   '’cause',
#   'and',
#   'was',
#   'was',
#   'was',
#   'was',
#   'off.',
#   'was',
#   'was',
#   'can.',
#   'slow.”',
#   'slow.”',
#   'slow…',
#   'slow.',
#   'stays',
#   'to',
#   'can',
#   'off',
#   'felt',
#   'terrifies',
#   'is.',
#   'any',
#   'to',
#   'at',
#   'couldn’t',
#   'would',
#   'without',
#   'right.',
#   'does',
#   'may',
#   'is',
#   'is',
#   'so.',
#   'is',
#   'work',
#   'work',
#   'would',
#   'to',
#   'were',
#   'wouldn’t',
#   'very',
#   'already',
#   'is',
#   'shall'],
#  'theatrical': ['experience'],
#  'experience': ['at', 'it', 'at'],
#  'at': ['the',
#   'him,',
#   'the',
#   'times.',
#   'all,',
#   'home.',
#   'the',
#   'minimum.',
#   'all.',
#   'all',
#   'being',
#   'being',
#   'her,',
#   'a',
#   'its',
#   'a',
#   'risk,',
#   'my',
#   'my',
#   'that',
#   'least',
#   'all',
#   'me,',
#   'all,',
#   'a',
#   'me,',
#   'the',
#   'ease.',
#   'its',
#   'the',
#   'some',
#   'the',
#   'this',
#   'Borders',
#   'most.',
#   'a',
#   'all,',
#   'all,',
#   'adjusting',
#   'the',
#   'me',
#   'the',
#   'that',
#   'all.',
#   'the',
#   'a',
#   'the',
#   'ease,',
#   'the',
#   'the',
#   'a',
#   'parties.',
#   'this',
#   'this',
#   'the',
#   'photos',
#   'these',
#   'a',
#   'night',
#   'school,',
#   'Batman',
#   'the',
#   'you.',
#   'you.”',
#   'you.',
#   'the',
#   'the',
#   'his',
#   'you',
#   'a…',
#   '14,',
#   'me',
#   'the',
#   'all?',
#   'all.',
#   'all.',
#   'bare',
#   'bare,',
#   'all.',
#   'this',
#   'the',
#   'all,'],
#  'Cherry': ['Lane'],
#  'Lane': ['Theater.'],
#  'Theater.': ['Stripping'],
#  'Stripping': ['away'],
#  'away': ['the', 'at', 'from', 'by', 'from'],
#  'primal': ['elements'],
#  'elements': ['typically'],
#  'typically': ['associated'],
#  'associated': ['with'],
#  'with': ['the',
#   'intellectual',
#   'contradictions.',
#   'a',
#   'dignity.',
#   'some',
#   'him.',
#   'it',
#   'anything',
#   'a',
#   'the',
#   'the',
#   'the',
#   'a',
#   'inspiration.',
#   'all',
#   'the',
#   'it.',
#   'my',
#   'these',
#   'my',
#   'my',
#   'authority',
#   'confidence?',
#   'me',
#   'the',
#   'the',
#   'those',
#   'something…',
#   'something?',
#   'what',
#   'balls',
#   'the',
#   'the',
#   'it.',
#   'precision,',
#   'more',
#   'me.”',
#   'those',
#   'it.”',
#   'the',
#   'the',
#   'my',
#   'me,',
#   'lip',
#   'a',
#   'which',
#   'every',
#   'you',
#   'your',
#   'feet.',
#   'the',
#   'this',
#   'a',
#   'the',
#   'the',
#   'brown',
#   'red',
#   'an',
#   'it,',
#   'which',
#   'this',
#   'me,',
#   'the',
#   'myself',
#   'yet',
#   'this',
#   'that',
#   'that',
#   'courage,',
#   'his',
#   'him.',
#   'every',
#   'that?',
#   'your',
#   'keen',
#   'personal'],
#  'act,': ['Novak', 'you', 'so'],
#  'invites': ['the'],
#  'audience': ['into'],
#  'cerebral': ['discussion'],
#  'discussion': ['on'],
#  'subject,': ['humorously', 'is'],
#  'humorously': ['dissecting', 'tackles', 'explores', 'critiques'],
#  'dissecting': ['its'],
#  'its': ['semantics,',
#   'own',
#   'needs,',
#   'wants,',
#   'sort',
#   'presence,',
#   'nature?',
#   'strength,',
#   'particular',
#   'most,',
#   'bit,',
#   'death',
#   'existence',
#   'hardest,',
#   'hardest,',
#   'own',
#   'teeth',
#   'glory?',
#   'very'],
#  'semantics,': ['cultural'],
#  'cultural': ['perceptions,'],
#  'perceptions,': ['and'],
#  'juxtaposition': ['of'],
#  'physical': ['desire', 'form.'],
#  'desire': ['with', 'or', 'through', 'alone.'],
#  'analysis.': ['Her'],
#  'Her': ['performance,'],
#  'performance,': ['characterized'],
#  'characterized': ['by'],
#  'self-deprecation,': ['sharp'],
#  'sharp': ['wit,', 'senses'],
#  'wit,': ['and'],
#  'refusal': ['to', 'to'],
#  'to': ['conform',
#   'conventional',
#   'a',
#   'give',
#   'do,',
#   'maintain',
#   'call',
#   'become',
#   'warn',
#   'write',
#   'grow',
#   'the',
#   'take',
#   'look,',
#   'be',
#   'say.',
#   'keep',
#   'keep',
#   'take',
#   'it.',
#   'discarding',
#   'being',
#   'cast',
#   'become',
#   'linger.',
#   'haunt',
#   'night',
#   'their',
#   'be',
#   'know',
#   'the',
#   'talk',
#   'gather',
#   'be',
#   'me.',
#   'discarding',
#   'me,',
#   'me.',
#   'it.',
#   'what',
#   'me,',
#   'hear.',
#   'talking.',
#   'it.',
#   'me,',
#   'the',
#   'act',
#   'me?',
#   'me.',
#   'me',
#   'code.',
#   'just',
#   'tell',
#   'say',
#   'get',
#   'me',
#   'me.',
#   'things.”',
#   'notice',
#   'it…',
#   'mind',
#   'say,',
#   'just',
#   'it.',
#   'the',
#   'go',
#   'retreat.”',
#   'think',
#   'be',
#   'see',
#   'please',
#   'the',
#   'see',
#   'a',
#   'injure',
#   'land',
#   'me.',
#   'do',
#   'look',
#   'relieve',
#   'get',
#   'relieve',
#   'relieve',
#   'burp',
#   'give',
#   'the',
#   'go',
#   'teach',
#   'us,',
#   'give',
#   'know',
#   'demonstrate',
#   'our',
#   'let',
#   'be',
#   'whom?”',
#   'ask',
#   'ask',
#   'be',
#   'say',
#   'err',
#   'me',
#   'look',
#   'play',
#   'let',
#   'do.',
#   'play',
#   'play',
#   'my',
#   'make',
#   'make',
#   'dance',
#   'freeze',
#   'the',
#   'this',
#   'think',
#   'a',
#   'do.',
#   'look',
#   'touch',
#   'know',
#   'the',
#   'add',
#   'be',
#   'do',
#   'help,',
#   'help',
#   'take',
#   'me,',
#   'be',
#   'know',
#   'the',
#   'be',
#   'me.',
#   'another',
#   'bite',
#   'it?',
#   'believe',
#   'remind',
#   'make',
#   'me',
#   'the',
#   'a',
#   'the',
#   'elbow',
#   'spend',
#   'line',
#   'it',
#   'Target',
#   'be',
#   'live',
#   'do',
#   'be',
#   'give',
#   'be',
#   'attempting',
#   'do',
#   'do',
#   'do',
#   'do',
#   'understand',
#   'try',
#   'get',
#   'this',
#   'give',
#   'be',
#   'the',
#   'some.',
#   'achieve',
#   'prepare',
#   'the',
#   'level',
#   'worry',
#   'be',
#   'have',
#   'have',
#   'have',
#   'you?”',
#   'put',
#   'you?”',
#   'me',
#   'have',
#   'it.',
#   'be',
#   'articulate',
#   'the',
#   'narrate,',
#   'explain',
#   'provide',
#   'make',
#   'communicate',
#   'attempt',
#   'go,',
#   'get',
#   'let',
#   'surprise.',
#   'do.',
#   'the',
#   'get',
#   'appear',
#   'him.',
#   'spend',
#   'use',
#   'my',
#   'the',
#   'be',
#   'employ',
#   'express',
#   'gain',
#   'have',
#   'have',
#   'yours.”',
#   'say,',
#   'the',
#   'your',
#   'put',
#   'pasture.',
#   'be',
#   'be',
#   'me,',
#   'me,',
#   'me',
#   'your',
#   'me',
#   'the',
#   'go',
#   'your',
#   'be',
#   'say.”',
#   'sort',
#   'break',
#   'men',
#   'the',
#   'be',
#   'a',
#   'know',
#   'be',
#   'just',
#   'wait',
#   'college',
#   'be',
#   'be',
#   'know',
#   'be',
#   'discern',
#   'act',
#   'say',
#   'keep',
#   'live…”',
#   'the',
#   'turn',
#   'be',
#   'just',
#   'yourself?',
#   'narrate',
#   'find',
#   'find',
#   'literature.',
#   'be',
#   'be',
#   'the',
#   'dissociation',
#   'me.',
#   'her,',
#   'a',
#   'show',
#   'me',
#   'just',
#   'it.',
#   'the',
#   'pick',
#   'write',
#   'college,',
#   'teach.',
#   'blow',
#   'speak…',
#   'our',
#   'be',
#   'forget',
#   'get',
#   'a',
#   'destroy',
#   'serve',
#   'me.',
#   'just',
#   'collect',
#   'give',
#   'express',
#   'the',
#   'the',
#   'the',
#   'turn',
#   'go',
#   'emerge',
#   'Jac,',
#   'really',
#   'me.',
#   'tell',
#   'at',
#   'wonder',
#   'school',
#   'do',
#   'make',
#   'her?”',
#   'conqueror',
#   'force',
#   'ripple',
#   'the',
#   'be',
#   'conjure',
#   'be',
#   'negotiate',
#   'date.”',
#   'just',
#   'be',
#   'try',
#   'save',
#   'learn.”',
#   'receive',
#   'poeticize',
#   'bolster',
#   'lay',
#   'modulate.',
#   'be',
#   'this',
#   'form',
#   'kind',
#   'emotionally',
#   'do',
#   'not',
#   'not',
#   'find',
#   'not',
#   'romanticize',
#   'defend',
#   'say',
#   'try',
#   'get',
#   'offer',
#   'him,',
#   'him,',
#   'smoothly',
#   'go',
#   'the',
#   'put',
#   'crawl.',
#   'this',
#   'her',
#   'a',
#   'the',
#   'the',
#   'push',
#   'have',
#   'o’er',
#   'make',
#   'try',
#   'make',
#   'be',
#   'understand',
#   'make',
#   'entertain',
#   'be',
#   'the',
#   'me',
#   'me',
#   'me',
#   'me',
#   'reflect',
#   'your'],
#  'conform': ['to'],
#  'conventional': ['comedic'],
#  'comedic': ['tactics,', 'lens,'],
#  'tactics,': ['offers'],
#  'offers': ['a'],
#  'fresh': ['perspective', 'rug.'],
#  'perspective': ['on'],
#  'gender': ['dynamics,'],
#  'dynamics,': ['sexual'],
#  'sexual': ['expectations,',
#   'identity',
#   'skills',
#   'experience,',
#   'running',
#   'experience'],
#  'expectations,': ['and'],
#  'often-comical': ['reality'],
#  'reality': ['of'],
#  'embodying': ['a', 'the'],
#  '“thinking,': ['feeling,'],
#  'feeling,': ['desiring'],
#  'desiring': ['body”'],
#  'body”': ['in'],
#  'in': ['a',
#   'the',
#   'a',
#   'college.',
#   'a',
#   'windowsills,',
#   'my',
#   'a',
#   'its',
#   'a',
#   'the',
#   'this',
#   'that',
#   'its',
#   'the',
#   'his',
#   'theory…',
#   'theory,',
#   'the',
#   'its',
#   'that',
#   'this',
#   'the',
#   'the',
#   'the',
#   'crinkly,',
#   'the',
#   'the',
#   'The',
#   'that',
#   'that',
#   'or',
#   'my',
#   'the',
#   'a',
#   'a',
#   'cellophane',
#   'this',
#   'the',
#   'this',
#   'this',
#   'favor',
#   'the',
#   'the',
#   'the',
#   'the',
#   'myself,',
#   'two',
#   'her',
#   'the',
#   'this',
#   'there,',
#   'gym',
#   'the',
#   'and',
#   'gym.',
#   'the',
#   'the',
#   'a',
#   'and',
#   'that',
#   'this',
#   'that',
#   'a',
#   'a',
#   'there,',
#   'the',
#   'there,',
#   'your',
#   'your',
#   'the',
#   'my',
#   'my',
#   'at',
#   'my',
#   'the',
#   'the',
#   'the',
#   'her.”',
#   'college.',
#   'her”',
#   'this',
#   'my',
#   'the',
#   'someone’s',
#   'this',
#   'this',
#   'a',
#   'the',
#   'my',
#   'the',
#   'those',
#   'a',
#   'sixth',
#   'seventh,',
#   'high',
#   'your',
#   'there?”',
#   'me',
#   'me',
#   'the',
#   'the',
#   'an',
#   'it.',
#   'those',
#   'this',
#   'this',
#   'a',
#   'it,',
#   'the',
#   'a',
#   'a',
#   'here.”',
#   'order',
#   'sunglasses.',
#   'the',
#   'general.',
#   'high',
#   'that',
#   'my',
#   'my',
#   'your',
#   'this',
#   'shorts.',
#   'fear.',
#   'front',
#   'the',
#   'my',
#   'this',
#   'good',
#   'my',
#   'me',
#   'this',
#   'front',
#   'college',
#   'this',
#   'a',
#   'the',
#   'my',
#   'a',
#   'Nabokov’s',
#   'a',
#   'literature,',
#   'the',
#   'the',
#   'on',
#   'my',
#   'my',
#   'my',
#   'a',
#   'neckties',
#   'high',
#   'no',
#   'a',
#   'a',
#   'the',
#   'every',
#   'the',
#   'the',
#   'some',
#   'my',
#   'beautiful',
#   'my',
#   'their',
#   'the',
#   'college…',
#   'college,',
#   'some',
#   'this',
#   'this',
#   'the',
#   'the',
#   'me?',
#   'a',
#   'this',
#   'an',
#   'my',
#   'yet',
#   'the',
#   'your',
#   'a',
#   'my',
#   'a',
#   'closed.',
#   'the',
#   'real',
#   'case',
#   'a',
#   'his',
#   'the',
#   'this',
#   'a',
#   'a',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   '2012,',
#   'every',
#   'this',
#   'the',
#   'the',
#   'the',
#   'the',
#   'coffee',
#   'the',
#   'the',
#   'your',
#   'town.',
#   'the',
#   'a',
#   'being',
#   'the',
#   'awe,',
#   'humble',
#   'a',
#   'my',
#   'my',
#   'the',
#   'its',
#   '“The'],
#  'society': ['filled'],
#  'filled': ['with'],
#  'contradictions.': ['Through'],
#  'Through': ['her'],
#  'her': ['insightful',
#   'is',
#   'to',
#   'coming',
#   'a',
#   'older',
#   'role',
#   'demonstration',
#   'lesson',
#   'global',
#   'out',
#   'yesterday.”',
#   'jumps',
#   'every',
#   'way',
#   'potential'],
#  'insightful': ['and'],
#  'lens,': ['Novak'],
#  'navigates': ['the'],
#  'complexities': ['of'],
#  'identity': ['and'],
#  'expression,': ['making'],
#  'making': ['“Get', 'eye', 'a', 'sure.', 'sure,'],
#  'Knees”': ['a'],
#  'thought-provoking': ['reflection'],
#  'reflection': ['on'],
#  'absurdity': ['of'],
#  'human': ['sexuality.', 'kind', 'form', 'tragedy.', 'absurdities'],
#  'sexuality.': ['*'],
#  '*': ['*', '*', '[“Like', 'Name*'],
#  '[“Like': ['a'],
#  'Prayer”': ['by'],
#  'Madonna': ['playing]'],
#  'playing]': ['[horn'],
#  '[horn': ['honking]'],
#  'honking]': ['♪'],
#  '♪': ['Life',
#   '♪',
#   'Everyone',
#   '♪',
#   'I',
#   '♪',
#   'And',
#   '♪',
#   'Home',
#   '[crowd',
#   'When',
#   '♪',
#   'It’s',
#   '♪',
#   'I’m',
#   '♪',
#   'I',
#   '♪',
#   'In',
#   '♪',
#   'I',
#   '♪',
#   'Just',
#   '♪',
#   'You',
#   'Thank',
#   'Just',
#   '♪',
#   'I’ll',
#   '♪',
#   'It’s',
#   '♪',
#   'Oh',
#   '♪',
#   'Just',
#   '♪',
#   'I’ll',
#   '♪',
#   'It’s',
#   '♪',
#   'Whoa',
#   '♪',
#   'Just',
#   '♪',
#   'Your',
#   '♪',
#   'Just',
#   '♪',
#   'You',
#   '♪',
#   'Just',
#   '♪',
#   'You',
#   '♪',
#   'Just',
#   '♪',
#   'No',
#   '♪',
#   'Just',
#   '♪',
#   'Your',
#   '♪',
#   'Just',
#   '♪',
#   'You',
#   '♪',
#   'Just',
#   '♪',
#   'You',
#   '♪',
#   'Just',
#   '♪',
#   'No',
#   '♪',
#   'Your',
#   '♪',
#   'Like',
#   '[song'],
#  'Life': ['is'],
#  'is': ['a',
#   'the',
#   'your',
#   'a',
#   'a',
#   'I',
#   '“penis”',
#   'a',
#   'our',
#   'a',
#   'one',
#   'clearly',
#   'the',
#   'that',
#   '“What?',
#   'enough,',
#   'in',
#   'the',
#   'its',
#   'a',
#   'a',
#   'a…',
#   'the',
#   'the',
#   'beautiful,',
#   'beautiful,',
#   'beautiful',
#   'beautiful.',
#   'beautiful.',
#   'the',
#   'the',
#   'a',
#   'a',
#   'a',
#   'the',
#   'the',
#   'the',
#   'the',
#   'my',
#   'the',
#   'for',
#   'over.',
#   'clearly',
#   'over',
#   'something',
#   'thin',
#   'always',
#   'that',
#   'to',
#   'over,',
#   'someone',
#   'a',
#   'unimpeachable?',
#   'authentic',
#   'a',
#   'authenticity.',
#   'me',
#   'what',
#   'entirely',
#   'kind',
#   'sort',
#   'no',
#   'that',
#   'just',
#   'no',
#   'there',
#   'something',
#   'like,',
#   'sort',
#   'my',
#   'gonna',
#   'no',
#   'hard.',
#   'not',
#   '“puncture,”',
#   'a',
#   'into',
#   'supposed',
#   'here.',
#   'here.',
#   'more',
#   'as',
#   'true.',
#   'wasted',
#   'and',
#   'you',
#   'when',
#   'that',
#   'stuffed',
#   'not',
#   'dumb',
#   'counting',
#   'supposed',
#   'you',
#   'the',
#   'one',
#   'a',
#   'a',
#   'an',
#   'you',
#   'why',
#   'why',
#   'almost',
#   'almost',
#   'no',
#   'what',
#   'just',
#   'coming.',
#   'coming.',
#   'coming',
#   'try',
#   'coming.',
#   'how',
#   'our',
#   'intended',
#   'the',
#   'a',
#   'to',
#   'my',
#   'not',
#   'about',
#   'the',
#   'the',
#   'not',
#   'inherently',
#   'a',
#   'poorly',
#   'not,',
#   'no',
#   'to',
#   'not',
#   'undiminished.',
#   'how'],
#  'mystery': ['♪', 'with', '♪', '♪'],
#  'Everyone': ['must', 'expresses'],
#  'must': ['stand', 'be', 'we', 'wipe'],
#  'stand': ['alone', 'still', 'around', 'in', 'by'],
#  'alone': ['♪', 'before', 'on'],
#  'I': ['hear',
#   'wanna',
#   'can',
#   'mean,',
#   'mean…',
#   'am',
#   'think',
#   'do',
#   'think',
#   'think',
#   'feel',
#   'gotta',
#   'know',
#   'feel',
#   'just',
#   'do',
#   'like',
#   'know',
#   'can’t',
#   'used',
#   'gave',
#   'grew',
#   'grew',
#   'just',
#   'wanted',
#   'hope',
#   'take',
#   'mean,',
#   'don’t',
#   'can’t',
#   'like',
#   'know,',
#   'know',
#   'stand',
#   'much',
#   'prefer',
#   'look',
#   'look',
#   'look',
#   'can’t',
#   'die',
#   'sort',
#   'want.',
#   'want',
#   'wanna',
#   'want',
#   'know',
#   'mean,',
#   'mean,',
#   'just,',
#   'wanna',
#   'make',
#   'wanna',
#   'wanna',
#   'want',
#   'want',
#   'don’t',
#   'do.',
#   'watch',
#   'mean,',
#   'mean,',
#   'mean,',
#   'mean,',
#   'certainly',
#   'will',
#   'look',
#   'am',
#   'know',
#   'do,',
#   'do,',
#   'when',
#   'can’t',
#   'mean,',
#   'feel',
#   'don’t.',
#   'don’t',
#   'think',
#   'felt',
#   'wouldn’t',
#   'don’t',
#   'don’t',
#   'mean',
#   'think',
#   'think',
#   'don’t',
#   'think',
#   'think…',
#   'think…',
#   'think',
#   'don’t',
#   'mean,',
#   'call',
#   'see',
#   'think',
#   'call',
#   'don’t',
#   'call',
#   'might',
#   'love',
#   'call',
#   'treat',
#   'treat',
#   'don’t',
#   'believe',
#   'mean,',
#   'show',
#   'feel',
#   'have',
#   'showing',
#   'think',
#   'think',
#   'don’t',
#   'don’t',
#   'mean,',
#   'mean,',
#   'only',
#   'appreciate',
#   'agree,',
#   'step',
#   'mean,',
#   'love',
#   'think',
#   'may',
#   'see',
#   'saying',
#   'guess',
#   'mean,',
#   'saw',
#   'see',
#   'get',
#   'feel',
#   'feel',
#   'feel',
#   'always',
#   'still',
#   'like',
#   'don’t',
#   'started',
#   'remember',
#   'have',
#   'go,',
#   'can',
#   'dab',
#   'have',
#   'think',
#   'have',
#   'don’t',
#   'would',
#   'don’t',
#   'occasionally',
#   'guess.',
#   'understood',
#   'was',
#   'was',
#   'always',
#   'know',
#   'feel',
#   'guess',
#   'appreciated…',
#   'don’t',
#   'mean,',
#   'see',
#   'had',
#   'asked,',
#   'mean',
#   'mean,',
#   'didn’t',
#   'think',
#   'mean,',
#   'get',
#   'mean,',
#   'mean,',
#   'fear',
#   'may',
#   'think',
#   'like',
#   'stand',
#   'am',
#   'get',
#   'mean,',
#   'mean,',
#   'mean,',
#   'mean,',
#   'could',
#   'was',
#   'was',
#   'could',
#   'could',
#   'feel',
#   'would',
#   'believe',
#   'was',
#   'know',
#   'don’t',
#   'don’t',
#   'tell',
#   'tell',
#   'hold',
#   'find',
#   'play',
#   'know',
#   'would',
#   'had',
#   'was',
#   'wouldn’t',
#   'think',
#   'planned',
#   'get',
#   'feel',
#   'go,',
#   'do',
#   'know',
#   'know',
#   'let',
#   'wouldn’t',
#   'think',
#   'was',
#   'don’t',
#   'do',
#   'do',
#   'have',
#   'have',
#   'don’t',
#   'don’t',
#   'lift',
#   'mean,',
#   'don’t',
#   'feel',
#   'get',
#   'try',
#   'get',
#   'will',
#   'find',
#   'back',
#   'say,',
#   'thank',
#   'will',
#   'become',
#   'gently',
#   'put',
#   'just',
#   'loved',
#   'was',
#   'bite',
#   'was',
#   'said',
#   'have',
#   '“could”',
#   'mean…',
#   'wanna',
#   'have',
#   'believe',
#   'knew.',
#   'believe',
#   'knew.',
#   'think',
#   'was',
#   'am?”',
#   'don’t.”',
#   'be',
#   'ever',
#   'mean,',
#   'had',
#   'think',
#   'wanna',
#   'get',
#   'like',
#   'mean,',
#   'mean,',
#   'think',
#   'prefer',
#   'much',
#   'prefer',
#   'try',
#   'have',
#   'think',
#   'invited',
#   'made',
#   'love',
#   'love',
#   'always',
#   'don’t,',
#   'think',
#   'don’t',
#   'don’t',
#   'think',
#   'heard',
#   'know',
#   'take',
#   'wasn’t',
#   'used',
#   'tried',
#   'failed',
#   'backed',
#   'realized',
#   'was',
#   'had',
#   'had',
#   'guess.',
#   'love',
#   'can’t',
#   'can’t',
#   'know',
#   'mean,',
#   'make',
#   'took',
#   'get',
#   'am',
#   'am',
#   'really',
#   'mean,',
#   'recognize',
#   'collapse',
#   'did',
#   'wanted',
#   'get',
#   'hear',
#   'can.',
#   'mean,',
#   'wanna',
#   'feel',
#   'actually',
#   'was',
#   'guess',
#   'said.',
#   'see',
#   'could',
#   'didn’t',
#   'didn’t',
#   'experienced',
#   'was',
#   'knew',
#   'had',
#   'was',
#   'know,',
#   'was',
#   'don’t',
#   'was',
#   'can',
#   'mean,',
#   'could',
#   'express',
#   'mean,',
#   'wanna',
#   'was',
#   'realize',
#   'won’t',
#   'know',
#   'don’t',
#   'can',
#   'hear',
#   'sewed',
#   'make',
#   'thought',
#   'had',
#   'mean,',
#   'hate',
#   'see',
#   'don’t',
#   'just',
#   'had',
#   'get',
#   'was',
#   'wanna',
#   'mean,',
#   'want',
#   'want',
#   'take',
#   'gave',
#   'never',
#   'had',
#   'hadn’t',
#   'got',
#   'think',
#   'mean,',
#   'don’t',
#   'wasn’t',
#   'was',
#   'can',
#   'could',
#   'know',
#   'wasn’t',
#   'was',
#   'was',
#   'mean,',
#   'was',
#   'sensed',
#   'felt',
#   'also',
#   'think',
#   'don’t',
#   'think',
#   'think',
#   'seem',
#   'seem',
#   'hear',
#   'can',
#   'see',
#   'directed',
#   'drop',
#   'say',
#   'know',
#   'eat',
#   'chew',
#   'spit',
#   'didn’t…',
#   'didn’t',
#   'could',
#   'could',
#   'mean,',
#   'mean,',
#   'could',
#   'could',
#   'think.',
#   'mean,',
#   'just…',
#   'couldn’t',
#   'were',
#   'felt',
#   'could',
#   'did,',
#   'scooped',
#   'knew',
#   'just…',
#   'kind',
#   'scoop',
#   'get',
#   'decide',
#   'don’t',
#   'wanna',
#   'go,',
#   'can',
#   'go,',
#   'just',
#   'don’t',
#   'just…',
#   'was',
#   'couldn’t',
#   'mean,',
#   'don’t',
#   'mean…',
#   'don’t',
#   'know',
#   'don’t',
#   'have',
#   'don’t',
#   'thought',
#   'am.',
#   'am.',
#   'don’t',
#   'don’t',
#   'know',
#   'have',
#   'turned',
#   'was',
#   'was',
#   'mean,',
#   'was',
#   'was',
#   'did',
#   'go,',
#   'imagine',
#   'imagine',
#   'imagine',
#   'mean,',
#   'mean,',
#   'go,',
#   'go,',
#   'go,',
#   'know',
#   'go',
#   'might',
#   'watch',
#   'feel',
#   'was',
#   'was',
#   'always',
#   'knew',
#   'swallowed',
#   'don’t',
#   'always',
#   'always',
#   'knew',
#   'mean,',
#   'wanted',
#   'knew',
#   'knew…',
#   'knew',
#   'had',
#   'went',
#   'had',
#   'felt',
#   'felt',
#   'highly',
#   'was',
#   'had',
#   'had',
#   'can',
#   'might',
#   'was…',
#   'was',
#   'was',
#   'eventually',
#   'really',
#   'blew',
#   'mean,',
#   'simply',
#   'mean,',
#   'don’t',
#   'wasn’t',
#   'wouldn’t',
#   'wasn’t',
#   'think',
#   'will',
#   'think',
#   'mean,',
#   'would',
#   'could',
#   'conjure',
#   'wish',
#   'have',
#   'have',
#   'know…',
#   'know',
#   'feel',
#   'look',
#   'mean,',
#   'look',
#   'can’t',
#   'can',
#   'just',
#   'mean,',
#   'feel',
#   'have',
#   'do,',
#   'stand',
#   'go',
#   'run',
#   'don’t',
#   'really',
#   'say',
#   'just',
#   'like',
#   'like',
#   'was.”',
#   'was',
#   'become?',
#   'was',
#   'was',
#   'was',
#   'was',
#   'guess.',
#   'always',
#   'was',
#   'still',
#   'was',
#   'started',
#   'was',
#   'went',
#   'mean,',
#   'don’t',
#   'could’ve',
#   'go,',
#   'shook',
#   'forced',
#   'join',
#   'have',
#   'gather…',
#   'gather',
#   'try',
#   'know',
#   'am.',
#   'will',
#   'think',
#   'tell',
#   'get',
#   'can’t',
#   'tell',
#   'cry',
#   'guess.',
#   'get',
#   'wonder',
#   'say',
#   'continue',
#   'kept',
#   'get',
#   'can',
#   'guess.',
#   'was',
#   'was',
#   'went',
#   'bought',
#   'know',
#   'know',
#   'was',
#   'was',
#   'wasn’t',
#   'was',
#   'mean,',
#   'wanna',
#   'feel',
#   'feel…',
#   'feel',
#   'know',
#   'cast',
#   'poeticize',
#   'love',
#   'coddle',
#   'have',
#   'do?',
#   'go',
#   'have',
#   'was',
#   'always',
#   'love',
#   'know',
#   'mean',
#   'know',
#   'love',
#   'do',
#   'don’t',
#   'mean,',
#   'wanted',
#   'remembered',
#   'say',
#   'say',
#   'give',
#   'give',
#   'give',
#   'mean,',
#   'did',
#   'kneel',
#   'drink',
#   'take',
#   'guess',
#   'want',
#   'want',
#   'want',
#   'am,',
#   'overreach?',
#   'do,',
#   'hope',
#   'know',
#   'put',
#   'win',
#   'shall',
#   'accept'],
#  'hear': ['you',
#   'it.',
#   'the',
#   'his',
#   'you',
#   'you,',
#   'the',
#   'them',
#   'is',
#   'the'],
#  'you': ['call',
#   'call',
#   'there',
#   'there',
#   'know…',
#   'feel',
#   'know,',
#   'know?',
#   'know,',
#   'know.',
#   'show',
#   'get',
#   'know,',
#   'bring',
#   'didn’t',
#   'people',
#   'see',
#   'like,',
#   'take',
#   'very',
#   'gotta',
#   'know?',
#   'see,',
#   'know,',
#   'know.',
#   'know.',
#   'to',
#   'just',
#   'don’t',
#   'talk',
#   'guys',
#   'don’t',
#   'don’t',
#   'try',
#   'know?',
#   'were',
#   'did',
#   'know?',
#   'ever',
#   'know,',
#   'insist',
#   'would,',
#   'know,',
#   'know,',
#   'know.',
#   'people.',
#   'know?',
#   'gotta',
#   'know?',
#   'say',
#   'believe',
#   'know,',
#   'see',
#   'know?',
#   'hear',
#   'know,',
#   'love',
#   'respect',
#   'do.',
#   'didn’t',
#   'can.”',
#   'know,',
#   'know?',
#   'know?',
#   'can',
#   'know.',
#   'know,',
#   'know,',
#   'know.',
#   'the',
#   'know.',
#   'know.',
#   'know.',
#   'know,',
#   'see',
#   'know.',
#   'in',
#   'awake?”',
#   'married.',
#   'know.',
#   'sad',
#   'don’t',
#   'in',
#   'know,',
#   'out',
#   'can’t',
#   'bury',
#   'know.',
#   'better',
#   'caused.',
#   'into',
#   'know,',
#   'know…',
#   'know,',
#   'have',
#   'go',
#   'put',
#   'toothy',
#   'gonna',
#   'know,',
#   'know,',
#   'can',
#   'girls',
#   'know,',
#   'know,',
#   'know?',
#   'know.',
#   'know.',
#   'know.',
#   'know,',
#   'see?',
#   'split',
#   'get',
#   'see…',
#   'see…',
#   'see',
#   'can',
#   'want,”',
#   'want.”',
#   'want.”',
#   'won’t',
#   'understand?',
#   'endless',
#   'endless',
#   'one',
#   'have',
#   'can’t,',
#   'mind',
#   'do',
#   'were',
#   'did',
#   'did',
#   'this',
#   'know.',
#   'this',
#   'understand',
#   'think',
#   'like',
#   'can’t',
#   'know?',
#   'know,',
#   'guys',
#   'for',
#   'do,',
#   'to',
#   'really',
#   'don’t',
#   'found',
#   'found',
#   'know,',
#   'use',
#   'blame',
#   'blame',
#   'couldn’t',
#   'see?',
#   'get',
#   'were',
#   'feel',
#   'feel',
#   'mean.”',
#   'can,',
#   'know,',
#   'know,',
#   'know',
#   'know.',
#   'know?',
#   'know.',
#   'penetrate,',
#   'penetrate,',
#   'penetrate',
#   'in,',
#   'know',
#   'look',
#   'didn’t',
#   'could',
#   'put',
#   'don’t',
#   'don’t',
#   'don’t',
#   'know',
#   'entered',
#   'know?',
#   'for',
#   'choke',
#   'want?',
#   'see?',
#   'don’t',
#   'know.',
#   'can',
#   'know,',
#   'know,',
#   'know,',
#   'speed-read',
#   'know,',
#   'know.',
#   'know,',
#   'haven’t',
#   'make',
#   'see,',
#   'tell',
#   'become',
#   'feel',
#   'see?',
#   'can’t',
#   'can',
#   'a',
#   'land',
#   'know,',
#   'done',
#   'given',
#   'know,',
#   'give',
#   'lubricate',
#   'wrap',
#   'smile.”',
#   'see.',
#   'are',
#   'solved',
#   'bad',
#   'feel',
#   'gotta',
#   'ask',
#   'know,',
#   'had',
#   'had',
#   'know',
#   'know.',
#   'know,',
#   'know.',
#   'know.',
#   'have',
#   'put',
#   'put',
#   'know.',
#   'know.',
#   'know?',
#   'see…',
#   'see?',
#   'know.',
#   'know',
#   'felt',
#   'know',
#   'have',
#   'know,',
#   'know.',
#   'need.',
#   'know,',
#   'know,',
#   'know,',
#   'know,',
#   'know,',
#   'want?”',
#   'then,',
#   'to',
#   'know?',
#   'like',
#   'know.',
#   'know,',
#   'know.',
#   'know.',
#   'heard',
#   'made',
#   'do',
#   'talk,',
#   'can',
#   'can',
#   'doing',
#   'refuse',
#   'know,',
#   'use',
#   'dilute',
#   'seem',
#   'couldn’t',
#   'would,',
#   'pig.',
#   'know,',
#   'know.',
#   'know?',
#   'know?',
#   'wind',
#   'would’ve',
#   'know?',
#   'know…',
#   'understand?',
#   'through.',
#   'people',
#   'at',
#   'know?',
#   'know',
#   'see',
#   'gonna',
#   'gonna',
#   'can',
#   'need',
#   'listen',
#   'need',
#   'know?',
#   'know.',
#   'know,',
#   'working',
#   'suburban',
#   'know,',
#   'know?',
#   'bite',
#   'there',
#   'know?',
#   'know',
#   'people.',
#   'know,',
#   'can',
#   'know.',
#   'see?',
#   'see,',
#   'back',
#   'know.',
#   'know,',
#   'really',
#   'said…',
#   'take',
#   'hook…”',
#   'gotta',
#   'know',
#   'shed',
#   'shed',
#   'know.',
#   'gotta',
#   'gotta',
#   'to',
#   'die,',
#   'know,',
#   'know',
#   'stare,',
#   'one',
#   'know',
#   'our',
#   'just',
#   'just',
#   'just',
#   'rob',
#   'try',
#   'know.”',
#   'know.',
#   'look',
#   'see',
#   'see',
#   'not',
#   'know.',
#   'get',
#   'know,',
#   'like',
#   'know.',
# ...
#  'would,': ['wouldn’t', 'you'],
#  'wouldn’t': ['you?',
#   'use',
#   'even',
#   'even',
#   'be,',
#   'I?',
#   'have',
#   'they,',
#   'quickly'],
#  'you?': ['No,', 'Keep'],
#  'needs,': ['its'],
#  'wants,': ['you'],
#  'hideousities': ['to'],
#  'historically': ['call', 'and'],
#  'heterosexual': ['woman,'],
#  'woman,': ['and'],
#  'no,': ['I’m',
#   'true',
#   'it’s',
#   'I',
#   'they',
#   'I',
#   'I',
#   'if',
#   'you',
#   'that',
#   'no,',
#   'that',
#   'I',
#   'not',
#   'but',
#   'regard'],
#  'proud.': ['[audience', 'You', 'It’s'],
#  'patent': ['humiliation'],
#  'humiliation': ['in'],
#  'day': ['and', 'when', 'perhaps', 'just', 'like'],
#  'age.': ['I'],
#  'thinking.': ['Does'],
#  'Does': ['she', 'the'],
#  'even': ['read?',
#   'make',
#   'faster',
#   'more',
#   'blink',
#   'if',
#   'have',
#   'spin',
#   'once',
#   'talk',
#   'passed',
#   'their',
#   'understand',
#   'though',
#   'in',
#   'a',
#   'think',
#   'is'],
#  'read?': ['[audience'],
#  'yet,': ['you'],
#  'when': ['I’m',
#   'I',
#   'I',
#   'I',
#   'they',
#   'I',
#   'she',
#   'I',
#   'it',
#   'it',
#   'she',
#   'you',
#   'I',
#   'someone',
#   'she',
#   'I',
#   'I’m',
#   'they’re',
#   'you',
#   'you',
#   'you',
#   'I',
#   'I',
#   'someone',
#   'you',
#   'you',
#   'you',
#   'he’s',
#   'it’s',
#   'they',
#   'I'],
#  'a…': ['a', '[clicking]', '“I', 'It’s', 'All', 'it’s'],
#  'girl': ['with', 'for', 'for', 'with'],
#  'ponytail': ['just'],
#  'lusting': ['after'],
#  'common': ['shaft?'],
#  'shaft?': ['[audience'],
#  'Oh,': ['I', 'yeah,', 'the', 'and', 'we', 'it', 'yes.', 'he', 'I'],
#  'believe': ['it',
#   'that’s',
#   'you',
#   'is',
#   'the',
#   'that',
#   'that',
#   'in',
#   'that',
#   'I',
#   'that',
#   'this,',
#   'it.',
#   'it,',
#   'it?'],
#  'happened': ['to', 'to'],
#  'simple': ['cylinder,', 'machinery', 'cylinder…”'],
#  'cylinder,': ['that…'],
#  'familiar': ['tube,'],
#  'tube,': ['that'],
#  'object': ['of'],
#  'seemingly': ['no', 'self-appointed', 'self-appointed'],
#  'no': ['nuance.',
#   'one',
#   'one',
#   'play.',
#   'play',
#   'way.',
#   'way',
#   'bone',
#   'bone',
#   'bone',
#   'great',
#   'matter',
#   'bone',
#   'bone',
#   'rules,',
#   'one',
#   'word',
#   'way',
#   'words,',
#   'dignity.',
#   'way',
#   'stink',
#   'way,',
#   'words.',
#   'matter',
#   'screams',
#   'hurry',
#   'roles.',
#   'spring',
#   'swagger.',
#   'distinguishing',
#   'one',
#   'one',
#   'clue',
#   'clue',
#   'poetic',
#   'clue',
#   'foolish',
#   'lesson.'],
#  'nuance.': ['The'],
#  'word': ['I’m',
#   '“cock”',
#   'and',
#   'penis',
#   'penis',
#   'penis',
#   '“cock”',
#   '“penis”',
#   'penis',
#   'penetrate’s',
#   'for',
#   '“like.”',
#   "‘like.'”",
#   'over',
#   'so',
#   '“like”',
#   'you'],
#  'avoiding': ['saying,'],
#  'saying,': ['of', '“It’s', '“Tenderest'],
#  '“penis”': ['and', 'should'],
#  'I’ve': ['said',
#   'never',
#   'been',
#   'always',
#   'stood',
#   'stood',
#   'overthought',
#   'done',
#   'been',
#   'never',
#   'never',
#   'hated',
#   'always',
#   'got',
#   'got',
#   'never',
#   'cleared',
#   'told',
#   'learned'],
#  'better?': ['No,'],
#  'don’t.': ['[audience'],
#  'love': ['the',
#   'and',
#   'your',
#   'when',
#   'of',
#   'the',
#   'the',
#   'the',
#   'on',
#   'a',
#   'letter…',
#   'behind',
#   'letter?',
#   'you',
#   'to',
#   'to',
#   'to',
#   'a',
#   'to',
#   'him.'],
#  'word,': ['few', 'it', 'but'],
#  'few': ['do,', 'courtesies', 'good', 'clumsy'],
#  'A': ['big',
#   '“ck,',
#   'burger',
#   'proper',
#   'proper',
#   'little…',
#   'hint…',
#   'Viking',
#   'whiff',
#   'penis,',
#   'rock',
#   'penis',
#   'child’s',
#   'sort',
#   'fate',
#   'couple',
#   'smooth,'],
#  'big': ['part', 'concept', 'man.', 'one', 'deal', 'questions'],
#  'part': ['of', 'of', 'of'],
#  'probably': ['rather', 'describing', 'stop', 'try', 'reading'],
#  'rather': ['say', 'hear', 'build', 'just'],
#  '“cock”': ['for', 'clearly,', 'is', 'for'],
#  'people.': ['I', '[audience', 'It'],
#  'lot': ['of', 'outside', 'on', 'of', 'of', 'of'],
#  'you’d': ['rather', 'know', 'just'],
#  'boyfriends': ['sure'],
#  'did,': ['you', 'top'],
#  'Cock': ['is'],
#  'has': ['a',
#   'a',
#   'the',
#   'kind',
#   'more',
#   'this',
#   '50%',
#   'already',
#   'to',
#   'already',
#   'just',
#   'arrived',
#   'always'],
#  'dignity': ['to', 'in', 'was', 'of'],
#  'kick': ['it'],
#  'back': ['of',
#   'to',
#   'to',
#   'in',
#   'the',
#   'away.',
#   'to',
#   'on',
#   'of',
#   'up',
#   'to',
#   'of',
#   'impossibly',
#   'your',
#   'and',
#   'to'],
#  'mouth.': ['“Co”', '[audience', '[audience'],
#  '“Co”': ['but'],
#  '“ck.”': ['It'],
#  'It': ['lands.',
#   'lands',
#   'sounds',
#   'cannot',
#   'springs',
#   'sees',
#   'fills',
#   'is',
#   'dies',
#   'just…',
#   'slipped',
#   'holds.',
#   'holds.',
#   'embodies',
#   'just',
#   'comes',
#   'must',
#   'just',
#   'didn’t',
#   'felt',
#   'was',
#   'could',
#   'could',
#   'just',
#   'seemed',
#   'is',
#   'seemed',
#   'was',
#   'was',
#   'doesn’t',
#   'sort',
#   'was',
#   'works.',
#   'is',
#   'almost',
#   'would',
#   'remains',
#   'All”'],
#  'lands.': ['A'],
#  '“ck,': ['ck.”'],
#  'ck.”': ['It'],
#  'lands': ['on'],
#  'same': ['damn',
#   'with',
#   'way.',
#   'weird',
#   'with',
#   'spot',
#   'with',
#   'word',
#   'old',
#   'for'],
#  'damn': ['consonant', 'bite.”'],
#  'consonant': ['it'],
#  'started': ['on,', 'reading', 'young.', 'on', 'on', 'on', 'to'],
#  'on,': ['you'],
#  'Penis.': ['Penis', 'Penis.', '[chuckles]', 'Penis,'],
#  'Penis': ['just'],
#  'slips': ['out'],
#  'side': ['of', 'of', 'of', 'of', 'of'],
#  '“Penis.”': ['“I’m', '[moaning]'],
#  '“I’m': ['sorry.',
#   'awake.',
#   'just',
#   'the',
#   'sorry.',
#   'just',
#   'in',
#   'coming',
#   'the'],
#  'sorry.': ['Did', 'Are', 'Do'],
#  'Did': ['you'],
#  'something?”': ['“Well,'],
#  '“Well,': ['I’m', 'as', 'primarily', 'you', 'maybe'],
#  'anymore.”': ['“I', 'And'],
#  '“I': ['thought',
#   'think',
#   'see',
#   'killed',
#   'feel',
#   'mean,',
#   'don’t',
#   'think',
#   'know',
#   'recognize',
#   'penetrated',
#   'laid',
#   'don’t',
#   'just',
#   'don’t',
#   'doubt',
#   'can’t',
#   'don’t',
#   'don’t',
#   'feel',
#   'just',
#   'simply'],
#  'thought': ['a',
#   'about',
#   'of',
#   'of',
#   'of',
#   'they',
#   'the',
#   'it',
#   'the',
#   'there'],
#  'felt': ['something',
#   'like',
#   'this',
#   'that.”',
#   'like',
#   'pretty',
#   'like',
#   'like',
#   'like',
#   'natural.',
#   'teeth,',
#   'teeth.',
#   'they'],
#  'happen.”': ['You'],
#  'People': ['say,'],
#  '“Well': ['sure,', 'then,'],
#  'sure,': ['I', 'I’m', 'isn’t', 'you'],
#  'use': ['the', 'that', 'it', 'of', 'that'],
#  'penis': ['sexually,',
#   'is',
#   'lies',
#   'is',
#   'a',
#   'a',
#   'a',
#   'a',
#   'is,',
#   'is',
#   'has',
#   'should',
#   'isn’t',
#   'to',
#   'is',
#   'is…',
#   'is',
#   'is',
#   'is',
#   'the',
#   'perfectly,',
#   'is',
#   'is',
#   'is',
#   'orgasm',
#   'is',
#   'is.”',
#   'at',
#   'when',
#   'is',
#   'you’re',
#   'that’s',
#   'as',
#   'is',
#   'anywhere',
#   'and',
#   'is',
#   '’cause',
#   'shall'],
#  'sexually,': ['it’s'],
#  'clinical.”': ['I'],
#  'voice': ['of', 'can', 'can', 'can', 'can', 'can'],
#  'clinician': ['in'],
#  'word.': ['I', 'I', 'You'],
#  'most': ['medical-sounding',
#   'feminine',
#   'sensitive',
#   'authentic',
#   'enjoy',
#   'iconic',
#   'of',
#   'worried',
#   'generous'],
#  'medical-sounding': ['word.'],
#  'mean': ['[chuckling]…', 'the', 'that', 'the', 'you’re…'],
#  '[chuckling]…': ['I'],
#  'problem': ['for',
#   'for',
#   'for',
#   'lies',
#   'with',
#   'is',
#   'in',
#   'with',
#   'of',
#   'is',
#   'and'],
#  'people…': ['I'],
#  'lies': ['in', 'in'],
#  'tender': ['emotionality.', 'syllable', 'penis.', 'nature.'],
#  'emotionality.': ['I'],
#  'sounds': ['accurate', 'like', 'strong,', 'like', 'in'],
#  'accurate': ['to'],
#  'soft': ['heartbeat.'],
#  'heartbeat.': ['Penis.'],
#  'Penis,': ['penis,'],
#  'penis,': ['penis,', 'penis.', 'you', 'it', 'like', 'I', 'you'],
#  'penis.': ['And', 'I’m', 'I’m', 'Like,', 'True', 'You', 'It’s', 'No,'],
#  'problem.': ['I', 'Pe…', 'The'],
#  'think…': ['I', 'I'],
#  'syllables': ['themselves'],
#  'themselves': ['too.', 'with'],
#  'too.': ['I', '[audience', 'Really.', 'You', '“You’d'],
#  'Rose-by-any-other-name': ['scenarios.'],
#  'scenarios.': ['No,'],
#  '“Pe-”': ['is'],
#  'clearly': ['a', 'the', 'in'],
#  'Pe…': ['Peener…'],
#  'Peener…': ['Pee-pee.'],
#  'Pee-pee.': ['You'],
#  'been': ['mocked',
#   'there',
#   'rewarded.',
#   'aware',
#   'a',
#   'distributed',
#   'for',
#   'standing',
#   'one',
#   'operational',
#   'entered.',
#   'afraid',
#   'afraid',
#   'destroyed.',
#   'proud.',
#   'proud.',
#   'shocked',
#   'however',
#   'turned',
#   'up',
#   'received',
#   'getting',
#   'slacking',
#   'my',
#   'more',
#   'talking'],
#  'mocked': ['for'],
#  'ages': ['and'],
#  'rightfully': ['so.'],
#  'so.': ['You', '[audience'],
#  'true…': ['the'],
#  'true': ['tender',
#   'respect…',
#   'respect',
#   'respect',
#   'love.',
#   'love,',
#   'love'],
#  'syllable': ['of'],
#  'devastation,': ['oh,'],
#  '“nis.”': ['It’s', '[audience'],
#  'time?': ['“Nis.”'],
#  '“Nis.”': ['“Nis.”', 'And'],
#  'why': ['no',
#   'no',
#   'I',
#   'are',
#   'I’ve',
#   'it',
#   'you’re',
#   'is',
#   'haven’t',
#   'haven’t',
#   'I',
#   'I',
#   'I',
#   'wouldn’t',
#   'as',
#   '“salad',
#   'we',
#   'we',
#   'we',
#   'reach'],
#  'speaks': ['of'],
#  'syllable.': ['That’s'],
#  'why…': ['that’s', 'why,'],
#  'says,': ['you', '‘No,'],
#  '“Show': ['me'],
#  'nis.”': ['[audience'],
#  'Wait': ['till', 'out'],
#  'till': ['you', 'they’re'],
#  'nis?': ['Nis-nis?'],
#  'Nis-nis?': ['They'],
#  'won’t': ['even', 'fully', 'know', 'be', 'be'],
#  'joke.': ['No,', 'There’s'],
#  'tender.': ['It', 'It’s'],
#  'cannot': ['be', 'be'],
#  'spoken.': ['No,'],
#  'clearly,': ['clearly…'],
#  'clearly…': ['“cock…”'],
#  '“cock…”': ['Clearly'],
#  'Clearly': ['“cock”'],
#  'sexy': ['word.'],
#  'issue.': ['There’s'],
#  'There’s': ['a', 'me.', 'a', 'no', 'no', 'just', 'something', 'a'],
#  'way,': ['it',
#   'just…',
#   'even',
#   'like,',
#   'the',
#   'you',
#   'you',
#   'you',
#   'like,',
#   'there’s',
#   'a',
#   'I'],
#  'becomes': ['unsexy.'],
#  'unsexy.': ['And'],
#  'cock,': ['I’m', 'I', 'it’s', 'I’m', 'I', 'that'],
#  'actually': ['calling', 'there', 'feel', 'mind'],
#  'calling': ['it'],
#  'telling': ['it', 'a', 'him'],
#  'wants': ['to'],
#  'hear.': ['[audience'],
#  'worrying': ['about'],
#  'feelings': ['of'],
#  'coddling': ['the'],
#  'ego': ['of'],
#  'humoring': ['the', 'it.'],
#  'Like,': ['when',
#   'if',
#   '“I’ll',
#   'I',
#   'if',
#   '“Oh',
#   'uh…',
#   'the',
#   '“What’s',
#   '“Wait,',
#   'two',
#   'through',
#   'you’re',
#   '“No.',
#   '“Sure,',
#   'quick,'],
#  'throw': ['it', 'myself', 'against'],
#  'away.': ['It’s', 'No,', 'I', 'I'],
#  'cock.': ['“Who’s', 'Do'],
#  '“Who’s': ['a'],
#  'cock?': ['You’re', 'You’re'],
#  'You’re': ['a',
#   'a',
#   'the',
#   'the',
#   'an',
#   'pretty',
#   'gonna',
#   'dead.',
#   'dead.”'],
#  'cock.”': ['[audience', 'Right?'],
#  'might': ['humor', 'want', 'feel', 'be', 'have', 'live', 'eventually'],
#  'humor': ['my'],
#  'nephew,': ['for'],
#  'friend’s': ['son,', 'house'],
#  'son,': ['you'],
#  'guys,': ['these', 'run,'],
#  'guys.': ['These'],
#  'These': ['little…', 'little', 'give'],
#  'little…': ['the', 'a', '[groans]'],
#  'person': ['I', 'in', 'in', 'who', 'that', 'to', 'to', 'in'],
#  'guy': ['below', 'who', 'that', 'I', 'I’ve,', 'in', 'you'],
#  'below': ['them.'],
#  'them.': ['Like…',
#   'And',
#   'And',
#   'You…',
#   'A',
#   'Not',
#   'I',
#   'Do',
#   'You',
#   'And',
#   'When',
#   '[sighs]'],
#  'Like…': ['when', 'like,'],
#  'treat': ['it', 'my', 'for'],
#  'nephew.': ['He’ll'],
#  'He’ll': ['come'],
#  'running': ['into', 'along.', 'start,', 'start', 'starts', 'start'],
#  'kitchen': ['where'],
#  'adults': ['are', 'at', 'that'],
#  'talking': ['wearing',
#   'about?',
#   'about',
#   'now,',
#   'like',
#   'with',
#   'at',
#   'and',
#   'for',
#   'to'],
#  'wearing': ['a'],
#  'monster': ['mask'],
#  'mask': ['or', 'of'],
#  'something,': ['and', '’cause', 'I…', 'that', 'I', 'I', 'just…', 'he'],
#  'we…': ['we'],
#  'we': ['see',
#   'come',
#   'proceed',
#   'can',
#   'could',
#   'worked',
#   'move',
#   'don’t',
#   'have',
#   'know',
#   'are',
#   'so',
#   'should',
#   'leave',
#   'do',
#   'all',
#   'hang',
#   'want',
#   'know.',
#   'know,',
#   'go',
#   'can',
#   'won’t',
#   'hung',
#   'not',
#   'can’t',
#   'ever',
#   'go.”',
#   'have',
#   'already',
#   'love',
#   'dig',
#   'have',
#   'must,',
#   'must,',
#   'must',
#   'still',
#   'give',
#   'regret',
#   'be',
#   'be',
#   'be'],
#  'sorry,': ['sorry…'],
#  'sorry…': ['Ah!”'],
#  'Ah!”': ['and'],
#  'right': ['back',
#   'there.',
#   'back.',
#   'there,',
#   'on',
#   'off',
#   'to',
#   'out,',
#   'up…',
#   'before',
#   'away,'],
#  'talking.': ['[audience'],
#  'he': ['didn’t',
#   'was',
#   'acted',
#   'cared,',
#   'loves',
#   'would',
#   'had',
#   'knows',
#   'ejaculated',
#   'was',
#   'didn’t',
#   'said',
#   'goes…',
#   'goes,',
#   'shortened',
#   'cares.',
#   'was',
#   'tugs',
#   'goes',
#   'goes',
#   'goes,',
#   'felt',
#   'felt',
#   'likely',
#   'says',
#   'makes',
#   'orders',
#   'meant',
#   'says.',
#   'came',
#   'clings,',
#   'fails,',
#   'appears',
#   'didn’t'],
#  'scare': ['us.', 'me,'],
#  'us.': ['He', 'We’re', 'Like,'],
#  'He': ['was',
#   'wasn’t',
#   'would',
#   'was',
#   'was',
#   'doesn’t',
#   'would’ve',
#   'lives',
#   'had',
#   'just',
#   'cares',
#   'cares',
#   'thought'],
#  'unsuccessful': ['in'],
#  'his': ['little',
#   'feet…',
#   'dick',
#   'dick',
#   'dick',
#   'dick',
#   'body',
#   'wealth,',
#   'son.',
#   'own',
#   'face.',
#   'son',
#   'Jac.',
#   'zipper',
#   'face',
#   'face',
#   'own',
#   'flaws',
#   'order,',
#   'day',
#   'trying'],
#  'ruse.': ['[audience'],
#  'feet…': ['you'],
#  'he’s': ['coming',
#   'been',
#   'buying',
#   'intimidated',
#   'one',
#   'nervous.”',
#   'truly',
#   'confused'],
#  'coming': ['around', 'my', 'down', 'from', 'down.”', 'and', 'to'],
#  'around': ['again.',
#   'complaining,',
#   'the',
#   'each',
#   'my',
#   'him.',
#   'the',
#   'you',
#   'campus',
#   'the',
#   'our'],
#  'again.': ['You', 'This', 'Block', 'I…', 'No,', 'And'],
#  'faster': ['the'],
#  'second': ['time.',
#   'thing',
#   'glass',
#   'before',
#   'I',
#   'mouth',
#   'one',
#   'of',
#   'mouth'],
#  '“Ah!”': ['Right', 'Right?', 'And'],
#  'Right': ['back'],
#  'showmanship…': ['[laughs]'],
#  '…and': ['yet', 'she', 'relax', 'articulating'],
#  'rewarded.': ['Now…'],
#  'Now…': ['Do'],
#  'nephew?': ['Of'],
#  'Of': ['course.', 'course,', 'course,'],
#  'respect': ['him?', 'for', 'for', 'for', 'for', 'for'],
#  'him?': ['[audience'],
#  'respect…': ['true'],
#  'nephew': ['isn’t', 'is'],
#  'isn’t': ['“Ah!”',
#   'the',
#   'anyone',
#   'going',
#   'phallic.',
#   'it?',
#   'real,”',
#   'it',
#   'that'],
#  'Right?': ['No,', 'True', 'I', '“I', 'A', 'A', 'A', 'If'],
#  '“What?': ['No,'],
#  'can.”': ['“So…'],
#  '“So…': ['so'],
#  'again.”': ['And', '[audience'],
#  'True': ['respect', 'respect'],
#  'not,': ['“Oh,', 'in', 'by', '“save'],
#  'is,': ['“Penis.”', 'you'],
#  '[moaning]': ['[audience', 'And', '‘Cause'],
#  'If': ['the',
#   'the',
#   'you’re',
#   'I',
#   'blue',
#   'they',
#   'you',
#   'that',
#   'I’m',
#   'you',
#   'had',
#   'you',
#   'my',
#   'you’re',
#   'my…',
#   'I',
#   'I',
#   'you',
#   'it’s',
#   'it'],
#  'enough,': ['then', 'you', 'you', 'I'],
#  'should': ['suffice,', 'have', 'go', 'just', 'probably', 'hold', 'you'],
#  'suffice,': ['you'],
#  'chance': ['at', 'at'],
#  'sexy,': ['then', 'but'],
#  'sexy.': ['And'],
#  'theory…': ['in'],
#  'theory,': ['it’s', 'it'],
#  'suffices.': ['I'],
#  'arguably,': ['I’m'],
#  'fan': ['in'],
#  'sense': ['that', 'to', 'of'],
#  'time': ['and',
#   'I',
#   'now.',
#   'you',
#   'in',
#   'that',
#   'in',
#   'I',
#   'can',
#   'in',
#   'when',
#   'was',
#   'now.',
#   'with',
#   'you',
#   'you',
#   'in',
#   'as'],
#  'again': ['with', 'for', 'but', 'with', 'next', 'for'],
#  'regularity': ['you'],
#  'count': ['on.'],
#  'on.': ['I’m', 'You'],
#  'church': ['mouse'],
#  'mouse': ['to'],
#  'wafer': ['crumb'],
#  'crumb': ['on'],
#  'Monday': ['morning.'],
#  'morning.': ['There’s'],
#  'Sniffing': ['about,'],
#  'about,': ['hoping'],
#  'hoping': ['for', 'someone', 'to'],
#  'taste': ['of'],
#  'divine.': ['So'],
#  'So': ['if',
#   'it',
#   'the',
#   'they',
#   'here’s',
#   'I',
#   'satisfying',
#   'I’ve',
#   'many',
#   'I',
#   'many',
#   'I',
#   'I',
#   'I',
#   'now',
#   'top',
#   'it',
#   'I’m',
#   'I',
#   'if',
#   'several',
#   'I',
#   'no,'],
#  'fucking': ['cock,', 'boner?', 'look', 'me,', 'him,', 'feet.”'],
#  'presence,': ['but'],
#  'showing': ['up', 'up', 'up'],
#  'fan.': ['Then'],
#  'Then': ['what',
#   'they',
#   'you',
#   'she',
#   'I',
#   'like',
#   'let',
#   'find',
#   'find',
#   'you'],
#  'for?': ['What'],
#  'What': ['is',
#   'is',
#   'are',
#   'do',
#   'if',
#   'if',
#   'if',
#   'if',
#   'if',
#   'did',
#   'do',
#   'even'],
#  'me?': ['What', 'All', 'And'],
#  'nature?': ['[exhales]'],
#  '[exhales]': ['[audience',
#   'Okay,',
#   'And',
#   '…the',
#   'And',
#   'Me.',
#   'And',
#   'That’s'],
#  'responsive.': ['You'],
#  'springs': ['up'],
#  'under': ['certain', 'the', 'a', 'and', 'a'],
#  'certain': ['conditions.', 'kind', 'qualities.', 'themes', 'dead'],
#  'conditions.': ['That’s'],
#  ...}

# %%
generate_sentence(j_dict)
# Out:
# 'Prudent self-doubt in your way that now you’re in the man who, looking out, before.'

# %% [markdown]
# # the iron claw

# %%
T_text = data.transcript.loc['The iron claw']
T_text[:200]
# Out:
# 'The Iron Claw (2023)\nDirected by: Sean Durkin\nWritten by: Sean Durkin\nStarring: Zac Efron, Jeremy Allen White, Harris Dickinson, Maura Tierney, Holt McCallany, Lily James\nDistributed by: A24 (United S'

# %%
T_dict = markov_chain(T_text)
T_dict
# Out:
# {'The': ['Iron',
#   'story',
#   'Iron',
#   'only',
#   'only',
#   'Von',
#   'brothers',
#   'pain',
#   'promoters',
#   'World’s',
#   '3,500',
#   'belt',
#   'champ',
#   'Ref',
#   'boos',
#   'fans',
#   'answer',
#   'world',
#   'hands',
#   'hands',
#   'only',
#   'reigning',
#   'Fabulous',
#   'Von',
#   'winners',
#   'Von',
#   'kind',
#   'Lord',
#   'champion',
#   'dream',
#   'Winner',
#   'toughest,',
#   'bottom',
#   'numbers'],
#  'Iron': ['Claw', 'Claw.', 'Claw.', 'Claw’', 'Claw,', 'Claw'],
#  'Claw': ['(2023)\nDirected', 'to'],
#  '(2023)\nDirected': ['by:'],
#  'by:': ['Sean', 'Sean', 'A24'],
#  'Sean': ['Durkin\nWritten', 'Durkin\nStarring:'],
#  'Durkin\nWritten': ['by:'],
#  'Durkin\nStarring:': ['Zac'],
#  'Zac': ['Efron,'],
#  'Efron,': ['Jeremy'],
#  'Jeremy': ['Allen'],
#  'Allen': ['White,'],
#  'White,': ['Harris'],
#  'Harris': ['Dickinson,'],
#  'Dickinson,': ['Maura'],
#  'Maura': ['Tierney,'],
#  'Tierney,': ['Holt'],
#  'Holt': ['McCallany,'],
#  'McCallany,': ['Lily'],
#  'Lily': ['James\nDistributed'],
#  'James\nDistributed': ['by:'],
#  'A24': ['(United'],
#  '(United': ['States),', 'States),'],
#  'States),': ['Lionsgate\xa0(United', 'February\xa09,\xa02024\xa0(United'],
#  'Lionsgate\xa0(United': ['Kingdom)\nRelease'],
#  'Kingdom)\nRelease': ['dates:'],
#  'dates:': ['November'],
#  'November': ['8,'],
#  '8,': ['2023'],
#  '2023': ['(Dallas),', '(United'],
#  '(Dallas),': ['December'],
#  'December': ['22,'],
#  '22,': ['2023'],
#  'February\xa09,\xa02024\xa0(United': ['Kingdom)\nRunning'],
#  'Kingdom)\nRunning': ['time:'],
#  'time:': ['132'],
#  '132': ['minutes'],
#  'minutes': ['Plot:'],
#  'Plot:': ['In'],
#  'In': ['1979,', 'my', 'his', 'here.', '“Coup', 'A.D.'],
#  '1979,': ['Texas'],
#  'Texas': ['NWA',
#   'Heavyweight',
#   'Champion.',
#   'Heavyweight',
#   'Heavyweight',
#   'Heavyweight',
#   'title,',
#   'Champion,',
#   'whooping',
#   'and',
#   'Stadium.',
#   'Stadium,'],
#  'NWA': ['Heavyweight',
#   'World',
#   'Texas',
#   'never',
#   'World',
#   'World',
#   'World',
#   'six-man',
#   'World’s',
#   'on',
#   'World',
#   'World',
#   'World',
#   'World',
#   'World'],
#  'Heavyweight': ['Champion',
#   'Champion',
#   'Champion,',
#   'Champion,',
#   'Champion,',
#   'Champion,',
#   'Champion',
#   'Champion.',
#   'Champion.',
#   'Champion.',
#   'Championship',
#   'Champion.',
#   'Champion.',
#   'Champion,',
#   'Champ',
#   'title.',
#   'Champion',
#   'Champion,',
#   'Champion',
#   'Champion.',
#   'title',
#   'title',
#   'Championship',
#   'Champion.',
#   'Champion,',
#   'Championship.',
#   'Champion,',
#   'Champion.',
#   'title,',
#   'Champion,'],
#  'Champion': ['Kevin', 'and', 'in', 'out', 'on', 'one', 'unless'],
#  'Kevin': ['Von',
#   'Von',
#   'is',
#   'Von',
#   'Von',
#   'Von',
#   'getting',
#   'Von',
#   'Von',
#   'Von',
#   'Von',
#   'Von',
#   'into',
#   'on',
#   'blocks',
#   'coming',
#   'again',
#   'goes',
#   'over',
#   'crashes',
#   'in',
#   'Von',
#   'is',
#   'is',
#   'Von',
#   'Von',
#   'spins',
#   'Von',
#   'tossing',
#   'back',
#   'Von',
#   'Von',
#   'Von'],
#  'Von': ['Erich',
#   'Erichs’',
#   'Erich.',
#   'Erich',
#   'Erich',
#   'Erich',
#   'Erich',
#   'Erichs',
#   'Erich',
#   'Erich!',
#   'Erich?',
#   'Erichs?',
#   'Erich,',
#   'Erich',
#   'Erich.',
#   'Erich',
#   'Erich',
#   'Erich,',
#   'Erich',
#   'Erich.',
#   'Erich.',
#   'Erich.',
#   'Erich.',
#   'Erichs',
#   'Erich!',
#   'Erichs',
#   'Erich',
#   'Erich’s',
#   'Erich!',
#   'Erich.',
#   'Erich.',
#   'Erich,',
#   'Erich',
#   'Erich!',
#   'Erich,',
#   'Erich.',
#   'Erich,',
#   'Erich',
#   'Erich.',
#   'Erich'],
#  'Erich': ['finds',
#   'curse,”',
#   'here,',
#   'here',
#   'here',
#   'Saga',
#   'are',
#   'kids.',
#   'faces',
#   'family.',
#   'is',
#   'will',
#   'family.',
#   'in',
#   'has'],
#  'finds': ['himself', 'solace'],
#  'himself': ['at'],
#  'at': ['the',
#   'you.',
#   'him.',
#   'it.',
#   'ESPN.',
#   'the',
#   'the',
#   'home',
#   'that',
#   'least',
#   'this',
#   'you.',
#   'that!',
#   'Southern',
#   'UT,',
#   '17.',
#   'my',
#   'all,',
#   'a',
#   'a',
#   'Parade',
#   'Texas',
#   'you.',
#   'the',
#   'you,',
#   'you',
#   'Parade',
#   'the',
#   'the',
#   'your',
#   'you.',
#   'you.',
#   'home.',
#   'the',
#   'the',
#   'destination'],
#  'the': ['crossroads',
#   'wrestling',
#   'tragic',
#   '“Von',
#   'lives',
#   'family',
#   'ring,',
#   'rise',
#   'family’s',
#   'curse’s',
#   'Von',
#   'WWE',
#   'corner.',
#   'bell!',
#   'Iron',
#   'idea.',
#   'boys',
#   'show.',
#   'promoter,',
#   'toughest,',
#   'strongest,',
#   'most',
#   'absolute',
#   'NWA',
#   'morning',
#   'way',
#   'toughest,',
#   'strongest,',
#   'most',
#   'winner',
#   'new',
#   'start.',
#   'wash.',
#   'weights',
#   'strongest,',
#   'most.',
#   'family’s',
#   'NWA',
#   'rankings',
#   'way?',
#   'cooler.',
#   'public',
#   'newlycrowned',
#   'top,',
#   'newly-crowned',
#   'newly',
#   'hometown',
#   'surprise,',
#   'reaper',
#   'wind,',
#   'sun',
#   'rain',
#   'reaper',
#   'reaper',
#   'reaper',
#   'corner,',
#   'post.',
#   'Claw?',
#   'show.',
#   'corner.',
#   'ring.',
#   'way',
#   'side.',
#   'top',
#   'roof',
#   'Iron',
#   'Von',
#   'chance',
#   'Saturday',
#   'biggest',
#   'road.',
#   'top,',
#   'best',
#   'crowd',
#   'oldest',
#   'oldest.',
#   'second',
#   'family',
#   'curse',
#   'Von',
#   'Sportatorium.',
#   'World',
#   'world',
#   'number',
#   'World',
#   'NWA',
#   'chance',
#   'last',
#   'one',
#   'fourtime',
#   'real',
#   'man.',
#   'only',
#   'man.',
#   'excitement',
#   'world-famous',
#   'indomitable',
#   'building',
#   'world.',
#   'number',
#   'corner.',
#   'midsection,',
#   'wind',
#   'young',
#   'lower',
#   'mat.',
#   'ropes',
#   'ropes.',
#   'old',
#   'champ',
#   'Ref',
#   'top',
#   'concrete',
#   'ring.',
#   'ring',
#   'ribs.',
#   'most',
#   'jaw,',
#   'champ',
#   'ropes.',
#   'Ref',
#   'bell,',
#   'winner',
#   'past,',
#   'future',
#   'floor',
#   'ring.',
#   'mic,',
#   'road,',
#   'World',
#   'principles',
#   'quality',
#   'Olympics,',
#   'imprimatur',
#   'Soviet',
#   'freedom-loving,',
#   'sacrifice',
#   'Summer',
#   'fastest',
#   'family,',
#   'best',
#   'state,',
#   'best',
#   'state',
#   'stands?”',
#   'new',
#   'rematch?',
#   'call.',
#   'new',
#   'World',
#   'music',
#   'clarinet',
#   'most',
#   'thing.',
#   'end',
#   'gig,',
#   'gates',
#   'sky',
#   'fourth',
#   'NWA',
#   'screen,',
#   'new',
#   'Olympics',
#   'way',
#   'more',
#   'better.',
#   'ring.',
#   'crowd',
#   'WCCW,',
#   'wrestling',
#   'Iron',
#   'challengers',
#   'way',
#   'ropes,',
#   'Ref',
#   'top',
#   'ropes',
#   'strength',
#   'NWA.',
#   'best',
#   'business.',
#   'best',
#   'business.',
#   'man',
#   'NWA',
#   'next',
#   'Von',
#   'greatest',
#   'history',
#   'road',
#   'next',
#   'title',
#   'two',
#   'top.',
#   'road.',
#   'whole',
#   'only',
#   'farm',
#   'sack',
#   'farm',
#   'situation.',
#   'house.',
#   'sun’s',
#   'griddle…',
#   'house.',
#   'time',
#   'World',
#   'ring',
#   'oldest',
#   'most',
#   'only',
#   'modern-day',
#   'life',
#   'favorite',
#   'biggest',
#   'hold',
#   'ropes.',
#   'pin.',
#   'NWA',
#   'whole',
#   'name.',
#   'ring.',
#   'surgery',
#   'shoulder,',
#   'ring.',
#   'love',
#   'timeframe',
#   'ring,',
#   'ring',
#   'house',
#   'end',
#   'only',
#   'ring?',
#   'ring.',
#   'toughest,',
#   'strongest…',
#   'strongest…',
#   'absolute',
#   'NWA',
#   'Sportatorium',
#   'difference',
#   'biggest',
#   'biggest',
#   'biggest',
#   'less-pretty',
#   'powers',
#   'World’s',
#   'greatest',
#   'toughest',
#   'most',
#   'bottom',
#   'show.',
#   'ups',
#   'World’s',
#   'worst',
#   'aisle,',
#   'aisle!',
#   'number',
#   'NWA',
#   'most',
#   'only',
#   'hold.',
#   'hold.',
#   'bell.',
#   'bell.',
#   'fuck',
#   'Holiday',
#   'guys',
#   'week.',
#   'WWF.',
#   'table',
#   'company',
#   'books.',
#   'TV.',
#   'babies?',
#   'babies?',
#   'rest.',
#   'fuck',
#   'house.',
#   'boys?',
#   'time.',
#   'ring.',
#   'early',
#   'other',
#   'afterlife,',
#   'extra',
#   'time.',
#   'end',
#   'gates',
#   'wheel',
#   'road',
#   'sky',
#   'sky',
#   'fourth',
#   'most',
#   'privacy',
#   'Loft.',
#   'best'],
#  'crossroads': ['of'],
#  'of': ['family',
#   'the',
#   'his',
#   'his',
#   'Fame',
#   'the',
#   'money',
#   'your',
#   'a',
#   'retirement.',
#   'you!',
#   'it?',
#   'yours',
#   'it.',
#   'ruin',
#   'here.',
#   'this',
#   'those',
#   'everyone.',
#   'the',
#   'the',
#   'the',
#   'tragedy.',
#   'that.',
#   'having',
#   'this',
#   'your',
#   'who',
#   'World',
#   'him.',
#   'our',
#   'here!',
#   'here!',
#   'here.',
#   'this',
#   'the',
#   'approval',
#   'Afghanistan.',
#   'a',
#   'things.',
#   'Texas.',
#   'from',
#   'it.',
#   'July',
#   'you.',
#   'it.',
#   'us',
#   'it.',
#   '740',
#   '690',
#   'the',
#   'you.',
#   'my',
#   'my',
#   'wrestling.',
#   'Champions',
#   'setbacks,',
#   'you.',
#   'man…',
#   'a',
#   'here,',
#   'the',
#   'them',
#   'you.',
#   'life.',
#   'Champions',
#   'a',
#   'you',
#   'David',
#   'a',
#   'a',
#   'talk',
#   'these',
#   'town.',
#   'life.',
#   'all',
#   'my',
#   'wrestling,',
#   'him!',
#   'a',
#   'it.',
#   'broccoli.',
#   'here.',
#   'yourself.',
#   'control.',
#   'me.',
#   'him!',
#   'any',
#   '’em!',
#   'the',
#   'buying',
#   'a',
#   'July',
#   'my',
#   'fate',
#   'the',
#   'all'],
#  'family': ['ambition',
#   'dynamics,',
#   'with',
#   'was',
#   'curse,',
#   'had',
#   'in',
#   'though.',
#   'and',
#   'is',
#   'was',
#   'drama?'],
#  'ambition': ['and'],
#  'and': ['personal',
#   'evolving',
#   'the',
#   'haunts',
#   'misfortune.',
#   'fall',
#   'the',
#   'legacy.',
#   'eventually',
#   'he',
#   'nothing',
#   'we’re',
#   'I',
#   'gentlemen,',
#   'the',
#   'day',
#   'gentlemen.',
#   'he',
#   'Bruiser',
#   'I’m',
#   'gentlemen.',
#   'he’s',
#   'Bruiser',
#   'my',
#   'gentlemen.',
#   'he',
#   'Bruiser',
#   'do',
#   'take',
#   'he',
#   'the',
#   'Kevin',
#   'Kevin',
#   'then',
#   'bigger',
#   'we',
#   'on',
#   'I',
#   'show',
#   'what',
#   'get',
#   'gentlemen,',
#   'welcome',
#   'everyone',
#   'Kevin',
#   'returns',
#   'he',
#   'a',
#   'he…',
#   'here',
#   'a',
#   'he',
#   'there’s',
#   'he',
#   'get',
#   'the',
#   'other',
#   'who',
#   'not',
#   'its',
#   'innocent,',
#   'deeply',
#   'had',
#   'I',
#   'that’s',
#   'we’ll',
#   'I’m',
#   'the',
#   'cheat',
#   'it',
#   'order',
#   'David',
#   'Hayes',
#   'new',
#   'David',
#   'resilience',
#   'every',
#   'unprecedented',
#   'every',
#   'will',
#   'feud',
#   'your',
#   'fast',
#   'easy',
#   'it',
#   'all.',
#   'already',
#   'workin’',
#   'my',
#   'wrestle',
#   'Kerry',
#   'new',
#   'I’ll',
#   'pray',
#   'I',
#   'thank',
#   'support.',
#   'it’s',
#   'a',
#   'a',
#   'I’ve',
#   'ordered',
#   'sweat',
#   'no',
#   'downs.',
#   'still',
#   'sell',
#   'I…',
#   'I,',
#   'we’ll',
#   'I’ll',
#   'get',
#   'you',
#   'now',
#   'woke',
#   'irony',
#   'is',
#   'find'],
#  'personal': ['relationships,'],
#  'relationships,': ['as'],
#  'as': ['his',
#   'he',
#   'much',
#   'a',
#   'we',
#   'Race',
#   'planned.',
#   'soon',
#   'I',
#   'secrets'],
#  'his': ['father,',
#   'sons,',
#   'marriage',
#   'brothers',
#   'brothers',
#   'growing',
#   'neck!',
#   'ring',
#   'partner',
#   'partner',
#   'partner',
#   'father’s',
#   'last',
#   'biggest',
#   'back.',
#   'rematch',
#   'ass',
#   'father.',
#   'own',
#   'own',
#   'corner.',
#   'hotel',
#   '25',
#   'place.',
#   'brother,',
#   'brother',
#   'father',
#   'last',
#   'father,',
#   'ranch.'],
#  'father,': ['WCCW', 'he', 'but', 'living'],
#  'WCCW': ['owner', 'is'],
#  'owner': ['Fritz,'],
#  'Fritz,': ['pushes', 'calling'],
#  'pushes': ['the', 'him'],
#  'wrestling': ['legacy', 'career', 'on', 'federation', 'since', 'if'],
#  'legacy': ['on', 'immortalized'],
#  'on': ['his',
#   'a',
#   'no',
#   'Mike,',
#   'in.',
#   'the',
#   'tonight',
#   'tonight',
#   'that',
#   'the',
#   'Gino.',
#   'the',
#   'your',
#   'your',
#   'how',
#   'him',
#   'ESPN.',
#   'Texas',
#   'this',
#   'the',
#   'that',
#   'top',
#   'that',
#   'Kevin',
#   'his',
#   'you.',
#   'running,',
#   'the',
#   'the',
#   'his',
#   'someone.',
#   'her,',
#   'it.',
#   'national',
#   'the',
#   'a',
#   'a',
#   'national',
#   'open',
#   'the',
#   'any',
#   'Kerry.',
#   'Gordy.',
#   'air',
#   'the',
#   'the',
#   'my',
#   'the',
#   'the',
#   'the',
#   'this',
#   'for',
#   'the',
#   'the',
#   'the',
#   'lizard',
#   'the',
#   'now.',
#   'the',
#   'the',
#   'a',
#   'you.',
#   'the',
#   'wrestling',
#   'open',
#   'my'],
#  'sons,': ['sidelining'],
#  'sidelining': ['youngest'],
#  'youngest': ['brother'],
#  'brother': ['Mike’s',
#   'to',
#   'syndrome.',
#   'syndrome.',
#   'died,',
#   'here',
#   'here',
#   'fought',
#   'better,',
#   'David,',
#   'left',
#   'ruined',
#   'and,',
#   'anymore.',
#   'along'],
#  'Mike’s': ['musical', 'tragic', 'fine,', 'temperature', 'a'],
#  'musical': ['aspirations.'],
#  'aspirations.': ['The'],
#  'story': ['chronicles'],
#  'chronicles': ['Kevin’s'],
#  'Kevin’s': ['wrestling',
#   'battles',
#   'life',
#   'got',
#   'struggling',
#   'gasping',
#   'eyes.'],
#  'career': ['and', 'but'],
#  'evolving': ['family'],
#  'dynamics,': ['including'],
#  'including': ['his'],
#  'marriage': ['to'],
#  'to': ['Pam',
#   'have',
#   'our',
#   'the',
#   'act',
#   'rent',
#   'raise',
#   'beat',
#   'beat',
#   'be',
#   'protect',
#   'protect',
#   'start',
#   'bulk',
#   'defend',
#   'become',
#   'make',
#   'start',
#   'you',
#   'be',
#   'see',
#   'see',
#   'see',
#   'size',
#   'fight',
#   'Gino,',
#   'take',
#   'fight',
#   'fight',
#   'fly',
#   'really',
#   'the',
#   'the',
#   'the',
#   'Emily?',
#   'make',
#   'say,',
#   'meet',
#   'meet',
#   'meet',
#   'sign?',
#   'ask',
#   'have',
#   'go',
#   'ask',
#   'as',
#   'me',
#   'you.',
#   'do',
#   'play',
#   'Von',
#   'come',
#   'the',
#   'take',
#   'bring',
#   'an',
#   'take',
#   'date.',
#   'the',
#   'make',
#   'the',
#   'get',
#   'the',
#   'step',
#   'come',
#   'the',
#   'do',
#   'see',
#   'come',
#   'stop',
#   'chase',
#   'throw',
#   'get',
#   'screw',
#   'the',
#   'make',
#   'Moscow',
#   'University',
#   'play',
#   'play',
#   'tell',
#   'set',
#   'run',
#   'provide',
#   'join',
#   'hear',
#   'victory.',
#   'restore',
#   'the',
#   'us.',
#   'you.',
#   'WCCW.',
#   'restore',
#   'his',
#   'do',
#   'Sam',
#   'see',
#   'it',
#   'be',
#   'your',
#   'Japan.',
#   'have',
#   'the',
#   'understand',
#   'be',
#   'see',
#   'rest.',
#   'Japan',
#   'me.',
#   'focus',
#   'do.',
#   'rise',
#   'worry',
#   'move',
#   'accept',
#   'the',
#   'send.',
#   'see',
#   'adversity.',
#   'bring',
#   'decide.',
#   'celebrate',
#   'the',
#   'that.',
#   'the',
#   'toss',
#   'head',
#   'do',
#   'bring',
#   '107',
#   'say',
#   'us?',
#   'blame',
#   'that',
#   'settle.',
#   'think',
#   'everyone.',
#   'the',
#   'be',
#   'be',
#   'tell',
#   'slow',
#   'a',
#   'me.',
#   'lay',
#   'rest',
#   'be',
#   'get',
#   'catch',
#   'worry',
#   'the',
#   'defend',
#   'be',
#   'toe.',
#   'wear',
#   'go,',
#   'the',
#   'Dallas',
#   'take',
#   'me.',
#   'me.',
#   'me',
#   'me',
#   'become',
#   'make',
#   'cut',
#   'one',
#   'the',
#   'buy',
#   'think',
#   'meet',
#   'meet',
#   'retire',
#   'you',
#   'Mexico',
#   'Mexico.',
#   'the',
#   'prepare.',
#   'be',
#   'get',
#   'hide',
#   'go.',
#   'end.',
#   'me,',
#   'do',
#   'Kerry.',
#   'figure',
#   'help',
#   'work',
#   'look',
#   'meet',
#   'stay',
#   'his',
#   'intimidate',
#   'be',
#   'stay',
#   'run',
#   'know',
#   'think',
#   'murder',
#   'fake',
#   'escape',
#   'be',
#   'your'],
#  'Pam': ['and'],
#  'tragic': ['unfolding', 'death,'],
#  'unfolding': ['of'],
#  '“Von': ['Erich'],
#  'curse,”': ['which'],
#  'which': ['claims', 'was'],
#  'claims': ['the'],
#  'lives': ['of'],
#  'brothers': ['and', 'in', 'and', 'are', 'line', 'in'],
#  'haunts': ['the'],
#  'with': ['loss',
#   'grief',
#   'his',
#   'the',
#   'God.',
#   'wrestling.',
#   'you,',
#   'your',
#   'my',
#   'Fate',
#   'me',
#   'you,',
#   'my',
#   'my',
#   'your',
#   'that.',
#   'that?',
#   'us.',
#   'one',
#   'out',
#   'a',
#   'a',
#   'Harley',
#   'our',
#   'his',
#   'a',
#   'him?',
#   'a',
#   'Kevin,',
#   'Ric',
#   'Flair',
#   'Flair',
#   'you',
#   'an',
#   'me',
#   'the',
#   'me.',
#   'me',
#   'your',
#   'us.',
#   '25',
#   'the',
#   'you?',
#   'him?',
#   'us.',
#   'my',
#   'her',
#   'an'],
#  'loss': ['and'],
#  'misfortune.': ['Key'],
#  'Key': ['moments'],
#  'moments': ['include'],
#  'include': ['Kevin’s'],
#  'battles': ['in'],
#  'in': ['the',
#   'wrestling,',
#   'a',
#   'Hawaii,',
#   'the',
#   '2009.',
#   'the',
#   'you.',
#   'you,',
#   'the',
#   'those',
#   'there,',
#   '15',
#   'the',
#   'the',
#   'a',
#   'a',
#   'a',
#   'and',
#   'the',
#   '‘The',
#   'our',
#   'wrestling.',
#   'Missouri.',
#   'life,',
#   'any',
#   'any',
#   'curses,',
#   'luck.',
#   'here.',
#   'this',
#   'town',
#   'downtown',
#   'the',
#   '62',
#   'this',
#   'a',
#   'the',
#   'the',
#   'this',
#   'Missouri.',
#   'freedom',
#   'human',
#   'an',
#   'the',
#   'not',
#   'the',
#   'the',
#   'the',
#   'music.',
#   'it',
#   'the',
#   'the',
#   'at',
#   'time.',
#   'the',
#   'the',
#   'the',
#   'the',
#   'every',
#   'America',
#   'May',
#   'the',
#   'the',
#   'a',
#   'his',
#   'Japan.',
#   'this',
#   'his',
#   'the',
#   'a',
#   'a',
#   'our',
#   'there.',
#   'a',
#   'the',
#   'the',
#   'no',
#   'the',
#   'the',
#   'it',
#   'the',
#   'all',
#   'that',
#   'wrestling',
#   'some',
#   'Dallas.',
#   'pain.',
#   'pain',
#   'the',
#   'me',
#   'a',
#   'a'],
#  'ring,': ['the', 'Mike?'],
#  'rise': ['and', 'early', 'these'],
#  'fall': ['of', 'and'],
#  'wrestling,': ['Mike’s', 'not', 'the'],
#  'death,': ['and'],
#  'family’s': ['struggle', 'first'],
#  'struggle': ['with'],
#  'grief': ['and'],
#  'legacy.': ['Despite'],
#  'Despite': ['the'],
#  'curse’s': ['toll,'],
#  'toll,': ['Kevin’s'],
#  'life': ['moves', 'in', 'to', 'on', 'never', 'for', 'of'],
#  'moves': ['forward'],
#  'forward': ['as'],
#  'he': ['takes',
#   'said',
#   'told',
#   'is',
#   'is',
#   'pushes',
#   'slaps',
#   'died.',
#   'just,',
#   'can',
#   'would',
#   'delivers',
#   'knocks',
#   'tosses',
#   'doesn’t',
#   'does!',
#   'is,',
#   'comes',
#   'doesn’t',
#   'throws',
#   'will',
#   'will',
#   'doesn’t',
#   'breaks',
#   'was',
#   'gave',
#   'doesn’t',
#   'lived',
#   'suffered',
#   'pulls',
#   'is.',
#   'is.',
#   'never'],
#  'takes': ['over', 'too'],
#  'over': ['WCCW,',
#   'to',
#   'at',
#   'the',
#   'the',
#   'the',
#   'Japan.',
#   'here.',
#   'to',
#   'there?',
#   'this'],
#  'WCCW,': ['welcomes', 'you’ve'],
#  'welcomes': ['new'],
#  'new': ['beginnings',
#   'life',
#   'Texas',
#   'show,',
#   'camera',
#   '(SIGHS)',
#   'NWA',
#   'address.',
#   'World',
#   'dress.',
#   'contract.'],
#  'beginnings': ['with'],
#  'growing': ['family,', 'well,'],
#  'family,': ['and', 'Kev.', 'Kevin.', 'Dad.'],
#  'eventually': ['finds'],
#  'solace': ['in'],
#  'a': ['new',
#   'chance!',
#   'star,',
#   'star.',
#   'Cadillac.',
#   'real',
#   'bunch',
#   'fancy',
#   'house?',
#   'run.',
#   'run?',
#   'child,',
#   'trip.',
#   'bitch!',
#   'joke.',
#   'little',
#   'dump.',
#   'second.',
#   'burger',
#   'try',
#   'tagteam',
#   'mystery.',
#   'tag-team',
#   'mystery.',
#   'tag-team',
#   'mystery.',
#   'big',
#   'body',
#   'go',
#   'kick',
#   'huge',
#   'double',
#   'drink',
#   'little',
#   'national',
#   'World',
#   'World',
#   'good',
#   'lot?',
#   'belt,',
#   'job',
#   'reward,',
#   'vet.',
#   'man',
#   'kid,',
#   'part',
#   'silly',
#   'nontitle',
#   'whooping',
#   'momentous',
#   'nontitle',
#   'tremendous',
#   'big',
#   'great',
#   'devastating',
#   'big',
#   'punch.',
#   'clothesline.',
#   'spectacular',
#   'bear',
#   'low',
#   'ride,',
#   'suplex.',
#   'standing',
#   'knee',
#   'big',
#   'good',
#   'fair',
#   'big',
#   'grateful',
#   'hit',
#   'hold',
#   'good',
#   'damn',
#   'Music',
#   'well-rounded',
#   'part',
#   'gig.',
#   'university',
#   'Saturday',
#   'lot.',
#   'problem?',
#   'combined',
#   'combined',
#   'cross',
#   'dropkick.',
#   'special',
#   'message',
#   'bold',
#   'problem?',
#   'World',
#   'couple',
#   'doctor.',
#   'bug',
#   'shotgun',
#   'country',
#   'simple',
#   'family',
#   'country',
#   'little',
#   'great',
#   'couple',
#   'country',
#   'black',
#   'mighty',
#   'country',
#   'fine',
#   'moment',
#   'lifetime.',
#   'chance',
#   'tough',
#   'coin.',
#   'handle.',
#   'match',
#   'stop',
#   'backslide.',
#   'ride',
#   'coma.',
#   'routine',
#   'terrible',
#   'fighter',
#   'fighter',
#   'fever',
#   'riot',
#   'game',
#   'feeling',
#   'better',
#   'new',
#   'child,',
#   'lot',
#   'lot',
#   'Rolex',
#   'limousine',
#   'mile-long',
#   'nothing-happenin’,',
#   'man,',
#   'real',
#   'bitch.',
#   'little',
#   'rematch',
#   'drink.',
#   'change.',
#   'bigger',
#   'Saturday',
#   'good',
#   'house.',
#   'free',
#   'look',
#   'drink,',
#   'Christmas',
#   'Smith',
#   'gun',
#   'nice',
#   'new',
#   'family.',
#   'pretty',
#   'minute.',
#   'good',
#   'brother',
#   'brother',
#   'feeling',
#   'riot',
#   'game',
#   'field',
#   'vice',
#   'messiah',
#   'teenager',
#   'week'],
#  'Hawaii,': ['with'],
#  'Erichs’': ['legacy'],
#  'immortalized': ['in'],
#  'WWE': ['Hall'],
#  'Hall': ['of'],
#  'Fame': ['in'],
#  '2009.': ['*'],
#  '*': ['*', '*', '(LIGHTS', 'Name*'],
#  '(LIGHTS': ['CLICKING)'],
#  'CLICKING)': ['(GRUNTING)'],
#  '(GRUNTING)': ['(PEOPLE',
#   'REFEREE:',
#   '(SCREAMING)',
#   'REFEREE:',
#   'REFEREE:',
#   'Morning.',
#   'Get',
#   '(INDISTINCT',
#   'Kerry.',
#   'Keep',
#   'FRITZ:',
#   '(BELL',
#   'REFEREE:',
#   '(GAGS)',
#   '(KEVIN',
#   '♪'],
#  '(PEOPLE': ['CHEERING'],
#  'CHEERING': ['IN', 'IN', 'IN', 'IN', 'FADES)'],
#  'IN': ['BACKGROUND)',
#   'THE',
#   'BACKGROUND)',
#   'BACKGROUND)',
#   'THE',
#   'THE',
#   'BACKGROUND)'],
#  'BACKGROUND)': ['(GRUNTING)', '(ROCK', '(DOOR', '(DOOR', 'BILL:'],
#  'REFEREE:': ['It’s',
#   'Do',
#   'One,',
#   'One,',
#   'That’s',
#   'Hey,',
#   'One!',
#   'Four!',
#   'Seven!',
#   'Nine!',
#   'One,',
#   'Ric,',
#   'Come',
#   'Kevin,',
#   'Kevin,',
#   'Okay,',
#   'Come',
#   'Come',
#   'Ring',
#   'What'],
#  'It’s': ['over,',
#   'over.',
#   'over.',
#   'incredible.',
#   'gonna',
#   'not',
#   'time',
#   'nice',
#   'okay.',
#   'Pam.',
#   'nice',
#   'a',
#   'great.',
#   'about',
#   'total',
#   'necessary,',
#   'early.',
#   'the',
#   'early',
#   'wild',
#   'hard',
#   'my',
#   'a',
#   'fine,',
#   'taken',
#   'okay.',
#   'okay.',
#   'gonna',
#   'a',
#   'so',
#   'so',
#   'so',
#   'beautiful,',
#   'in',
#   'got',
#   'okay.',
#   'okay,',
#   'getting',
#   'slipping'],
#  'over,': ['Rick,'],
#  'Rick,': ['they’re'],
#  'they’re': ['gonna', 'gone'],
#  'gonna': ['disqualify',
#   'ask',
#   'be',
#   'leave',
#   'be.',
#   'get',
#   'tell',
#   'be',
#   'love…',
#   'drive',
#   'be',
#   'go.',
#   'fight',
#   'beat',
#   'light',
#   'be',
#   'slow',
#   'be',
#   'flip',
#   'go',
#   'be',
#   'take',
#   'have',
#   'say',
#   'come',
#   'light',
#   'light'],
#  'disqualify': ['you.'],
#  'you.': ['One,',
#   'FRITZ:',
#   'Show',
#   'DORIS:',
#   'FRITZ:',
#   'BILL:',
#   'Stop.',
#   'GIRL:',
#   'KEVIN:',
#   'Thanks',
#   'Okay,',
#   'Is',
#   'I',
#   'Thank',
#   'I…',
#   'You',
#   'Oh,',
#   'And',
#   'Did',
#   'Ready,',
#   'You',
#   'I',
#   'Get',
#   '(CROWD',
#   '(CROWD',
#   'You’ve',
#   'Just',
#   'No',
#   'It',
#   '(SIGHS)',
#   'I',
#   'All',
#   '(SNIFFLES)',
#   'Hang',
#   '(SIGHS',
#   'Hey!',
#   'Let',
#   'You',
#   'Go',
#   'Yeah.',
#   'Never',
#   'Hmm.',
#   '(SIGHS)',
#   'Come',
#   '(CHUCKLES',
#   '(SOFTLY)',
#   '(SNIFFLES)'],
#  'One,': ['two,',
#   'two,',
#   'two,',
#   'two…',
#   'two,',
#   'two…',
#   'two…',
#   'two!',
#   'two,',
#   'two…',
#   'two,',
#   'two,',
#   'two,'],
#  'two,': ['three.',
#   'three.',
#   'three,',
#   'three!',
#   'three!',
#   'three!',
#   'three…',
#   'three!'],
#  'three.': ['Come', 'Ring'],
#  'Come': ['on.',
#   'on.',
#   'on!',
#   'on,',
#   'in.',
#   'on',
#   'on.',
#   'on,',
#   'on,',
#   'next',
#   'in,',
#   'on.',
#   'here,',
#   'on!',
#   'on,',
#   'on',
#   'on.',
#   'on,',
#   'on,',
#   'here.',
#   'on.',
#   'on!',
#   'on!',
#   'on!',
#   'on.',
#   'home.',
#   'on,',
#   'on.',
#   'on,',
#   'on,',
#   'on,',
#   'on.',
#   'on,',
#   'on,',
#   'on.',
#   'here.',
#   'on'],
#  'on.': ['Get',
#   'Let’s',
#   'It’s',
#   'MIKE:',
#   'Get',
#   'Get',
#   '(ALL',
#   '(PAM',
#   'Hold',
#   'Let',
#   'We',
#   'Yeah.',
#   'Everyone',
#   '(SNIFFLES)',
#   'DORIS:',
#   'But',
#   'Oh,',
#   '(CROWD',
#   'What',
#   'Hey!',
#   'They',
#   'Hey,'],
#  'Get': ['him',
#   'in',
#   'up.',
#   'out',
#   'out',
#   'out',
#   'down,',
#   'you',
#   'up!',
#   'off',
#   'out',
#   'the'],
#  'him': ['out',
#   'back.',
#   'a',
#   'in',
#   'and',
#   'down.',
#   'into',
#   'on',
#   'to',
#   'in',
#   'to',
#   'for',
#   'till',
#   'to'],
#  'out': ['of',
#   'during',
#   'of',
#   'of',
#   'from',
#   'to',
#   'to?',
#   'to?”',
#   'with',
#   'on',
#   'there.',
#   'of',
#   'and',
#   'of',
#   'of',
#   'of',
#   'the',
#   'on',
#   'there.',
#   'there.',
#   'for',
#   'and',
#   'of',
#   'there',
#   'the',
#   'there.',
#   'there',
#   'this',
#   'there.',
#   'of',
#   'there',
#   'there,',
#   'here.',
#   'of',
#   'of',
#   'to',
#   'there.',
#   'how',
#   'between',
#   'for',
#   'for',
#   'to',
#   'of'],
#  'corner.': ['(GRUNTS)', 'And', 'And', 'Buddy'],
#  '(GRUNTS)': ['(GROANS)',
#   '(CROWD',
#   '(SIGHS)',
#   'Come',
#   '(GROANS)',
#   '(THUDS)',
#   '(GROANS)',
#   'BILL:',
#   'CROWD:',
#   'KERRY:',
#   '(FRITZ',
#   '(GRUNTING)',
#   '(CROWD',
#   'FRITZ:',
#   '(GRUNTS)',
#   'You',
#   '(PANTING)',
#   '(FRITZ'],
#  '(GROANS)': ['(CROWD',
#   '(INDISTINCT',
#   '(CROWD',
#   'CROWD:',
#   'HARLEY:',
#   'BILL:',
#   'BILL:',
#   'FRITZ:',
#   '(SNORTING)',
#   '(PANTS)'],
#  '(CROWD': ['CHEERING)',
#   'CHEERING)',
#   'GASPING)',
#   'CHEERING)',
#   'CHEERING)',
#   'CHEERING)',
#   'BOOING)',
#   'CHEERING)',
#   'CHEERING)',
#   'CHEERING)',
#   'CHEERING)',
#   'CHEERING)',
#   'CHEERING)',
#   'CHEERING)',
#   'CHEERING)',
#   'CHEERING)',
#   'CHEERING)',
#   'BOOING)',
#   'BOOING)',
#   'SCREAMING)',
#   'BOOING)',
#   'CHEERING)',
#   'CHEERING',
#   'CHEERING)',
#   'CHEERING)',
#   'CHEERING)',
#   'CHEERING)',
#   'CLAMORING)',
#   'CHEERING)',
#   'BOOING)',
#   'CHEERING)',
#   'CHEERING)',
#   'CHEERING)',
#   'CHEERING,',
#   'CHEERING)',
#   'CHEERING,',
#   'CHEERING)',
#   'CHEERING',
#   'CHEERING',
#   'CHEERING)',
#   'CHEERING)',
#   'CHEERING)',
#   'CHEERING,',
#   'CHEERING)',
#   'CHEERING)',
#   'CHEERING)',
#   'CHEERING)',
#   'CHEERING,',
#   'CHEERING)',
#   'CHEERING)',
#   'CHEERING)'],
#  'CHEERING)': ['(GRUNTING)',
#   '(CROWD',
#   '(PANTING)',
#   'CROWD:',
#   '(GRUNTING)',
#   '(GROANS)',
#   'Yeah!',
#   'RING',
#   '(THUDS)',
#   'CROWD:',
#   'Breaking',
#   'BILL:',
#   'BILL:',
#   'BILL:',
#   'BILL:',
#   'You',
#   '(INDISTINCT',
#   'Oh,',
#   'Yeah!',
#   '(THUDS)',
#   '(GRUNTS)',
#   '(THUDS)',
#   'DAVID:',
#   '(INDISTINCT',
#   '(KEVIN',
#   'BILL:',
#   'BILL:',
#   'BILL:',
#   'The',
#   'BILL:',
#   '♪',
#   '(BOTH',
#   '(OPPONENT',
#   '(CROWD',
#   'RING',
#   'The',
#   'RIC:',
#   'COMMENTATOR:',
#   'REFEREE:',
#   '(GRUNTING)',
#   '(RIC'],
#  '(SCREAMING)': ['REFEREE:', 'FRITZ:', 'Mike!'],
#  'Do': ['you', 'I', 'you', 'you'],
#  'you': ['wanna',
#   'guys',
#   'see',
#   'thinking?',
#   'son',
#   'need',
#   'need',
#   'to',
#   'about',
#   'been?',
#   'doing?',
#   'doing?',
#   'doing?',
#   'again.',
#   'so',
#   'again.',
#   'later.',
#   'see?',
#   'would',
#   'were',
#   'know',
#   'better',
#   'lies',
#   'down',
#   'tonight,',
#   'get',
#   'know?',
#   'a',
#   'to',
#   'to',
#   'hear',
#   'make',
#   'so',
#   'so',
#   'wanna',
#   'too,',
#   'how',
#   'know,',
#   'like',
#   'asking',
#   'again.',
#   'that.',
#   'go.',
#   'this',
#   'want',
#   'just',
#   'move',
#   'moving',
#   'do',
#   'reach',
#   'become',
#   'want?',
#   'like',
#   'be',
#   'have',
#   'wanna',
#   'never',
#   'put',
#   'are',
#   'can',
#   'will',
#   'so',
#   'have',
#   'all',
#   'to',
#   'so…',
#   'what',
#   'keep',
#   'whether',
#   'down',
#   'anywhere,',
#   'did.',
#   'out',
#   'some',
#   'were',
#   'let',
#   'didn’t.',
#   'make',
#   'some',
#   'fight',
#   'see',
#   'play?',
#   'cry',
#   'think?',
#   'ever?',
#   'sweet',
#   'see,',
#   'folks.',
#   'should',
#   'all.',
#   'boys',
#   'the',
#   'to',
#   'training,',
#   'gotta',
#   'go.',
#   'know',
#   'saw',
#   'all.',
#   'win',
#   'up',
#   'too,',
#   'perform,',
#   '♪',
#   '♪',
#   '♪',
#   'give',
#   'to',
#   'become',
#   'should',
#   'jumping',
#   'guys.',
#   'guys.',
#   'real',
#   'getting',
#   'get',
#   'soon.',
#   'wanna',
#   'will',
#   'were',
#   'doing?',
#   'have',
#   'sure',
#   'wanna',
#   'know',
#   'want',
#   'blame',
#   'do,',
#   'take',
#   'all',
#   'all',
#   'feeling',
#   'go.',
#   'tell',
#   'to',
#   'should',
#   'in',
#   'coming',
#   'guys',
#   'can’t',
#   'what,',
#   'like',
#   'take',
#   'doing?',
#   'doing?',
#   'were',
#   'got',
#   'a',
#   'change',
#   'doing?',
#   'learn?',
#   'decide,',
#   'the',
#   'could',
#   'sell,',
#   'can',
#   'dare',
#   'do',
#   'do?',
#   'get',
#   'something',
#   'now.',
#   'were',
#   'know,',
#   'think?',
#   'doing?',
#   'always',
#   'get',
#   'getting',
#   'too.',
#   'okay?',
#   'go',
#   'don’t.',
#   'don’t.',
#   'gonna',
#   'are,',
#   'to',
#   'didn’t',
#   'to',
#   'want.',
#   'know,',
#   'a',
#   'doing?',
#   'talking',
#   'think',
#   'know',
#   'to',
#   'to',
#   'run'],
#  'wanna': ['quit?',
#   'be',
#   'say',
#   'say',
#   'say,',
#   'ask',
#   'offer',
#   'be',
#   'be',
#   'be',
#   'take',
#   'hear.',
#   'get',
#   'live',
#   'live',
#   'live',
#   'live',
#   'live',
#   'live',
#   'live',
#   'fight',
#   'say,',
#   'see',
#   'talk.',
#   'do',
#   'see',
#   'live',
#   'live',
#   'wait.',
#   'give',
#   'shoot',
#   'shoot',
#   'be',
#   'die.',
#   'live',
#   'live',
#   'live',
#   'live',
#   'live',
#   'live',
#   'live',
#   'live',
#   'be',
#   'live',
#   'live',
#   'live',
#   'live',
#   'live',
#   'live',
#   'live',
#   'live',
#   'live',
#   'live',
#   'live',
#   'live',
#   'live',
#   'live',
#   'live'],
#  'quit?': ['I’ll'],
#  'I’ll': ['break',
#   'snap',
#   'come',
#   'always',
#   'eat',
#   'give',
#   'still',
#   'heat',
#   'chase',
#   'be',
#   'be',
#   'probably',
#   'do',
#   'do',
#   'be',
#   'feel',
#   'be',
#   'tell',
#   'give',
#   'be',
#   'come',
#   'be',
#   'give'],
#  'break': ['it!', 'it', 'the'],
#  'it!': ['I’ll', 'He', 'Ric', 'Well,', 'The', 'That’s'],
#  'snap': ['his'],
#  'neck!': ['(GRUNTS)'],
#  'GASPING)': ['(GRUNTING)'],
#  'Ring': ['the', 'the', 'the'],
#  'bell!': ['It’s'],
#  'over.': ['It’s', 'Let’s', 'But', 'PAM:'],
#  'Let’s': ['go.', 'go', 'go!', 'go,', 'move', 'go', 'go.', 'get', 'do'],
#  'go.': ['(CROWD',
#   '(CHUCKLES)',
#   'Thanks.',
#   'Ours',
#   '(GRUNTS)',
#   'Now,',
#   'Let’s',
#   '(BABY',
#   'Thanks.',
#   'I',
#   'I'],
#  '(PANTING)': ['(BOYS',
#   'You',
#   'Harley',
#   '(MUSIC',
#   '(GRUNTS)',
#   '(BREATHING',
#   '(CROWD',
#   'No!',
#   'I',
#   '(KEVIN'],
#  '(BOYS': ['GIGGLING).', 'CHATTERING)', 'GRUNTING)'],
#  'GIGGLING).': ['Hey,'],
#  'Hey,': ['now.',
#   'Kevin.',
#   'David.',
#   'Kevin.',
#   'I’ve',
#   'how',
#   'how',
#   'um…',
#   'Pop.',
#   'break',
#   'smile,',
#   'Ma.',
#   'boys.',
#   'Pam.',
#   'I,',
#   'Ker,',
#   'how’s',
#   'what',
#   'uh…',
#   'Dave.',
#   'I',
#   'Ker.',
#   'Hey.',
#   'Doc.',
#   'hon.',
#   'Mike,',
#   'listen',
#   'guys.',
#   'boys,',
#   'Mom.',
#   'Mom!',
#   'how',
#   'Dad.',
#   'Pam.',
#   'stop.',
#   'you',
#   'I',
#   'Kerry.',
#   'Mikey.',
#   'where’s',
#   'I’m'],
#  'now.': ['Hey,',
#   'I’ll',
#   '(CROWD',
#   'A',
#   'Hey,',
#   'Come',
#   '(CROWD',
#   'Break',
#   'Is',
#   'Well,',
#   'It’s'],
#  'Kevin.': ['Hey,',
#   '(SIGHS)',
#   'Hey,',
#   'Did',
#   'If',
#   'Really?',
#   '(CROWD',
#   'Fritz.',
#   'A',
#   'Oh,',
#   'No,'],
#  'David.': ['You',
#   'Sorry,',
#   '(KNOCKING',
#   'If',
#   'Welcome',
#   'BILL:',
#   'Great',
#   'Don’t',
#   'Fuck',
#   'What',
#   'What?'],
#  'You': ['crushed',
#   'guys',
#   'did',
#   'won’t',
#   'gotta',
#   'know,',
#   'been',
#   'travel',
#   'know,',
#   'know,',
#   'are',
#   'kidding',
#   'can',
#   'have',
#   'can',
#   'ain’t',
#   'coward.',
#   'afraid',
#   'came',
#   'are',
#   'were',
#   'gotta',
#   'should’ve',
#   'just',
#   'all',
#   'still',
#   'gotta',
#   'gotta',
#   'keep',
#   'put',
#   'know,',
#   'aren’t',
#   'feel',
#   'feel',
#   'did',
#   'earned',
#   'can’t',
#   'never',
#   'all',
#   'need',
#   'need',
#   'think',
#   'rat',
#   'gotta',
#   'don’t',
#   'are',
#   'know',
#   'were',
#   'get',
#   'want',
#   'want',
#   'see',
#   'were',
#   'were',
#   'should',
#   'think',
#   'look',
#   'gotta',
#   'brought',
#   'look',
#   'okay?',
#   'know,',
#   'know,',
#   'don’t',
#   'boys',
#   'didn’t',
#   'didn’t',
#   '(GRUNTING)',
#   'must',
#   'okay,',
#   'shouldn’t',
#   'can'],
#  'crushed': ['that'],
#  'that': ['guy,',
#   'thing',
#   'behind.',
#   'was',
#   'long',
#   'Don’t',
#   '♪',
#   'mouth',
#   'again',
#   'top,',
#   'the',
#   'with',
#   'to',
#   'all',
#   'like?',
#   'it',
#   'belt',
#   'you',
#   'man',
#   'man',
#   'one.',
#   'bellytoback',
#   'concrete',
#   'NWA',
#   'hard',
#   'we',
#   'you’ll',
#   'down,',
#   'I’m',
#   'way',
#   'way',
#   'way',
#   'way',
#   'way',
#   'way',
#   'way',
#   'way',
#   'way',
#   'be',
#   'our',
#   'were',
#   'will',
#   'David',
#   'World',
#   'belt.',
#   'bad.',
#   'matters',
#   'makes',
#   'happen?',
#   'S',
#   'mean?',
#   'Mike',
#   'man.',
#   'Mike',
#   'we',
#   'y’all',
#   'way',
#   'way',
#   'you’ve',
#   'I’m',
#   'costs!',
#   'be',
#   'from',
#   'escaped',
#   'apartment',
#   'all',
#   'your',
#   'to',
#   'way',
#   'way',
#   'way',
#   'way',
#   'way',
#   'way',
#   'way',
#   'way',
#   'way',
#   'way',
#   'way',
#   'way',
#   'way',
#   'way',
#   'way',
#   'way',
#   'way',
#   'way',
#   'way',
#   'way',
#   'way',
#   'way',
#   'way'],
#  'guy,': ['Pop.'],
#  'Pop.': ['I',
#   'This',
#   'Kid',
#   'Get',
#   'Me',
#   'It’s',
#   'I',
#   'I’m',
#   'TANIA:',
#   'Soon.'],
#  'I': ['sure',
#   'had',
#   'was',
#   'wanna',
#   'need',
#   'will',
#   'will',
#   'have',
#   'should',
#   'entrust',
#   'promise.',
#   'was',
#   'don’t',
#   'believed',
#   'believed',
#   'couldn’t',
#   'eat',
#   'still',
#   'gotta',
#   'talk',
#   'know,',
#   'don’t',
#   'miss',
#   'got',
#   'can’t',
#   'love',
#   'just',
#   'have',
#   'just',
#   'got',
#   'hear',
#   'didn’t',
#   'got',
#   'just',
#   'mean',
#   'know.',
#   'want',
#   'tag',
#   'get',
#   'make',
#   'would',
#   'just…',
#   'can',
#   'wanna',
#   'wanna',
#   'don’t',
#   'wanna',
#   'want',
#   'want',
#   'want',
#   'would.',
#   'was',
#   'had',
#   'don’t',
#   'don’t',
#   'must',
#   'guess.',
#   'don’t',
#   'guess',
#   'don’t',
#   'know',
#   'don’t',
#   'don’t',
#   'think',
#   'booked',
#   'will',
#   'deserved.',
#   'got',
#   'am',
#   'don’t',
#   'hope',
#   'dare',
#   'dare',
#   'was',
#   'know.',
#   'could',
#   'physically…',
#   'just',
#   'do',
#   'thought',
#   'was',
#   'hope',
#   'can’t',
#   'can',
#   'saw',
#   'was',
#   'first',
#   'chose',
#   'was',
#   'ever',
#   'got',
#   'got',
#   'mean,',
#   'wanna',
#   'wanna',
#   'wanna',
#   'wanna',
#   'wanna',
#   'wanna',
#   'wanna',
#   'love',
#   'got',
#   'just,',
#   'just…',
#   'don’t',
#   'wouldn’t',
#   'only',
#   'always',
#   'wanna',
#   'want',
#   'will',
#   'am.',
#   'love',
#   'love',
#   'can',
#   'was',
#   'played',
#   'had',
#   'walked',
#   'need',
#   'picked',
#   'don’t',
#   'just',
#   'didn’t',
#   'understand.',
#   'got',
#   'didn’t',
#   'just',
#   'got',
#   'knew',
#   'could',
#   'don’t',
#   'wouldn’t',
#   'never',
#   'mean',
#   'thank',
#   'got',
#   'got',
#   'got',
#   'don’t',
#   'sent',
#   'couldn’t',
#   'miss',
#   'was',
#   'am',
#   'can',
#   'can',
#   'want',
#   'deserve',
#   'didn’t',
#   'bet.',
#   'can’t',
#   'think',
#   'do.',
#   'just…',
#   'think.',
#   'know.',
#   'don’t',
#   'should’ve',
#   'can’t',
#   'can’t.',
#   'gotta',
#   'can’t.',
#   'know',
#   'think.',
#   'grew',
#   'painted',
#   'had',
#   'can’t',
#   'wanna',
#   'wanna',
#   'see',
#   'want',
#   'can’t',
#   'hurt',
#   'can’t',
#   'can’t.',
#   'can’t.',
#   'need',
#   'don’t',
#   'know',
#   'do.',
#   'know.',
#   'don’t',
#   'don’t',
#   'can’t,',
#   'was',
#   'believed',
#   'don’t',
#   'am',
#   'am',
#   'have',
#   'don’t',
#   'don’t',
#   'carry',
#   'am',
#   'am',
#   'can',
#   'don’t',
#   'don’t',
#   'mean,',
#   'always',
#   'hear',
#   'love',
#   'be',
#   'think',
#   'didn’t',
#   'need',
#   'didn’t',
#   'did.',
#   'did',
#   'know.',
#   'did.',
#   'got',
#   'got',
#   'don’t',
#   'wanna',
#   'thought',
#   'need',
#   'don’t',
#   'don’t',
#   'see',
#   'can',
#   'got',
#   'got',
#   'need',
#   'need',
#   'can’t.',
#   'can’t',
#   'want',
#   'do.',
#   'wanna',
#   'just',
#   'can.',
#   'told',
#   'don’t',
#   'can’t',
#   'walk',
#   'love',
#   'appreciate',
#   'could',
#   'didn’t',
#   'guess',
#   'used',
#   'got',
#   'wanna',
#   'wanna',
#   'wanna',
#   'wanna',
#   'fell',
#   'ran',
#   'wanna',
#   'wanna',
#   'wanna',
#   'wanna',
#   'want',
#   'feel',
#   'feel',
#   'wanna',
#   'wanna',
#   'wanna',
#   'wanna',
#   'wanna',
#   'wanna',
#   'wanna',
#   'wanna',
#   'wanna',
#   'wanna',
#   'wanna',
#   'wanna',
#   'wanna',
#   'wanna',
#   'wanna',
#   'accept'],
#  'sure': ['did.', 'sounded', 'yet.', 'he', 'you’re', 'you'],
#  'did.': ['Oh!', 'We', 'We’ll', '(GRUNTS)', 'I', 'Kerry,'],
#  'Oh!': ['The'],
#  'Claw.': ['Kevin’s', 'You’re'],
#  'got': ['me',
#   'food',
#   'this',
#   'something',
#   'something',
#   'close',
#   'no',
#   'it,',
#   'the',
#   'this…',
#   'this',
#   'an',
#   'it.',
#   'good',
#   'just',
#   'pretty',
#   'some',
#   'me',
#   'me',
#   'me',
#   'cakes',
#   'him.',
#   'him',
#   'nothing',
#   'a',
#   'the',
#   'on',
#   'a',
#   'together',
#   'it.',
#   'you,',
#   'you',
#   'this',
#   'nothing',
#   'to',
#   'me',
#   'nowhere',
#   'no',
#   'ahold',
#   'a',
#   'a'],
#  'me': ['in',
#   'out.',
#   'to',
#   'word',
#   'the',
#   'a',
#   'right',
#   '♪',
#   'like',
#   'like',
#   'and',
#   'there',
#   'who',
#   'sometime,',
#   'out?',
#   'feel',
#   'from',
#   '’cause',
#   'the',
#   'at',
#   'out',
#   'off',
#   'talk?',
#   'talk.',
#   'from',
#   'when',
#   'away',
#   'first.',
#   'then',
#   'and',
#   'so',
#   'look',
#   'can’t',
#   'no',
#   'a',
#   'a…',
#   'of',
#   'pregnant',
#   'tell',
#   'a',
#   'an',
#   'next',
#   'for',
#   'very',
#   'update',
#   'through',
#   'to',
#   'and',
#   'to',
#   'back',
#   'on',
#   'talk',
#   'alone!',
#   'alone!',
#   'know.',
#   'get',
#   'a',
#   'look',
#   'a',
#   'in-house',
#   'anymore.',
#   'like',
#   'at',
#   'now.',
#   'where',
#   'out',
#   'out',
#   'like',
#   'away'],
#  'You’re': ['getting',
#   'growing',
#   'not',
#   'supposed',
#   'lucky',
#   'the',
#   'too',
#   'not',
#   'doing',
#   'denying',
#   'late.',
#   'still'],
#  'getting': ['strong.',
#   'up',
#   'up.',
#   'paid.',
#   'a',
#   'me',
#   'the',
#   'through',
#   'your',
#   'harder'],
#  'strong.': ['Nice'],
#  'Nice': ['to', 'to'],
#  'have': ['you',
#   'put',
#   'your',
#   'the',
#   'somethin’',
#   'the',
#   'the',
#   'come',
#   'a',
#   'the',
#   'ad',
#   'a',
#   'a',
#   'a',
#   'to',
#   'our',
#   'oldest',
#   'the,',
#   'to',
#   'all',
#   'a',
#   'to',
#   '105,000',
#   'to',
#   'a',
#   'that',
#   'to',
#   'my',
#   'to',
#   'a',
#   'ever',
#   'to.',
#   'your',
#   'even',
#   'bled',
#   'to…',
#   'learnt…',
#   'an',
#   'a'],
#  'guys': ['here', 'like', 'walking', 'to', 'touring'],
#  'here': ['for',
#   'to',
#   'tonight,',
#   'and',
#   'and',
#   'comes',
#   'comes',
#   'we',
#   'at',
#   'tonight.',
#   'he',
#   'he',
#   'comes',
#   'put',
#   'deserves',
#   'today',
#   'if',
#   'to',
#   'with',
#   'love',
#   'to',
#   'to',
#   'comes',
#   'was',
#   'now,',
#   'anymore.'],
#  'for': ['once.',
#   'I',
#   'in',
#   'a',
#   'a',
#   'you',
#   'coming',
#   'me',
#   'you',
#   'you,',
#   'you.',
#   'coming,',
#   'coming.',
#   'Saturday',
#   'me.',
#   'sure.',
#   'you.',
#   'the',
#   'us.',
#   'Von',
#   'Kevin.',
#   'the',
#   'that',
#   'a',
#   'air',
#   'a',
#   'the',
#   'the',
#   'them,',
#   'that.',
#   'me',
#   'work.',
#   'the',
#   'sure.',
#   'you',
#   'you',
#   'it?',
#   'you',
#   'diamonds',
#   'David',
#   'an',
#   'in',
#   'Kerry.',
#   'Kevin.',
#   'his',
#   'his',
#   'his',
#   'the',
#   'a',
#   'him,',
#   'this',
#   'almost',
#   'work,',
#   'me?',
#   'coming,',
#   'your',
#   'me.',
#   'one',
#   'the',
#   'me',
#   'this',
#   'the',
#   'dinner.',
#   'a',
#   'Christmas',
#   'Christmas.',
#   'Christmas.',
#   'Christmas.',
#   'you.',
#   'the',
#   'him,',
#   'him!',
#   'you',
#   'dinner?',
#   'the',
#   'another',
#   'her',
#   'jaded'],
#  'once.': ['DORIS:', 'Twice.', '(CHUCKLES)'],
#  'DORIS:': ['Hi.',
#   'Not',
#   'What',
#   'Jack,',
#   'Wait.',
#   'I’m',
#   'Hi.',
#   'Hi,',
#   'Hey.',
#   'When',
#   'Today',
#   'Kerry,',
#   'In',
#   'Painting.'],
#  'Hi.': ['(KISSES)',
#   'Come',
#   'Come',
#   'FRITZ:',
#   'You’re',
#   'Hey.',
#   'Hey.',
#   'World'],
#  '(KISSES)': ['Did'],
#  'Did': ['you', 'you,', 'I'],
#  'see': ['anything,',
#   'you.',
#   'you',
#   'you',
#   'it',
#   'all',
#   'to',
#   'a',
#   'any',
#   'clearly',
#   'any',
#   'how',
#   'the',
#   'your',
#   'me',
#   'me'],
#  'anything,': ['Dottie?', 'all'],
#  'Dottie?': ['DORIS:', 'DORIS:'],
#  'Not': ['a', 'fake.', 'anymore.', 'any', 'a', 'like', 'at', 'never,', 'at'],
#  'chance!': ['But'],
#  'But': ['it',
#   'his',
#   'his',
#   'his',
#   'if',
#   'we',
#   'I',
#   'it',
#   'the',
#   'Kevin',
#   'I’ll',
#   'you',
#   'he',
#   'the',
#   'Kerry',
#   'easy',
#   'just',
#   'it',
#   'the',
#   'I’ve',
#   'you’re'],
#  'it': ['sure',
#   'out',
#   'costs.',
#   'cost?',
#   'is',
#   'back',
#   'up',
#   'no',
#   'from',
#   'then.',
#   'on',
#   'out',
#   'out',
#   'is',
#   'will',
#   'down',
#   'all',
#   'was',
#   'was',
#   'home',
#   'is',
#   'and',
#   'off.',
#   'off.',
#   'off!',
#   'all.',
#   'end',
#   'and',
#   '’cause',
#   'didn’t',
#   'up.',
#   'up',
#   'then?',
#   'together,',
#   'isn’t.',
#   'my',
#   'that',
#   'to',
#   'up',
#   'hard',
#   'would',
#   'so',
#   'that',
#   'was',
#   'away.',
#   'for',
#   'and',
#   'again,',
#   'mean',
#   'is.',
#   'again.',
#   'hurt?',
#   'go?',
#   'was',
#   'down,',
#   'was',
#   'happens.',
#   'just',
#   'keeps',
#   'is',
#   'away',
#   'on.',
#   'just',
#   'two.',
#   'says',
#   'was',
#   'to',
#   'hard.',
#   'now.',
#   'doesn’t',
#   'all',
#   'out',
#   'didn’t'],
#  'sounded': ['like'],
#  'like': ['everyone',
#   'it?',
#   'a',
#   'you’re',
#   'that',
#   'that',
#   'they',
#   'to',
#   'my',
#   'to',
#   'this.',
#   'his',
#   'anyone',
#   'that.',
#   'me',
#   'this.',
#   'a',
#   'Ric',
#   'talking',
#   'this.',
#   'this.',
#   'a'],
#  'everyone': ['was', 'watching', 'sees'],
#  'was': ['angry',
#   'talking',
#   'a',
#   'cursed.',
#   'good.',
#   'good.',
#   'orchestra',
#   'great.',
#   'five,',
#   'that',
#   'strange.',
#   'my',
#   'this',
#   'all',
#   'gonna',
#   'nothing',
#   'helping.',
#   'real',
#   'classically',
#   'no',
#   'right.',
#   'for',
#   'taken',
#   'electrified.',
#   'king',
#   'one',
#   'time',
#   'you.',
#   'trickier',
#   'close',
#   'a',
#   'a',
#   'a',
#   'cursed.',
#   'your',
#   'amazing,',
#   'your',
#   'right',
#   'a',
#   'time',
#   'nothing.'],
#  'angry': ['at'],
#  'FRITZ:': ['That’s',
#   'You',
#   'We’ve',
#   'Morning,',
#   'Come',
#   'Hey,',
#   'How',
#   'Hey,',
#   'Howdy.',
#   'Yeah.',
#   'You’re',
#   'You',
#   'That',
#   'We',
#   'There',
#   'You',
#   'Freebirds,',
#   'Boys,',
#   'What',
#   'The',
#   '…the',
#   'Faster!',
#   'Get',
#   'Come',
#   'Hey.',
#   'We’ve',
#   'I',
#   'It’s',
#   'Sleeping.',
#   'Dottie?'],
#  'That’s': ['the',
#   'an',
#   'a',
#   'why',
#   'it.',
#   'right,',
#   'right,',
#   'right,',
#   'for',
#   'great',
#   'for',
#   'how',
#   'why',
#   'the',
#   'good.',
#   'it!',
#   'a',
#   'the',
#   'my',
#   'the',
#   'why',
#   'why',
#   'why',
#   'why',
#   'how',
#   'uh,',
#   'for'],
#  'idea.': ['(SCOFFS)', 'Oh,'],
#  '(SCOFFS)': ['DORIS:'],
#  'What': ['is',
#   'are',
#   'if',
#   'do',
#   'about',
#   'was',
#   'an',
#   'this',
#   'is',
#   'he’s',
#   'a',
#   'happened?',
#   'does',
#   'could',
#   'are',
#   'are',
#   'the',
#   'do',
#   'are',
#   'are',
#   'are'],
#  'is': ['that',
#   'our',
#   'to',
#   'just',
#   'about',
#   'the',
#   'about',
#   'your',
#   'scheduled',
#   'still',
#   'still',
#   'scheduled',
#   'too',
#   'nice',
#   'doing',
#   'really',
#   'the',
#   'the',
#   'me.',
#   'in',
#   'for',
#   'a',
#   'a',
#   'right',
#   'down.',
#   'stunned.',
#   'not',
#   'not',
#   'why',
#   'the',
#   'how',
#   'preserving',
#   'absolutely',
#   'the',
#   'work.',
#   'no.',
#   'it',
#   'pressing.',
#   'the',
#   'your',
#   'it?',
#   'a',
#   'kinda',
#   'it?',
#   'stupid.',
#   'a',
#   'riding',
#   'always',
#   'in',
#   'wait',
#   'this',
#   'not',
#   'not',
#   'no',
#   'here',
#   'nothing',
#   'God',
#   'scheduled',
#   'so',
#   'that',
#   'going',
#   'professional',
#   'the',
#   'still',
#   'wrong',
#   'crucified,',
#   'protesting'],
#  'thing': ['attached', 'that'],
#  'attached': ['to'],
#  'our': ['home?',
#   'car?',
#   'father.',
#   'times',
#   'roster,',
#   'show',
#   'own',
#   'own',
#   'time.',
#   'building',
#   'fans…',
#   'voices',
#   'father',
#   'response',
#   'family.',
#   'son,',
#   'promotion.'],
#  'home?': ['FRITZ:', 'You'],
#  'it?': ['KEVIN:', 'Michael,', 'Of', 'Shit,', 'David.'],
#  'KEVIN:': ['Oh,',
#   'Let’s',
#   'Yeah.',
#   'All',
#   'Ever',
#   'Thanks,',
#   'Yes,',
#   'Good.',
#   'Thank',
#   'How',
#   'We',
#   'Yeah.',
#   'That’s',
#   'David,',
#   'Yeah,',
#   'Yeah,',
#   'Emily.',
#   'Thank',
#   'Yeah,',
#   'All',
#   'Oh,',
#   'There',
#   'Harley',
#   'Hey.',
#   'Thanks,',
#   'Yeah?',
#   'Cheers!',
#   'I',
#   'Oh,',
#   'Hey,',
#   'Hey,',
#   'What?',
#   'Why',
#   '(SCREAMING)',
#   'Ever',
#   '…the',
#   '…the',
#   'I',
#   'We',
#   'Hey.',
#   'I',
#   'Yeah,',
#   'Tania.',
#   'Kerry?',
#   'Hey.'],
#  'Oh,': ['Dad.',
#   'and',
#   'don’t',
#   'yeah.',
#   'we’ll',
#   'damn',
#   'my',
#   'it’s',
#   'I’m',
#   'it’s',
#   'and',
#   'and',
#   'I',
#   'and',
#   'no.',
#   'and',
#   'oh,',
#   'yeah.',
#   'Mikey.',
#   'my',
#   'yeah.',
#   'my',
#   'yeah.',
#   'Kevin,',
#   'no.',
#   'man,',
#   'honey,',
#   'no,',
#   'man.',
#   'I’m…',
#   'hello,',
#   'handsman.',
#   'come',
#   'I',
#   'soon.',
#   'I’m',
#   'hey.',
#   'I’m',
#   'I’m',
#   'finally.',
#   'he',
#   'well.',
#   'I',
#   'don’t',
#   'don’t'],
#  'Dad.': ['It’s',
#   'KERRY:',
#   'I',
#   'So,',
#   'I’m',
#   'Dad,',
#   'You',
#   'Yeah,',
#   'We’ll'],
#  'incredible.': ['DAVID:', 'DORIS:'],
#  'DAVID:': ['Yeah,',
#   'No,',
#   'How',
#   'Shoobadoobadoo.',
#   'All',
#   'What?',
#   'Wow.',
#   'Aww.',
#   'Whoo!',
#   'Yeah.',
#   'No,',
#   'Kev,',
#   'Brother.',
#   'There'],
#  'Yeah,': ['it’s',
#   'that',
#   'absolutely.',
#   'I',
#   'I',
#   'yes.',
#   'thanks',
#   'sure.',
#   'I’m',
#   'I',
#   'have',
#   'you',
#   'I',
#   'I’m',
#   'we',
#   'Kerry',
#   'come',
#   'we',
#   'city',
#   'just',
#   'I',
#   'be',
#   'I',
#   'soon.',
#   'all',
#   'I',
#   'yeah,',
#   'okay.',
#   'I',
#   'you',
#   'okay.',
#   'yeah,',
#   'Dad.'],
#  'it’s': ['incredible.',
#   'so',
#   'good',
#   'all',
#   'uh…',
#   'a',
#   'tonight',
#   'just',
#   'gonna',
#   'finally',
#   'got',
#   'still',
#   'rare,',
#   'just…',
#   'too',
#   'for',
#   'so',
#   'because',
#   'slippin’,',
#   'slippin’',
#   'slippin’'],
#  'Jack,': ['where'],
#  'where': ['is', 'you'],
#  'car?': ['I'],
#  'had': ['the', 'no', 'all', 'a', 'a', 'everything', 'my'],
#  'boys': ['swap', 'would', 'in', 'see', 'need'],
#  'swap': ['it'],
#  'during': ['the', 'the'],
#  'show.': ['Surprise!', '(CROWD', 'You’ll', 'Two'],
#  'Surprise!': ['DORIS:'],
#  'Wait.': ['What'],
#  'are': ['you',
#   'in',
#   'for.',
#   'you?',
#   'you?',
#   'you?',
#   'really',
#   '♪',
#   'here!',
#   'gonna',
#   'and',
#   'the',
#   'broadcasting',
#   'on',
#   'the',
#   'the',
#   'doing',
#   'the',
#   'and',
#   'finally',
#   'all',
#   'the',
#   'you',
#   'here',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you?',
#   'you',
#   'you',
#   'you',
#   'marked'],
#  'thinking?': ['We'],
#  'We': ['can’t',
#   'need',
#   'never',
#   'all',
#   'loved',
#   'leave',
#   'got',
#   'have',
#   'have',
#   'have',
#   'can',
#   'go',
#   'could',
#   'can',
#   'are',
#   'just',
#   'could…',
#   'get',
#   'are',
#   'could',
#   'have',
#   'still',
#   'repaired',
#   'worked',
#   'believe',
#   'can’t',
#   'all',
#   'have',
#   'need',
#   'need',
#   'can',
#   'need',
#   'wait',
#   'need',
#   'want',
#   'cry'],
#  'can’t': ['afford',
#   'take',
#   'say',
#   'be',
#   'hack',
#   'find',
#   'believe',
#   'get',
#   'replace',
#   'rush',
#   'do',
#   'put',
#   'be',
#   'fit',
#   'take',
#   'let',
#   'be'],
#  'afford': ['this.'],
#  'this.': ['Well,', 'RING', 'Here', 'It’s', '(SIGHS)', 'A'],
#  'Well,': ['hear',
#   'may',
#   'like,',
#   'hopefully,',
#   'it’s',
#   'can',
#   'I',
#   'I',
#   'this',
#   'he’s',
#   'you',
#   'you',
#   'Fritz,',
#   'life',
#   'a',
#   'I',
#   'I',
#   'I',
#   'son,',
#   'I',
#   'it’s',
#   'you',
#   'you’ve',
#   'it',
#   'I’ve',
#   'then',
#   'glad',
#   'I'],
#  'hear': ['me', 'you.', 'these', 'it,', 'you.'],
#  'out.': ['I', 'And', 'The', '(CROWD', '(INDISTINCT'],
#  'talking': ['to', 'loud', 'about', 'right', 'to', 'about?'],
#  'promoter,': ['and'],
#  'said': ['if', 'my', 'if', 'no', 'my', 'if'],
#  'if': ['I',
#   'my',
#   'we',
#   'I',
#   'we',
#   'you',
#   'you',
#   'you',
#   'we',
#   'you’ve',
#   'you',
#   'one',
#   'I',
#   'we',
#   'you’re',
#   'you',
#   'you'],
#  'be': ['a',
#   'fine,',
#   'the',
#   'the',
#   'around.',
#   'able',
#   'the',
#   'late.',
#   'all',
#   'like',
#   'able',
#   'coming',
#   'sellin’',
#   'the',
#   'World',
#   'with',
#   'with',
#   'a',
#   'okay',
#   'one',
#   'a',
#   'the',
#   'it.',
#   'disqualified.',
#   'heard',
#   'a',
#   'World',
#   'the',
#   'the',
#   'you,',
#   'World',
#   'ours.',
#   'happening',
#   'your',
#   'good.',
#   'pretty',
#   'an',
#   'an',
#   'home',
#   'measured',
#   'careful.',
#   'Adkisson.',
#   'right',
#   'back,',
#   'back',
#   'scared',
#   'David,',
#   'patient',
#   'with',
#   'serious.',
#   'humble',
#   'ashamed',
#   'and',
#   'down',
#   'excused?',
#   'rude.',
#   'home.',
#   'there',
#   'here',
#   'my',
#   'a',
#   'your',
#   'your',
#   'replaced',
#   'published.',
#   'resurrected'],
#  'star,': ['I'],
#  'need': ['to',
#   'a',
#   'to',
#   'to',
#   'you',
#   'to',
#   'to',
#   'a…',
#   'to',
#   'a',
#   'to',
#   'to',
#   'a',
#   'the',
#   'someone.',
#   'a',
#   'to',
#   'to'],
#  'act': ['like'],
#  'star.': ['So,'],
#  'So,': ['he',
#   'what',
#   'would',
#   'I’m',
#   'when',
#   'you',
#   'what',
#   'Kerry,',
#   'put',
#   'put',
#   'you’re',
#   'just',
#   'what',
#   'we'],
#  'told': ['me', 'you'],
#  'rent': ['a'],
#  'Cadillac.': ['DORIS:'],
#  'I’m': ['not',
#   'almost',
#   'not',
#   'starving.',
#   'here',
#   'your',
#   'gonna',
#   'a',
#   'gonna',
#   'sorry.',
#   'not',
#   'so',
#   'not',
#   'so',
#   'just',
#   'sorry,',
#   'sorry',
#   'working',
#   'a',
#   'hanging',
#   'not',
#   'gonna',
#   'sick',
#   'real',
#   'sure',
#   'beggin’',
#   'beggin’,',
#   'begging’',
#   'fine.',
#   'almost',
#   'fine,',
#   'just',
#   'gonna',
#   'happy',
#   'good.',
#   'a',
#   'a',
#   'a',
#   'a',
#   'good.',
#   'ready,',
#   'about',
#   'having',
#   'gonna',
#   'sorry',
#   'very',
#   'late',
#   'sorry.',
#   'moved',
#   'thankful',
#   'scared,',
#   'not',
#   'ready.',
#   'ready.',
#   'sorry',
#   'going',
#   'not',
#   'trying',
#   'sorry.',
#   'sorry.',
#   'custom-made',
#   'out',
#   'good.',
#   'just',
#   'almost',
#   'here',
#   'so',
#   'up.',
#   'in',
#   'scared,',
#   'scared.',
#   'out',
#   'in',
#   'in',
#   'fucking',
#   'fucking',
#   'heading',
#   'worried',
#   'gonna',
#   'not',
#   'sorry.',
#   'sorry,',
#   'sorry,',
#   'not',
#   'tougher',
#   'not',
#   'gonna',
#   'gonna'],
#  'not': ['even',
#   'doing',
#   'be',
#   'a',
#   'helping.',
#   'teach',
#   'everywhere.',
#   'such',
#   'the',
#   'the',
#   'moving,',
#   'moving.',
#   'want',
#   'destroying',
#   'add',
#   'going',
#   'go.',
#   'go.',
#   'sure',
#   'camera',
#   'ready',
#   'fine.',
#   'your',
#   'your',
#   'David.',
#   'sure.',
#   'giving',
#   'hungry.',
#   'a',
#   'ready',
#   'be'],
#  'even': ['gonna', 'really', 'been', 'realize,'],
#  'ask': ['how', 'me', 'questions?', 'you'],
#  'how': ['much',
#   'are',
#   'you',
#   'you',
#   'to',
#   'the',
#   'they',
#   'they',
#   'you',
#   'lovely',
#   'much',
#   'much',
#   'painful',
#   'was',
#   'you',
#   'to'],
#  'much': ['it',
#   'does',
#   'anymore,',
#   'already?',
#   'an',
#   'of',
#   'to',
#   'pain',
#   'to'],
#  'costs.': ['(SIGHING)'],
#  '(SIGHING)': ['How', '(MOTORCYCLE', 'Oh.'],
#  'How': ['much',
#   'does',
#   'you',
#   'are',
#   'you',
#   'are',
#   'was',
#   'about',
#   'does',
#   'you',
#   'you',
#   'was',
#   'do',
#   'are',
#   'about'],
#  'does': ['it', 'blowing', 'that', 'it', 'that', 'it'],
#  'cost?': ['It’s'],
#  'fine,': ['Dottie.', 'Pop.', 'Kev.', 'Mike.'],
#  'Dottie.': ['I’m', 'Well,'],
#  'almost': ['there.', 'there.', 'two', 'lost', 'broke.', '40'],
#  'there.': ['We',
#   'I',
#   'You',
#   'Why',
#   'COACH:',
#   'You',
#   'You',
#   '(COUNTRY',
#   'Switch',
#   'We'],
# ...
#  'PLAYING': ['ON', 'IN'],
#  'ON': ['CAR', 'TV)', 'AMPLIFIER)', 'TV)', 'TV)'],
#  'CAR': ['RADIO)'],
#  'RADIO)': ['♪'],
#  '♪': ['Love',
#   'I',
#   'And',
#   'Listen,',
#   'Baby,',
#   'If',
#   'Givin’',
#   'And',
#   'Or',
#   'Someone’s',
#   'Cut',
#   'Don’t',
#   'What',
#   'Don’t,',
#   'All',
#   'Here',
#   'Seasons',
#   'Nor',
#   'We',
#   'Come',
#   'Baby,',
#   'We’ll',
#   'Baby,',
#   '(VOCALIZING)',
#   'Come',
#   'I’m',
#   'I',
#   'I',
#   'I',
#   'I',
#   'So',
#   'I’m',
#   'Mama',
#   'I’m',
#   'A',
#   'I',
#   'I',
#   'I',
#   'CROWD:',
#   'Wanna',
#   'Wanna',
#   '(CHEERING',
#   'Put',
#   'I’m',
#   'Beggin’',
#   'So,',
#   'I’m',
#   'So,',
#   'Riding',
#   'I',
#   'I',
#   'But',
#   'I’m',
#   'Won’t',
#   'Beggin’',
#   'Put',
#   'I',
#   'Tried',
#   'The',
#   '(DOOR',
#   'Well,',
#   'Ain’t',
#   'It’s',
#   'Thank',
#   'Well,',
#   'A',
#   'My',
#   'Thank',
#   'Well,',
#   'Look',
#   'Well,',
#   'I',
#   'I’d',
#   'Thank',
#   'Yeah,',
#   'A',
#   'Well,',
#   'I',
#   'Well,',
#   'When',
#   'Pop?',
#   'I’ve',
#   'Revved',
#   'Got',
#   'I',
#   'I',
#   'I',
#   'Revved',
#   'Come',
#   'Hanging',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'It’s',
#   'But',
#   'And',
#   'Hold',
#   'I’m',
#   'I’m',
#   'Roman',
#   'I',
#   'I',
#   'I',
#   'I',
#   'Want',
#   'I',
#   'Don’t',
#   'But',
#   'I',
#   'Oh,',
#   'Oh,',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'Your'],
#  'Love': ['doesn’t'],
#  'doesn’t': ['last',
#   'budge.',
#   'do',
#   'wanna',
#   'wanna',
#   'mean',
#   'make',
#   'mean',
#   'work',
#   'add',
#   'show',
#   'cry.'],
#  'last': ['that', 'name', 'name.', 'minute.', 'name', 'two'],
#  'long': ['♪', 'about', 'getting'],
#  'feelin’': ['inside'],
#  'inside': ['night'],
#  'night': ['and', 'of'],
#  'day': ['♪', 'will', 'of', 'flight'],
#  'now': ['I', 'they’re', 'don’t', 'exactly', 'is', 'on.', 'I’m'],
#  'more': ['♪', 'exposure.', 'lemonade', 'of', 'than', 'pieces', 'piece'],
#  'Listen,': ['honey,'],
#  'honey,': ['can', 'I’m', 'we'],
#  'see?': ['♪'],
#  'bury': ['me'],
#  'If': ['you', 'it’s', 'he', 'you', 'you', 'you’re', 'you'],
#  'public': ['eye'],
#  'Givin’': ['someone'],
#  'someone': ['else', 'else'],
#  'else': ['a', 'will', 'will', 'with'],
#  'try': ['♪', 'again?'],
#  'better': ['watch', 'place.'],
#  'watch': ['your'],
#  'step': ['♪', 'up.', 'up'],
#  'yourself': ['♪'],
#  'Someone’s': ['gonna'],
#  'tell': ['you',
#   'everyone,',
#   'anyone.',
#   'ya',
#   'anyone?',
#   'you',
#   'you',
#   'me.',
#   'me'],
#  'lies': ['♪'],
#  'Cut': ['you'],
#  'down': ['to',
#   'Brody.',
#   'for',
#   'the',
#   'on',
#   'in',
#   'to',
#   'when',
#   'to',
#   'here',
#   'at',
#   'again',
#   'and'],
#  'size': ['(CHEERING)'],
#  '(CHEERING)': ['♪', '♪'],
#  'Don’t': ['do',
#   'do',
#   'fear',
#   'fear',
#   'look',
#   'worry',
#   'tell',
#   'cross',
#   'you',
#   'do',
#   'wanna'],
#  'do': ['me',
#   'me',
#   'that',
#   'it',
#   'the',
#   'you',
#   'well.',
#   'you',
#   'with',
#   'anything.',
#   'it.',
#   'some',
#   'enough',
#   'you',
#   'you',
#   'with',
#   'it.',
#   'it,',
#   'it,',
#   'it.',
#   'that?',
#   'with',
#   'it',
#   'now',
#   'something',
#   'this',
#   'it.',
#   'you',
#   'you',
#   'that.',
#   'that.',
#   'some'],
#  'love': ['you,',
#   'to,',
#   'to',
#   'your',
#   'that.',
#   'you,',
#   'you',
#   'being',
#   'and',
#   'you.',
#   'you.',
#   'you.',
#   'you,',
#   'for',
#   'for'],
#  'baby?': ['Hi,'],
#  'Kevin!': ['♪',
#   'Kevin!',
#   'Kevin!',
#   'REFEREE:',
#   'Kevin!',
#   'Kevin!',
#   'REFEREE:',
#   'Come'],
#  'Don’t,': ['don’t,'],
#  'don’t,': ['don’t…'],
#  'don’t…': ['Welcome'],
#  'Welcome': ['back,', 'back,', 'back,', 'to', 'home,', 'to', 'home,'],
#  'ladies': ['and', 'and', 'and', 'and'],
#  'gentlemen.': ['We', 'We', 'We'],
#  'newlycrowned': ['Texas'],
#  'here,': ['and', 'tonight.', 'man.', 'Dottie.', 'can’t'],
#  'scheduled': ['to', 'to', 'to', 'for'],
#  'fight': ['in', 'in', 'in', 'him', 'the', 'you', 'Harley,', 'back.', 'with'],
#  'tagteam': ['match'],
#  'match': ['later', 'against', 'later', 'will', 'against', 'like', 'is', 'on'],
#  'later': ['on', 'on'],
#  'tonight': ['against', 'against', 'we', 'at', 'you'],
#  'against': ['Gino', 'Gino', 'Gino', 'Ric', 'Kevin'],
#  'Gino': ['Hernandez', 'Hernandez', 'Hernandez', 'in,', 'taps'],
#  'Hernandez': ['and', 'and', 'and'],
#  'Bruiser': ['Brody.', 'Brody.', 'Brody.'],
#  'Brody.': ['But', 'But', 'But', 'The'],
#  'partner': ['is', 'is', 'still', 'Hellwig’s'],
#  'mystery.': ['That’s', 'KEVIN:', 'That’s'],
#  'Bill.': ['First', 'First', 'I'],
#  'First': ['off,', 'off,'],
#  'off,': ['I', 'I', 'I'],
#  'Gino,': ['you’ve', 'you’ve', 'you’ve', 'but'],
#  'you’ve': ['been',
#   'been',
#   'been',
#   'been',
#   'arrived',
#   'done',
#   'made',
#   'been',
#   'got'],
#  'running': ['that'],
#  'mouth': ['of', 'off'],
#  'yours': ['way,'],
#  'way,': ['way', 'way'],
#  'long,': ['and'],
#  'care': ['of', 'of', 'of', 'of', 'of'],
#  '(CHUCKLES': ['SOFTLY)',
#   'SOFTLY)',
#   'SOFTLY)',
#   'SOFTLY)',
#   'SOFTLY)',
#   'SOFTLY)'],
#  'Boy,': ['oh,'],
#  'oh,': ['boy.', 'boy.', 'here'],
#  'boy.': ['Do', 'It', 'Kind,'],
#  'somethin’': ['special'],
#  'special': ['for', 'for', 'for…', 'moment'],
#  'tonight,': ['buddy.', 'and'],
#  'buddy.': ['Can'],
#  'again': ['from', 'pretty', 'off', 'to', 'this'],
#  'from': ['that',
#   'the',
#   'Gino…',
#   'over',
#   'Race',
#   'UT.',
#   'the',
#   'school',
#   'you',
#   'me.',
#   'us,',
#   'Bad',
#   'Denton,',
#   'Flair,',
#   'head',
#   'me.',
#   'Jerry',
#   'now',
#   'you.',
#   'the'],
#  'top,': ['yeah?', 'okay?', 'so', 'you'],
#  'yeah?': ['BILL:'],
#  'BILL:': ['Yeah,',
#   'Take',
#   'It’s',
#   'Welcome',
#   'David.',
#   'Wanna',
#   'And',
#   'David',
#   'And',
#   'Can',
#   'And',
#   'The',
#   'Morning.',
#   'David’s',
#   'Okay.',
#   'And',
#   'And',
#   'Kevin',
#   'Oh,',
#   'Oh,',
#   'Kevin',
#   'He’s',
#   'He’s',
#   'Kick',
#   'One,',
#   'And',
#   'Yes,',
#   'Oh,',
#   'It’s',
#   'What',
#   'So…',
#   'Congratulations,',
#   'Texas',
#   '35,000',
#   'So,',
#   'That'],
#  'absolutely.': ['Thank'],
#  'Take': ['it', 'those'],
#  'okay?': ['Okay.',
#   '(ALL',
#   'KEVIN:',
#   'Yeah.',
#   '(SHUSHING)',
#   'Yeah.',
#   'Kerry?',
#   'You'],
#  'Okay.': ['(KEVIN',
#   '(ROCK',
#   'Cross',
#   '(INDISTINCT',
#   'All',
#   'You',
#   '(DOOR',
#   '(BOTH',
#   '(STATIC',
#   'All',
#   'Okay.',
#   '(PANTING)'],
#  '(KEVIN': ['EXHALES)',
#   'EXHALES)',
#   'MOANING)',
#   'GRUNTS)',
#   'BREATHING',
#   'CLEARS',
#   'GRUNTS)',
#   'GROANS)',
#   'SIGHS)',
#   'SNIFFLES)',
#   'SNIFFLES)'],
#  'EXHALES)': ['(BOTH', 'BILL:'],
#  '(BOTH': ['CLEAR',
#   'MOANING)',
#   'KISSING,',
#   'PANTING)',
#   'MOANING)',
#   'LAUGH)',
#   'LAUGH)',
#   'GRUNTING)',
#   'GRUNTING)',
#   'GRUNTING)',
#   'CHUCKLE)'],
#  'CLEAR': ['THROAT)'],
#  'THROAT)': ['Ready?', 'PAM:', 'Your', 'Wasn’t', 'DAVID:', '(BABY'],
#  'Ready?': ['KEVIN:', 'You'],
#  'CAMERA': ['CREW:'],
#  'CREW:': ['Ready.'],
#  'Ready.': ['Welcome'],
#  'newly-crowned': ['Texas'],
#  'he’s': ['scheduled', 'self-sacrificed.', 'doing.', 'up', 'going', 'gonna'],
#  'tag-team': ['match', 'match'],
#  'that,': ['Gino,', 'uh,'],
#  'shooting': ['your', 'your', 'your…', 'your'],
#  'off': ['way,',
#   'of',
#   'the',
#   'the',
#   'the',
#   'guard.',
#   'steam.',
#   'the',
#   'of',
#   'the'],
#  'family.': ['I', 'You', 'The', '(CROWD', 'RING', '(EXHALES)', 'Just'],
#  'something': ['special', 'special', 'else', 'for'],
#  'boy,': ['oh,', 'Kerry.'],
#  'ain’t': ['gonna', 'it', 'got'],
#  'roses…': ['Fuck.'],
#  'Fuck.': ['(SNICKERING)'],
#  '(SNICKERING)': ['BILL:'],
#  'okay.': ['We’ll', 'It’s', 'Thank', 'Now,', '(PHONE', 'I’m', 'Careful,'],
#  'We’ll': ['go', 'be', 'see.', 'get', 'be', 'be'],
#  'Stop.': ['I', 'Hey,'],
#  'didn’t': ['say',
#   'you',
#   'work',
#   'take',
#   'even',
#   'know',
#   'you',
#   'give',
#   'make',
#   'you',
#   'take',
#   'take',
#   'help',
#   'work.',
#   'make'],
#  'anything.': ['(KEVIN', '(INHALES', 'I’m'],
#  'newly': ['crowned'],
#  'crowned': ['Texas'],
#  'remains': ['a'],
#  'for…': ['that'],
#  'hometown': ['crowd'],
#  'crowd': ['fans', 'responds', 'is', 'was'],
#  'fans': ['are', 'up', 'in', 'did'],
#  'really': ['gonna', 'sell', 'just', 'think', 'want', 'hard'],
#  'love…': ['tonight.'],
#  'tonight.': ['You', 'But', 'And'],
#  'say,': ['Gino,', '“Nice', 'I'],
#  'mouth…': ['shooting', 'DAVID:'],
#  'your…': ['shoot…'],
#  'shoot…': ['shooting'],
#  'Shoobadoobadoo.': ['Shit,'],
#  'Shit,': ['sorry.', 'brother.'],
#  'sorry.': ['(DAVID',
#   'Uh,',
#   'I',
#   'It’s',
#   'KEVIN:',
#   '(BABY',
#   'Just…',
#   'Come',
#   'I…'],
#  '(DAVID': ['SINGING)', 'GROANS)'],
#  'SINGING)': ['BILL:'],
#  'easy,': ['you'],
#  'then.': ['Yeah,', '(CLEARS', 'Kev.'],
#  'mean': ['I…', 'me', '♪', 'anything,', 'something.', 'that.'],
#  'I…': ['I’d', 'I', 'well,', 'I’m', 'I', 'I', 'I', 'I', 'I’m'],
#  'I’d': ['love', 'love', 'rather', 'be', 'love'],
#  'to,': ['but', 'uh,'],
#  'it’ll': ['kind'],
#  'kind': ['of', 'of'],
#  'ruin': ['the'],
#  'surprise,': ['you'],
#  'know?': ['KEVIN:'],
#  'know.': ['You’re',
#   'Just',
#   'It',
#   'He',
#   'Don’t',
#   'I’m',
#   'So,',
#   'I',
#   '(DOOR',
#   'I’ll',
#   'Who’s'],
#  'helping.': ['DAVID:', '(EXHALES)'],
#  'Just': ['get',
#   'being',
#   'at',
#   'keep',
#   'don’t',
#   'be',
#   'settle',
#   'come',
#   'look',
#   'so'],
#  'here.': ['BILL:',
#   'Come',
#   'You',
#   '(CROWD',
#   'He',
#   'Someone',
#   'Yeah,',
#   'Where',
#   'I',
#   '(CROWD',
#   'Hey,',
#   'Stay',
#   '(SIGHS',
#   'What'],
#  'Wanna': ['try', 'live', 'live'],
#  'again?': ['KEVIN:'],
#  'yes.': ['Okay.'],
#  'times': ['have'],
#  'Here': ['but', 'comes', 'on', 'you'],
#  'gone': ['♪'],
#  'Seasons': ['don’t'],
#  'fear': ['the', 'the', 'the', 'the'],
#  'reaper': ['♪', '♪', '♪', '♪'],
#  'Nor': ['do'],
#  'wind,': ['the'],
#  'sun': ['or'],
#  'rain': ['♪'],
#  'they': ['are',
#   'always',
#   'are',
#   'lock',
#   'test',
#   'can',
#   'have',
#   'drag',
#   'want',
#   'thought',
#   'take',
#   'got',
#   'drag',
#   'overcome'],
#  'baby,': ['don’t', 'stay', 'you'],
#  'hand': ['Don’t', 'out,', 'out,', 'out,', 'out,', 'out,'],
#  'fly': ['Don’t'],
#  'man…': ['♪', '♪'],
#  '(VOCALIZING)': ['I’ll'],
#  'give': ['you', 'your', 'you', 'you', 'it', 'you'],
#  'big': ['boot,', 'fans', 'brother,', 'blow', 'shot', 'splash.', 'one.'],
#  'boot,': ['so'],
#  'sell': ['it.', 'it.'],
#  'tag': ['Gino', 'team', 'team', 'team'],
#  'in,': ['fight', 'son.', 'then'],
#  'back.': ['Give', 'Highest', 'He’s', 'And', 'Mmmhmm.'],
#  'body': ['slam,', 'knocks'],
#  'slam,': ['an'],
#  'elbow': ['drop.'],
#  'drop.': ['He’s'],
#  'He’s': ['gonna',
#   'lining',
#   'starting',
#   'starting',
#   'seen',
#   'Well,',
#   'worked',
#   'back',
#   'got',
#   'letting',
#   'gonna',
#   'got',
#   'in'],
#  'drive': ['you'],
#  'corner,': ['stay'],
#  'there': ['’cause',
#   'too',
#   'to',
#   'was',
#   'in',
#   'a',
#   'with',
#   'sent',
#   'since',
#   'as'],
#  '’cause': ['I’m', 'ain’t', 'he', 'I'],
#  'post.': ['And'],
#  'straight': ['up', 'into'],
#  'long.': ['BRUISER:', 'Yeah.'],
#  'BRUISER:': ['Hmm.', 'Yeah.'],
#  'Hmm.': ['Okay.', 'Well,', 'What', 'It’s', 'You'],
#  'Cross': ['body.'],
#  'body.': ['GINO:', 'Terry'],
#  'GINO:': ['I’ll', 'Right,'],
#  'sellin’': ['I’ll'],
#  'heat': ['up.', 'lately.'],
#  'up.': ['And',
#   'Shaking',
#   'REFEREE:',
#   'REFEREE:',
#   'Kevin',
#   'Yeah.',
#   'Yeah,',
#   'But',
#   '(SOFTLY)',
#   '(GRUNT)',
#   'You',
#   'That’s',
#   'Leave',
#   'I',
#   'Where'],
#  'double': ['dropkick?', 'drop', 'drop'],
#  'dropkick?': ['BRUISER:'],
#  'Then': ['the', 'you’ll', 'you’ll', 'get'],
#  'Claw?': ['GINO:'],
#  'Right,': ['yeah.'],
#  'dad?': ['A'],
#  'little,': ['yeah.'],
#  'fuck': ['with', 'happened,', 'not?'],
#  'hair': ['too'],
#  'much,': ['okay?'],
#  '(ALL': ['LAUGHING)', 'PANTING)', 'CHEERING)', 'CHEERING)', 'CHEERING)'],
#  'LAUGHING)': ['All'],
#  'kick': ['out'],
#  'Gino…': ['Let’s'],
#  'picks': ['up'],
#  'comes': ['Brody', 'all', 'the', 'off', 'David', 'in.', 'David', 'Kevin.'],
#  'Brody': ['charging', 'dazed'],
#  'charging': ['across'],
#  'across': ['the'],
#  'ring.': ['He', 'CROWD:', 'Caught', 'Yes,', 'He', 'PAM:', 'I', 'KERRY:'],
#  'misses': ['him.', 'him.'],
#  'side.': ['Kevin'],
#  'top': ['rope.', 'in', 'rope.', 'rope.'],
#  'rope.': ['Brody', 'My', 'Kerry'],
#  'dazed': ['now.'],
#  'Breaking': ['Holds,', 'Hearts:'],
#  'Holds,': ['Breaking'],
#  'Hearts:': ['The'],
#  'Saga': ['Wrestles'],
#  'Wrestles': ['with'],
#  'Fate': ['in'],
#  '‘The': ['Iron'],
#  'Claw’': ['Epic'],
#  'Epic': ['BILL:'],
#  'huge': ['flying'],
#  'flying': ['cross', 'clothesline.'],
#  'cross': ['body', 'body.', 'your'],
#  'knocks': ['down', 'the', 'him', 'down', 'it'],
#  'line': ['up', 'is…', 'is,'],
#  'drop': ['kick.', 'kick.'],
#  'kick.': ['An', 'Blowing'],
#  'An': ['incredible'],
#  'incredible': ['double', 'out'],
#  'Blowing': ['the'],
#  'roof': ['off'],
#  'place!': ['(CROWD'],
#  'people?': ['(CROWD'],
#  'Claw,': ['his'],
#  'father’s': ['notorious'],
#  'notorious': ['signature'],
#  'signature': ['move.'],
#  'move.': ['Oh,', 'This', 'It’s'],
#  'slaps': ['it'],
#  'Gino.': ['Look'],
#  'Look': ['at', 'out,', 'at', 'at', 'at', 'how', 'at'],
#  'pain': ['is', 'you’re', 'all', '♪'],
#  'taps': ['out,'],
#  'Erichs': ['win.', 'win!', 'are'],
#  'win.': ['Look'],
#  'NWA.': ['David', 'WCCW'],
#  'here!': ['RING', 'Get', 'I'],
#  'Erich!': ['No', 'FRITZ:', '(ENTRANCE', '(CROWD'],
#  'No': ['problem.', 'way.', 'one', 'boys', 'hiding.'],
#  'problem.': ['GIRL:'],
#  'GIRL:': ['Excuse', 'Thank'],
#  'Excuse': ['me.', 'me.'],
#  'me.': ['Can',
#   'Well,',
#   'The',
#   'FRITZ:',
#   'The',
#   'Look',
#   'Okay?',
#   'People',
#   '(BABY',
#   'RIC',
#   'Listen',
#   'I’ll',
#   'ROSS:',
#   'When',
#   '(SMACKS'],
#  'Emily?': ['KEVIN:'],
#  'Emily.': ['That’s'],
#  'thank': ['you.', 'you.', 'God', 'you'],
#  'coming,': ['guys.', 'Mike?', 'and'],
#  'GIRL': ['1:', '2:'],
#  '1:': ['Thank', 'Hey,', 'So'],
#  '2:': ['Thank'],
#  'thanks': ['for'],
#  'coming.': ['Come'],
#  'next': ['week,', 'NWA', 'six', 'week.', 'time.'],
#  'week,': ['all'],
#  'right?': ['PAM:',
#   'PAM:',
#   '(CROWD',
#   'Yep.',
#   'DAVID:',
#   'Twist',
#   'They',
#   'Just',
#   'No.'],
#  'PAM:': ['I’m',
#   'Hi,',
#   'Thanks.',
#   'Oh,',
#   'Mmmhmm.',
#   'Mmmhmm.',
#   'I’m',
#   'Yeah,',
#   'Oh,',
#   'This',
#   'Ow.',
#   'Yeah.',
#   'Whoo!',
#   'Come',
#   'It',
#   'This',
#   'No.',
#   'Hey.',
#   'Hang',
#   'Make',
#   'Yeah.',
#   'Whoa,'],
#  '(CHUCKLES)': ['Okay,',
#   'It’s',
#   'David’s',
#   'So,',
#   'Big',
#   'You',
#   'DAVID:',
#   'So,',
#   'Maybe.',
#   'Oh,',
#   'How',
#   'Yeah.',
#   'You',
#   'I'],
#  'Okay,': ['bye.', 'then.', 'come', 'baby,', 'just', 'Kevin,'],
#  'Bye,': ['bye.'],
#  'um…': ['Can', 'I', 'That’s'],
#  'autograph?': ['Yeah,'],
#  'sure.': ['PAM:', 'You', 'That’s', '(BOTH', 'Um,'],
#  'Thanks.': ['(CLEARS', 'Yeah,', 'Are', 'That’s', 'All', 'Thanks,'],
#  '(CLEARS': ['THROAT)', 'THROAT)', 'THROAT)', 'THROAT)'],
#  'who': ['to', 'you', 'is', 'looks', 'believe', 'believe', 'runs', 'is'],
#  'to?': ['KEVIN:'],
#  'Sure.': ['It’s', 'No.'],
#  'Pam.': ['Pam.', 'PAM:', '(CHUCKLES)', '(CLEARS', 'Hmm?', 'Where’s'],
#  'Mmmhmm.': ['You’re', 'So', 'Thanks.', 'How'],
#  'supposed': ['to', 'to'],
#  '“Nice': ['to'],
#  'meet': ['you,', 'you,', 'you', 'you.', 'you.', 'me', 'you.'],
#  'Pam.”': ['Yeah,'],
#  'Uh,': ['it', 'we’ll', 'yeah.', 'not', 'and,'],
#  'too,': ['Kevin.', 'son.', 'son.'],
#  'uh,': ['want', 'my', 'soon.', 'truly', 'I’m', 'that’s', 'to'],
#  'sign?': ['No,'],
#  'Your': ['folks', 'first', 'brother', 'mom', 'email'],
#  'folks': ['not'],
#  'teach': ['you'],
#  'questions?': ['Like'],
#  'Like': ['what?', 'we’re', 'that?'],
#  'what?': ['Well,', 'I', 'Why'],
#  'like,': ['you'],
#  '“Who': ['shall'],
#  'shall': ['I'],
#  'to?”': ['Or,'],
#  'Or,': ['um,'],
#  'um,': ['or…', 'well,', 'I’m'],
#  'or…': ['(BLOWS'],
#  '(BLOWS': ['RASPBERRY)'],
#  'RASPBERRY)': ['“Would'],
#  '“Would': ['you'],
#  'drink': ['with'],
#  'sometime,': ['Pam?”'],
#  'Pam?”': ['Are'],
#  'Are': ['you', 'you', 'you', 'you', 'you', 'these'],
#  'asking': ['me'],
#  'out?': ['Make'],
#  'Make': ['me', 'sure', 'it'],
#  'feel': ['a', 'the', 'that?', 'that?', 'it.', 'safer', 'it’s', 'it’s'],
#  'worse': ['while'],
#  'while': ['you’re', 'they', 'I’m'],
#  'no,': ['no.', 'I,', 'no.', 'no,', 'no,', 'no,', 'no!', 'no,', 'no.'],
#  'I,': ['uh…', 'uh…', 'we’re'],
#  'uh…': ['I', 'He', 'the', 'it’s', 'I', 'PAM:', 'I', 'after', 'that', 'and'],
#  'Wasn’t': ['that…'],
#  'that…': ['Yeah,'],
#  'just…': ['I’ve', 'Honey,', 'I’ll', 'it’s'],
#  'asked': ['before.', 'me'],
#  'before.': ['Oh.', 'You'],
#  'Oh.': ['Well,', 'That’s', 'Oh,', 'I’m', 'No.', '(SLURPS,', 'ROSS:', 'Thank'],
#  'hopefully,': ['it'],
#  'well': ['and', 'it’s'],
#  'chance': ['to', 'I', 'to'],
#  'David’s': ['good.', 'good.', 'title'],
#  '(BILL': ['CHUCKLES)', 'CHUCKLES'],
#  'CHUCKLES)': ['Got', 'We', 'We', 'Dad’s', '(SOFTLY)'],
#  'Got': ['the', 'a'],
#  'Saturday': ['ratings', 'nights.', 'night.', 'night.'],
#  'ratings': ['back.'],
#  ...}

# %%
generate_sentence(T_dict)
# Out:
# 'Support. REPORTER 1: So hold from me. FRITZ: Hey, Mike, shut up! Get him down..'

# %% [markdown]
# # question 2

# %%
import random
import string

def generate_sentence1(chain, min_words=10, max_words=20):
    '''Generate a sentence using the Markov chain dictionary.'''
    
    # Capitalize the first word
    word1 = random.choice(list(chain.keys()))
    sentence = word1.capitalize()

    # Keep generating words until we reach the minimum number of words
    while len(sentence.split()) < min_words:
        word2 = random.choice(chain.get(word1, ['']))
        word1 = word2
        if not word2:
            break
        sentence += ' ' + word2

    # Check if the last word ends with punctuation
    if sentence[-1] in string.punctuation:
        return sentence.strip()

    # Keep generating words until we reach the maximum number of words or encounter punctuation
    while len(sentence.split()) < max_words:
        word2 = random.choice(chain.get(word1, ['']))
        if not word2 or word2[-1] in string.punctuation:
            break
        word1 = word2
        sentence += ' ' + word2

    # End the sentence with a random punctuation mark
    sentence += random.choice(string.punctuation)
    return sentence.strip()

# %%
k_text = data.transcript.loc['Kevin']
k_text[:200]
# Out:
# 'Kevin Bridges: The Overdue Catch-Up (2023) is a comedy special that encapsulates Kevin Bridges’ return to the stage, set against the backdrop of the Cork Opera House. He opens with gratitude for the a'

# %%
j_dict = markov_chain(j_text)
j_dict
# Out:
# {'In': ['“Get', 'the', 'order', 'a', 'theory,', 'order'],
#  '“Get': ['on', 'on'],
#  'on': ['Your',
#   'the',
#   'gender',
#   'Your',
#   'the',
#   'my',
#   'that',
#   'keeping',
#   'through',
#   'it.',
#   'some',
#   'stage',
#   'who',
#   'such',
#   'the',
#   'Monday',
#   'the',
#   'one',
#   'it.',
#   'my',
#   'this',
#   'the',
#   'me.',
#   'you',
#   'the',
#   'the',
#   'the',
#   'the',
#   'it',
#   'the',
#   'this',
#   'the',
#   'the',
#   'what',
#   'this',
#   'that',
#   'the',
#   'to',
#   'the',
#   'terms',
#   'your',
#   'the',
#   'track',
#   'track.',
#   'in.',
#   'and',
#   'it,',
#   'this',
#   'this',
#   'the',
#   'the',
#   'it.',
#   'it.',
#   'that',
#   'a',
#   'this',
#   'this',
#   'upstairs.',
#   'the',
#   'that',
#   'it,',
#   'this',
#   'this',
#   'the',
#   'the',
#   'the',
#   'a',
#   'this',
#   'me.',
#   'this',
#   'Earth.',
#   'my',
#   'behalf',
#   'this.”',
#   'her.',
#   'her,',
#   'her,',
#   'itself?',
#   'behalf',
#   'the',
#   'my',
#   'the',
#   'your',
#   'unfamiliar',
#   'the',
#   'that',
#   'that',
#   'few.',
#   'the',
#   'this',
#   'that',
#   'coming.',
#   'his',
#   'our',
#   'the',
#   '1,000',
#   'through',
#   'just',
#   'purpose.',
#   'the',
#   'purpose.',
#   'human'],
#  'Your': ['Knees,”',
#   'Knees”',
#   'appendage,',
#   'body,',
#   'voice',
#   'voice',
#   'voice',
#   'email'],
#  'Knees,”': ['Jacqueline'],
#  'Jacqueline': ['Novak'],
#  'Novak': ['transcends', 'invites', 'navigates'],
#  'transcends': ['the'],
#  'the': ['typical',
#   'act',
#   'Cherry',
#   'primal',
#   'act,',
#   'audience',
#   'subject,',
#   'juxtaposition',
#   'often-comical',
#   'complexities',
#   'absurdity',
#   'midnight',
#   'journey,',
#   'whole',
#   'thing,',
#   'air',
#   'whole',
#   'thing',
#   'uncertainty,',
#   '[exhales]…',
#   'tenuousness.',
#   'blow',
#   'point',
#   'position',
#   'eyes',
#   'Hound’s',
#   'future',
#   'caboose.',
#   'wind',
#   'top',
#   'show',
#   'muscles',
#   'eyes',
#   'moon',
#   'first',
#   'moon,',
#   'stage,',
#   'chin',
#   'class?”',
#   'form,',
#   'flesh,',
#   'body',
#   'one.',
#   'surrender',
#   'edges',
#   'point?',
#   'orb',
#   'embarrassment',
#   'ghost',
#   'home',
#   'orbs,',
#   'wedding.”',
#   'great-grandmother',
#   'afterlife',
#   'basic',
#   'point.',
#   'point.',
#   'point',
#   'form,',
#   'flesh,',
#   'common',
#   'word,',
#   'word',
#   'back',
#   'same',
#   'side',
#   'mouth.',
#   'word',
#   'voice',
#   'clinician',
#   'problem',
#   'problem',
#   'word',
#   'word',
#   'problem.',
#   'problem',
#   'syllables',
#   'true…',
#   'true',
#   '“nis.”',
#   '“nis.”',
#   'whole',
#   'sexy',
#   'word',
#   'problem',
#   'penis',
#   'feelings',
#   'penis.',
#   'little',
#   'penis.',
#   'penis.',
#   'penis',
#   'person',
#   'little',
#   'penis',
#   'kitchen',
#   'adults',
#   'second',
#   'nephew',
#   'nephew',
#   'same',
#   'penis.',
#   'penis,',
#   'penis',
#   'penis',
#   'word',
#   'penis',
#   'word',
#   'sense',
#   'wafer',
#   'divine.',
#   'penis',
#   'fucking',
#   'penis',
#   'soul',
#   'vine.',
#   'penis,',
#   'sun.',
#   'rest',
#   'body.',
#   'vulva',
#   'flower,',
#   'rose,',
#   'petals',
#   'rose.',
#   'vulva.',
#   'vulva',
#   'roses.”',
#   'bouquet,',
#   'evidence',
#   'wall.',
#   'petals',
#   'vulva…',
#   'vulva',
#   'kind',
#   'vulva…',
#   'way',
#   'way',
#   'layers,',
#   'burger',
#   'flower.',
#   'penis',
#   'most',
#   'shower',
#   'little',
#   'shoulder.',
#   'penis',
#   'fuck',
#   'rude',
#   'penis',
#   'whole',
#   'penis',
#   'night.”',
#   'sensitive.',
#   'nag.',
#   'drama',
#   'ultimate',
#   'party,',
#   'very',
#   'fainting',
#   'inner',
#   'face',
#   'old',
#   'courthouse',
#   'Devil!',
#   'only',
#   'journal.',
#   'journal,',
#   'grenade',
#   'shock',
#   'vaginal',
#   'masculine,',
#   'battle',
#   'rhythm',
#   'battle',
#   'penis…',
#   'penis',
#   'more',
#   'crotchal',
#   'body…',
#   'things',
#   'puppet',
#   'front',
#   'stage',
#   'children',
#   'show',
#   'other',
#   'narrative.',
#   'cover,',
#   'story',
#   'article',
#   'tender',
#   'tip.”',
#   'body',
#   'tip',
#   'first',
#   'penis,',
#   'most',
#   'castle?',
#   'gauntlet',
#   'sensitive',
#   'shaft,',
#   'underside',
#   'shaft,',
#   'skin',
#   'balls,',
#   'storied',
#   'balls,',
#   'way',
#   'essence',
#   'same,',
#   'cause…',
#   'cause',
#   'witch.',
#   'witch.',
#   'witch',
#   'helplessness',
#   'refusal',
#   'lower',
#   'urine',
#   'dick.',
#   'love',
#   'game.',
#   'idea,',
#   'plan?',
#   'idea?',
#   'penis,',
#   'older',
#   'relationship',
#   'blow',
#   'fridge',
#   'cucumber.',
#   'art',
#   'teacher.”',
#   'humiliations',
#   'cucumber',
#   'way',
#   'words',
#   'air.',
#   'first',
#   'few',
#   'impossible?',
#   'confidence',
#   'potentially',
#   'biz.”',
#   'bathroom',
#   'mirror',
#   'person',
#   'mirror.',
#   'mirror,',
#   'gamble',
#   'math',
#   'seemingly',
#   'years.',
#   'balls',
#   'balls',
#   'toys',
#   'pediatrician’s',
#   'balls,',
#   'balls,',
#   'balls?',
#   'most',
#   'principle',
#   'teacher',
#   'position',
#   'position',
#   'position',
#   'dancing',
#   'big',
#   'end',
#   'potential',
#   'other',
#   'counterclockwise',
#   'balls,',
#   'impulse',
#   'anatomy',
#   'balls',
#   'neck',
#   'bag',
#   'balls,',
#   'question',
#   'balls.',
#   'balls.',
#   'balls',
#   'bag',
#   'burden',
#   'intern',
#   'same',
#   'other',
#   'weight.',
#   'way.',
#   'work.”',
#   'same',
#   'balls',
#   'feebleness',
#   'blow',
#   'lesson,',
#   'end',
#   'day',
#   'blow',
#   'person?',
#   'spirit',
#   'thing.”',
#   'simple',
#   'thing',
#   'beat.',
#   'whole',
#   'question',
#   'penis’s',
#   'penis',
#   'penis.',
#   'sky,',
#   'change',
#   'rockest-hardest',
#   'jus,',
#   'chef.',
#   'bone.”',
#   'way',
#   'side',
#   'street',
#   'way,',
#   'Washington',
#   'next',
#   'language',
#   'penis',
#   'penis’s',
#   'rock-hard',
#   'anaconda,',
#   'penis',
#   'very',
#   'sort',
#   'same',
#   'arm',
#   'sleeve',
#   'silky',
#   'woolen',
#   'word',
#   'dictionary,',
#   'thesaurus…',
#   'thesaurus.',
#   'way',
#   'ribbon-cutting',
#   'walls',
#   'more',
#   'moment.”',
#   'very',
#   'equivalent',
#   'entryway.',
#   'parking',
#   'first',
#   'penis',
#   'pipe.',
#   'plumber?',
#   'choke…',
#   'penis.',
#   'penis',
#   'back',
#   'cock.',
#   'need',
#   'first',
#   'last',
#   'essential',
#   'thing',
#   'boyfriend',
#   'smell',
#   'fresh',
#   'family’s',
#   'basement,',
#   'deck?',
#   'boyfriend.',
#   'torso.',
#   'whole…',
#   'whole',
#   'sense',
#   'desire,',
#   'desire',
#   'consumption',
#   'fry,',
#   'quote',
#   'wisdom',
#   'ages.',
#   'young.”',
#   'past.',
#   'July',
#   'moonlight,',
#   'feeling',
#   'awesomeness',
#   'full',
#   'entire',
#   'entire',
#   'older',
#   'beer',
#   'car',
#   'Personal',
#   '48',
#   'Giant',
#   'PSATs.',
#   'limiting',
#   'party',
#   'way,',
#   'teeth.”',
#   'teeth',
#   'way',
#   'blow',
#   'mouth,',
#   'side',
#   'road…',
#   'blow',
#   'ages,',
#   'first',
#   'woods',
#   'other',
#   'craziest…”',
#   'craziest',
#   'windowed',
#   'letter,',
#   'address',
#   'same',
#   'craziest',
#   'intensity',
#   'blow',
#   'wasting',
#   'essential',
#   'thing.',
#   'problem.',
#   'person',
#   'jangle',
#   'bells',
#   'blow',
#   'problem',
#   'dumb',
#   'moment',
#   'torso',
#   'face',
#   'thing.',
#   'answer',
#   'house’s',
#   'resort.',
#   'eventual',
#   'moody',
#   'true',
#   'family.',
#   'idea',
#   'scratch-and-sniff',
#   'back',
#   'sticker',
#   'seam',
#   'Health',
#   'pride',
#   'time.',
#   'son',
#   'father,',
#   'man’s',
#   'role',
#   'side.',
#   'road,',
#   'hell',
#   'boyfriend’s',
#   'word',
#   'word',
#   'same',
#   'mix',
#   'meanings',
#   'recognition',
#   'potency',
#   'word',
#   'current',
#   'fuck',
#   'way',
#   'father,',
#   'way',
#   'father’s',
#   'quality',
#   'Olympic',
#   'year,',
#   'failed',
#   'end',
#   'summer',
#   'first',
#   'difference',
#   'spirit',
#   'cave',
#   'way',
#   'basement',
#   'stairs',
#   'running',
#   'confident',
#   'top',
#   'show,',
#   'fuckin’',
#   'course',
#   'show.',
#   'running',
#   'end',
#   'last',
#   'original',
#   'ladder,',
#   'plan',
#   'way.',
#   'time.',
#   'language',
#   'windows',
#   'Russian',
#   'same',
#   'prose',
#   'interesting',
#   'story,',
#   'worst',
#   'most',
#   'collection.”',
#   'dick',
#   'end.',
#   'moon,',
#   'south',
#   'simple',
#   'little',
#   'clicker,',
#   'ego.',
#   'expression.',
#   'difficult',
#   'chips',
#   'sophistication.',
#   'guidance',
#   'deans,',
#   'very',
#   'place,',
#   'coursework',
#   'blow',
#   'blow',
#   'blow',
#   'blow',
#   'work',
#   'fruits',
#   'time',
#   'sort',
#   'day.',
#   'lead',
#   'television',
#   'lead',
#   'show?',
#   'darkest',
#   'show.',
#   'form,',
#   'flesh',
#   'indignities',
#   'embarrassments',
#   'real',
#   'photo,',
#   'old',
#   'diner',
#   'table?',
#   'latest',
#   'old',
#   'old',
#   'way',
#   '“B.”',
#   'prospect',
#   'cycle',
#   'innocent,',
#   'innocent,',
#   'scary,',
#   'way',
#   'bats',
#   'cave',
#   'bats',
#   'little',
#   'other',
#   'way',
#   'university',
#   'level',
#   'slut',
#   'rules',
#   'sleeves',
#   'place?',
#   'top.',
#   'cost',
#   'latest',
#   'end',
#   'blow',
#   'final',
#   'others',
#   'Sharon',
#   'whole',
#   'latest',
#   'entire',
#   'very',
#   'Batman',
#   'courage',
#   'teeth',
#   'most',
#   'other',
#   'cave',
#   'while',
#   'fools.',
#   'two',
#   'toothy',
#   'biz,',
#   'sunset',
#   'most',
#   'male',
#   'day',
#   'male',
#   'pops',
#   'table.',
#   'mystery',
#   'ditz.',
#   'answer',
#   'D',
#   'D',
#   'man',
#   'way',
#   'same',
#   'favor,',
#   'beauty',
#   'toothy',
#   'audacity',
#   'reminder',
#   'way',
#   'teeth.',
#   'teeth',
#   'blow',
#   'seeds',
#   'watermelon.',
#   'pleasure',
#   'blow',
#   'sand',
#   'oyster',
#   'pearl.',
#   'sea',
#   'caramel.',
#   'caramel',
#   'taste.',
#   'blow',
#   'ways',
#   'little',
#   'cereal',
#   'little',
#   'wall',
#   'grains',
#   'steady,',
#   'cereal.',
#   'teeth',
#   'blow',
#   'details',
#   'textures',
#   'English',
#   'universal',
#   'particular.',
#   'plums',
#   'icebox,',
#   'popping',
#   'microphone.',
#   'windowpane,”',
#   'blow',
#   'richest',
#   'blow',
#   'stakes.',
#   'teeth,',
#   'boneless',
#   'teeth…',
#   'centuries',
#   'thing.',
#   'fun',
#   'rough',
#   'lip',
#   'point.',
#   'ghost',
#   'orb.',
#   'human',
#   'form’s',
#   'universe',
#   'splendor',
#   'soul',
#   'translation',
#   'lesson',
#   'way…',
#   'lesson',
#   'dignity',
#   'ocean.',
#   'ocean.',
#   'ocean',
#   'feet',
#   'ocean',
#   'legs',
#   'ocean.',
#   'holes',
#   'teeth',
#   'blow',
#   'rules,',
#   'throne,',
#   'ecstasy',
#   'blow',
#   'pursuit',
#   'privacy',
#   'Loft.',
#   'best'],
#  'typical': ['stand-up'],
#  'stand-up': ['comedy'],
#  'comedy': ['show'],
#  'show': ['by', 'because', 'up,', 'up', 'continues,', 'you', 'me', 'me'],
#  'by': ['delivering',
#   'self-deprecation,',
#   'Madonna',
#   'now',
#   'some',
#   'the',
#   'kicking',
#   'since',
#   'for',
#   'the',
#   'a',
#   'the',
#   'car.”',
#   'the',
#   'to',
#   'Vladimir',
#   'one.',
#   'it.',
#   'you.”',
#   'me',
#   'the',
#   'now,',
#   'the'],
#  'delivering': ['a'],
#  'a': ['unique',
#   'theatrical',
#   'cerebral',
#   'refusal',
#   'fresh',
#   '“thinking,',
#   'society',
#   'thought-provoking',
#   'Prayer”',
#   'mystery',
#   'little',
#   'prayer',
#   'microphone',
#   'blow',
#   'bit',
#   'way',
#   'parent',
#   'sibling,',
#   'term',
#   'more',
#   'strong',
#   'sort',
#   'constant',
#   'nightmare,',
#   'nightmare',
#   'woman',
#   'bit',
#   'mental',
#   'mental',
#   'gray',
#   'ghost.',
#   'ghost,',
#   'future',
#   'ghost,',
#   'place',
#   'house,',
#   'quaint',
#   'meditation',
#   'ghost,',
#   'ghost,',
#   'strong',
#   'robust',
#   'ghost.',
#   'bit.',
#   'lifelong',
#   'photograph',
#   'little',
#   'great-grandson.',
#   'thing',
#   'heterosexual',
#   'patent',
#   'girl',
#   'ponytail',
#   'lot',
#   'good',
#   'kind',
#   'word',
#   'problem',
#   'soft',
#   'problem.',
#   'joke.',
#   'problem',
#   'way,',
#   'cock,',
#   'cock,',
#   'cock?',
#   'cock.”',
#   'penis',
#   'cock,',
#   'friend’s',
#   'cock,',
#   'little',
#   'cock?',
#   'cock.”',
#   'chance',
#   'chance',
#   'fan',
#   'regularity',
#   'sort',
#   'taste',
#   'fan.',
#   'filling',
#   'filling',
#   'little',
#   'building,',
#   'romantic',
#   'boldly',
#   'minute.”',
#   'bouquet',
#   'crack',
#   'more',
#   'shot.',
#   'tattered',
#   'tale',
#   'vulva',
#   'burger',
#   'threat',
#   'spill.',
#   'risk',
#   'sudden',
#   'feminine',
#   'Susan,',
#   'little',
#   'certain',
#   'scene,',
#   'face.',
#   'hysterical',
#   'kind',
#   'hideous',
#   'little',
#   'hint',
#   'family',
#   'pushing',
#   'journal',
#   'selfless,',
#   'tree',
#   'puppet',
#   'puppet',
#   'list',
#   'part',
#   'penis.”',
#   'warning',
#   'sexually-inspiring',
#   'village.',
#   'very',
#   'burping',
#   'room',
#   'penis',
#   'toothy',
#   'big',
#   'practical',
#   'potential',
#   'diagonal…',
#   'diagonal',
#   'blow',
#   'cucumber',
#   'demonstration',
#   'face',
#   'little',
#   'storm.',
#   'nearly',
#   'proper',
#   'sort',
#   'good',
#   'risk',
#   'risk',
#   'fool.”',
#   'fool,',
#   'fool.',
#   'fool',
#   'fool',
#   'guaran…',
#   'guarantee',
#   'couple',
#   'specific',
#   'hint',
#   'principal',
#   'baby.”',
#   'couple',
#   'freeze.',
#   'freeze.',
#   'plastic',
#   'bus',
#   'bit',
#   'point',
#   'single',
#   'minor',
#   'couple',
#   'group',
#   'picnic',
#   'moment',
#   'dick',
#   'dick',
#   'dick',
#   'dick',
#   'dick',
#   'field',
#   'pinch',
#   'weapon…',
#   'girl',
#   'second?',
#   'girl',
#   'penis-paper-scissors',
#   'good',
#   'rock.',
#   '50-50',
#   'rock',
#   'rock.”',
#   'slappy',
#   'spirit.',
#   'spirit.',
#   'risk',
#   'nice',
#   'pureed',
#   'bite,',
#   'boneless',
#   'bag',
#   'nipple.',
#   'pebble',
#   'tiny,',
#   'rock',
#   'rock',
#   'sudden.',
#   'little',
#   'snake.',
#   'snake.',
#   'penis',
#   'complaint',
#   'guided',
#   'guided',
#   'coat',
#   'minute',
#   'bit',
#   'penis',
#   'guest',
#   'working',
#   'while',
#   'glove',
#   'glove,',
#   'matter',
#   'building.',
#   'store,',
#   'Target,',
#   'problem',
#   'choking',
#   'long',
#   'few',
#   'gumball.',
#   'gumball',
#   'real',
#   'threat',
#   'blow',
#   'boyfriend',
#   'grade',
#   'bed',
#   'patient',
#   'table',
#   'slow-moving',
#   'newly-finished',
#   'blow',
#   'vacuum.',
#   'bummer',
#   'French',
#   'bit.',
#   'big',
#   'young,',
#   'team-spirit-building',
#   'way.',
#   'blow',
#   '‘Just',
#   'car.',
#   'beer.”',
#   'cocktail',
#   'young',
#   'close',
#   'negative',
#   'blow',
#   'blow',
#   'thing,',
#   'blow',
#   'thing',
#   'simple,',
#   'window',
#   'blow',
#   'risk,',
#   'way',
#   'little',
#   'fool',
#   'second',
#   'second',
#   'blow',
#   'position',
#   'solution,',
#   'deep',
#   'self-starter,',
#   'voucher.',
#   'gift',
#   'hotel',
#   'big',
#   'shit.',
#   'goof,',
#   'collection',
#   'variety',
#   'little',
#   'good',
#   'faded',
#   'man’s',
#   'stink',
#   'sticker',
#   'sexually-active',
#   'problem,',
#   'sexually-active,',
#   'notable',
#   'boyfriend’s',
#   'figure',
#   'good',
#   'wave',
#   'whiff',
#   'particular',
#   'lot',
#   'cognitive',
#   'man',
#   'single',
#   'river,',
#   'river',
#   'stone,',
#   'courtesy',
#   'man.',
#   'blow',
#   'new',
#   'new',
#   'new',
#   'blow',
#   'mask',
#   'sexual',
#   'literal',
#   'moment',
#   'dead',
#   'single',
#   'little',
#   'diving',
#   'move',
#   'new',
#   'new',
#   '‘just',
#   'second',
#   'way.',
#   'slightly',
#   'tooth,',
#   'character',
#   'short',
#   'blow',
#   'way?',
#   'young',
#   'little',
#   'minute.',
#   'little',
#   'tiny',
#   'difference,',
#   'Tony',
#   'point',
#   'difficult',
#   'sort',
#   '4.0',
#   'lesser',
#   'triumph.',
#   'goddamn',
#   'sort',
#   'lot',
#   'Jew,',
#   'kind',
#   'Jewish',
#   'conquered',
#   'basic',
#   'working',
#   'love',
#   'poem?',
#   'crude',
#   'lot',
#   'French',
#   'fry.',
#   'let-down',
#   'marriage',
#   'blow',
#   'love',
#   'modern',
#   'real',
#   'man.',
#   'single',
#   'photo',
#   'hint',
#   'knowing',
#   'photo,',
#   'winter',
#   'fear',
#   'little',
#   'Batman,',
#   'fear',
#   'strength,',
#   'fear',
#   'restaurant.',
#   'blow',
#   'little',
#   'little',
#   'broken',
#   'lot',
#   'chuckle',
#   'fear,',
#   'confident',
#   'long,',
#   'quirky',
#   'little',
#   'bookstore',
#   'little',
#   'bookshop.',
#   'little.',
#   'spirit…”',
#   'toothy',
#   'problem,',
#   'tragic',
#   'confident…',
#   'giant.',
#   'giant,',
#   'little',
#   'single',
#   'flaw,',
#   'thousand',
#   'constant',
#   'steady',
#   'man’s',
#   'base…',
#   'dry',
#   'restaurant.',
#   'man',
#   'lantern,',
#   'mystery.”',
#   'word.”',
#   'vigilance.',
#   'child-proofing,',
#   'drunken',
#   'sweat.',
#   'hard',
#   'toothy',
#   'toothy',
#   'toothy',
#   'toothy',
#   'blow',
#   'blow',
#   'blow',
#   'blow',
#   'mouth.',
#   'mouth',
#   'roomier',
#   'dick',
#   'blow',
#   'reminder,',
#   'flawed',
#   'flailing',
#   'bad',
#   'prize.',
#   'wonderful',
#   'Susan',
#   'bone',
#   'boneless',
#   'hobgoblin',
#   'smooth,',
#   'fit.',
#   'round',
#   'round',
#   'mouth',
#   'couple',
#   'more',
#   'visitation.',
#   'small',
#   'few',
#   'body',
#   'ghost.',
#   'nightclub',
#   'cautionary',
#   'single',
#   'prayer',
#   'dream',
#   'prayer',
#   'dream',
#   'prayer',
#   'muse',
#   'mystery',
#   'dream',
#   'prayer',
#   'prayer',
#   'muse',
#   'mystery',
#   'dream',
#   'prayer',
#   'prayer',
#   'week'],
#  'unique': ['blend'],
#  'blend': ['of'],
#  'of': ['personal',
#   'oral',
#   'physical',
#   'embodying',
#   'sexual',
#   'human',
#   'tedium,”',
#   'our',
#   'these',
#   'your',
#   'love,',
#   'thing.',
#   'poetic',
#   'the',
#   'being',
#   'enchantment.',
#   'ideas',
#   'mine,',
#   'sack',
#   'sex',
#   'course,',
#   'myself',
#   'course.',
#   'in',
#   'instantly',
#   'these',
#   'the',
#   'light',
#   'you',
#   'the',
#   'a',
#   'seemingly',
#   'course,',
#   'me',
#   'you’d',
#   'dignity',
#   'your',
#   'slips',
#   'the',
#   'the',
#   'tender',
#   'these',
#   'devastation,',
#   'that',
#   'telling',
#   'the',
#   'the',
#   'these',
#   'like,',
#   'church',
#   'the',
#   'an',
#   'eternal',
#   'the',
#   'the',
#   'roses',
#   'them',
#   'the',
#   'the',
#   'tilted',
#   'a',
#   'how',
#   'a',
#   'a',
#   'the',
#   'guy',
#   'women.',
#   'the',
#   'the',
#   'a',
#   'sudden',
#   'Abigail',
#   'my',
#   'a',
#   'pleasure,',
#   'the',
#   'the',
#   'the',
#   'it',
#   'the',
#   'for',
#   'came',
#   'instructions',
#   'the',
#   'a',
#   'the',
#   'the',
#   'the',
#   'course.',
#   'an',
#   'blue',
#   'overtired…',
#   'the',
#   'the',
#   '“Oh,',
#   'teeth,',
#   'a',
#   'nowhere,',
#   'the',
#   'respect',
#   'which',
#   'the',
#   'blinking',
#   'prudent',
#   'the',
#   'as',
#   'the',
#   '50%',
#   'zero',
#   'self-hatred',
#   'act.',
#   'play…',
#   'cliché',
#   'contrivance.',
#   'the',
#   'me',
#   'my',
#   'all,',
#   'my',
#   'authenticity.',
#   'this.',
#   'what',
#   'the',
#   'daring',
#   'the',
#   'the',
#   'inherently',
#   'could',
#   'the',
#   'gravity',
#   'people',
#   'running',
#   'this',
#   'how',
#   'the',
#   'the',
#   'object.',
#   'spinach,',
#   'parsley.',
#   'meat.',
#   'blood',
#   'the',
#   'a',
#   'thing',
#   'the',
#   'me',
#   'me',
#   'a',
#   'them',
#   'amble',
#   'this',
#   'a',
#   'scale',
#   'what',
#   'fear',
#   'choking,',
#   'my',
#   'choking',
#   'myself',
#   'their',
#   'a',
#   'a',
#   'the',
#   'desire',
#   'the',
#   'things,',
#   'quotations.',
#   'lock',
#   'the',
#   'the',
#   'this',
#   'the',
#   'thing.”',
#   'the',
#   'a',
#   'Awaken',
#   'your',
#   'teeth,',
#   'you',
#   'you.',
#   'you.',
#   'view',
#   'the',
#   'it?',
#   'that,',
#   'that.',
#   'genius,',
#   'my',
#   'dignity.',
#   'the',
#   'genitals.',
#   'the',
#   'the',
#   'someone',
#   'sexual',
#   'confidence,',
#   'idiosyncratic',
#   'lesser',
#   'the',
#   'the',
#   'personhood.',
#   'the',
#   'being',
#   'your',
#   'my',
#   'his',
#   'us',
#   'yours.',
#   'asshole.',
#   'the',
#   'six',
#   'these',
#   'stir',
#   'original',
#   'my',
#   'your',
#   'it.',
#   'the',
#   'someone',
#   'the',
#   'my',
#   'needed',
#   'my',
#   'confidence',
#   'the',
#   'my',
#   'a',
#   'the',
#   'the',
#   'a',
#   'in',
#   'Vladimir',
#   'pizza',
#   'it,',
#   'yourself.',
#   'the',
#   'a',
#   'you',
#   'course.',
#   'the',
#   'pain.',
#   'neuroses.',
#   '3.7-in-the-AP-course-load',
#   'gal.',
#   'them.',
#   'Catholic-ish',
#   'Catholic',
#   'scurrying',
#   'Philip',
#   'philosophy',
#   'our',
#   'friends,',
#   'prevailing',
#   'course,',
#   'yourself',
#   'your',
#   'mine.',
#   'mine.',
#   'them.',
#   'them,',
#   'them',
#   'you',
#   'a',
#   'these',
#   'sugar',
#   'my',
#   'bats.',
#   'bats',
#   'these',
#   'my',
#   'nuance',
#   'diagonals',
#   'my',
#   'excellence?',
#   'tragic',
#   'excellence.',
#   'my',
#   'goes',
#   'a',
#   'confident',
#   'blow',
#   'his',
#   'laughter',
#   'laying',
#   'just…',
#   'the',
#   'them.',
#   'orifices',
#   'the',
#   'spectacle.',
#   'the',
#   'my',
#   'life',
#   'little',
#   'act,',
#   'our',
#   'course…',
#   'course,',
#   'the',
#   'appreciating',
#   'that,',
#   'riches.',
#   'their',
#   'riches',
#   'men',
#   'letters',
#   'appreciating…',
#   'fools,',
#   'you',
#   'my',
#   'my',
#   'societal'],
#  'personal': ['anecdotes', 'stories', 'anecdotes'],
#  'anecdotes': ['and', 'Dylan'],
#  'and': ['intellectual',
#   'the',
#   'a',
#   'the',
#   'comedic',
#   'expression,',
#   'keep',
#   'fair',
#   'torso,',
#   'ass',
#   'it’s',
#   'fly',
#   'I’ll',
#   'I',
#   'someone’ll',
#   'you',
#   'appear',
#   'you',
#   'no,',
#   'age.',
#   'yet,',
#   'now',
#   'kick',
#   'I',
#   'rightfully',
#   'down',
#   'the',
#   'we…',
#   'it’s',
#   'then',
#   'again',
#   'it',
#   'it',
#   'it',
#   'I',
#   'one',
#   'then',
#   'then',
#   'they’re',
#   'applauding]',
#   'said,',
#   'then',
#   'sulking',
#   'fair',
#   'that’s',
#   'absorb',
#   'strong.',
#   'does',
#   'hangs',
#   'scaring',
#   'you’re',
#   'I’d',
#   'that’s',
#   'delicate.',
#   'tap.',
#   'tap.',
#   'it’ll',
#   'pretty',
#   'I’m',
#   'me',
#   'the',
#   'over',
#   'I',
#   'Over',
#   'Over?',
#   '’cause',
#   'she',
#   'I’m',
#   'she',
#   'I',
#   'do',
#   'let',
#   'then',
#   'that',
#   'myself?',
#   'insult',
#   'someone',
#   'someone',
#   'then',
#   'hate',
#   'applauding]',
#   'you',
#   'then',
#   'she',
#   'the',
#   'if',
#   'applauding]',
#   'authentically',
#   'I',
#   'I',
#   'I',
#   'came',
#   'presently?',
#   'I',
#   'I',
#   'that’s',
#   'what',
#   'applauding]',
#   'sure,',
#   'take',
#   'shake',
#   'at',
#   'angle',
#   'the',
#   'me.',
#   'I',
#   'it’s',
#   'you',
#   'me',
#   'someone',
#   'close',
#   'open',
#   'close',
#   'the',
#   'I’ve',
#   'applauding]',
#   'make',
#   'panic',
#   'applauding]',
#   'make',
#   'then',
#   'it',
#   'I',
#   'I',
#   'the',
#   'my',
#   'that’s',
#   'I’d',
#   'speed-read',
#   'I’m',
#   'the',
#   'I’m',
#   'the',
#   'me,',
#   'then',
#   'that',
#   'they',
#   'now',
#   'applauding]',
#   'on',
#   'she',
#   'then',
#   'then',
#   'still',
#   'applauding]',
#   'for',
#   'then',
#   'the',
#   'I’m',
#   'applauding]',
#   'I',
#   'a',
#   'we',
#   'we',
#   'so',
#   'feebly',
#   'I…',
#   'I',
#   'the',
#   'for',
#   'applauding]',
#   'I',
#   'discomfort',
#   'yours.',
#   'an',
#   'then',
#   'I',
#   'there',
#   'shouldn’t',
#   'did',
#   'it’s',
#   'applauding]',
#   'over',
#   'applauding]',
#   'the',
#   'I',
#   'drowned.',
#   'applauding]',
#   'I',
#   'he',
#   'then',
#   'then',
#   'I',
#   'my',
#   'right,',
#   'actual',
#   'I',
#   'just',
#   'decay',
#   'sort',
#   'sort',
#   'then',
#   'applauding]',
#   'it’s',
#   'I',
#   'I',
#   'cheering]',
#   'hideous',
#   'I…',
#   'it',
#   'I',
#   'I',
#   'cheering]',
#   'let',
#   'it',
#   'I',
#   'now',
#   'it',
#   'inspiring.',
#   'my',
#   'that’s',
#   'there',
#   'dies',
#   'I',
#   'the',
#   'I',
#   'applauding]',
#   'someone',
#   '“I’m',
#   'I’m',
#   'this',
#   'I',
#   'I',
#   'you',
#   'uh…',
#   'I',
#   'applauding]',
#   'this',
#   'not',
#   'fair',
#   'demonstrate',
#   'I',
#   'I',
#   'you',
#   'applauding]',
#   'I',
#   'I',
#   'I’m',
#   'cigarettes.”',
#   'hold',
#   'I',
#   'so',
#   'applauding]',
#   'with',
#   'finally,',
#   'say,',
#   'destroys',
#   'it’s',
#   'now',
#   'just',
#   'I',
#   'applauding]',
#   'it',
#   'that’s',
#   'he',
#   'fails,',
#   'tries',
#   'fails,',
#   'through',
#   'failing',
#   'trying,',
#   'you’re',
#   'this',
#   'desire',
#   'another',
#   'laughing]',
#   'let',
#   'cheering]',
#   'past',
#   'before',
#   'yet',
#   'directly,',
#   'I',
#   'delight.',
#   'I’ll',
#   'assholes',
#   'self-discovery,',
#   'broader',
#   'self-discovery,',
#   'relationships,',
#   'whimsy',
#   'truths'],
#  'intellectual': ['exploration', 'analysis.', 'like'],
#  'exploration': ['into'],
#  'into': ['the',
#   'a',
#   'a',
#   'the',
#   'the',
#   'the',
#   'the',
#   'a',
#   'the',
#   'the',
#   'on',
#   'this',
#   'your',
#   'her',
#   'what',
#   'the',
#   'a',
#   'a',
#   'Target,',
#   'that',
#   'my',
#   'my',
#   'the',
#   'the',
#   'my',
#   'which'],
#  'act': ['of', 'like', 'like', 'like'],
#  'oral': ['sex,'],
#  'sex,': ['transforming', 'technically-speaking,'],
#  'transforming': ['it'],
#  'it': ['into',
#   'feels',
#   'reminds',
#   'in',
#   'will',
#   'represents',
#   'up',
#   'can',
#   'up.',
#   'is',
#   'is',
#   'moving',
#   'later?',
#   'takes.',
#   'as',
#   'happened',
#   'has',
#   'up',
#   'from',
#   'started',
#   'sounds',
#   'is.',
#   'becomes',
#   'like',
#   'what',
#   'wants',
#   'away.',
#   'like',
#   'even',
#   'suffices.',
#   'time',
#   'is',
#   'has',
#   'and',
#   'sort',
#   'is',
#   'is',
#   'doesn’t…',
#   'doesn’t',
#   'withers.',
#   'blooms',
#   'withers',
#   'blooms',
#   'gathers',
#   'in',
#   'into',
#   'just',
#   'requires',
#   'a',
#   'up',
#   'holds.',
#   'down,',
#   'out.',
#   'on',
#   'doesn’t',
#   'holds.',
#   'doesn’t',
#   'does.',
#   'as',
#   'doesn’t',
#   'back',
#   'always',
#   'with',
#   'can',
#   'takes',
#   'was',
#   'was',
#   'in',
#   'and',
#   'and',
#   'but',
#   'was',
#   'feels',
#   'is',
#   'wasn’t',
#   'more',
#   'again',
#   'one',
#   'spin',
#   'all',
#   'took',
#   'comes',
#   'feels',
#   'comes',
#   'takes.',
#   'in',
#   'happens.',
#   'into',
#   'over',
#   'fell',
#   'out.',
#   'seems',
#   'is.',
#   'seem',
#   'was',
#   'to',
#   'quite',
#   'gets',
#   'with',
#   '’cause',
#   'was',
#   'too',
#   'in',
#   'as',
#   '’cause',
#   '’cause',
#   'and',
#   'and',
#   'sounds',
#   'as',
#   'up',
#   'taut,',
#   'safely',
#   'was',
#   'to',
#   'to',
#   'in',
#   'on',
#   'in',
#   'was',
#   'cannot',
#   'shouldn’t',
#   'should',
#   'just',
#   'like',
#   'yet.',
#   'well.',
#   'before.',
#   'badly,',
#   'badly.',
#   'did.',
#   'to',
#   'was',
#   'was',
#   'before',
#   'to',
#   'goes.',
#   'aside.',
#   'solved',
#   'would',
#   'is',
#   'out,',
#   'white',
#   'was',
#   'was',
#   'wasn’t',
#   'once',
#   'again,',
#   'would',
#   'again,',
#   'all',
#   'was',
#   'crack.',
#   'crack,',
#   'back',
#   'is',
#   'is',
#   'is.',
#   'in',
#   'in',
#   'all',
#   'all',
#   'might',
#   'got',
#   'should,',
#   '’cause',
#   'and',
#   'was',
#   'was',
#   'was',
#   'was',
#   'off.',
#   'was',
#   'was',
#   'can.',
#   'slow.”',
#   'slow.”',
#   'slow…',
#   'slow.',
#   'stays',
#   'to',
#   'can',
#   'off',
#   'felt',
#   'terrifies',
#   'is.',
#   'any',
#   'to',
#   'at',
#   'couldn’t',
#   'would',
#   'without',
#   'right.',
#   'does',
#   'may',
#   'is',
#   'is',
#   'so.',
#   'is',
#   'work',
#   'work',
#   'would',
#   'to',
#   'were',
#   'wouldn’t',
#   'very',
#   'already',
#   'is',
#   'shall'],
#  'theatrical': ['experience'],
#  'experience': ['at', 'it', 'at'],
#  'at': ['the',
#   'him,',
#   'the',
#   'times.',
#   'all,',
#   'home.',
#   'the',
#   'minimum.',
#   'all.',
#   'all',
#   'being',
#   'being',
#   'her,',
#   'a',
#   'its',
#   'a',
#   'risk,',
#   'my',
#   'my',
#   'that',
#   'least',
#   'all',
#   'me,',
#   'all,',
#   'a',
#   'me,',
#   'the',
#   'ease.',
#   'its',
#   'the',
#   'some',
#   'the',
#   'this',
#   'Borders',
#   'most.',
#   'a',
#   'all,',
#   'all,',
#   'adjusting',
#   'the',
#   'me',
#   'the',
#   'that',
#   'all.',
#   'the',
#   'a',
#   'the',
#   'ease,',
#   'the',
#   'the',
#   'a',
#   'parties.',
#   'this',
#   'this',
#   'the',
#   'photos',
#   'these',
#   'a',
#   'night',
#   'school,',
#   'Batman',
#   'the',
#   'you.',
#   'you.”',
#   'you.',
#   'the',
#   'the',
#   'his',
#   'you',
#   'a…',
#   '14,',
#   'me',
#   'the',
#   'all?',
#   'all.',
#   'all.',
#   'bare',
#   'bare,',
#   'all.',
#   'this',
#   'the',
#   'all,'],
#  'Cherry': ['Lane'],
#  'Lane': ['Theater.'],
#  'Theater.': ['Stripping'],
#  'Stripping': ['away'],
#  'away': ['the', 'at', 'from', 'by', 'from'],
#  'primal': ['elements'],
#  'elements': ['typically'],
#  'typically': ['associated'],
#  'associated': ['with'],
#  'with': ['the',
#   'intellectual',
#   'contradictions.',
#   'a',
#   'dignity.',
#   'some',
#   'him.',
#   'it',
#   'anything',
#   'a',
#   'the',
#   'the',
#   'the',
#   'a',
#   'inspiration.',
#   'all',
#   'the',
#   'it.',
#   'my',
#   'these',
#   'my',
#   'my',
#   'authority',
#   'confidence?',
#   'me',
#   'the',
#   'the',
#   'those',
#   'something…',
#   'something?',
#   'what',
#   'balls',
#   'the',
#   'the',
#   'it.',
#   'precision,',
#   'more',
#   'me.”',
#   'those',
#   'it.”',
#   'the',
#   'the',
#   'my',
#   'me,',
#   'lip',
#   'a',
#   'which',
#   'every',
#   'you',
#   'your',
#   'feet.',
#   'the',
#   'this',
#   'a',
#   'the',
#   'the',
#   'brown',
#   'red',
#   'an',
#   'it,',
#   'which',
#   'this',
#   'me,',
#   'the',
#   'myself',
#   'yet',
#   'this',
#   'that',
#   'that',
#   'courage,',
#   'his',
#   'him.',
#   'every',
#   'that?',
#   'your',
#   'keen',
#   'personal'],
#  'act,': ['Novak', 'you', 'so'],
#  'invites': ['the'],
#  'audience': ['into'],
#  'cerebral': ['discussion'],
#  'discussion': ['on'],
#  'subject,': ['humorously', 'is'],
#  'humorously': ['dissecting', 'tackles', 'explores', 'critiques'],
#  'dissecting': ['its'],
#  'its': ['semantics,',
#   'own',
#   'needs,',
#   'wants,',
#   'sort',
#   'presence,',
#   'nature?',
#   'strength,',
#   'particular',
#   'most,',
#   'bit,',
#   'death',
#   'existence',
#   'hardest,',
#   'hardest,',
#   'own',
#   'teeth',
#   'glory?',
#   'very'],
#  'semantics,': ['cultural'],
#  'cultural': ['perceptions,'],
#  'perceptions,': ['and'],
#  'juxtaposition': ['of'],
#  'physical': ['desire', 'form.'],
#  'desire': ['with', 'or', 'through', 'alone.'],
#  'analysis.': ['Her'],
#  'Her': ['performance,'],
#  'performance,': ['characterized'],
#  'characterized': ['by'],
#  'self-deprecation,': ['sharp'],
#  'sharp': ['wit,', 'senses'],
#  'wit,': ['and'],
#  'refusal': ['to', 'to'],
#  'to': ['conform',
#   'conventional',
#   'a',
#   'give',
#   'do,',
#   'maintain',
#   'call',
#   'become',
#   'warn',
#   'write',
#   'grow',
#   'the',
#   'take',
#   'look,',
#   'be',
#   'say.',
#   'keep',
#   'keep',
#   'take',
#   'it.',
#   'discarding',
#   'being',
#   'cast',
#   'become',
#   'linger.',
#   'haunt',
#   'night',
#   'their',
#   'be',
#   'know',
#   'the',
#   'talk',
#   'gather',
#   'be',
#   'me.',
#   'discarding',
#   'me,',
#   'me.',
#   'it.',
#   'what',
#   'me,',
#   'hear.',
#   'talking.',
#   'it.',
#   'me,',
#   'the',
#   'act',
#   'me?',
#   'me.',
#   'me',
#   'code.',
#   'just',
#   'tell',
#   'say',
#   'get',
#   'me',
#   'me.',
#   'things.”',
#   'notice',
#   'it…',
#   'mind',
#   'say,',
#   'just',
#   'it.',
#   'the',
#   'go',
#   'retreat.”',
#   'think',
#   'be',
#   'see',
#   'please',
#   'the',
#   'see',
#   'a',
#   'injure',
#   'land',
#   'me.',
#   'do',
#   'look',
#   'relieve',
#   'get',
#   'relieve',
#   'relieve',
#   'burp',
#   'give',
#   'the',
#   'go',
#   'teach',
#   'us,',
#   'give',
#   'know',
#   'demonstrate',
#   'our',
#   'let',
#   'be',
#   'whom?”',
#   'ask',
#   'ask',
#   'be',
#   'say',
#   'err',
#   'me',
#   'look',
#   'play',
#   'let',
#   'do.',
#   'play',
#   'play',
#   'my',
#   'make',
#   'make',
#   'dance',
#   'freeze',
#   'the',
#   'this',
#   'think',
#   'a',
#   'do.',
#   'look',
#   'touch',
#   'know',
#   'the',
#   'add',
#   'be',
#   'do',
#   'help,',
#   'help',
#   'take',
#   'me,',
#   'be',
#   'know',
#   'the',
#   'be',
#   'me.',
#   'another',
#   'bite',
#   'it?',
#   'believe',
#   'remind',
#   'make',
#   'me',
#   'the',
#   'a',
#   'the',
#   'elbow',
#   'spend',
#   'line',
#   'it',
#   'Target',
#   'be',
#   'live',
#   'do',
#   'be',
#   'give',
#   'be',
#   'attempting',
#   'do',
#   'do',
#   'do',
#   'do',
#   'understand',
#   'try',
#   'get',
#   'this',
#   'give',
#   'be',
#   'the',
#   'some.',
#   'achieve',
#   'prepare',
#   'the',
#   'level',
#   'worry',
#   'be',
#   'have',
#   'have',
#   'have',
#   'you?”',
#   'put',
#   'you?”',
#   'me',
#   'have',
#   'it.',
#   'be',
#   'articulate',
#   'the',
#   'narrate,',
#   'explain',
#   'provide',
#   'make',
#   'communicate',
#   'attempt',
#   'go,',
#   'get',
#   'let',
#   'surprise.',
#   'do.',
#   'the',
#   'get',
#   'appear',
#   'him.',
#   'spend',
#   'use',
#   'my',
#   'the',
#   'be',
#   'employ',
#   'express',
#   'gain',
#   'have',
#   'have',
#   'yours.”',
#   'say,',
#   'the',
#   'your',
#   'put',
#   'pasture.',
#   'be',
#   'be',
#   'me,',
#   'me,',
#   'me',
#   'your',
#   'me',
#   'the',
#   'go',
#   'your',
#   'be',
#   'say.”',
#   'sort',
#   'break',
#   'men',
#   'the',
#   'be',
#   'a',
#   'know',
#   'be',
#   'just',
#   'wait',
#   'college',
#   'be',
#   'be',
#   'know',
#   'be',
#   'discern',
#   'act',
#   'say',
#   'keep',
#   'live…”',
#   'the',
#   'turn',
#   'be',
#   'just',
#   'yourself?',
#   'narrate',
#   'find',
#   'find',
#   'literature.',
#   'be',
#   'be',
#   'the',
#   'dissociation',
#   'me.',
#   'her,',
#   'a',
#   'show',
#   'me',
#   'just',
#   'it.',
#   'the',
#   'pick',
#   'write',
#   'college,',
#   'teach.',
#   'blow',
#   'speak…',
#   'our',
#   'be',
#   'forget',
#   'get',
#   'a',
#   'destroy',
#   'serve',
#   'me.',
#   'just',
#   'collect',
#   'give',
#   'express',
#   'the',
#   'the',
#   'the',
#   'turn',
#   'go',
#   'emerge',
#   'Jac,',
#   'really',
#   'me.',
#   'tell',
#   'at',
#   'wonder',
#   'school',
#   'do',
#   'make',
#   'her?”',
#   'conqueror',
#   'force',
#   'ripple',
#   'the',
#   'be',
#   'conjure',
#   'be',
#   'negotiate',
#   'date.”',
#   'just',
#   'be',
#   'try',
#   'save',
#   'learn.”',
#   'receive',
#   'poeticize',
#   'bolster',
#   'lay',
#   'modulate.',
#   'be',
#   'this',
#   'form',
#   'kind',
#   'emotionally',
#   'do',
#   'not',
#   'not',
#   'find',
#   'not',
#   'romanticize',
#   'defend',
#   'say',
#   'try',
#   'get',
#   'offer',
#   'him,',
#   'him,',
#   'smoothly',
#   'go',
#   'the',
#   'put',
#   'crawl.',
#   'this',
#   'her',
#   'a',
#   'the',
#   'the',
#   'push',
#   'have',
#   'o’er',
#   'make',
#   'try',
#   'make',
#   'be',
#   'understand',
#   'make',
#   'entertain',
#   'be',
#   'the',
#   'me',
#   'me',
#   'me',
#   'me',
#   'reflect',
#   'your'],
#  'conform': ['to'],
#  'conventional': ['comedic'],
#  'comedic': ['tactics,', 'lens,'],
#  'tactics,': ['offers'],
#  'offers': ['a'],
#  'fresh': ['perspective', 'rug.'],
#  'perspective': ['on'],
#  'gender': ['dynamics,'],
#  'dynamics,': ['sexual'],
#  'sexual': ['expectations,',
#   'identity',
#   'skills',
#   'experience,',
#   'running',
#   'experience'],
#  'expectations,': ['and'],
#  'often-comical': ['reality'],
#  'reality': ['of'],
#  'embodying': ['a', 'the'],
#  '“thinking,': ['feeling,'],
#  'feeling,': ['desiring'],
#  'desiring': ['body”'],
#  'body”': ['in'],
#  'in': ['a',
#   'the',
#   'a',
#   'college.',
#   'a',
#   'windowsills,',
#   'my',
#   'a',
#   'its',
#   'a',
#   'the',
#   'this',
#   'that',
#   'its',
#   'the',
#   'his',
#   'theory…',
#   'theory,',
#   'the',
#   'its',
#   'that',
#   'this',
#   'the',
#   'the',
#   'the',
#   'crinkly,',
#   'the',
#   'the',
#   'The',
#   'that',
#   'that',
#   'or',
#   'my',
#   'the',
#   'a',
#   'a',
#   'cellophane',
#   'this',
#   'the',
#   'this',
#   'this',
#   'favor',
#   'the',
#   'the',
#   'the',
#   'the',
#   'myself,',
#   'two',
#   'her',
#   'the',
#   'this',
#   'there,',
#   'gym',
#   'the',
#   'and',
#   'gym.',
#   'the',
#   'the',
#   'a',
#   'and',
#   'that',
#   'this',
#   'that',
#   'a',
#   'a',
#   'there,',
#   'the',
#   'there,',
#   'your',
#   'your',
#   'the',
#   'my',
#   'my',
#   'at',
#   'my',
#   'the',
#   'the',
#   'the',
#   'her.”',
#   'college.',
#   'her”',
#   'this',
#   'my',
#   'the',
#   'someone’s',
#   'this',
#   'this',
#   'a',
#   'the',
#   'my',
#   'the',
#   'those',
#   'a',
#   'sixth',
#   'seventh,',
#   'high',
#   'your',
#   'there?”',
#   'me',
#   'me',
#   'the',
#   'the',
#   'an',
#   'it.',
#   'those',
#   'this',
#   'this',
#   'a',
#   'it,',
#   'the',
#   'a',
#   'a',
#   'here.”',
#   'order',
#   'sunglasses.',
#   'the',
#   'general.',
#   'high',
#   'that',
#   'my',
#   'my',
#   'your',
#   'this',
#   'shorts.',
#   'fear.',
#   'front',
#   'the',
#   'my',
#   'this',
#   'good',
#   'my',
#   'me',
#   'this',
#   'front',
#   'college',
#   'this',
#   'a',
#   'the',
#   'my',
#   'a',
#   'Nabokov’s',
#   'a',
#   'literature,',
#   'the',
#   'the',
#   'on',
#   'my',
#   'my',
#   'my',
#   'a',
#   'neckties',
#   'high',
#   'no',
#   'a',
#   'a',
#   'the',
#   'every',
#   'the',
#   'the',
#   'some',
#   'my',
#   'beautiful',
#   'my',
#   'their',
#   'the',
#   'college…',
#   'college,',
#   'some',
#   'this',
#   'this',
#   'the',
#   'the',
#   'me?',
#   'a',
#   'this',
#   'an',
#   'my',
#   'yet',
#   'the',
#   'your',
#   'a',
#   'my',
#   'a',
#   'closed.',
#   'the',
#   'real',
#   'case',
#   'a',
#   'his',
#   'the',
#   'this',
#   'a',
#   'a',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   '2012,',
#   'every',
#   'this',
#   'the',
#   'the',
#   'the',
#   'the',
#   'coffee',
#   'the',
#   'the',
#   'your',
#   'town.',
#   'the',
#   'a',
#   'being',
#   'the',
#   'awe,',
#   'humble',
#   'a',
#   'my',
#   'my',
#   'the',
#   'its',
#   '“The'],
#  'society': ['filled'],
#  'filled': ['with'],
#  'contradictions.': ['Through'],
#  'Through': ['her'],
#  'her': ['insightful',
#   'is',
#   'to',
#   'coming',
#   'a',
#   'older',
#   'role',
#   'demonstration',
#   'lesson',
#   'global',
#   'out',
#   'yesterday.”',
#   'jumps',
#   'every',
#   'way',
#   'potential'],
#  'insightful': ['and'],
#  'lens,': ['Novak'],
#  'navigates': ['the'],
#  'complexities': ['of'],
#  'identity': ['and'],
#  'expression,': ['making'],
#  'making': ['“Get', 'eye', 'a', 'sure.', 'sure,'],
#  'Knees”': ['a'],
#  'thought-provoking': ['reflection'],
#  'reflection': ['on'],
#  'absurdity': ['of'],
#  'human': ['sexuality.', 'kind', 'form', 'tragedy.', 'absurdities'],
#  'sexuality.': ['*'],
#  '*': ['*', '*', '[“Like', 'Name*'],
#  '[“Like': ['a'],
#  'Prayer”': ['by'],
#  'Madonna': ['playing]'],
#  'playing]': ['[horn'],
#  '[horn': ['honking]'],
#  'honking]': ['♪'],
#  '♪': ['Life',
#   '♪',
#   'Everyone',
#   '♪',
#   'I',
#   '♪',
#   'And',
#   '♪',
#   'Home',
#   '[crowd',
#   'When',
#   '♪',
#   'It’s',
#   '♪',
#   'I’m',
#   '♪',
#   'I',
#   '♪',
#   'In',
#   '♪',
#   'I',
#   '♪',
#   'Just',
#   '♪',
#   'You',
#   'Thank',
#   'Just',
#   '♪',
#   'I’ll',
#   '♪',
#   'It’s',
#   '♪',
#   'Oh',
#   '♪',
#   'Just',
#   '♪',
#   'I’ll',
#   '♪',
#   'It’s',
#   '♪',
#   'Whoa',
#   '♪',
#   'Just',
#   '♪',
#   'Your',
#   '♪',
#   'Just',
#   '♪',
#   'You',
#   '♪',
#   'Just',
#   '♪',
#   'You',
#   '♪',
#   'Just',
#   '♪',
#   'No',
#   '♪',
#   'Just',
#   '♪',
#   'Your',
#   '♪',
#   'Just',
#   '♪',
#   'You',
#   '♪',
#   'Just',
#   '♪',
#   'You',
#   '♪',
#   'Just',
#   '♪',
#   'No',
#   '♪',
#   'Your',
#   '♪',
#   'Like',
#   '[song'],
#  'Life': ['is'],
#  'is': ['a',
#   'the',
#   'your',
#   'a',
#   'a',
#   'I',
#   '“penis”',
#   'a',
#   'our',
#   'a',
#   'one',
#   'clearly',
#   'the',
#   'that',
#   '“What?',
#   'enough,',
#   'in',
#   'the',
#   'its',
#   'a',
#   'a',
#   'a…',
#   'the',
#   'the',
#   'beautiful,',
#   'beautiful,',
#   'beautiful',
#   'beautiful.',
#   'beautiful.',
#   'the',
#   'the',
#   'a',
#   'a',
#   'a',
#   'the',
#   'the',
#   'the',
#   'the',
#   'my',
#   'the',
#   'for',
#   'over.',
#   'clearly',
#   'over',
#   'something',
#   'thin',
#   'always',
#   'that',
#   'to',
#   'over,',
#   'someone',
#   'a',
#   'unimpeachable?',
#   'authentic',
#   'a',
#   'authenticity.',
#   'me',
#   'what',
#   'entirely',
#   'kind',
#   'sort',
#   'no',
#   'that',
#   'just',
#   'no',
#   'there',
#   'something',
#   'like,',
#   'sort',
#   'my',
#   'gonna',
#   'no',
#   'hard.',
#   'not',
#   '“puncture,”',
#   'a',
#   'into',
#   'supposed',
#   'here.',
#   'here.',
#   'more',
#   'as',
#   'true.',
#   'wasted',
#   'and',
#   'you',
#   'when',
#   'that',
#   'stuffed',
#   'not',
#   'dumb',
#   'counting',
#   'supposed',
#   'you',
#   'the',
#   'one',
#   'a',
#   'a',
#   'an',
#   'you',
#   'why',
#   'why',
#   'almost',
#   'almost',
#   'no',
#   'what',
#   'just',
#   'coming.',
#   'coming.',
#   'coming',
#   'try',
#   'coming.',
#   'how',
#   'our',
#   'intended',
#   'the',
#   'a',
#   'to',
#   'my',
#   'not',
#   'about',
#   'the',
#   'the',
#   'not',
#   'inherently',
#   'a',
#   'poorly',
#   'not,',
#   'no',
#   'to',
#   'not',
#   'undiminished.',
#   'how'],
#  'mystery': ['♪', 'with', '♪', '♪'],
#  'Everyone': ['must', 'expresses'],
#  'must': ['stand', 'be', 'we', 'wipe'],
#  'stand': ['alone', 'still', 'around', 'in', 'by'],
#  'alone': ['♪', 'before', 'on'],
#  'I': ['hear',
#   'wanna',
#   'can',
#   'mean,',
#   'mean…',
#   'am',
#   'think',
#   'do',
#   'think',
#   'think',
#   'feel',
#   'gotta',
#   'know',
#   'feel',
#   'just',
#   'do',
#   'like',
#   'know',
#   'can’t',
#   'used',
#   'gave',
#   'grew',
#   'grew',
#   'just',
#   'wanted',
#   'hope',
#   'take',
#   'mean,',
#   'don’t',
#   'can’t',
#   'like',
#   'know,',
#   'know',
#   'stand',
#   'much',
#   'prefer',
#   'look',
#   'look',
#   'look',
#   'can’t',
#   'die',
#   'sort',
#   'want.',
#   'want',
#   'wanna',
#   'want',
#   'know',
#   'mean,',
#   'mean,',
#   'just,',
#   'wanna',
#   'make',
#   'wanna',
#   'wanna',
#   'want',
#   'want',
#   'don’t',
#   'do.',
#   'watch',
#   'mean,',
#   'mean,',
#   'mean,',
#   'mean,',
#   'certainly',
#   'will',
#   'look',
#   'am',
#   'know',
#   'do,',
#   'do,',
#   'when',
#   'can’t',
#   'mean,',
#   'feel',
#   'don’t.',
#   'don’t',
#   'think',
#   'felt',
#   'wouldn’t',
#   'don’t',
#   'don’t',
#   'mean',
#   'think',
#   'think',
#   'don’t',
#   'think',
#   'think…',
#   'think…',
#   'think',
#   'don’t',
#   'mean,',
#   'call',
#   'see',
#   'think',
#   'call',
#   'don’t',
#   'call',
#   'might',
#   'love',
#   'call',
#   'treat',
#   'treat',
#   'don’t',
#   'believe',
#   'mean,',
#   'show',
#   'feel',
#   'have',
#   'showing',
#   'think',
#   'think',
#   'don’t',
#   'don’t',
#   'mean,',
#   'mean,',
#   'only',
#   'appreciate',
#   'agree,',
#   'step',
#   'mean,',
#   'love',
#   'think',
#   'may',
#   'see',
#   'saying',
#   'guess',
#   'mean,',
#   'saw',
#   'see',
#   'get',
#   'feel',
#   'feel',
#   'feel',
#   'always',
#   'still',
#   'like',
#   'don’t',
#   'started',
#   'remember',
#   'have',
#   'go,',
#   'can',
#   'dab',
#   'have',
#   'think',
#   'have',
#   'don’t',
#   'would',
#   'don’t',
#   'occasionally',
#   'guess.',
#   'understood',
#   'was',
#   'was',
#   'always',
#   'know',
#   'feel',
#   'guess',
#   'appreciated…',
#   'don’t',
#   'mean,',
#   'see',
#   'had',
#   'asked,',
#   'mean',
#   'mean,',
#   'didn’t',
#   'think',
#   'mean,',
#   'get',
#   'mean,',
#   'mean,',
#   'fear',
#   'may',
#   'think',
#   'like',
#   'stand',
#   'am',
#   'get',
#   'mean,',
#   'mean,',
#   'mean,',
#   'mean,',
#   'could',
#   'was',
#   'was',
#   'could',
#   'could',
#   'feel',
#   'would',
#   'believe',
#   'was',
#   'know',
#   'don’t',
#   'don’t',
#   'tell',
#   'tell',
#   'hold',
#   'find',
#   'play',
#   'know',
#   'would',
#   'had',
#   'was',
#   'wouldn’t',
#   'think',
#   'planned',
#   'get',
#   'feel',
#   'go,',
#   'do',
#   'know',
#   'know',
#   'let',
#   'wouldn’t',
#   'think',
#   'was',
#   'don’t',
#   'do',
#   'do',
#   'have',
#   'have',
#   'don’t',
#   'don’t',
#   'lift',
#   'mean,',
#   'don’t',
#   'feel',
#   'get',
#   'try',
#   'get',
#   'will',
#   'find',
#   'back',
#   'say,',
#   'thank',
#   'will',
#   'become',
#   'gently',
#   'put',
#   'just',
#   'loved',
#   'was',
#   'bite',
#   'was',
#   'said',
#   'have',
#   '“could”',
#   'mean…',
#   'wanna',
#   'have',
#   'believe',
#   'knew.',
#   'believe',
#   'knew.',
#   'think',
#   'was',
#   'am?”',
#   'don’t.”',
#   'be',
#   'ever',
#   'mean,',
#   'had',
#   'think',
#   'wanna',
#   'get',
#   'like',
#   'mean,',
#   'mean,',
#   'think',
#   'prefer',
#   'much',
#   'prefer',
#   'try',
#   'have',
#   'think',
#   'invited',
#   'made',
#   'love',
#   'love',
#   'always',
#   'don’t,',
#   'think',
#   'don’t',
#   'don’t',
#   'think',
#   'heard',
#   'know',
#   'take',
#   'wasn’t',
#   'used',
#   'tried',
#   'failed',
#   'backed',
#   'realized',
#   'was',
#   'had',
#   'had',
#   'guess.',
#   'love',
#   'can’t',
#   'can’t',
#   'know',
#   'mean,',
#   'make',
#   'took',
#   'get',
#   'am',
#   'am',
#   'really',
#   'mean,',
#   'recognize',
#   'collapse',
#   'did',
#   'wanted',
#   'get',
#   'hear',
#   'can.',
#   'mean,',
#   'wanna',
#   'feel',
#   'actually',
#   'was',
#   'guess',
#   'said.',
#   'see',
#   'could',
#   'didn’t',
#   'didn’t',
#   'experienced',
#   'was',
#   'knew',
#   'had',
#   'was',
#   'know,',
#   'was',
#   'don’t',
#   'was',
#   'can',
#   'mean,',
#   'could',
#   'express',
#   'mean,',
#   'wanna',
#   'was',
#   'realize',
#   'won’t',
#   'know',
#   'don’t',
#   'can',
#   'hear',
#   'sewed',
#   'make',
#   'thought',
#   'had',
#   'mean,',
#   'hate',
#   'see',
#   'don’t',
#   'just',
#   'had',
#   'get',
#   'was',
#   'wanna',
#   'mean,',
#   'want',
#   'want',
#   'take',
#   'gave',
#   'never',
#   'had',
#   'hadn’t',
#   'got',
#   'think',
#   'mean,',
#   'don’t',
#   'wasn’t',
#   'was',
#   'can',
#   'could',
#   'know',
#   'wasn’t',
#   'was',
#   'was',
#   'mean,',
#   'was',
#   'sensed',
#   'felt',
#   'also',
#   'think',
#   'don’t',
#   'think',
#   'think',
#   'seem',
#   'seem',
#   'hear',
#   'can',
#   'see',
#   'directed',
#   'drop',
#   'say',
#   'know',
#   'eat',
#   'chew',
#   'spit',
#   'didn’t…',
#   'didn’t',
#   'could',
#   'could',
#   'mean,',
#   'mean,',
#   'could',
#   'could',
#   'think.',
#   'mean,',
#   'just…',
#   'couldn’t',
#   'were',
#   'felt',
#   'could',
#   'did,',
#   'scooped',
#   'knew',
#   'just…',
#   'kind',
#   'scoop',
#   'get',
#   'decide',
#   'don’t',
#   'wanna',
#   'go,',
#   'can',
#   'go,',
#   'just',
#   'don’t',
#   'just…',
#   'was',
#   'couldn’t',
#   'mean,',
#   'don’t',
#   'mean…',
#   'don’t',
#   'know',
#   'don’t',
#   'have',
#   'don’t',
#   'thought',
#   'am.',
#   'am.',
#   'don’t',
#   'don’t',
#   'know',
#   'have',
#   'turned',
#   'was',
#   'was',
#   'mean,',
#   'was',
#   'was',
#   'did',
#   'go,',
#   'imagine',
#   'imagine',
#   'imagine',
#   'mean,',
#   'mean,',
#   'go,',
#   'go,',
#   'go,',
#   'know',
#   'go',
#   'might',
#   'watch',
#   'feel',
#   'was',
#   'was',
#   'always',
#   'knew',
#   'swallowed',
#   'don’t',
#   'always',
#   'always',
#   'knew',
#   'mean,',
#   'wanted',
#   'knew',
#   'knew…',
#   'knew',
#   'had',
#   'went',
#   'had',
#   'felt',
#   'felt',
#   'highly',
#   'was',
#   'had',
#   'had',
#   'can',
#   'might',
#   'was…',
#   'was',
#   'was',
#   'eventually',
#   'really',
#   'blew',
#   'mean,',
#   'simply',
#   'mean,',
#   'don’t',
#   'wasn’t',
#   'wouldn’t',
#   'wasn’t',
#   'think',
#   'will',
#   'think',
#   'mean,',
#   'would',
#   'could',
#   'conjure',
#   'wish',
#   'have',
#   'have',
#   'know…',
#   'know',
#   'feel',
#   'look',
#   'mean,',
#   'look',
#   'can’t',
#   'can',
#   'just',
#   'mean,',
#   'feel',
#   'have',
#   'do,',
#   'stand',
#   'go',
#   'run',
#   'don’t',
#   'really',
#   'say',
#   'just',
#   'like',
#   'like',
#   'was.”',
#   'was',
#   'become?',
#   'was',
#   'was',
#   'was',
#   'was',
#   'guess.',
#   'always',
#   'was',
#   'still',
#   'was',
#   'started',
#   'was',
#   'went',
#   'mean,',
#   'don’t',
#   'could’ve',
#   'go,',
#   'shook',
#   'forced',
#   'join',
#   'have',
#   'gather…',
#   'gather',
#   'try',
#   'know',
#   'am.',
#   'will',
#   'think',
#   'tell',
#   'get',
#   'can’t',
#   'tell',
#   'cry',
#   'guess.',
#   'get',
#   'wonder',
#   'say',
#   'continue',
#   'kept',
#   'get',
#   'can',
#   'guess.',
#   'was',
#   'was',
#   'went',
#   'bought',
#   'know',
#   'know',
#   'was',
#   'was',
#   'wasn’t',
#   'was',
#   'mean,',
#   'wanna',
#   'feel',
#   'feel…',
#   'feel',
#   'know',
#   'cast',
#   'poeticize',
#   'love',
#   'coddle',
#   'have',
#   'do?',
#   'go',
#   'have',
#   'was',
#   'always',
#   'love',
#   'know',
#   'mean',
#   'know',
#   'love',
#   'do',
#   'don’t',
#   'mean,',
#   'wanted',
#   'remembered',
#   'say',
#   'say',
#   'give',
#   'give',
#   'give',
#   'mean,',
#   'did',
#   'kneel',
#   'drink',
#   'take',
#   'guess',
#   'want',
#   'want',
#   'want',
#   'am,',
#   'overreach?',
#   'do,',
#   'hope',
#   'know',
#   'put',
#   'win',
#   'shall',
#   'accept'],
#  'hear': ['you',
#   'it.',
#   'the',
#   'his',
#   'you',
#   'you,',
#   'the',
#   'them',
#   'is',
#   'the'],
#  'you': ['call',
#   'call',
#   'there',
#   'there',
#   'know…',
#   'feel',
#   'know,',
#   'know?',
#   'know,',
#   'know.',
#   'show',
#   'get',
#   'know,',
#   'bring',
#   'didn’t',
#   'people',
#   'see',
#   'like,',
#   'take',
#   'very',
#   'gotta',
#   'know?',
#   'see,',
#   'know,',
#   'know.',
#   'know.',
#   'to',
#   'just',
#   'don’t',
#   'talk',
#   'guys',
#   'don’t',
#   'don’t',
#   'try',
#   'know?',
#   'were',
#   'did',
#   'know?',
#   'ever',
#   'know,',
#   'insist',
#   'would,',
#   'know,',
#   'know,',
#   'know.',
#   'people.',
#   'know?',
#   'gotta',
#   'know?',
#   'say',
#   'believe',
#   'know,',
#   'see',
#   'know?',
#   'hear',
#   'know,',
#   'love',
#   'respect',
#   'do.',
#   'didn’t',
#   'can.”',
#   'know,',
#   'know?',
#   'know?',
#   'can',
#   'know.',
#   'know,',
#   'know,',
#   'know.',
#   'the',
#   'know.',
#   'know.',
#   'know.',
#   'know,',
#   'see',
#   'know.',
#   'in',
#   'awake?”',
#   'married.',
#   'know.',
#   'sad',
#   'don’t',
#   'in',
#   'know,',
#   'out',
#   'can’t',
#   'bury',
#   'know.',
#   'better',
#   'caused.',
#   'into',
#   'know,',
#   'know…',
#   'know,',
#   'have',
#   'go',
#   'put',
#   'toothy',
#   'gonna',
#   'know,',
#   'know,',
#   'can',
#   'girls',
#   'know,',
#   'know,',
#   'know?',
#   'know.',
#   'know.',
#   'know.',
#   'know,',
#   'see?',
#   'split',
#   'get',
#   'see…',
#   'see…',
#   'see',
#   'can',
#   'want,”',
#   'want.”',
#   'want.”',
#   'won’t',
#   'understand?',
#   'endless',
#   'endless',
#   'one',
#   'have',
#   'can’t,',
#   'mind',
#   'do',
#   'were',
#   'did',
#   'did',
#   'this',
#   'know.',
#   'this',
#   'understand',
#   'think',
#   'like',
#   'can’t',
#   'know?',
#   'know,',
#   'guys',
#   'for',
#   'do,',
#   'to',
#   'really',
#   'don’t',
#   'found',
#   'found',
#   'know,',
#   'use',
#   'blame',
#   'blame',
#   'couldn’t',
#   'see?',
#   'get',
#   'were',
#   'feel',
#   'feel',
#   'mean.”',
#   'can,',
#   'know,',
#   'know,',
#   'know',
#   'know.',
#   'know?',
#   'know.',
#   'penetrate,',
#   'penetrate,',
#   'penetrate',
#   'in,',
#   'know',
#   'look',
#   'didn’t',
#   'could',
#   'put',
#   'don’t',
#   'don’t',
#   'don’t',
#   'know',
#   'entered',
#   'know?',
#   'for',
#   'choke',
#   'want?',
#   'see?',
#   'don’t',
#   'know.',
#   'can',
#   'know,',
#   'know,',
#   'know,',
#   'speed-read',
#   'know,',
#   'know.',
#   'know,',
#   'haven’t',
#   'make',
#   'see,',
#   'tell',
#   'become',
#   'feel',
#   'see?',
#   'can’t',
#   'can',
#   'a',
#   'land',
#   'know,',
#   'done',
#   'given',
#   'know,',
#   'give',
#   'lubricate',
#   'wrap',
#   'smile.”',
#   'see.',
#   'are',
#   'solved',
#   'bad',
#   'feel',
#   'gotta',
#   'ask',
#   'know,',
#   'had',
#   'had',
#   'know',
#   'know.',
#   'know,',
#   'know.',
#   'know.',
#   'have',
#   'put',
#   'put',
#   'know.',
#   'know.',
#   'know?',
#   'see…',
#   'see?',
#   'know.',
#   'know',
#   'felt',
#   'know',
#   'have',
#   'know,',
#   'know.',
#   'need.',
#   'know,',
#   'know,',
#   'know,',
#   'know,',
#   'know,',
#   'want?”',
#   'then,',
#   'to',
#   'know?',
#   'like',
#   'know.',
#   'know,',
#   'know.',
#   'know.',
#   'heard',
#   'made',
#   'do',
#   'talk,',
#   'can',
#   'can',
#   'doing',
#   'refuse',
#   'know,',
#   'use',
#   'dilute',
#   'seem',
#   'couldn’t',
#   'would,',
#   'pig.',
#   'know,',
#   'know.',
#   'know?',
#   'know?',
#   'wind',
#   'would’ve',
#   'know?',
#   'know…',
#   'understand?',
#   'through.',
#   'people',
#   'at',
#   'know?',
#   'know',
#   'see',
#   'gonna',
#   'gonna',
#   'can',
#   'need',
#   'listen',
#   'need',
#   'know?',
#   'know.',
#   'know,',
#   'working',
#   'suburban',
#   'know,',
#   'know?',
#   'bite',
#   'there',
#   'know?',
#   'know',
#   'people.',
#   'know,',
#   'can',
#   'know.',
#   'see?',
#   'see,',
#   'back',
#   'know.',
#   'know,',
#   'really',
#   'said…',
#   'take',
#   'hook…”',
#   'gotta',
#   'know',
#   'shed',
#   'shed',
#   'know.',
#   'gotta',
#   'gotta',
#   'to',
#   'die,',
#   'know,',
#   'know',
#   'stare,',
#   'one',
#   'know',
#   'our',
#   'just',
#   'just',
#   'just',
#   'rob',
#   'try',
#   'know.”',
#   'know.',
#   'look',
#   'see',
#   'see',
#   'not',
#   'know.',
#   'get',
#   'know,',
#   'like',
#   'know.',
# ...
#  'would,': ['wouldn’t', 'you'],
#  'wouldn’t': ['you?',
#   'use',
#   'even',
#   'even',
#   'be,',
#   'I?',
#   'have',
#   'they,',
#   'quickly'],
#  'you?': ['No,', 'Keep'],
#  'needs,': ['its'],
#  'wants,': ['you'],
#  'hideousities': ['to'],
#  'historically': ['call', 'and'],
#  'heterosexual': ['woman,'],
#  'woman,': ['and'],
#  'no,': ['I’m',
#   'true',
#   'it’s',
#   'I',
#   'they',
#   'I',
#   'I',
#   'if',
#   'you',
#   'that',
#   'no,',
#   'that',
#   'I',
#   'not',
#   'but',
#   'regard'],
#  'proud.': ['[audience', 'You', 'It’s'],
#  'patent': ['humiliation'],
#  'humiliation': ['in'],
#  'day': ['and', 'when', 'perhaps', 'just', 'like'],
#  'age.': ['I'],
#  'thinking.': ['Does'],
#  'Does': ['she', 'the'],
#  'even': ['read?',
#   'make',
#   'faster',
#   'more',
#   'blink',
#   'if',
#   'have',
#   'spin',
#   'once',
#   'talk',
#   'passed',
#   'their',
#   'understand',
#   'though',
#   'in',
#   'a',
#   'think',
#   'is'],
#  'read?': ['[audience'],
#  'yet,': ['you'],
#  'when': ['I’m',
#   'I',
#   'I',
#   'I',
#   'they',
#   'I',
#   'she',
#   'I',
#   'it',
#   'it',
#   'she',
#   'you',
#   'I',
#   'someone',
#   'she',
#   'I',
#   'I’m',
#   'they’re',
#   'you',
#   'you',
#   'you',
#   'I',
#   'I',
#   'someone',
#   'you',
#   'you',
#   'you',
#   'he’s',
#   'it’s',
#   'they',
#   'I'],
#  'a…': ['a', '[clicking]', '“I', 'It’s', 'All', 'it’s'],
#  'girl': ['with', 'for', 'for', 'with'],
#  'ponytail': ['just'],
#  'lusting': ['after'],
#  'common': ['shaft?'],
#  'shaft?': ['[audience'],
#  'Oh,': ['I', 'yeah,', 'the', 'and', 'we', 'it', 'yes.', 'he', 'I'],
#  'believe': ['it',
#   'that’s',
#   'you',
#   'is',
#   'the',
#   'that',
#   'that',
#   'in',
#   'that',
#   'I',
#   'that',
#   'this,',
#   'it.',
#   'it,',
#   'it?'],
#  'happened': ['to', 'to'],
#  'simple': ['cylinder,', 'machinery', 'cylinder…”'],
#  'cylinder,': ['that…'],
#  'familiar': ['tube,'],
#  'tube,': ['that'],
#  'object': ['of'],
#  'seemingly': ['no', 'self-appointed', 'self-appointed'],
#  'no': ['nuance.',
#   'one',
#   'one',
#   'play.',
#   'play',
#   'way.',
#   'way',
#   'bone',
#   'bone',
#   'bone',
#   'great',
#   'matter',
#   'bone',
#   'bone',
#   'rules,',
#   'one',
#   'word',
#   'way',
#   'words,',
#   'dignity.',
#   'way',
#   'stink',
#   'way,',
#   'words.',
#   'matter',
#   'screams',
#   'hurry',
#   'roles.',
#   'spring',
#   'swagger.',
#   'distinguishing',
#   'one',
#   'one',
#   'clue',
#   'clue',
#   'poetic',
#   'clue',
#   'foolish',
#   'lesson.'],
#  'nuance.': ['The'],
#  'word': ['I’m',
#   '“cock”',
#   'and',
#   'penis',
#   'penis',
#   'penis',
#   '“cock”',
#   '“penis”',
#   'penis',
#   'penetrate’s',
#   'for',
#   '“like.”',
#   "‘like.'”",
#   'over',
#   'so',
#   '“like”',
#   'you'],
#  'avoiding': ['saying,'],
#  'saying,': ['of', '“It’s', '“Tenderest'],
#  '“penis”': ['and', 'should'],
#  'I’ve': ['said',
#   'never',
#   'been',
#   'always',
#   'stood',
#   'stood',
#   'overthought',
#   'done',
#   'been',
#   'never',
#   'never',
#   'hated',
#   'always',
#   'got',
#   'got',
#   'never',
#   'cleared',
#   'told',
#   'learned'],
#  'better?': ['No,'],
#  'don’t.': ['[audience'],
#  'love': ['the',
#   'and',
#   'your',
#   'when',
#   'of',
#   'the',
#   'the',
#   'the',
#   'on',
#   'a',
#   'letter…',
#   'behind',
#   'letter?',
#   'you',
#   'to',
#   'to',
#   'to',
#   'a',
#   'to',
#   'him.'],
#  'word,': ['few', 'it', 'but'],
#  'few': ['do,', 'courtesies', 'good', 'clumsy'],
#  'A': ['big',
#   '“ck,',
#   'burger',
#   'proper',
#   'proper',
#   'little…',
#   'hint…',
#   'Viking',
#   'whiff',
#   'penis,',
#   'rock',
#   'penis',
#   'child’s',
#   'sort',
#   'fate',
#   'couple',
#   'smooth,'],
#  'big': ['part', 'concept', 'man.', 'one', 'deal', 'questions'],
#  'part': ['of', 'of', 'of'],
#  'probably': ['rather', 'describing', 'stop', 'try', 'reading'],
#  'rather': ['say', 'hear', 'build', 'just'],
#  '“cock”': ['for', 'clearly,', 'is', 'for'],
#  'people.': ['I', '[audience', 'It'],
#  'lot': ['of', 'outside', 'on', 'of', 'of', 'of'],
#  'you’d': ['rather', 'know', 'just'],
#  'boyfriends': ['sure'],
#  'did,': ['you', 'top'],
#  'Cock': ['is'],
#  'has': ['a',
#   'a',
#   'the',
#   'kind',
#   'more',
#   'this',
#   '50%',
#   'already',
#   'to',
#   'already',
#   'just',
#   'arrived',
#   'always'],
#  'dignity': ['to', 'in', 'was', 'of'],
#  'kick': ['it'],
#  'back': ['of',
#   'to',
#   'to',
#   'in',
#   'the',
#   'away.',
#   'to',
#   'on',
#   'of',
#   'up',
#   'to',
#   'of',
#   'impossibly',
#   'your',
#   'and',
#   'to'],
#  'mouth.': ['“Co”', '[audience', '[audience'],
#  '“Co”': ['but'],
#  '“ck.”': ['It'],
#  'It': ['lands.',
#   'lands',
#   'sounds',
#   'cannot',
#   'springs',
#   'sees',
#   'fills',
#   'is',
#   'dies',
#   'just…',
#   'slipped',
#   'holds.',
#   'holds.',
#   'embodies',
#   'just',
#   'comes',
#   'must',
#   'just',
#   'didn’t',
#   'felt',
#   'was',
#   'could',
#   'could',
#   'just',
#   'seemed',
#   'is',
#   'seemed',
#   'was',
#   'was',
#   'doesn’t',
#   'sort',
#   'was',
#   'works.',
#   'is',
#   'almost',
#   'would',
#   'remains',
#   'All”'],
#  'lands.': ['A'],
#  '“ck,': ['ck.”'],
#  'ck.”': ['It'],
#  'lands': ['on'],
#  'same': ['damn',
#   'with',
#   'way.',
#   'weird',
#   'with',
#   'spot',
#   'with',
#   'word',
#   'old',
#   'for'],
#  'damn': ['consonant', 'bite.”'],
#  'consonant': ['it'],
#  'started': ['on,', 'reading', 'young.', 'on', 'on', 'on', 'to'],
#  'on,': ['you'],
#  'Penis.': ['Penis', 'Penis.', '[chuckles]', 'Penis,'],
#  'Penis': ['just'],
#  'slips': ['out'],
#  'side': ['of', 'of', 'of', 'of', 'of'],
#  '“Penis.”': ['“I’m', '[moaning]'],
#  '“I’m': ['sorry.',
#   'awake.',
#   'just',
#   'the',
#   'sorry.',
#   'just',
#   'in',
#   'coming',
#   'the'],
#  'sorry.': ['Did', 'Are', 'Do'],
#  'Did': ['you'],
#  'something?”': ['“Well,'],
#  '“Well,': ['I’m', 'as', 'primarily', 'you', 'maybe'],
#  'anymore.”': ['“I', 'And'],
#  '“I': ['thought',
#   'think',
#   'see',
#   'killed',
#   'feel',
#   'mean,',
#   'don’t',
#   'think',
#   'know',
#   'recognize',
#   'penetrated',
#   'laid',
#   'don’t',
#   'just',
#   'don’t',
#   'doubt',
#   'can’t',
#   'don’t',
#   'don’t',
#   'feel',
#   'just',
#   'simply'],
#  'thought': ['a',
#   'about',
#   'of',
#   'of',
#   'of',
#   'they',
#   'the',
#   'it',
#   'the',
#   'there'],
#  'felt': ['something',
#   'like',
#   'this',
#   'that.”',
#   'like',
#   'pretty',
#   'like',
#   'like',
#   'like',
#   'natural.',
#   'teeth,',
#   'teeth.',
#   'they'],
#  'happen.”': ['You'],
#  'People': ['say,'],
#  '“Well': ['sure,', 'then,'],
#  'sure,': ['I', 'I’m', 'isn’t', 'you'],
#  'use': ['the', 'that', 'it', 'of', 'that'],
#  'penis': ['sexually,',
#   'is',
#   'lies',
#   'is',
#   'a',
#   'a',
#   'a',
#   'a',
#   'is,',
#   'is',
#   'has',
#   'should',
#   'isn’t',
#   'to',
#   'is',
#   'is…',
#   'is',
#   'is',
#   'is',
#   'the',
#   'perfectly,',
#   'is',
#   'is',
#   'is',
#   'orgasm',
#   'is',
#   'is.”',
#   'at',
#   'when',
#   'is',
#   'you’re',
#   'that’s',
#   'as',
#   'is',
#   'anywhere',
#   'and',
#   'is',
#   '’cause',
#   'shall'],
#  'sexually,': ['it’s'],
#  'clinical.”': ['I'],
#  'voice': ['of', 'can', 'can', 'can', 'can', 'can'],
#  'clinician': ['in'],
#  'word.': ['I', 'I', 'You'],
#  'most': ['medical-sounding',
#   'feminine',
#   'sensitive',
#   'authentic',
#   'enjoy',
#   'iconic',
#   'of',
#   'worried',
#   'generous'],
#  'medical-sounding': ['word.'],
#  'mean': ['[chuckling]…', 'the', 'that', 'the', 'you’re…'],
#  '[chuckling]…': ['I'],
#  'problem': ['for',
#   'for',
#   'for',
#   'lies',
#   'with',
#   'is',
#   'in',
#   'with',
#   'of',
#   'is',
#   'and'],
#  'people…': ['I'],
#  'lies': ['in', 'in'],
#  'tender': ['emotionality.', 'syllable', 'penis.', 'nature.'],
#  'emotionality.': ['I'],
#  'sounds': ['accurate', 'like', 'strong,', 'like', 'in'],
#  'accurate': ['to'],
#  'soft': ['heartbeat.'],
#  'heartbeat.': ['Penis.'],
#  'Penis,': ['penis,'],
#  'penis,': ['penis,', 'penis.', 'you', 'it', 'like', 'I', 'you'],
#  'penis.': ['And', 'I’m', 'I’m', 'Like,', 'True', 'You', 'It’s', 'No,'],
#  'problem.': ['I', 'Pe…', 'The'],
#  'think…': ['I', 'I'],
#  'syllables': ['themselves'],
#  'themselves': ['too.', 'with'],
#  'too.': ['I', '[audience', 'Really.', 'You', '“You’d'],
#  'Rose-by-any-other-name': ['scenarios.'],
#  'scenarios.': ['No,'],
#  '“Pe-”': ['is'],
#  'clearly': ['a', 'the', 'in'],
#  'Pe…': ['Peener…'],
#  'Peener…': ['Pee-pee.'],
#  'Pee-pee.': ['You'],
#  'been': ['mocked',
#   'there',
#   'rewarded.',
#   'aware',
#   'a',
#   'distributed',
#   'for',
#   'standing',
#   'one',
#   'operational',
#   'entered.',
#   'afraid',
#   'afraid',
#   'destroyed.',
#   'proud.',
#   'proud.',
#   'shocked',
#   'however',
#   'turned',
#   'up',
#   'received',
#   'getting',
#   'slacking',
#   'my',
#   'more',
#   'talking'],
#  'mocked': ['for'],
#  'ages': ['and'],
#  'rightfully': ['so.'],
#  'so.': ['You', '[audience'],
#  'true…': ['the'],
#  'true': ['tender',
#   'respect…',
#   'respect',
#   'respect',
#   'love.',
#   'love,',
#   'love'],
#  'syllable': ['of'],
#  'devastation,': ['oh,'],
#  '“nis.”': ['It’s', '[audience'],
#  'time?': ['“Nis.”'],
#  '“Nis.”': ['“Nis.”', 'And'],
#  'why': ['no',
#   'no',
#   'I',
#   'are',
#   'I’ve',
#   'it',
#   'you’re',
#   'is',
#   'haven’t',
#   'haven’t',
#   'I',
#   'I',
#   'I',
#   'wouldn’t',
#   'as',
#   '“salad',
#   'we',
#   'we',
#   'we',
#   'reach'],
#  'speaks': ['of'],
#  'syllable.': ['That’s'],
#  'why…': ['that’s', 'why,'],
#  'says,': ['you', '‘No,'],
#  '“Show': ['me'],
#  'nis.”': ['[audience'],
#  'Wait': ['till', 'out'],
#  'till': ['you', 'they’re'],
#  'nis?': ['Nis-nis?'],
#  'Nis-nis?': ['They'],
#  'won’t': ['even', 'fully', 'know', 'be', 'be'],
#  'joke.': ['No,', 'There’s'],
#  'tender.': ['It', 'It’s'],
#  'cannot': ['be', 'be'],
#  'spoken.': ['No,'],
#  'clearly,': ['clearly…'],
#  'clearly…': ['“cock…”'],
#  '“cock…”': ['Clearly'],
#  'Clearly': ['“cock”'],
#  'sexy': ['word.'],
#  'issue.': ['There’s'],
#  'There’s': ['a', 'me.', 'a', 'no', 'no', 'just', 'something', 'a'],
#  'way,': ['it',
#   'just…',
#   'even',
#   'like,',
#   'the',
#   'you',
#   'you',
#   'you',
#   'like,',
#   'there’s',
#   'a',
#   'I'],
#  'becomes': ['unsexy.'],
#  'unsexy.': ['And'],
#  'cock,': ['I’m', 'I', 'it’s', 'I’m', 'I', 'that'],
#  'actually': ['calling', 'there', 'feel', 'mind'],
#  'calling': ['it'],
#  'telling': ['it', 'a', 'him'],
#  'wants': ['to'],
#  'hear.': ['[audience'],
#  'worrying': ['about'],
#  'feelings': ['of'],
#  'coddling': ['the'],
#  'ego': ['of'],
#  'humoring': ['the', 'it.'],
#  'Like,': ['when',
#   'if',
#   '“I’ll',
#   'I',
#   'if',
#   '“Oh',
#   'uh…',
#   'the',
#   '“What’s',
#   '“Wait,',
#   'two',
#   'through',
#   'you’re',
#   '“No.',
#   '“Sure,',
#   'quick,'],
#  'throw': ['it', 'myself', 'against'],
#  'away.': ['It’s', 'No,', 'I', 'I'],
#  'cock.': ['“Who’s', 'Do'],
#  '“Who’s': ['a'],
#  'cock?': ['You’re', 'You’re'],
#  'You’re': ['a',
#   'a',
#   'the',
#   'the',
#   'an',
#   'pretty',
#   'gonna',
#   'dead.',
#   'dead.”'],
#  'cock.”': ['[audience', 'Right?'],
#  'might': ['humor', 'want', 'feel', 'be', 'have', 'live', 'eventually'],
#  'humor': ['my'],
#  'nephew,': ['for'],
#  'friend’s': ['son,', 'house'],
#  'son,': ['you'],
#  'guys,': ['these', 'run,'],
#  'guys.': ['These'],
#  'These': ['little…', 'little', 'give'],
#  'little…': ['the', 'a', '[groans]'],
#  'person': ['I', 'in', 'in', 'who', 'that', 'to', 'to', 'in'],
#  'guy': ['below', 'who', 'that', 'I', 'I’ve,', 'in', 'you'],
#  'below': ['them.'],
#  'them.': ['Like…',
#   'And',
#   'And',
#   'You…',
#   'A',
#   'Not',
#   'I',
#   'Do',
#   'You',
#   'And',
#   'When',
#   '[sighs]'],
#  'Like…': ['when', 'like,'],
#  'treat': ['it', 'my', 'for'],
#  'nephew.': ['He’ll'],
#  'He’ll': ['come'],
#  'running': ['into', 'along.', 'start,', 'start', 'starts', 'start'],
#  'kitchen': ['where'],
#  'adults': ['are', 'at', 'that'],
#  'talking': ['wearing',
#   'about?',
#   'about',
#   'now,',
#   'like',
#   'with',
#   'at',
#   'and',
#   'for',
#   'to'],
#  'wearing': ['a'],
#  'monster': ['mask'],
#  'mask': ['or', 'of'],
#  'something,': ['and', '’cause', 'I…', 'that', 'I', 'I', 'just…', 'he'],
#  'we…': ['we'],
#  'we': ['see',
#   'come',
#   'proceed',
#   'can',
#   'could',
#   'worked',
#   'move',
#   'don’t',
#   'have',
#   'know',
#   'are',
#   'so',
#   'should',
#   'leave',
#   'do',
#   'all',
#   'hang',
#   'want',
#   'know.',
#   'know,',
#   'go',
#   'can',
#   'won’t',
#   'hung',
#   'not',
#   'can’t',
#   'ever',
#   'go.”',
#   'have',
#   'already',
#   'love',
#   'dig',
#   'have',
#   'must,',
#   'must,',
#   'must',
#   'still',
#   'give',
#   'regret',
#   'be',
#   'be',
#   'be'],
#  'sorry,': ['sorry…'],
#  'sorry…': ['Ah!”'],
#  'Ah!”': ['and'],
#  'right': ['back',
#   'there.',
#   'back.',
#   'there,',
#   'on',
#   'off',
#   'to',
#   'out,',
#   'up…',
#   'before',
#   'away,'],
#  'talking.': ['[audience'],
#  'he': ['didn’t',
#   'was',
#   'acted',
#   'cared,',
#   'loves',
#   'would',
#   'had',
#   'knows',
#   'ejaculated',
#   'was',
#   'didn’t',
#   'said',
#   'goes…',
#   'goes,',
#   'shortened',
#   'cares.',
#   'was',
#   'tugs',
#   'goes',
#   'goes',
#   'goes,',
#   'felt',
#   'felt',
#   'likely',
#   'says',
#   'makes',
#   'orders',
#   'meant',
#   'says.',
#   'came',
#   'clings,',
#   'fails,',
#   'appears',
#   'didn’t'],
#  'scare': ['us.', 'me,'],
#  'us.': ['He', 'We’re', 'Like,'],
#  'He': ['was',
#   'wasn’t',
#   'would',
#   'was',
#   'was',
#   'doesn’t',
#   'would’ve',
#   'lives',
#   'had',
#   'just',
#   'cares',
#   'cares',
#   'thought'],
#  'unsuccessful': ['in'],
#  'his': ['little',
#   'feet…',
#   'dick',
#   'dick',
#   'dick',
#   'dick',
#   'body',
#   'wealth,',
#   'son.',
#   'own',
#   'face.',
#   'son',
#   'Jac.',
#   'zipper',
#   'face',
#   'face',
#   'own',
#   'flaws',
#   'order,',
#   'day',
#   'trying'],
#  'ruse.': ['[audience'],
#  'feet…': ['you'],
#  'he’s': ['coming',
#   'been',
#   'buying',
#   'intimidated',
#   'one',
#   'nervous.”',
#   'truly',
#   'confused'],
#  'coming': ['around', 'my', 'down', 'from', 'down.”', 'and', 'to'],
#  'around': ['again.',
#   'complaining,',
#   'the',
#   'each',
#   'my',
#   'him.',
#   'the',
#   'you',
#   'campus',
#   'the',
#   'our'],
#  'again.': ['You', 'This', 'Block', 'I…', 'No,', 'And'],
#  'faster': ['the'],
#  'second': ['time.',
#   'thing',
#   'glass',
#   'before',
#   'I',
#   'mouth',
#   'one',
#   'of',
#   'mouth'],
#  '“Ah!”': ['Right', 'Right?', 'And'],
#  'Right': ['back'],
#  'showmanship…': ['[laughs]'],
#  '…and': ['yet', 'she', 'relax', 'articulating'],
#  'rewarded.': ['Now…'],
#  'Now…': ['Do'],
#  'nephew?': ['Of'],
#  'Of': ['course.', 'course,', 'course,'],
#  'respect': ['him?', 'for', 'for', 'for', 'for', 'for'],
#  'him?': ['[audience'],
#  'respect…': ['true'],
#  'nephew': ['isn’t', 'is'],
#  'isn’t': ['“Ah!”',
#   'the',
#   'anyone',
#   'going',
#   'phallic.',
#   'it?',
#   'real,”',
#   'it',
#   'that'],
#  'Right?': ['No,', 'True', 'I', '“I', 'A', 'A', 'A', 'If'],
#  '“What?': ['No,'],
#  'can.”': ['“So…'],
#  '“So…': ['so'],
#  'again.”': ['And', '[audience'],
#  'True': ['respect', 'respect'],
#  'not,': ['“Oh,', 'in', 'by', '“save'],
#  'is,': ['“Penis.”', 'you'],
#  '[moaning]': ['[audience', 'And', '‘Cause'],
#  'If': ['the',
#   'the',
#   'you’re',
#   'I',
#   'blue',
#   'they',
#   'you',
#   'that',
#   'I’m',
#   'you',
#   'had',
#   'you',
#   'my',
#   'you’re',
#   'my…',
#   'I',
#   'I',
#   'you',
#   'it’s',
#   'it'],
#  'enough,': ['then', 'you', 'you', 'I'],
#  'should': ['suffice,', 'have', 'go', 'just', 'probably', 'hold', 'you'],
#  'suffice,': ['you'],
#  'chance': ['at', 'at'],
#  'sexy,': ['then', 'but'],
#  'sexy.': ['And'],
#  'theory…': ['in'],
#  'theory,': ['it’s', 'it'],
#  'suffices.': ['I'],
#  'arguably,': ['I’m'],
#  'fan': ['in'],
#  'sense': ['that', 'to', 'of'],
#  'time': ['and',
#   'I',
#   'now.',
#   'you',
#   'in',
#   'that',
#   'in',
#   'I',
#   'can',
#   'in',
#   'when',
#   'was',
#   'now.',
#   'with',
#   'you',
#   'you',
#   'in',
#   'as'],
#  'again': ['with', 'for', 'but', 'with', 'next', 'for'],
#  'regularity': ['you'],
#  'count': ['on.'],
#  'on.': ['I’m', 'You'],
#  'church': ['mouse'],
#  'mouse': ['to'],
#  'wafer': ['crumb'],
#  'crumb': ['on'],
#  'Monday': ['morning.'],
#  'morning.': ['There’s'],
#  'Sniffing': ['about,'],
#  'about,': ['hoping'],
#  'hoping': ['for', 'someone', 'to'],
#  'taste': ['of'],
#  'divine.': ['So'],
#  'So': ['if',
#   'it',
#   'the',
#   'they',
#   'here’s',
#   'I',
#   'satisfying',
#   'I’ve',
#   'many',
#   'I',
#   'many',
#   'I',
#   'I',
#   'I',
#   'now',
#   'top',
#   'it',
#   'I’m',
#   'I',
#   'if',
#   'several',
#   'I',
#   'no,'],
#  'fucking': ['cock,', 'boner?', 'look', 'me,', 'him,', 'feet.”'],
#  'presence,': ['but'],
#  'showing': ['up', 'up', 'up'],
#  'fan.': ['Then'],
#  'Then': ['what',
#   'they',
#   'you',
#   'she',
#   'I',
#   'like',
#   'let',
#   'find',
#   'find',
#   'you'],
#  'for?': ['What'],
#  'What': ['is',
#   'is',
#   'are',
#   'do',
#   'if',
#   'if',
#   'if',
#   'if',
#   'if',
#   'did',
#   'do',
#   'even'],
#  'me?': ['What', 'All', 'And'],
#  'nature?': ['[exhales]'],
#  '[exhales]': ['[audience',
#   'Okay,',
#   'And',
#   '…the',
#   'And',
#   'Me.',
#   'And',
#   'That’s'],
#  'responsive.': ['You'],
#  'springs': ['up'],
#  'under': ['certain', 'the', 'a', 'and', 'a'],
#  'certain': ['conditions.', 'kind', 'qualities.', 'themes', 'dead'],
#  'conditions.': ['That’s'],
#  ...}

# %%
generate_sentence1(j_dict)
# Out:
# "“choke on the stage and it’s done doing it. And before the way you wanna be'"
